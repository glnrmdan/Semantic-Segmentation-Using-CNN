# %%
from utils import conv
from utils import NN as nn
from utils import dataprepare as dp
from utils import Feature_extract as fe

import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
# Load the saved weights
def load_weights(filename):
    with open(filename, 'rb') as f:
        data = np.load(f)
        weights_hidden_output = data['weights_hidden_output']
        bias_hidden_output = data['bias_hidden_output']
        weights_input_hidden = data['weights_input_hidden']
        bias_input_hidden = data['bias_input_hidden']
    return weights_hidden_output, bias_hidden_output, weights_input_hidden, bias_input_hidden

# %%
# Load images and ground truth labels
images_path = 'patching_fix/patch_image'
feature_images_path = 'patching_fix/feature_extract'
ground_truths_path = 'patching_fix/patch_ground'

images_load = dp.load_images_from_folder(images_path)
feature_images_load = dp.load_images_from_folder(feature_images_path)
ground_truths = dp.load_ground_truth_from_folder(ground_truths_path)

# %%
feature_images_train = feature_images_load[:math.ceil(len(feature_images_load)*0.8)] 
image_label_train = ground_truths[:math.ceil(len(ground_truths)*0.8)]

image_test = images_load[math.ceil(len(images_load)*0.8):]
image_label_test = ground_truths[math.ceil(len(ground_truths)*0.8):]

# %%
# # Prepare data
# X_test, y_test = dp.prepare_data(image_test, image_label_test)
# # Normalize the features
# X__test_normalized = X_test / 255.0

# %%
# input_size = X__test_normalized.shape[0]
input_size = 3
hidden_size = 2  # hidden neuron
output_size = 2  # 2 classes: vegetation and non-vegetation

# %%
# Load weights for testing
weights_hidden_output, bias_hidden_output, weights_input_hidden, bias_input_hidden = load_weights('1. Bobot_skenario_1.npz')

# Initialize the neural network with the loaded weights
model_loaded = nn.NeuralNetwork(input_size, hidden_size, output_size)
model_loaded.weights_hidden_output = weights_hidden_output
model_loaded.bias_hidden_output = bias_hidden_output
model_loaded.weights_input_hidden = weights_input_hidden
model_loaded.bias_input_hidden = bias_input_hidden

# %%
print('Load Bobot dan bias optimal')
print('Bobot hidden-output:')
print(model_loaded.weights_hidden_output)
print('Bias hidden-output:')
print(model_loaded.bias_hidden_output[0][0])
print('Bobot input-hidden:')
print(model_loaded.weights_input_hidden)
print('Bias input-hidden:')
print(model_loaded.bias_input_hidden[0][0])
# Out:
# Load Bobot dan bias optimal
# Bobot hidden-output:
# [[-0.78190079  0.78190079]
#  [ 4.00247311 -4.00247311]]
# Bias hidden-output:
# 1.0204940779277847
# Bobot input-hidden:
# [[ 46.3323245  -13.18520221]
#  [-60.97568134  -6.13730188]
#  [-38.26890401  -3.07821027]]
# Bias input-hidden:
# 1.0634810159482069

# %%
TP = 0  # True Positives
FP = 0  # False Positives
FN = 0  # False Negatives
TN = 0  # True Negatives

# Loop over testing images
for i in range(len(image_test)):
    TPi = 0  # True Positives index
    FPi = 0  # False Positives index
    FNi = 0  # False Negatives index
    TNi = 0  # True Negatives index

    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN, TN for the current image
    for row in range(predicted_mask.shape[0]):
        for col in range(predicted_mask.shape[1]):
            if predicted_mask[row, col] == 1 and vegetation_ground_truth[row, col]:
                TPi += 1
                TP += 1
            elif predicted_mask[row, col] == 1 and not vegetation_ground_truth[row, col]:
                FPi += 1
                FP += 1
            elif predicted_mask[row, col] == 0 and vegetation_ground_truth[row, col]:
                FNi += 1
                FN += 1
            elif predicted_mask[row, col] == 0 and not vegetation_ground_truth[row, col]:
                TNi += 1
                TN += 1
    
    # Print the values for TP, FP, FN, TN for the current image
    print("Image {}: TP = {}, FP = {}, FN = {}, TN = {}".format(i+1, TPi, FPi, FNi, TNi))
# Out:
# Image 1: TP = 1164, FP = 0, FN = 3295, TN = 11925
# Image 2: TP = 9684, FP = 0, FN = 4256, TN = 2444
# Image 3: TP = 2628, FP = 0, FN = 3267, TN = 10489
# Image 4: TP = 1678, FP = 0, FN = 5614, TN = 9092
# Image 5: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 6: TP = 559, FP = 0, FN = 250, TN = 15575
# Image 7: TP = 1407, FP = 3, FN = 646, TN = 14328
# Image 8: TP = 88, FP = 0, FN = 92, TN = 16204
# Image 9: TP = 5162, FP = 0, FN = 3731, TN = 7491
# Image 10: TP = 1299, FP = 0, FN = 5971, TN = 9114
# Image 11: TP = 2598, FP = 0, FN = 1366, TN = 12420
# Image 12: TP = 552, FP = 0, FN = 3059, TN = 12773
# Image 13: TP = 0, FP = 0, FN = 1, TN = 16383
# Image 14: TP = 0, FP = 0, FN = 3989, TN = 12395
# Image 15: TP = 4793, FP = 0, FN = 2651, TN = 8940
# Image 16: TP = 6580, FP = 0, FN = 3867, TN = 5937
# Image 17: TP = 6706, FP = 198, FN = 1871, TN = 7609
# Image 18: TP = 7433, FP = 13, FN = 4332, TN = 4606
# Image 19: TP = 0, FP = 21, FN = 0, TN = 16363
# Image 20: TP = 32, FP = 8, FN = 3, TN = 16341
# Image 21: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 22: TP = 5038, FP = 0, FN = 9198, TN = 2148
# Image 23: TP = 5387, FP = 1, FN = 5399, TN = 5597
# Image 24: TP = 907, FP = 5, FN = 1354, TN = 14118
# Image 25: TP = 1266, FP = 26, FN = 7210, TN = 7882
# Image 26: TP = 1118, FP = 14, FN = 1256, TN = 13996
# Image 27: TP = 5560, FP = 5, FN = 4354, TN = 6465
# Image 28: TP = 1, FP = 0, FN = 13786, TN = 2597
# Image 29: TP = 1737, FP = 3, FN = 6288, TN = 8356
# Image 30: TP = 2722, FP = 0, FN = 6253, TN = 7409
# Image 31: TP = 3772, FP = 0, FN = 8910, TN = 3702
# Image 32: TP = 2483, FP = 0, FN = 4517, TN = 9384
# Image 33: TP = 3553, FP = 5, FN = 7216, TN = 5610
# Image 34: TP = 6071, FP = 0, FN = 6988, TN = 3325
# Image 35: TP = 5509, FP = 38, FN = 6773, TN = 4064
# Image 36: TP = 2359, FP = 24, FN = 8842, TN = 5159
# Image 37: TP = 2936, FP = 0, FN = 1963, TN = 11485
# Image 38: TP = 6713, FP = 7, FN = 3101, TN = 6563
# Image 39: TP = 3663, FP = 9, FN = 3788, TN = 8924
# Image 40: TP = 1467, FP = 0, FN = 5718, TN = 9199
# Image 41: TP = 1150, FP = 0, FN = 4392, TN = 10842
# Image 42: TP = 19, FP = 1, FN = 2605, TN = 13759
# Image 43: TP = 4, FP = 0, FN = 1203, TN = 15177
# Image 44: TP = 249, FP = 0, FN = 3597, TN = 12538
# Image 45: TP = 342, FP = 2, FN = 5118, TN = 10922
# Image 46: TP = 183, FP = 0, FN = 2225, TN = 13976
# Image 47: TP = 0, FP = 0, FN = 613, TN = 15771
# Image 48: TP = 1206, FP = 9, FN = 4919, TN = 10250
# Image 49: TP = 4655, FP = 8, FN = 2470, TN = 9251
# Image 50: TP = 2525, FP = 3, FN = 4245, TN = 9611
# Image 51: TP = 3523, FP = 12, FN = 5726, TN = 7123
# Image 52: TP = 1035, FP = 0, FN = 1676, TN = 13673
# Image 53: TP = 4314, FP = 0, FN = 3024, TN = 9046
# Image 54: TP = 4225, FP = 0, FN = 2128, TN = 10031
# Image 55: TP = 209, FP = 0, FN = 2435, TN = 13740
# Image 56: TP = 392, FP = 0, FN = 2592, TN = 13400
# Image 57: TP = 1674, FP = 0, FN = 10101, TN = 4609
# Image 58: TP = 0, FP = 0, FN = 6106, TN = 10278
# Image 59: TP = 119, FP = 2, FN = 3004, TN = 13259
# Image 60: TP = 4726, FP = 0, FN = 11546, TN = 112
# Image 61: TP = 167, FP = 8, FN = 3195, TN = 13014
# Image 62: TP = 453, FP = 0, FN = 1971, TN = 13960
# Image 63: TP = 1417, FP = 0, FN = 8739, TN = 6228
# Image 64: TP = 756, FP = 0, FN = 1528, TN = 14100
# Image 65: TP = 95, FP = 0, FN = 4105, TN = 12184
# Image 66: TP = 0, FP = 0, FN = 1315, TN = 15069
# Image 67: TP = 0, FP = 0, FN = 1422, TN = 14962
# Image 68: TP = 614, FP = 0, FN = 5474, TN = 10296
# Image 69: TP = 184, FP = 0, FN = 155, TN = 16045
# Image 70: TP = 65, FP = 0, FN = 7482, TN = 8837
# Image 71: TP = 236, FP = 0, FN = 773, TN = 15375
# Image 72: TP = 4996, FP = 0, FN = 11308, TN = 80
# Image 73: TP = 4134, FP = 0, FN = 4752, TN = 7498
# Image 74: TP = 2429, FP = 31, FN = 6460, TN = 7464
# Image 75: TP = 463, FP = 2, FN = 312, TN = 15607
# Image 76: TP = 1207, FP = 0, FN = 6760, TN = 8417
# Image 77: TP = 7236, FP = 13, FN = 4358, TN = 4777
# Image 78: TP = 1371, FP = 0, FN = 1014, TN = 13999
# Image 79: TP = 1856, FP = 45, FN = 8663, TN = 5820
# Image 80: TP = 10569, FP = 31, FN = 4144, TN = 1640
# Image 81: TP = 6669, FP = 33, FN = 2336, TN = 7346
# Image 82: TP = 11235, FP = 4, FN = 3172, TN = 1973
# Image 83: TP = 7639, FP = 5, FN = 3731, TN = 5009
# Image 84: TP = 1998, FP = 0, FN = 1901, TN = 12485
# Image 85: TP = 690, FP = 0, FN = 5660, TN = 10034
# Image 86: TP = 88, FP = 0, FN = 9205, TN = 7091
# Image 87: TP = 0, FP = 0, FN = 3912, TN = 12472
# Image 88: TP = 3, FP = 0, FN = 10502, TN = 5879
# Image 89: TP = 0, FP = 0, FN = 3051, TN = 13333
# Image 90: TP = 4355, FP = 26, FN = 7109, TN = 4894
# Image 91: TP = 1906, FP = 27, FN = 4030, TN = 10421
# Image 92: TP = 3482, FP = 7, FN = 2897, TN = 9998
# Image 93: TP = 3183, FP = 28, FN = 9611, TN = 3562
# Image 94: TP = 1088, FP = 42, FN = 991, TN = 14263
# Image 95: TP = 3053, FP = 82, FN = 7121, TN = 6128
# Image 96: TP = 148, FP = 0, FN = 5793, TN = 10443
# Image 97: TP = 38, FP = 0, FN = 1860, TN = 14486
# Image 98: TP = 4886, FP = 2, FN = 4448, TN = 7048
# Image 99: TP = 47, FP = 0, FN = 2155, TN = 14182
# Image 100: TP = 509, FP = 0, FN = 10343, TN = 5532
# Image 101: TP = 217, FP = 0, FN = 14904, TN = 1263
# Image 102: TP = 1648, FP = 0, FN = 14736, TN = 0
# Image 103: TP = 6791, FP = 0, FN = 9593, TN = 0
# Image 104: TP = 6368, FP = 0, FN = 6429, TN = 3587
# Image 105: TP = 3768, FP = 0, FN = 9437, TN = 3179
# Image 106: TP = 2, FP = 0, FN = 1286, TN = 15096
# Image 107: TP = 188, FP = 0, FN = 1697, TN = 14499
# Image 108: TP = 5002, FP = 0, FN = 11382, TN = 0
# Image 109: TP = 2254, FP = 0, FN = 1409, TN = 12721
# Image 110: TP = 7241, FP = 12, FN = 6818, TN = 2313
# Image 111: TP = 549, FP = 0, FN = 6486, TN = 9349
# Image 112: TP = 160, FP = 12, FN = 1552, TN = 14660
# Image 113: TP = 861, FP = 0, FN = 4663, TN = 10860
# Image 114: TP = 2204, FP = 0, FN = 13454, TN = 726
# Image 115: TP = 2908, FP = 0, FN = 13476, TN = 0
# Image 116: TP = 2804, FP = 0, FN = 13580, TN = 0
# Image 117: TP = 3064, FP = 0, FN = 13320, TN = 0
# Image 118: TP = 1784, FP = 0, FN = 13201, TN = 1399
# Image 119: TP = 417, FP = 1, FN = 5886, TN = 10080
# Image 120: TP = 4083, FP = 0, FN = 10344, TN = 1957
# Image 121: TP = 3324, FP = 0, FN = 3222, TN = 9838
# Image 122: TP = 5272, FP = 16, FN = 2215, TN = 8881
# Image 123: TP = 4701, FP = 0, FN = 10367, TN = 1316
# Image 124: TP = 2320, FP = 51, FN = 1586, TN = 12427
# Image 125: TP = 7177, FP = 0, FN = 5070, TN = 4137
# Image 126: TP = 36, FP = 0, FN = 4228, TN = 12120
# Image 127: TP = 0, FP = 0, FN = 34, TN = 16350
# Image 128: TP = 8, FP = 0, FN = 2466, TN = 13910
# Image 129: TP = 4541, FP = 0, FN = 11677, TN = 166
# Image 130: TP = 885, FP = 0, FN = 7623, TN = 7876
# Image 131: TP = 32, FP = 0, FN = 14553, TN = 1799
# Image 132: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 133: TP = 83, FP = 0, FN = 11536, TN = 4765
# Image 134: TP = 1902, FP = 0, FN = 8074, TN = 6408
# Image 135: TP = 6145, FP = 0, FN = 10239, TN = 0
# Image 136: TP = 999, FP = 0, FN = 1283, TN = 14102
# Image 137: TP = 1825, FP = 6, FN = 4455, TN = 10098
# Image 138: TP = 3295, FP = 0, FN = 9843, TN = 3246
# Image 139: TP = 3378, FP = 0, FN = 2009, TN = 10997
# Image 140: TP = 3008, FP = 0, FN = 6702, TN = 6674
# Image 141: TP = 165, FP = 0, FN = 4355, TN = 11864
# Image 142: TP = 278, FP = 10, FN = 1797, TN = 14299
# Image 143: TP = 1060, FP = 0, FN = 13504, TN = 1820
# Image 144: TP = 37, FP = 0, FN = 13907, TN = 2440
# Image 145: TP = 0, FP = 0, FN = 8077, TN = 8307
# Image 146: TP = 0, FP = 0, FN = 16322, TN = 62
# Image 147: TP = 12, FP = 0, FN = 16372, TN = 0
# Image 148: TP = 1308, FP = 0, FN = 15076, TN = 0
# Image 149: TP = 1546, FP = 0, FN = 14521, TN = 317
# Image 150: TP = 7492, FP = 65, FN = 3271, TN = 5556
# Image 151: TP = 283, FP = 0, FN = 6037, TN = 10064
# Image 152: TP = 7136, FP = 210, FN = 2797, TN = 6241
# Image 153: TP = 1750, FP = 20, FN = 533, TN = 14081
# Image 154: TP = 625, FP = 1, FN = 213, TN = 15545
# Image 155: TP = 1696, FP = 108, FN = 1696, TN = 12884
# Image 156: TP = 1219, FP = 3, FN = 6562, TN = 8600
# Image 157: TP = 25, FP = 0, FN = 1411, TN = 14948
# Image 158: TP = 0, FP = 0, FN = 1126, TN = 15258
# Image 159: TP = 3925, FP = 101, FN = 2210, TN = 10148
# Image 160: TP = 402, FP = 6, FN = 2158, TN = 13818
# Image 161: TP = 1042, FP = 0, FN = 7845, TN = 7497
# Image 162: TP = 2858, FP = 12, FN = 726, TN = 12788
# Image 163: TP = 4467, FP = 0, FN = 7969, TN = 3948
# Image 164: TP = 1269, FP = 2, FN = 3519, TN = 11594
# Image 165: TP = 6001, FP = 17, FN = 2863, TN = 7503
# Image 166: TP = 5477, FP = 10, FN = 6953, TN = 3944
# Image 167: TP = 6800, FP = 12, FN = 7809, TN = 1763
# Image 168: TP = 6541, FP = 18, FN = 1993, TN = 7832
# Image 169: TP = 4515, FP = 7, FN = 7218, TN = 4644
# Image 170: TP = 4012, FP = 21, FN = 2627, TN = 9724
# Image 171: TP = 4136, FP = 3, FN = 3797, TN = 8448
# Image 172: TP = 4419, FP = 89, FN = 6675, TN = 5201
# Image 173: TP = 4422, FP = 29, FN = 5029, TN = 6904
# Image 174: TP = 10437, FP = 170, FN = 2896, TN = 2881
# Image 175: TP = 254, FP = 64, FN = 339, TN = 15727
# Image 176: TP = 1661, FP = 0, FN = 6384, TN = 8339
# Image 177: TP = 795, FP = 0, FN = 7730, TN = 7859
# Image 178: TP = 424, FP = 1, FN = 3265, TN = 12694
# Image 179: TP = 3674, FP = 0, FN = 7700, TN = 5010
# Image 180: TP = 14291, FP = 118, FN = 1373, TN = 602
# Image 181: TP = 1578, FP = 15, FN = 3194, TN = 11597
# Image 182: TP = 3049, FP = 0, FN = 9279, TN = 4056
# Image 183: TP = 7858, FP = 0, FN = 6936, TN = 1590
# Image 184: TP = 6237, FP = 0, FN = 7973, TN = 2174
# Image 185: TP = 4395, FP = 65, FN = 9041, TN = 2883
# Image 186: TP = 5186, FP = 12, FN = 8364, TN = 2822
# Image 187: TP = 3272, FP = 4, FN = 9685, TN = 3423
# Image 188: TP = 2490, FP = 5, FN = 11196, TN = 2693
# Image 189: TP = 2229, FP = 2, FN = 2874, TN = 11279
# Image 190: TP = 1680, FP = 21, FN = 2270, TN = 12413
# Image 191: TP = 13, FP = 0, FN = 1770, TN = 14601
# Image 192: TP = 324, FP = 0, FN = 9091, TN = 6969
# Image 193: TP = 487, FP = 25, FN = 3573, TN = 12299
# Image 194: TP = 2203, FP = 0, FN = 10821, TN = 3360
# Image 195: TP = 2690, FP = 117, FN = 5889, TN = 7688
# Image 196: TP = 1994, FP = 0, FN = 11475, TN = 2915
# Image 197: TP = 534, FP = 0, FN = 5721, TN = 10129
# Image 198: TP = 4429, FP = 0, FN = 6105, TN = 5850
# Image 199: TP = 290, FP = 0, FN = 16094, TN = 0
# Image 200: TP = 2235, FP = 0, FN = 14149, TN = 0
# Image 201: TP = 83, FP = 0, FN = 16301, TN = 0
# Image 202: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 203: TP = 381, FP = 0, FN = 16003, TN = 0
# Image 204: TP = 2017, FP = 10, FN = 4104, TN = 10253
# Image 205: TP = 558, FP = 0, FN = 8039, TN = 7787
# Image 206: TP = 271, FP = 38, FN = 931, TN = 15144
# Image 207: TP = 879, FP = 0, FN = 9186, TN = 6319
# Image 208: TP = 4123, FP = 0, FN = 12261, TN = 0
# Image 209: TP = 9200, FP = 0, FN = 7184, TN = 0
# Image 210: TP = 2249, FP = 7, FN = 5324, TN = 8804
# Image 211: TP = 12897, FP = 0, FN = 3456, TN = 31
# Image 212: TP = 1597, FP = 0, FN = 5303, TN = 9484
# Image 213: TP = 5208, FP = 35, FN = 2720, TN = 8421
# Image 214: TP = 2312, FP = 0, FN = 12654, TN = 1418
# Image 215: TP = 240, FP = 0, FN = 14909, TN = 1235
# Image 216: TP = 381, FP = 0, FN = 15807, TN = 196
# Image 217: TP = 670, FP = 0, FN = 14569, TN = 1145
# Image 218: TP = 5, FP = 0, FN = 11457, TN = 4922
# Image 219: TP = 6943, FP = 0, FN = 9102, TN = 339
# Image 220: TP = 0, FP = 0, FN = 2348, TN = 14036
# Image 221: TP = 363, FP = 3, FN = 1561, TN = 14457
# Image 222: TP = 883, FP = 0, FN = 3518, TN = 11983
# Image 223: TP = 12219, FP = 0, FN = 4096, TN = 69
# Image 224: TP = 13310, FP = 0, FN = 3074, TN = 0
# Image 225: TP = 6420, FP = 0, FN = 2029, TN = 7935
# Image 226: TP = 12057, FP = 0, FN = 4327, TN = 0
# Image 227: TP = 3505, FP = 0, FN = 2635, TN = 10244
# Image 228: TP = 3981, FP = 0, FN = 8588, TN = 3815
# Image 229: TP = 0, FP = 0, FN = 2739, TN = 13645
# Image 230: TP = 83, FP = 0, FN = 5100, TN = 11201
# Image 231: TP = 0, FP = 0, FN = 224, TN = 16160
# Image 232: TP = 472, FP = 0, FN = 5503, TN = 10409
# Image 233: TP = 293, FP = 0, FN = 1158, TN = 14933
# Image 234: TP = 5817, FP = 0, FN = 3598, TN = 6969
# Image 235: TP = 2218, FP = 1, FN = 5423, TN = 8742
# Image 236: TP = 936, FP = 20, FN = 3073, TN = 12355
# Image 237: TP = 64, FP = 0, FN = 405, TN = 15915
# Image 238: TP = 1867, FP = 0, FN = 4548, TN = 9969
# Image 239: TP = 7232, FP = 0, FN = 8739, TN = 413
# Image 240: TP = 3618, FP = 34, FN = 2372, TN = 10360
# Image 241: TP = 667, FP = 17, FN = 583, TN = 15117
# Image 242: TP = 380, FP = 1, FN = 222, TN = 15781
# Image 243: TP = 13373, FP = 36, FN = 1285, TN = 1690
# Image 244: TP = 981, FP = 27, FN = 1041, TN = 14335
# Image 245: TP = 5934, FP = 129, FN = 1513, TN = 8808
# Image 246: TP = 945, FP = 14, FN = 1475, TN = 13950
# Image 247: TP = 4914, FP = 0, FN = 5096, TN = 6374
# Image 248: TP = 8001, FP = 28, FN = 5107, TN = 3248
# Image 249: TP = 13349, FP = 9, FN = 2126, TN = 900
# Image 250: TP = 10609, FP = 7, FN = 2702, TN = 3066
# Image 251: TP = 7719, FP = 122, FN = 334, TN = 8209
# Image 252: TP = 71, FP = 56, FN = 465, TN = 15792
# Image 253: TP = 1504, FP = 35, FN = 635, TN = 14210
# Image 254: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 255: TP = 2375, FP = 92, FN = 691, TN = 13226
# Image 256: TP = 12281, FP = 74, FN = 2093, TN = 1936
# Image 257: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 258: TP = 10950, FP = 0, FN = 5434, TN = 0
# Image 259: TP = 13386, FP = 0, FN = 2998, TN = 0
# Image 260: TP = 3959, FP = 0, FN = 12425, TN = 0
# Image 261: TP = 12371, FP = 0, FN = 4013, TN = 0
# Image 262: TP = 29, FP = 0, FN = 275, TN = 16080
# Image 263: TP = 614, FP = 39, FN = 1207, TN = 14524
# Image 264: TP = 74, FP = 0, FN = 222, TN = 16088
# Image 265: TP = 35, FP = 0, FN = 512, TN = 15837
# Image 266: TP = 3647, FP = 0, FN = 3051, TN = 9686
# Image 267: TP = 206, FP = 0, FN = 895, TN = 15283
# Image 268: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 269: TP = 781, FP = 19, FN = 3880, TN = 11704
# Image 270: TP = 3530, FP = 95, FN = 2875, TN = 9884
# Image 271: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 272: TP = 11849, FP = 37, FN = 1688, TN = 2810
# Image 273: TP = 9710, FP = 1, FN = 6487, TN = 186
# Image 274: TP = 12828, FP = 0, FN = 3556, TN = 0
# Image 275: TP = 8842, FP = 0, FN = 7542, TN = 0
# Image 276: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 277: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 278: TP = 775, FP = 0, FN = 774, TN = 14835
# Image 279: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 280: TP = 176, FP = 0, FN = 194, TN = 16014
# Image 281: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 282: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 283: TP = 5781, FP = 44, FN = 4330, TN = 6229
# Image 284: TP = 3160, FP = 114, FN = 2620, TN = 10490
# Image 285: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 286: TP = 0, FP = 0, FN = 253, TN = 16131
# Image 287: TP = 2238, FP = 0, FN = 5548, TN = 8598
# Image 288: TP = 9284, FP = 0, FN = 7100, TN = 0
# Image 289: TP = 14196, FP = 10, FN = 1451, TN = 727
# Image 290: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 291: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 292: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 293: TP = 219, FP = 0, FN = 417, TN = 15748
# Image 294: TP = 163, FP = 0, FN = 140, TN = 16081
# Image 295: TP = 431, FP = 1, FN = 156, TN = 15796
# Image 296: TP = 4483, FP = 3, FN = 1865, TN = 10033
# Image 297: TP = 125, FP = 1, FN = 99, TN = 16159
# Image 298: TP = 2665, FP = 25, FN = 5303, TN = 8391
# Image 299: TP = 1683, FP = 8, FN = 211, TN = 14482
# Image 300: TP = 1551, FP = 0, FN = 3514, TN = 11319
# Image 301: TP = 2374, FP = 0, FN = 2925, TN = 11085
# Image 302: TP = 1878, FP = 40, FN = 5427, TN = 9039
# Image 303: TP = 4321, FP = 40, FN = 1583, TN = 10440
# Image 304: TP = 4046, FP = 4, FN = 6913, TN = 5421
# Image 305: TP = 8675, FP = 0, FN = 7709, TN = 0
# Image 306: TP = 13933, FP = 0, FN = 2451, TN = 0
# Image 307: TP = 8059, FP = 2, FN = 7641, TN = 682
# Image 308: TP = 608, FP = 0, FN = 4668, TN = 11108
# Image 309: TP = 5255, FP = 60, FN = 1524, TN = 9545
# Image 310: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 311: TP = 1682, FP = 6, FN = 1723, TN = 12973
# Image 312: TP = 5993, FP = 102, FN = 3023, TN = 7266
# Image 313: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 314: TP = 5383, FP = 47, FN = 2586, TN = 8368
# Image 315: TP = 5520, FP = 6, FN = 5994, TN = 4864
# Image 316: TP = 16140, FP = 0, FN = 244, TN = 0
# Image 317: TP = 11492, FP = 64, FN = 948, TN = 3880
# Image 318: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 319: TP = 0, FP = 0, FN = 24, TN = 16360
# Image 320: TP = 1758, FP = 0, FN = 4063, TN = 10563
# Image 321: TP = 139, FP = 0, FN = 463, TN = 15782
# Image 322: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 323: TP = 590, FP = 0, FN = 908, TN = 14886
# Image 324: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 325: TP = 8829, FP = 0, FN = 1070, TN = 6485
# Image 326: TP = 601, FP = 1, FN = 507, TN = 15275
# Image 327: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 328: TP = 151, FP = 12, FN = 197, TN = 16024
# Image 329: TP = 8060, FP = 0, FN = 5127, TN = 3197
# Image 330: TP = 12288, FP = 0, FN = 4096, TN = 0
# Image 331: TP = 3200, FP = 0, FN = 2373, TN = 10811
# Image 332: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 333: TP = 42, FP = 2, FN = 338, TN = 16002
# Image 334: TP = 1449, FP = 0, FN = 1640, TN = 13295
# Image 335: TP = 2102, FP = 3, FN = 1671, TN = 12608
# Image 336: TP = 618, FP = 37, FN = 1076, TN = 14653
# Image 337: TP = 14305, FP = 1, FN = 1460, TN = 618
# Image 338: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 339: TP = 9178, FP = 0, FN = 7206, TN = 0
# Image 340: TP = 7798, FP = 89, FN = 2216, TN = 6281
# Image 341: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 342: TP = 3991, FP = 1, FN = 686, TN = 11706
# Image 343: TP = 656, FP = 14, FN = 1092, TN = 14622
# Image 344: TP = 2649, FP = 0, FN = 5801, TN = 7934
# Image 345: TP = 0, FP = 0, FN = 1453, TN = 14931
# Image 346: TP = 0, FP = 0, FN = 57, TN = 16327
# Image 347: TP = 0, FP = 0, FN = 264, TN = 16120
# Image 348: TP = 0, FP = 0, FN = 156, TN = 16228
# Image 349: TP = 107, FP = 7, FN = 609, TN = 15661
# Image 350: TP = 7362, FP = 6, FN = 896, TN = 8120
# Image 351: TP = 15052, FP = 0, FN = 1332, TN = 0
# Image 352: TP = 0, FP = 0, FN = 111, TN = 16273
# Image 353: TP = 11634, FP = 0, FN = 4750, TN = 0
# Image 354: TP = 7439, FP = 109, FN = 4369, TN = 4467
# Image 355: TP = 0, FP = 0, FN = 178, TN = 16206
# Image 356: TP = 7871, FP = 0, FN = 8060, TN = 453
# Image 357: TP = 5690, FP = 27, FN = 1766, TN = 8901
# Image 358: TP = 234, FP = 0, FN = 382, TN = 15768
# Image 359: TP = 285, FP = 0, FN = 536, TN = 15563
# Image 360: TP = 1145, FP = 2, FN = 1872, TN = 13365
# Image 361: TP = 5854, FP = 0, FN = 8386, TN = 2144
# Image 362: TP = 886, FP = 0, FN = 3280, TN = 12218
# Image 363: TP = 0, FP = 0, FN = 571, TN = 15813
# Image 364: TP = 13214, FP = 0, FN = 1919, TN = 1251
# Image 365: TP = 12883, FP = 0, FN = 3501, TN = 0
# Image 366: TP = 200, FP = 0, FN = 1125, TN = 15059
# Image 367: TP = 15987, FP = 0, FN = 397, TN = 0
# Image 368: TP = 4488, FP = 3, FN = 6389, TN = 5504
# Image 369: TP = 1624, FP = 0, FN = 2169, TN = 12591
# Image 370: TP = 3355, FP = 0, FN = 4951, TN = 8078
# Image 371: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 372: TP = 0, FP = 0, FN = 3146, TN = 13238
# Image 373: TP = 34, FP = 10, FN = 490, TN = 15850
# Image 374: TP = 8357, FP = 0, FN = 2912, TN = 5115
# Image 375: TP = 5015, FP = 64, FN = 4367, TN = 6938
# Image 376: TP = 5582, FP = 50, FN = 1727, TN = 9025
# Image 377: TP = 5442, FP = 0, FN = 3796, TN = 7146
# Image 378: TP = 15608, FP = 0, FN = 776, TN = 0
# Image 379: TP = 12088, FP = 0, FN = 4296, TN = 0
# Image 380: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 381: TP = 11695, FP = 0, FN = 4689, TN = 0
# Image 382: TP = 6314, FP = 0, FN = 4896, TN = 5174
# Image 383: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 384: TP = 0, FP = 0, FN = 524, TN = 15860
# Image 385: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 386: TP = 0, FP = 0, FN = 3278, TN = 13106
# Image 387: TP = 0, FP = 1, FN = 0, TN = 16383
# Image 388: TP = 1124, FP = 30, FN = 777, TN = 14453
# Image 389: TP = 0, FP = 0, FN = 994, TN = 15390
# Image 390: TP = 4490, FP = 92, FN = 1762, TN = 10040
# Image 391: TP = 4078, FP = 35, FN = 2525, TN = 9746
# Image 392: TP = 15552, FP = 0, FN = 832, TN = 0
# Image 393: TP = 12106, FP = 0, FN = 4278, TN = 0
# Image 394: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 395: TP = 6487, FP = 0, FN = 9897, TN = 0
# Image 396: TP = 12509, FP = 0, FN = 3874, TN = 1
# Image 397: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 398: TP = 9250, FP = 0, FN = 1925, TN = 5209
# Image 399: TP = 1068, FP = 0, FN = 661, TN = 14655
# Image 400: TP = 50, FP = 0, FN = 1734, TN = 14600
# Image 401: TP = 1358, FP = 17, FN = 1222, TN = 13787
# Image 402: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 403: TP = 0, FP = 0, FN = 739, TN = 15645
# Image 404: TP = 1873, FP = 0, FN = 1383, TN = 13128
# Image 405: TP = 8573, FP = 68, FN = 1657, TN = 6086
# Image 406: TP = 11316, FP = 0, FN = 5068, TN = 0
# Image 407: TP = 11999, FP = 0, FN = 4385, TN = 0
# Image 408: TP = 2963, FP = 0, FN = 741, TN = 12680
# Image 409: TP = 3399, FP = 73, FN = 4369, TN = 8543
# Image 410: TP = 11694, FP = 0, FN = 2607, TN = 2083
# Image 411: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 412: TP = 15314, FP = 0, FN = 1070, TN = 0
# Image 413: TP = 1547, FP = 0, FN = 1182, TN = 13655
# Image 414: TP = 455, FP = 0, FN = 2017, TN = 13912
# Image 415: TP = 7081, FP = 12, FN = 8537, TN = 754
# Image 416: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 417: TP = 0, FP = 0, FN = 87, TN = 16297
# Image 418: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 419: TP = 2061, FP = 0, FN = 1426, TN = 12897
# Image 420: TP = 7711, FP = 23, FN = 4351, TN = 4299
# Image 421: TP = 4726, FP = 92, FN = 1114, TN = 10452
# Image 422: TP = 0, FP = 0, FN = 2442, TN = 13942
# Image 423: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 424: TP = 1987, FP = 0, FN = 3671, TN = 10726
# Image 425: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 426: TP = 8055, FP = 0, FN = 8281, TN = 48
# Image 427: TP = 6803, FP = 0, FN = 9570, TN = 11
# Image 428: TP = 2324, FP = 2, FN = 4040, TN = 10018
# Image 429: TP = 6910, FP = 0, FN = 8677, TN = 797
# Image 430: TP = 3613, FP = 50, FN = 3476, TN = 9245
# Image 431: TP = 6009, FP = 98, FN = 4744, TN = 5533
# Image 432: TP = 11805, FP = 0, FN = 4260, TN = 319
# Image 433: TP = 6648, FP = 0, FN = 9736, TN = 0
# Image 434: TP = 11073, FP = 0, FN = 5311, TN = 0
# Image 435: TP = 5329, FP = 2, FN = 1402, TN = 9651
# Image 436: TP = 0, FP = 0, FN = 278, TN = 16106
# Image 437: TP = 0, FP = 0, FN = 336, TN = 16048
# Image 438: TP = 2482, FP = 0, FN = 6720, TN = 7182
# Image 439: TP = 0, FP = 0, FN = 3, TN = 16381
# Image 440: TP = 5718, FP = 0, FN = 10666, TN = 0
# Image 441: TP = 6008, FP = 0, FN = 10376, TN = 0
# Image 442: TP = 10931, FP = 0, FN = 5453, TN = 0
# Image 443: TP = 14697, FP = 0, FN = 1687, TN = 0
# Image 444: TP = 5252, FP = 35, FN = 3793, TN = 7304
# Image 445: TP = 221, FP = 25, FN = 224, TN = 15914
# Image 446: TP = 0, FP = 0, FN = 2751, TN = 13633
# Image 447: TP = 605, FP = 0, FN = 11800, TN = 3979
# Image 448: TP = 13107, FP = 20, FN = 1323, TN = 1934
# Image 449: TP = 273, FP = 5, FN = 1543, TN = 14563
# Image 450: TP = 0, FP = 0, FN = 186, TN = 16198
# Image 451: TP = 0, FP = 0, FN = 462, TN = 15922
# Image 452: TP = 4192, FP = 0, FN = 6105, TN = 6087
# Image 453: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 454: TP = 46, FP = 0, FN = 7689, TN = 8649
# Image 455: TP = 8510, FP = 0, FN = 7874, TN = 0
# Image 456: TP = 16376, FP = 0, FN = 8, TN = 0
# Image 457: TP = 11468, FP = 0, FN = 4916, TN = 0
# Image 458: TP = 226, FP = 0, FN = 3642, TN = 12516
# Image 459: TP = 4913, FP = 94, FN = 3958, TN = 7419
# Image 460: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 461: TP = 132, FP = 0, FN = 306, TN = 15946
# Image 462: TP = 2448, FP = 60, FN = 253, TN = 13623
# Image 463: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 464: TP = 35, FP = 0, FN = 823, TN = 15526
# Image 465: TP = 9648, FP = 5, FN = 3970, TN = 2761
# Image 466: TP = 6041, FP = 10, FN = 5703, TN = 4630
# Image 467: TP = 792, FP = 0, FN = 830, TN = 14762
# Image 468: TP = 10291, FP = 0, FN = 5314, TN = 779
# Image 469: TP = 14263, FP = 0, FN = 2121, TN = 0
# Image 470: TP = 16384, FP = 0, FN = 0, TN = 0
# Image 471: TP = 13086, FP = 0, FN = 3298, TN = 0
# Image 472: TP = 1551, FP = 0, FN = 3781, TN = 11052
# Image 473: TP = 1074, FP = 1, FN = 2137, TN = 13172
# Image 474: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 475: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 476: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 477: TP = 283, FP = 0, FN = 1523, TN = 14578
# Image 478: TP = 451, FP = 0, FN = 720, TN = 15213
# Image 479: TP = 10782, FP = 0, FN = 2675, TN = 2927
# Image 480: TP = 7036, FP = 0, FN = 9348, TN = 0
# Image 481: TP = 0, FP = 0, FN = 2842, TN = 13542
# Image 482: TP = 14047, FP = 0, FN = 2337, TN = 0
# Image 483: TP = 13797, FP = 0, FN = 2587, TN = 0
# Image 484: TP = 13990, FP = 0, FN = 2394, TN = 0
# Image 485: TP = 4988, FP = 0, FN = 11396, TN = 0
# Image 486: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 487: TP = 611, FP = 0, FN = 222, TN = 15551
# Image 488: TP = 1292, FP = 61, FN = 2661, TN = 12370
# Image 489: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 490: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 491: TP = 2699, FP = 12, FN = 2044, TN = 11629
# Image 492: TP = 203, FP = 0, FN = 378, TN = 15803
# Image 493: TP = 11, FP = 0, FN = 936, TN = 15437
# Image 494: TP = 12364, FP = 0, FN = 1796, TN = 2224
# Image 495: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 496: TP = 13693, FP = 0, FN = 2691, TN = 0
# Image 497: TP = 16165, FP = 0, FN = 219, TN = 0
# Image 498: TP = 7259, FP = 0, FN = 9125, TN = 0
# Image 499: TP = 6204, FP = 0, FN = 10180, TN = 0
# Image 500: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 501: TP = 1, FP = 0, FN = 35, TN = 16348
# Image 502: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 503: TP = 1268, FP = 6, FN = 2920, TN = 12190
# Image 504: TP = 396, FP = 0, FN = 2066, TN = 13922
# Image 505: TP = 205, FP = 0, FN = 480, TN = 15699

# %%
recall = TP / (TP + FN)
precision = TP / (TP + FP)
accuracy = (TP + TN) / (TP + FP + FN + TN)
f1_score = 2 * (precision * recall) / (precision + recall)
IoU = TP / (TP + FP + FN)

print('TP:', TP)
print('FP:', FP)
print('FN:', FN)
print('TN:', TN)

print()
print('Precision: {:.3f}'.format(precision))
print('Recall: {:.3f}'.format(recall))
print('Accuracy: {:.3f}'.format(accuracy))
print('F1 Score: {:.3f}'.format(f1_score))

print()
print("IoU Overall: {:.3f} ".format(IoU))
# Out:
# TP: 1750570
# FP: 5194
# FN: 2011664
# TN: 4506492
#
# Precision: 0.997
# Recall: 0.465
# Accuracy: 0.756
# F1 Score: 0.634
#
# IoU Overall: 0.465

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
conf_matrix = np.array([[TP, FP],
                        [FN, TN]])

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted Vegetation', 'Predicted Non-Vegetation'], 
            yticklabels=['Actual Vegetation', 'Actual Non-Vegetation'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Initialize lists for TP, FP, FN, and IoU
TP_vegetation = []
FP_vegetation = []
FN_vegetation = []
IoU_vegetation = []

TP_non_vegetation = []
FP_non_vegetation = []
FN_non_vegetation = []
IoU_non_vegetation = []

# Loop over testing images
for i in range(len(image_test)):
    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN counts for both vegetation and non-vegetation classes
    TP_veg = np.sum(np.logical_and(vegetation_ground_truth, predicted_mask))
    FP_veg = np.sum(predicted_mask & ~vegetation_ground_truth)
    FN_veg = np.sum(vegetation_ground_truth & ~predicted_mask)
    
    TP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, ~predicted_mask))
    FP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, predicted_mask))
    FN_non_veg = np.sum(np.logical_and(vegetation_ground_truth, ~predicted_mask))

    # Append TP, FP, FN counts for vegetation and non-vegetation classes
    TP_vegetation.append(TP_veg)
    FP_vegetation.append(FP_veg)
    FN_vegetation.append(FN_veg)
    
    TP_non_vegetation.append(TP_non_veg)
    FP_non_vegetation.append(FP_non_veg)
    FN_non_vegetation.append(FN_non_veg)

    # Calculate IoU for vegetation and non-vegetation
    # IoU_vegetation.append(TP_veg / (TP_veg + FP_veg + FN_veg))
    # IoU_non_vegetation.append(TP_non_veg / (TP_non_veg + FP_non_veg + FN_non_veg))
    
    # Calculate IoU for vegetation and non-vegetation classes if the denominator is not zero
    denominator_veg = TP_veg + FP_veg + FN_veg
    denominator_non_veg = TP_non_veg + FP_non_veg + FN_non_veg

    IoU_vegetation.append(TP_veg / denominator_veg if denominator_veg != 0 else 0.0)
    IoU_non_vegetation.append(TP_non_veg / denominator_non_veg if denominator_non_veg != 0 else 0.0)

    # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
    print("Image {}:".format(i+1))
    print("TP_veg: {}, FP_veg: {}, FN_veg: {}, IoU_veg: {:.4f}".format(TP_veg, FP_veg, FN_veg, IoU_vegetation[-1]))
    print("TP_non_veg: {}, FP_non_veg: {}, FN_non_veg: {}, IoU_non_veg: {:.4f}".format(TP_non_veg, FP_non_veg, FN_non_veg, IoU_non_vegetation[-1]))
# Out:
# Image 1:
# TP_veg: 1164, FP_veg: 0, FN_veg: 3295, IoU_veg: 0.2610
# TP_non_veg: 11925, FP_non_veg: 0, FN_non_veg: 4459, IoU_non_veg: 0.7278
# Image 2:
# TP_veg: 9684, FP_veg: 0, FN_veg: 4256, IoU_veg: 0.6947
# TP_non_veg: 2444, FP_non_veg: 0, FN_non_veg: 13940, IoU_non_veg: 0.1492
# Image 3:
# TP_veg: 2628, FP_veg: 0, FN_veg: 3267, IoU_veg: 0.4458
# TP_non_veg: 10489, FP_non_veg: 0, FN_non_veg: 5895, IoU_non_veg: 0.6402
# Image 4:
# TP_veg: 1678, FP_veg: 0, FN_veg: 5614, IoU_veg: 0.2301
# TP_non_veg: 9092, FP_non_veg: 0, FN_non_veg: 7292, IoU_non_veg: 0.5549
# Image 5:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 6:
# TP_veg: 559, FP_veg: 0, FN_veg: 250, IoU_veg: 0.6910
# TP_non_veg: 15575, FP_non_veg: 0, FN_non_veg: 809, IoU_non_veg: 0.9506
# Image 7:
# TP_veg: 1407, FP_veg: 3, FN_veg: 646, IoU_veg: 0.6843
# TP_non_veg: 14331, FP_non_veg: 3, FN_non_veg: 2053, IoU_non_veg: 0.8745
# Image 8:
# TP_veg: 88, FP_veg: 0, FN_veg: 92, IoU_veg: 0.4889
# TP_non_veg: 16204, FP_non_veg: 0, FN_non_veg: 180, IoU_non_veg: 0.9890
# Image 9:
# TP_veg: 5162, FP_veg: 0, FN_veg: 3731, IoU_veg: 0.5805
# TP_non_veg: 7491, FP_non_veg: 0, FN_non_veg: 8893, IoU_non_veg: 0.4572
# Image 10:
# TP_veg: 1299, FP_veg: 0, FN_veg: 5971, IoU_veg: 0.1787
# TP_non_veg: 9114, FP_non_veg: 0, FN_non_veg: 7270, IoU_non_veg: 0.5563
# Image 11:
# TP_veg: 2598, FP_veg: 0, FN_veg: 1366, IoU_veg: 0.6554
# TP_non_veg: 12420, FP_non_veg: 0, FN_non_veg: 3964, IoU_non_veg: 0.7581
# Image 12:
# TP_veg: 552, FP_veg: 0, FN_veg: 3059, IoU_veg: 0.1529
# TP_non_veg: 12773, FP_non_veg: 0, FN_non_veg: 3611, IoU_non_veg: 0.7796
# Image 13:
# TP_veg: 0, FP_veg: 0, FN_veg: 1, IoU_veg: 0.0000
# TP_non_veg: 16383, FP_non_veg: 0, FN_non_veg: 1, IoU_non_veg: 0.9999
# Image 14:
# TP_veg: 0, FP_veg: 0, FN_veg: 3989, IoU_veg: 0.0000
# TP_non_veg: 12395, FP_non_veg: 0, FN_non_veg: 3989, IoU_non_veg: 0.7565
# Image 15:
# TP_veg: 4793, FP_veg: 0, FN_veg: 2651, IoU_veg: 0.6439
# TP_non_veg: 8940, FP_non_veg: 0, FN_non_veg: 7444, IoU_non_veg: 0.5457
# Image 16:
# TP_veg: 6580, FP_veg: 0, FN_veg: 3867, IoU_veg: 0.6298
# TP_non_veg: 5937, FP_non_veg: 0, FN_non_veg: 10447, IoU_non_veg: 0.3624
# Image 17:
# TP_veg: 6706, FP_veg: 198, FN_veg: 1871, IoU_veg: 0.7642
# TP_non_veg: 7807, FP_non_veg: 198, FN_non_veg: 8577, IoU_non_veg: 0.4708
# Image 18:
# TP_veg: 7433, FP_veg: 13, FN_veg: 4332, IoU_veg: 0.6311
# TP_non_veg: 4619, FP_non_veg: 13, FN_non_veg: 11765, IoU_non_veg: 0.2817
# Image 19:
# TP_veg: 0, FP_veg: 21, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 21, FN_non_veg: 0, IoU_non_veg: 0.9987
# Image 20:
# TP_veg: 32, FP_veg: 8, FN_veg: 3, IoU_veg: 0.7442
# TP_non_veg: 16349, FP_non_veg: 8, FN_non_veg: 35, IoU_non_veg: 0.9974
# Image 21:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 22:
# TP_veg: 5038, FP_veg: 0, FN_veg: 9198, IoU_veg: 0.3539
# TP_non_veg: 2148, FP_non_veg: 0, FN_non_veg: 14236, IoU_non_veg: 0.1311
# Image 23:
# TP_veg: 5387, FP_veg: 1, FN_veg: 5399, IoU_veg: 0.4994
# TP_non_veg: 5598, FP_non_veg: 1, FN_non_veg: 10786, IoU_non_veg: 0.3417
# Image 24:
# TP_veg: 907, FP_veg: 5, FN_veg: 1354, IoU_veg: 0.4003
# TP_non_veg: 14123, FP_non_veg: 5, FN_non_veg: 2261, IoU_non_veg: 0.8617
# Image 25:
# TP_veg: 1266, FP_veg: 26, FN_veg: 7210, IoU_veg: 0.1489
# TP_non_veg: 7908, FP_non_veg: 26, FN_non_veg: 8476, IoU_non_veg: 0.4819
# Image 26:
# TP_veg: 1118, FP_veg: 14, FN_veg: 1256, IoU_veg: 0.4682
# TP_non_veg: 14010, FP_non_veg: 14, FN_non_veg: 2374, IoU_non_veg: 0.8544
# Image 27:
# TP_veg: 5560, FP_veg: 5, FN_veg: 4354, IoU_veg: 0.5605
# TP_non_veg: 6470, FP_non_veg: 5, FN_non_veg: 9914, IoU_non_veg: 0.3948
# Image 28:
# TP_veg: 1, FP_veg: 0, FN_veg: 13786, IoU_veg: 0.0001
# TP_non_veg: 2597, FP_non_veg: 0, FN_non_veg: 13787, IoU_non_veg: 0.1585
# Image 29:
# TP_veg: 1737, FP_veg: 3, FN_veg: 6288, IoU_veg: 0.2164
# TP_non_veg: 8359, FP_non_veg: 3, FN_non_veg: 8025, IoU_non_veg: 0.5101
# Image 30:
# TP_veg: 2722, FP_veg: 0, FN_veg: 6253, IoU_veg: 0.3033
# TP_non_veg: 7409, FP_non_veg: 0, FN_non_veg: 8975, IoU_non_veg: 0.4522
# Image 31:
# TP_veg: 3772, FP_veg: 0, FN_veg: 8910, IoU_veg: 0.2974
# TP_non_veg: 3702, FP_non_veg: 0, FN_non_veg: 12682, IoU_non_veg: 0.2260
# Image 32:
# TP_veg: 2483, FP_veg: 0, FN_veg: 4517, IoU_veg: 0.3547
# TP_non_veg: 9384, FP_non_veg: 0, FN_non_veg: 7000, IoU_non_veg: 0.5728
# Image 33:
# TP_veg: 3553, FP_veg: 5, FN_veg: 7216, IoU_veg: 0.3298
# TP_non_veg: 5615, FP_non_veg: 5, FN_non_veg: 10769, IoU_non_veg: 0.3426
# Image 34:
# TP_veg: 6071, FP_veg: 0, FN_veg: 6988, IoU_veg: 0.4649
# TP_non_veg: 3325, FP_non_veg: 0, FN_non_veg: 13059, IoU_non_veg: 0.2029
# Image 35:
# TP_veg: 5509, FP_veg: 38, FN_veg: 6773, IoU_veg: 0.4472
# TP_non_veg: 4102, FP_non_veg: 38, FN_non_veg: 12282, IoU_non_veg: 0.2498
# Image 36:
# TP_veg: 2359, FP_veg: 24, FN_veg: 8842, IoU_veg: 0.2102
# TP_non_veg: 5183, FP_non_veg: 24, FN_non_veg: 11201, IoU_non_veg: 0.3159
# Image 37:
# TP_veg: 2936, FP_veg: 0, FN_veg: 1963, IoU_veg: 0.5993
# TP_non_veg: 11485, FP_non_veg: 0, FN_non_veg: 4899, IoU_non_veg: 0.7010
# Image 38:
# TP_veg: 6713, FP_veg: 7, FN_veg: 3101, IoU_veg: 0.6835
# TP_non_veg: 6570, FP_non_veg: 7, FN_non_veg: 9814, IoU_non_veg: 0.4008
# Image 39:
# TP_veg: 3663, FP_veg: 9, FN_veg: 3788, IoU_veg: 0.4910
# TP_non_veg: 8933, FP_non_veg: 9, FN_non_veg: 7451, IoU_non_veg: 0.5449
# Image 40:
# TP_veg: 1467, FP_veg: 0, FN_veg: 5718, IoU_veg: 0.2042
# TP_non_veg: 9199, FP_non_veg: 0, FN_non_veg: 7185, IoU_non_veg: 0.5615
# Image 41:
# TP_veg: 1150, FP_veg: 0, FN_veg: 4392, IoU_veg: 0.2075
# TP_non_veg: 10842, FP_non_veg: 0, FN_non_veg: 5542, IoU_non_veg: 0.6617
# Image 42:
# TP_veg: 19, FP_veg: 1, FN_veg: 2605, IoU_veg: 0.0072
# TP_non_veg: 13760, FP_non_veg: 1, FN_non_veg: 2624, IoU_non_veg: 0.8398
# Image 43:
# TP_veg: 4, FP_veg: 0, FN_veg: 1203, IoU_veg: 0.0033
# TP_non_veg: 15177, FP_non_veg: 0, FN_non_veg: 1207, IoU_non_veg: 0.9263
# Image 44:
# TP_veg: 249, FP_veg: 0, FN_veg: 3597, IoU_veg: 0.0647
# TP_non_veg: 12538, FP_non_veg: 0, FN_non_veg: 3846, IoU_non_veg: 0.7653
# Image 45:
# TP_veg: 342, FP_veg: 2, FN_veg: 5118, IoU_veg: 0.0626
# TP_non_veg: 10924, FP_non_veg: 2, FN_non_veg: 5460, IoU_non_veg: 0.6667
# Image 46:
# TP_veg: 183, FP_veg: 0, FN_veg: 2225, IoU_veg: 0.0760
# TP_non_veg: 13976, FP_non_veg: 0, FN_non_veg: 2408, IoU_non_veg: 0.8530
# Image 47:
# TP_veg: 0, FP_veg: 0, FN_veg: 613, IoU_veg: 0.0000
# TP_non_veg: 15771, FP_non_veg: 0, FN_non_veg: 613, IoU_non_veg: 0.9626
# Image 48:
# TP_veg: 1206, FP_veg: 9, FN_veg: 4919, IoU_veg: 0.1966
# TP_non_veg: 10259, FP_non_veg: 9, FN_non_veg: 6125, IoU_non_veg: 0.6258
# Image 49:
# TP_veg: 4655, FP_veg: 8, FN_veg: 2470, IoU_veg: 0.6526
# TP_non_veg: 9259, FP_non_veg: 8, FN_non_veg: 7125, IoU_non_veg: 0.5648
# Image 50:
# TP_veg: 2525, FP_veg: 3, FN_veg: 4245, IoU_veg: 0.3728
# TP_non_veg: 9614, FP_non_veg: 3, FN_non_veg: 6770, IoU_non_veg: 0.5867
# Image 51:
# TP_veg: 3523, FP_veg: 12, FN_veg: 5726, IoU_veg: 0.3804
# TP_non_veg: 7135, FP_non_veg: 12, FN_non_veg: 9249, IoU_non_veg: 0.4352
# Image 52:
# TP_veg: 1035, FP_veg: 0, FN_veg: 1676, IoU_veg: 0.3818
# TP_non_veg: 13673, FP_non_veg: 0, FN_non_veg: 2711, IoU_non_veg: 0.8345
# Image 53:
# TP_veg: 4314, FP_veg: 0, FN_veg: 3024, IoU_veg: 0.5879
# TP_non_veg: 9046, FP_non_veg: 0, FN_non_veg: 7338, IoU_non_veg: 0.5521
# Image 54:
# TP_veg: 4225, FP_veg: 0, FN_veg: 2128, IoU_veg: 0.6650
# TP_non_veg: 10031, FP_non_veg: 0, FN_non_veg: 6353, IoU_non_veg: 0.6122
# Image 55:
# TP_veg: 209, FP_veg: 0, FN_veg: 2435, IoU_veg: 0.0790
# TP_non_veg: 13740, FP_non_veg: 0, FN_non_veg: 2644, IoU_non_veg: 0.8386
# Image 56:
# TP_veg: 392, FP_veg: 0, FN_veg: 2592, IoU_veg: 0.1314
# TP_non_veg: 13400, FP_non_veg: 0, FN_non_veg: 2984, IoU_non_veg: 0.8179
# Image 57:
# TP_veg: 1674, FP_veg: 0, FN_veg: 10101, IoU_veg: 0.1422
# TP_non_veg: 4609, FP_non_veg: 0, FN_non_veg: 11775, IoU_non_veg: 0.2813
# Image 58:
# TP_veg: 0, FP_veg: 0, FN_veg: 6106, IoU_veg: 0.0000
# TP_non_veg: 10278, FP_non_veg: 0, FN_non_veg: 6106, IoU_non_veg: 0.6273
# Image 59:
# TP_veg: 119, FP_veg: 2, FN_veg: 3004, IoU_veg: 0.0381
# TP_non_veg: 13261, FP_non_veg: 2, FN_non_veg: 3123, IoU_non_veg: 0.8093
# Image 60:
# TP_veg: 4726, FP_veg: 0, FN_veg: 11546, IoU_veg: 0.2904
# TP_non_veg: 112, FP_non_veg: 0, FN_non_veg: 16272, IoU_non_veg: 0.0068
# Image 61:
# TP_veg: 167, FP_veg: 8, FN_veg: 3195, IoU_veg: 0.0496
# TP_non_veg: 13022, FP_non_veg: 8, FN_non_veg: 3362, IoU_non_veg: 0.7944
# Image 62:
# TP_veg: 453, FP_veg: 0, FN_veg: 1971, IoU_veg: 0.1869
# TP_non_veg: 13960, FP_non_veg: 0, FN_non_veg: 2424, IoU_non_veg: 0.8521
# Image 63:
# TP_veg: 1417, FP_veg: 0, FN_veg: 8739, IoU_veg: 0.1395
# TP_non_veg: 6228, FP_non_veg: 0, FN_non_veg: 10156, IoU_non_veg: 0.3801
# Image 64:
# TP_veg: 756, FP_veg: 0, FN_veg: 1528, IoU_veg: 0.3310
# TP_non_veg: 14100, FP_non_veg: 0, FN_non_veg: 2284, IoU_non_veg: 0.8606
# Image 65:
# TP_veg: 95, FP_veg: 0, FN_veg: 4105, IoU_veg: 0.0226
# TP_non_veg: 12184, FP_non_veg: 0, FN_non_veg: 4200, IoU_non_veg: 0.7437
# Image 66:
# TP_veg: 0, FP_veg: 0, FN_veg: 1315, IoU_veg: 0.0000
# TP_non_veg: 15069, FP_non_veg: 0, FN_non_veg: 1315, IoU_non_veg: 0.9197
# Image 67:
# TP_veg: 0, FP_veg: 0, FN_veg: 1422, IoU_veg: 0.0000
# TP_non_veg: 14962, FP_non_veg: 0, FN_non_veg: 1422, IoU_non_veg: 0.9132
# Image 68:
# TP_veg: 614, FP_veg: 0, FN_veg: 5474, IoU_veg: 0.1009
# TP_non_veg: 10296, FP_non_veg: 0, FN_non_veg: 6088, IoU_non_veg: 0.6284
# Image 69:
# TP_veg: 184, FP_veg: 0, FN_veg: 155, IoU_veg: 0.5428
# TP_non_veg: 16045, FP_non_veg: 0, FN_non_veg: 339, IoU_non_veg: 0.9793
# Image 70:
# TP_veg: 65, FP_veg: 0, FN_veg: 7482, IoU_veg: 0.0086
# TP_non_veg: 8837, FP_non_veg: 0, FN_non_veg: 7547, IoU_non_veg: 0.5394
# Image 71:
# TP_veg: 236, FP_veg: 0, FN_veg: 773, IoU_veg: 0.2339
# TP_non_veg: 15375, FP_non_veg: 0, FN_non_veg: 1009, IoU_non_veg: 0.9384
# Image 72:
# TP_veg: 4996, FP_veg: 0, FN_veg: 11308, IoU_veg: 0.3064
# TP_non_veg: 80, FP_non_veg: 0, FN_non_veg: 16304, IoU_non_veg: 0.0049
# Image 73:
# TP_veg: 4134, FP_veg: 0, FN_veg: 4752, IoU_veg: 0.4652
# TP_non_veg: 7498, FP_non_veg: 0, FN_non_veg: 8886, IoU_non_veg: 0.4576
# Image 74:
# TP_veg: 2429, FP_veg: 31, FN_veg: 6460, IoU_veg: 0.2723
# TP_non_veg: 7495, FP_non_veg: 31, FN_non_veg: 8889, IoU_non_veg: 0.4566
# Image 75:
# TP_veg: 463, FP_veg: 2, FN_veg: 312, IoU_veg: 0.5959
# TP_non_veg: 15609, FP_non_veg: 2, FN_non_veg: 775, IoU_non_veg: 0.9526
# Image 76:
# TP_veg: 1207, FP_veg: 0, FN_veg: 6760, IoU_veg: 0.1515
# TP_non_veg: 8417, FP_non_veg: 0, FN_non_veg: 7967, IoU_non_veg: 0.5137
# Image 77:
# TP_veg: 7236, FP_veg: 13, FN_veg: 4358, IoU_veg: 0.6234
# TP_non_veg: 4790, FP_non_veg: 13, FN_non_veg: 11594, IoU_non_veg: 0.2921
# Image 78:
# TP_veg: 1371, FP_veg: 0, FN_veg: 1014, IoU_veg: 0.5748
# TP_non_veg: 13999, FP_non_veg: 0, FN_non_veg: 2385, IoU_non_veg: 0.8544
# Image 79:
# TP_veg: 1856, FP_veg: 45, FN_veg: 8663, IoU_veg: 0.1757
# TP_non_veg: 5865, FP_non_veg: 45, FN_non_veg: 10519, IoU_non_veg: 0.3570
# Image 80:
# TP_veg: 10569, FP_veg: 31, FN_veg: 4144, IoU_veg: 0.7168
# TP_non_veg: 1671, FP_non_veg: 31, FN_non_veg: 14713, IoU_non_veg: 0.1018
# Image 81:
# TP_veg: 6669, FP_veg: 33, FN_veg: 2336, IoU_veg: 0.7379
# TP_non_veg: 7379, FP_non_veg: 33, FN_non_veg: 9005, IoU_non_veg: 0.4495
# Image 82:
# TP_veg: 11235, FP_veg: 4, FN_veg: 3172, IoU_veg: 0.7796
# TP_non_veg: 1977, FP_non_veg: 4, FN_non_veg: 14407, IoU_non_veg: 0.1206
# Image 83:
# TP_veg: 7639, FP_veg: 5, FN_veg: 3731, IoU_veg: 0.6716
# TP_non_veg: 5014, FP_non_veg: 5, FN_non_veg: 11370, IoU_non_veg: 0.3059
# Image 84:
# TP_veg: 1998, FP_veg: 0, FN_veg: 1901, IoU_veg: 0.5124
# TP_non_veg: 12485, FP_non_veg: 0, FN_non_veg: 3899, IoU_non_veg: 0.7620
# Image 85:
# TP_veg: 690, FP_veg: 0, FN_veg: 5660, IoU_veg: 0.1087
# TP_non_veg: 10034, FP_non_veg: 0, FN_non_veg: 6350, IoU_non_veg: 0.6124
# Image 86:
# TP_veg: 88, FP_veg: 0, FN_veg: 9205, IoU_veg: 0.0095
# TP_non_veg: 7091, FP_non_veg: 0, FN_non_veg: 9293, IoU_non_veg: 0.4328
# Image 87:
# TP_veg: 0, FP_veg: 0, FN_veg: 3912, IoU_veg: 0.0000
# TP_non_veg: 12472, FP_non_veg: 0, FN_non_veg: 3912, IoU_non_veg: 0.7612
# Image 88:
# TP_veg: 3, FP_veg: 0, FN_veg: 10502, IoU_veg: 0.0003
# TP_non_veg: 5879, FP_non_veg: 0, FN_non_veg: 10505, IoU_non_veg: 0.3588
# Image 89:
# TP_veg: 0, FP_veg: 0, FN_veg: 3051, IoU_veg: 0.0000
# TP_non_veg: 13333, FP_non_veg: 0, FN_non_veg: 3051, IoU_non_veg: 0.8138
# Image 90:
# TP_veg: 4355, FP_veg: 26, FN_veg: 7109, IoU_veg: 0.3790
# TP_non_veg: 4920, FP_non_veg: 26, FN_non_veg: 11464, IoU_non_veg: 0.2998
# Image 91:
# TP_veg: 1906, FP_veg: 27, FN_veg: 4030, IoU_veg: 0.3196
# TP_non_veg: 10448, FP_non_veg: 27, FN_non_veg: 5936, IoU_non_veg: 0.6366
# Image 92:
# TP_veg: 3482, FP_veg: 7, FN_veg: 2897, IoU_veg: 0.5453
# TP_non_veg: 10005, FP_non_veg: 7, FN_non_veg: 6379, IoU_non_veg: 0.6104
# Image 93:
# TP_veg: 3183, FP_veg: 28, FN_veg: 9611, IoU_veg: 0.2482
# TP_non_veg: 3590, FP_non_veg: 28, FN_non_veg: 12794, IoU_non_veg: 0.2187
# Image 94:
# TP_veg: 1088, FP_veg: 42, FN_veg: 991, IoU_veg: 0.5130
# TP_non_veg: 14305, FP_non_veg: 42, FN_non_veg: 2079, IoU_non_veg: 0.8709
# Image 95:
# TP_veg: 3053, FP_veg: 82, FN_veg: 7121, IoU_veg: 0.2977
# TP_non_veg: 6210, FP_non_veg: 82, FN_non_veg: 10174, IoU_non_veg: 0.3771
# Image 96:
# TP_veg: 148, FP_veg: 0, FN_veg: 5793, IoU_veg: 0.0249
# TP_non_veg: 10443, FP_non_veg: 0, FN_non_veg: 5941, IoU_non_veg: 0.6374
# Image 97:
# TP_veg: 38, FP_veg: 0, FN_veg: 1860, IoU_veg: 0.0200
# TP_non_veg: 14486, FP_non_veg: 0, FN_non_veg: 1898, IoU_non_veg: 0.8842
# Image 98:
# TP_veg: 4886, FP_veg: 2, FN_veg: 4448, IoU_veg: 0.5234
# TP_non_veg: 7050, FP_non_veg: 2, FN_non_veg: 9334, IoU_non_veg: 0.4302
# Image 99:
# TP_veg: 47, FP_veg: 0, FN_veg: 2155, IoU_veg: 0.0213
# TP_non_veg: 14182, FP_non_veg: 0, FN_non_veg: 2202, IoU_non_veg: 0.8656
# Image 100:
# TP_veg: 509, FP_veg: 0, FN_veg: 10343, IoU_veg: 0.0469
# TP_non_veg: 5532, FP_non_veg: 0, FN_non_veg: 10852, IoU_non_veg: 0.3376
# Image 101:
# TP_veg: 217, FP_veg: 0, FN_veg: 14904, IoU_veg: 0.0144
# TP_non_veg: 1263, FP_non_veg: 0, FN_non_veg: 15121, IoU_non_veg: 0.0771
# Image 102:
# TP_veg: 1648, FP_veg: 0, FN_veg: 14736, IoU_veg: 0.1006
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 103:
# TP_veg: 6791, FP_veg: 0, FN_veg: 9593, IoU_veg: 0.4145
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 104:
# TP_veg: 6368, FP_veg: 0, FN_veg: 6429, IoU_veg: 0.4976
# TP_non_veg: 3587, FP_non_veg: 0, FN_non_veg: 12797, IoU_non_veg: 0.2189
# Image 105:
# TP_veg: 3768, FP_veg: 0, FN_veg: 9437, IoU_veg: 0.2853
# TP_non_veg: 3179, FP_non_veg: 0, FN_non_veg: 13205, IoU_non_veg: 0.1940
# Image 106:
# TP_veg: 2, FP_veg: 0, FN_veg: 1286, IoU_veg: 0.0016
# TP_non_veg: 15096, FP_non_veg: 0, FN_non_veg: 1288, IoU_non_veg: 0.9214
# Image 107:
# TP_veg: 188, FP_veg: 0, FN_veg: 1697, IoU_veg: 0.0997
# TP_non_veg: 14499, FP_non_veg: 0, FN_non_veg: 1885, IoU_non_veg: 0.8849
# Image 108:
# TP_veg: 5002, FP_veg: 0, FN_veg: 11382, IoU_veg: 0.3053
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 109:
# TP_veg: 2254, FP_veg: 0, FN_veg: 1409, IoU_veg: 0.6153
# TP_non_veg: 12721, FP_non_veg: 0, FN_non_veg: 3663, IoU_non_veg: 0.7764
# Image 110:
# TP_veg: 7241, FP_veg: 12, FN_veg: 6818, IoU_veg: 0.5146
# TP_non_veg: 2325, FP_non_veg: 12, FN_non_veg: 14059, IoU_non_veg: 0.1418
# Image 111:
# TP_veg: 549, FP_veg: 0, FN_veg: 6486, IoU_veg: 0.0780
# TP_non_veg: 9349, FP_non_veg: 0, FN_non_veg: 7035, IoU_non_veg: 0.5706
# Image 112:
# TP_veg: 160, FP_veg: 12, FN_veg: 1552, IoU_veg: 0.0928
# TP_non_veg: 14672, FP_non_veg: 12, FN_non_veg: 1712, IoU_non_veg: 0.8949
# Image 113:
# TP_veg: 861, FP_veg: 0, FN_veg: 4663, IoU_veg: 0.1559
# TP_non_veg: 10860, FP_non_veg: 0, FN_non_veg: 5524, IoU_non_veg: 0.6628
# Image 114:
# TP_veg: 2204, FP_veg: 0, FN_veg: 13454, IoU_veg: 0.1408
# TP_non_veg: 726, FP_non_veg: 0, FN_non_veg: 15658, IoU_non_veg: 0.0443
# Image 115:
# TP_veg: 2908, FP_veg: 0, FN_veg: 13476, IoU_veg: 0.1775
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 116:
# TP_veg: 2804, FP_veg: 0, FN_veg: 13580, IoU_veg: 0.1711
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 117:
# TP_veg: 3064, FP_veg: 0, FN_veg: 13320, IoU_veg: 0.1870
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 118:
# TP_veg: 1784, FP_veg: 0, FN_veg: 13201, IoU_veg: 0.1191
# TP_non_veg: 1399, FP_non_veg: 0, FN_non_veg: 14985, IoU_non_veg: 0.0854
# Image 119:
# TP_veg: 417, FP_veg: 1, FN_veg: 5886, IoU_veg: 0.0661
# TP_non_veg: 10081, FP_non_veg: 1, FN_non_veg: 6303, IoU_non_veg: 0.6153
# Image 120:
# TP_veg: 4083, FP_veg: 0, FN_veg: 10344, IoU_veg: 0.2830
# TP_non_veg: 1957, FP_non_veg: 0, FN_non_veg: 14427, IoU_non_veg: 0.1194
# Image 121:
# TP_veg: 3324, FP_veg: 0, FN_veg: 3222, IoU_veg: 0.5078
# TP_non_veg: 9838, FP_non_veg: 0, FN_non_veg: 6546, IoU_non_veg: 0.6005
# Image 122:
# TP_veg: 5272, FP_veg: 16, FN_veg: 2215, IoU_veg: 0.7027
# TP_non_veg: 8897, FP_non_veg: 16, FN_non_veg: 7487, IoU_non_veg: 0.5425
# Image 123:
# TP_veg: 4701, FP_veg: 0, FN_veg: 10367, IoU_veg: 0.3120
# TP_non_veg: 1316, FP_non_veg: 0, FN_non_veg: 15068, IoU_non_veg: 0.0803
# Image 124:
# TP_veg: 2320, FP_veg: 51, FN_veg: 1586, IoU_veg: 0.5863
# TP_non_veg: 12478, FP_non_veg: 51, FN_non_veg: 3906, IoU_non_veg: 0.7592
# Image 125:
# TP_veg: 7177, FP_veg: 0, FN_veg: 5070, IoU_veg: 0.5860
# TP_non_veg: 4137, FP_non_veg: 0, FN_non_veg: 12247, IoU_non_veg: 0.2525
# Image 126:
# TP_veg: 36, FP_veg: 0, FN_veg: 4228, IoU_veg: 0.0084
# TP_non_veg: 12120, FP_non_veg: 0, FN_non_veg: 4264, IoU_non_veg: 0.7397
# Image 127:
# TP_veg: 0, FP_veg: 0, FN_veg: 34, IoU_veg: 0.0000
# TP_non_veg: 16350, FP_non_veg: 0, FN_non_veg: 34, IoU_non_veg: 0.9979
# Image 128:
# TP_veg: 8, FP_veg: 0, FN_veg: 2466, IoU_veg: 0.0032
# TP_non_veg: 13910, FP_non_veg: 0, FN_non_veg: 2474, IoU_non_veg: 0.8490
# Image 129:
# TP_veg: 4541, FP_veg: 0, FN_veg: 11677, IoU_veg: 0.2800
# TP_non_veg: 166, FP_non_veg: 0, FN_non_veg: 16218, IoU_non_veg: 0.0101
# Image 130:
# TP_veg: 885, FP_veg: 0, FN_veg: 7623, IoU_veg: 0.1040
# TP_non_veg: 7876, FP_non_veg: 0, FN_non_veg: 8508, IoU_non_veg: 0.4807
# Image 131:
# TP_veg: 32, FP_veg: 0, FN_veg: 14553, IoU_veg: 0.0022
# TP_non_veg: 1799, FP_non_veg: 0, FN_non_veg: 14585, IoU_non_veg: 0.1098
# Image 132:
# TP_veg: 0, FP_veg: 0, FN_veg: 16384, IoU_veg: 0.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 133:
# TP_veg: 83, FP_veg: 0, FN_veg: 11536, IoU_veg: 0.0071
# TP_non_veg: 4765, FP_non_veg: 0, FN_non_veg: 11619, IoU_non_veg: 0.2908
# Image 134:
# TP_veg: 1902, FP_veg: 0, FN_veg: 8074, IoU_veg: 0.1907
# TP_non_veg: 6408, FP_non_veg: 0, FN_non_veg: 9976, IoU_non_veg: 0.3911
# Image 135:
# TP_veg: 6145, FP_veg: 0, FN_veg: 10239, IoU_veg: 0.3751
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 136:
# TP_veg: 999, FP_veg: 0, FN_veg: 1283, IoU_veg: 0.4378
# TP_non_veg: 14102, FP_non_veg: 0, FN_non_veg: 2282, IoU_non_veg: 0.8607
# Image 137:
# TP_veg: 1825, FP_veg: 6, FN_veg: 4455, IoU_veg: 0.2903
# TP_non_veg: 10104, FP_non_veg: 6, FN_non_veg: 6280, IoU_non_veg: 0.6165
# Image 138:
# TP_veg: 3295, FP_veg: 0, FN_veg: 9843, IoU_veg: 0.2508
# TP_non_veg: 3246, FP_non_veg: 0, FN_non_veg: 13138, IoU_non_veg: 0.1981
# Image 139:
# TP_veg: 3378, FP_veg: 0, FN_veg: 2009, IoU_veg: 0.6271
# TP_non_veg: 10997, FP_non_veg: 0, FN_non_veg: 5387, IoU_non_veg: 0.6712
# Image 140:
# TP_veg: 3008, FP_veg: 0, FN_veg: 6702, IoU_veg: 0.3098
# TP_non_veg: 6674, FP_non_veg: 0, FN_non_veg: 9710, IoU_non_veg: 0.4073
# Image 141:
# TP_veg: 165, FP_veg: 0, FN_veg: 4355, IoU_veg: 0.0365
# TP_non_veg: 11864, FP_non_veg: 0, FN_non_veg: 4520, IoU_non_veg: 0.7241
# Image 142:
# TP_veg: 278, FP_veg: 10, FN_veg: 1797, IoU_veg: 0.1333
# TP_non_veg: 14309, FP_non_veg: 10, FN_non_veg: 2075, IoU_non_veg: 0.8728
# Image 143:
# TP_veg: 1060, FP_veg: 0, FN_veg: 13504, IoU_veg: 0.0728
# TP_non_veg: 1820, FP_non_veg: 0, FN_non_veg: 14564, IoU_non_veg: 0.1111
# Image 144:
# TP_veg: 37, FP_veg: 0, FN_veg: 13907, IoU_veg: 0.0027
# TP_non_veg: 2440, FP_non_veg: 0, FN_non_veg: 13944, IoU_non_veg: 0.1489
# Image 145:
# TP_veg: 0, FP_veg: 0, FN_veg: 8077, IoU_veg: 0.0000
# TP_non_veg: 8307, FP_non_veg: 0, FN_non_veg: 8077, IoU_non_veg: 0.5070
# Image 146:
# TP_veg: 0, FP_veg: 0, FN_veg: 16322, IoU_veg: 0.0000
# TP_non_veg: 62, FP_non_veg: 0, FN_non_veg: 16322, IoU_non_veg: 0.0038
# Image 147:
# TP_veg: 12, FP_veg: 0, FN_veg: 16372, IoU_veg: 0.0007
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 148:
# TP_veg: 1308, FP_veg: 0, FN_veg: 15076, IoU_veg: 0.0798
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 149:
# TP_veg: 1546, FP_veg: 0, FN_veg: 14521, IoU_veg: 0.0962
# TP_non_veg: 317, FP_non_veg: 0, FN_non_veg: 16067, IoU_non_veg: 0.0193
# Image 150:
# TP_veg: 7492, FP_veg: 65, FN_veg: 3271, IoU_veg: 0.6919
# TP_non_veg: 5621, FP_non_veg: 65, FN_non_veg: 10763, IoU_non_veg: 0.3417
# Image 151:
# TP_veg: 283, FP_veg: 0, FN_veg: 6037, IoU_veg: 0.0448
# TP_non_veg: 10064, FP_non_veg: 0, FN_non_veg: 6320, IoU_non_veg: 0.6143
# Image 152:
# TP_veg: 7136, FP_veg: 210, FN_veg: 2797, IoU_veg: 0.7035
# TP_non_veg: 6451, FP_non_veg: 210, FN_non_veg: 9933, IoU_non_veg: 0.3888
# Image 153:
# TP_veg: 1750, FP_veg: 20, FN_veg: 533, IoU_veg: 0.7599
# TP_non_veg: 14101, FP_non_veg: 20, FN_non_veg: 2283, IoU_non_veg: 0.8596
# Image 154:
# TP_veg: 625, FP_veg: 1, FN_veg: 213, IoU_veg: 0.7449
# TP_non_veg: 15546, FP_non_veg: 1, FN_non_veg: 838, IoU_non_veg: 0.9488
# Image 155:
# TP_veg: 1696, FP_veg: 108, FN_veg: 1696, IoU_veg: 0.4846
# TP_non_veg: 12992, FP_non_veg: 108, FN_non_veg: 3392, IoU_non_veg: 0.7878
# Image 156:
# TP_veg: 1219, FP_veg: 3, FN_veg: 6562, IoU_veg: 0.1566
# TP_non_veg: 8603, FP_non_veg: 3, FN_non_veg: 7781, IoU_non_veg: 0.5250
# Image 157:
# TP_veg: 25, FP_veg: 0, FN_veg: 1411, IoU_veg: 0.0174
# TP_non_veg: 14948, FP_non_veg: 0, FN_non_veg: 1436, IoU_non_veg: 0.9124
# Image 158:
# TP_veg: 0, FP_veg: 0, FN_veg: 1126, IoU_veg: 0.0000
# TP_non_veg: 15258, FP_non_veg: 0, FN_non_veg: 1126, IoU_non_veg: 0.9313
# Image 159:
# TP_veg: 3925, FP_veg: 101, FN_veg: 2210, IoU_veg: 0.6294
# TP_non_veg: 10249, FP_non_veg: 101, FN_non_veg: 6135, IoU_non_veg: 0.6217
# Image 160:
# TP_veg: 402, FP_veg: 6, FN_veg: 2158, IoU_veg: 0.1567
# TP_non_veg: 13824, FP_non_veg: 6, FN_non_veg: 2560, IoU_non_veg: 0.8434
# Image 161:
# TP_veg: 1042, FP_veg: 0, FN_veg: 7845, IoU_veg: 0.1172
# TP_non_veg: 7497, FP_non_veg: 0, FN_non_veg: 8887, IoU_non_veg: 0.4576
# Image 162:
# TP_veg: 2858, FP_veg: 12, FN_veg: 726, IoU_veg: 0.7948
# TP_non_veg: 12800, FP_non_veg: 12, FN_non_veg: 3584, IoU_non_veg: 0.7807
# Image 163:
# TP_veg: 4467, FP_veg: 0, FN_veg: 7969, IoU_veg: 0.3592
# TP_non_veg: 3948, FP_non_veg: 0, FN_non_veg: 12436, IoU_non_veg: 0.2410
# Image 164:
# TP_veg: 1269, FP_veg: 2, FN_veg: 3519, IoU_veg: 0.2649
# TP_non_veg: 11596, FP_non_veg: 2, FN_non_veg: 4788, IoU_non_veg: 0.7077
# Image 165:
# TP_veg: 6001, FP_veg: 17, FN_veg: 2863, IoU_veg: 0.6757
# TP_non_veg: 7520, FP_non_veg: 17, FN_non_veg: 8864, IoU_non_veg: 0.4585
# Image 166:
# TP_veg: 5477, FP_veg: 10, FN_veg: 6953, IoU_veg: 0.4403
# TP_non_veg: 3954, FP_non_veg: 10, FN_non_veg: 12430, IoU_non_veg: 0.2412
# Image 167:
# TP_veg: 6800, FP_veg: 12, FN_veg: 7809, IoU_veg: 0.4651
# TP_non_veg: 1775, FP_non_veg: 12, FN_non_veg: 14609, IoU_non_veg: 0.1083
# Image 168:
# TP_veg: 6541, FP_veg: 18, FN_veg: 1993, IoU_veg: 0.7649
# TP_non_veg: 7850, FP_non_veg: 18, FN_non_veg: 8534, IoU_non_veg: 0.4786
# Image 169:
# TP_veg: 4515, FP_veg: 7, FN_veg: 7218, IoU_veg: 0.3846
# TP_non_veg: 4651, FP_non_veg: 7, FN_non_veg: 11733, IoU_non_veg: 0.2838
# Image 170:
# TP_veg: 4012, FP_veg: 21, FN_veg: 2627, IoU_veg: 0.6024
# TP_non_veg: 9745, FP_non_veg: 21, FN_non_veg: 6639, IoU_non_veg: 0.5940
# Image 171:
# TP_veg: 4136, FP_veg: 3, FN_veg: 3797, IoU_veg: 0.5212
# TP_non_veg: 8451, FP_non_veg: 3, FN_non_veg: 7933, IoU_non_veg: 0.5157
# Image 172:
# TP_veg: 4419, FP_veg: 89, FN_veg: 6675, IoU_veg: 0.3952
# TP_non_veg: 5290, FP_non_veg: 89, FN_non_veg: 11094, IoU_non_veg: 0.3211
# Image 173:
# TP_veg: 4422, FP_veg: 29, FN_veg: 5029, IoU_veg: 0.4665
# TP_non_veg: 6933, FP_non_veg: 29, FN_non_veg: 9451, IoU_non_veg: 0.4224
# Image 174:
# TP_veg: 10437, FP_veg: 170, FN_veg: 2896, IoU_veg: 0.7729
# TP_non_veg: 3051, FP_non_veg: 170, FN_non_veg: 13333, IoU_non_veg: 0.1843
# Image 175:
# TP_veg: 254, FP_veg: 64, FN_veg: 339, IoU_veg: 0.3866
# TP_non_veg: 15791, FP_non_veg: 64, FN_non_veg: 593, IoU_non_veg: 0.9601
# Image 176:
# TP_veg: 1661, FP_veg: 0, FN_veg: 6384, IoU_veg: 0.2065
# TP_non_veg: 8339, FP_non_veg: 0, FN_non_veg: 8045, IoU_non_veg: 0.5090
# Image 177:
# TP_veg: 795, FP_veg: 0, FN_veg: 7730, IoU_veg: 0.0933
# TP_non_veg: 7859, FP_non_veg: 0, FN_non_veg: 8525, IoU_non_veg: 0.4797
# Image 178:
# TP_veg: 424, FP_veg: 1, FN_veg: 3265, IoU_veg: 0.1149
# TP_non_veg: 12695, FP_non_veg: 1, FN_non_veg: 3689, IoU_non_veg: 0.7748
# Image 179:
# TP_veg: 3674, FP_veg: 0, FN_veg: 7700, IoU_veg: 0.3230
# TP_non_veg: 5010, FP_non_veg: 0, FN_non_veg: 11374, IoU_non_veg: 0.3058
# Image 180:
# TP_veg: 14291, FP_veg: 118, FN_veg: 1373, IoU_veg: 0.9055
# TP_non_veg: 720, FP_non_veg: 118, FN_non_veg: 15664, IoU_non_veg: 0.0436
# Image 181:
# TP_veg: 1578, FP_veg: 15, FN_veg: 3194, IoU_veg: 0.3296
# TP_non_veg: 11612, FP_non_veg: 15, FN_non_veg: 4772, IoU_non_veg: 0.7081
# Image 182:
# TP_veg: 3049, FP_veg: 0, FN_veg: 9279, IoU_veg: 0.2473
# TP_non_veg: 4056, FP_non_veg: 0, FN_non_veg: 12328, IoU_non_veg: 0.2476
# Image 183:
# TP_veg: 7858, FP_veg: 0, FN_veg: 6936, IoU_veg: 0.5312
# TP_non_veg: 1590, FP_non_veg: 0, FN_non_veg: 14794, IoU_non_veg: 0.0970
# Image 184:
# TP_veg: 6237, FP_veg: 0, FN_veg: 7973, IoU_veg: 0.4389
# TP_non_veg: 2174, FP_non_veg: 0, FN_non_veg: 14210, IoU_non_veg: 0.1327
# Image 185:
# TP_veg: 4395, FP_veg: 65, FN_veg: 9041, IoU_veg: 0.3255
# TP_non_veg: 2948, FP_non_veg: 65, FN_non_veg: 13436, IoU_non_veg: 0.1792
# Image 186:
# TP_veg: 5186, FP_veg: 12, FN_veg: 8364, IoU_veg: 0.3824
# TP_non_veg: 2834, FP_non_veg: 12, FN_non_veg: 13550, IoU_non_veg: 0.1728
# Image 187:
# TP_veg: 3272, FP_veg: 4, FN_veg: 9685, IoU_veg: 0.2524
# TP_non_veg: 3427, FP_non_veg: 4, FN_non_veg: 12957, IoU_non_veg: 0.2091
# Image 188:
# TP_veg: 2490, FP_veg: 5, FN_veg: 11196, IoU_veg: 0.1819
# TP_non_veg: 2698, FP_non_veg: 5, FN_non_veg: 13686, IoU_non_veg: 0.1646
# Image 189:
# TP_veg: 2229, FP_veg: 2, FN_veg: 2874, IoU_veg: 0.4366
# TP_non_veg: 11281, FP_non_veg: 2, FN_non_veg: 5103, IoU_non_veg: 0.6885
# Image 190:
# TP_veg: 1680, FP_veg: 21, FN_veg: 2270, IoU_veg: 0.4231
# TP_non_veg: 12434, FP_non_veg: 21, FN_non_veg: 3950, IoU_non_veg: 0.7579
# Image 191:
# TP_veg: 13, FP_veg: 0, FN_veg: 1770, IoU_veg: 0.0073
# TP_non_veg: 14601, FP_non_veg: 0, FN_non_veg: 1783, IoU_non_veg: 0.8912
# Image 192:
# TP_veg: 324, FP_veg: 0, FN_veg: 9091, IoU_veg: 0.0344
# TP_non_veg: 6969, FP_non_veg: 0, FN_non_veg: 9415, IoU_non_veg: 0.4254
# Image 193:
# TP_veg: 487, FP_veg: 25, FN_veg: 3573, IoU_veg: 0.1192
# TP_non_veg: 12324, FP_non_veg: 25, FN_non_veg: 4060, IoU_non_veg: 0.7511
# Image 194:
# TP_veg: 2203, FP_veg: 0, FN_veg: 10821, IoU_veg: 0.1691
# TP_non_veg: 3360, FP_non_veg: 0, FN_non_veg: 13024, IoU_non_veg: 0.2051
# Image 195:
# TP_veg: 2690, FP_veg: 117, FN_veg: 5889, IoU_veg: 0.3093
# TP_non_veg: 7805, FP_non_veg: 117, FN_non_veg: 8579, IoU_non_veg: 0.4730
# Image 196:
# TP_veg: 1994, FP_veg: 0, FN_veg: 11475, IoU_veg: 0.1480
# TP_non_veg: 2915, FP_non_veg: 0, FN_non_veg: 13469, IoU_non_veg: 0.1779
# Image 197:
# TP_veg: 534, FP_veg: 0, FN_veg: 5721, IoU_veg: 0.0854
# TP_non_veg: 10129, FP_non_veg: 0, FN_non_veg: 6255, IoU_non_veg: 0.6182
# Image 198:
# TP_veg: 4429, FP_veg: 0, FN_veg: 6105, IoU_veg: 0.4204
# TP_non_veg: 5850, FP_non_veg: 0, FN_non_veg: 10534, IoU_non_veg: 0.3571
# Image 199:
# TP_veg: 290, FP_veg: 0, FN_veg: 16094, IoU_veg: 0.0177
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 200:
# TP_veg: 2235, FP_veg: 0, FN_veg: 14149, IoU_veg: 0.1364
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 201:
# TP_veg: 83, FP_veg: 0, FN_veg: 16301, IoU_veg: 0.0051
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 202:
# TP_veg: 0, FP_veg: 0, FN_veg: 16384, IoU_veg: 0.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 203:
# TP_veg: 381, FP_veg: 0, FN_veg: 16003, IoU_veg: 0.0233
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 204:
# TP_veg: 2017, FP_veg: 10, FN_veg: 4104, IoU_veg: 0.3290
# TP_non_veg: 10263, FP_non_veg: 10, FN_non_veg: 6121, IoU_non_veg: 0.6260
# Image 205:
# TP_veg: 558, FP_veg: 0, FN_veg: 8039, IoU_veg: 0.0649
# TP_non_veg: 7787, FP_non_veg: 0, FN_non_veg: 8597, IoU_non_veg: 0.4753
# Image 206:
# TP_veg: 271, FP_veg: 38, FN_veg: 931, IoU_veg: 0.2185
# TP_non_veg: 15182, FP_non_veg: 38, FN_non_veg: 1202, IoU_non_veg: 0.9245
# Image 207:
# TP_veg: 879, FP_veg: 0, FN_veg: 9186, IoU_veg: 0.0873
# TP_non_veg: 6319, FP_non_veg: 0, FN_non_veg: 10065, IoU_non_veg: 0.3857
# Image 208:
# TP_veg: 4123, FP_veg: 0, FN_veg: 12261, IoU_veg: 0.2516
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 209:
# TP_veg: 9200, FP_veg: 0, FN_veg: 7184, IoU_veg: 0.5615
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 210:
# TP_veg: 2249, FP_veg: 7, FN_veg: 5324, IoU_veg: 0.2967
# TP_non_veg: 8811, FP_non_veg: 7, FN_non_veg: 7573, IoU_non_veg: 0.5376
# Image 211:
# TP_veg: 12897, FP_veg: 0, FN_veg: 3456, IoU_veg: 0.7887
# TP_non_veg: 31, FP_non_veg: 0, FN_non_veg: 16353, IoU_non_veg: 0.0019
# Image 212:
# TP_veg: 1597, FP_veg: 0, FN_veg: 5303, IoU_veg: 0.2314
# TP_non_veg: 9484, FP_non_veg: 0, FN_non_veg: 6900, IoU_non_veg: 0.5789
# Image 213:
# TP_veg: 5208, FP_veg: 35, FN_veg: 2720, IoU_veg: 0.6540
# TP_non_veg: 8456, FP_non_veg: 35, FN_non_veg: 7928, IoU_non_veg: 0.5150
# Image 214:
# TP_veg: 2312, FP_veg: 0, FN_veg: 12654, IoU_veg: 0.1545
# TP_non_veg: 1418, FP_non_veg: 0, FN_non_veg: 14966, IoU_non_veg: 0.0865
# Image 215:
# TP_veg: 240, FP_veg: 0, FN_veg: 14909, IoU_veg: 0.0158
# TP_non_veg: 1235, FP_non_veg: 0, FN_non_veg: 15149, IoU_non_veg: 0.0754
# Image 216:
# TP_veg: 381, FP_veg: 0, FN_veg: 15807, IoU_veg: 0.0235
# TP_non_veg: 196, FP_non_veg: 0, FN_non_veg: 16188, IoU_non_veg: 0.0120
# Image 217:
# TP_veg: 670, FP_veg: 0, FN_veg: 14569, IoU_veg: 0.0440
# TP_non_veg: 1145, FP_non_veg: 0, FN_non_veg: 15239, IoU_non_veg: 0.0699
# Image 218:
# TP_veg: 5, FP_veg: 0, FN_veg: 11457, IoU_veg: 0.0004
# TP_non_veg: 4922, FP_non_veg: 0, FN_non_veg: 11462, IoU_non_veg: 0.3004
# Image 219:
# TP_veg: 6943, FP_veg: 0, FN_veg: 9102, IoU_veg: 0.4327
# TP_non_veg: 339, FP_non_veg: 0, FN_non_veg: 16045, IoU_non_veg: 0.0207
# Image 220:
# TP_veg: 0, FP_veg: 0, FN_veg: 2348, IoU_veg: 0.0000
# TP_non_veg: 14036, FP_non_veg: 0, FN_non_veg: 2348, IoU_non_veg: 0.8567
# Image 221:
# TP_veg: 363, FP_veg: 3, FN_veg: 1561, IoU_veg: 0.1884
# TP_non_veg: 14460, FP_non_veg: 3, FN_non_veg: 1924, IoU_non_veg: 0.8824
# Image 222:
# TP_veg: 883, FP_veg: 0, FN_veg: 3518, IoU_veg: 0.2006
# TP_non_veg: 11983, FP_non_veg: 0, FN_non_veg: 4401, IoU_non_veg: 0.7314
# Image 223:
# TP_veg: 12219, FP_veg: 0, FN_veg: 4096, IoU_veg: 0.7489
# TP_non_veg: 69, FP_non_veg: 0, FN_non_veg: 16315, IoU_non_veg: 0.0042
# Image 224:
# TP_veg: 13310, FP_veg: 0, FN_veg: 3074, IoU_veg: 0.8124
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 225:
# TP_veg: 6420, FP_veg: 0, FN_veg: 2029, IoU_veg: 0.7599
# TP_non_veg: 7935, FP_non_veg: 0, FN_non_veg: 8449, IoU_non_veg: 0.4843
# Image 226:
# TP_veg: 12057, FP_veg: 0, FN_veg: 4327, IoU_veg: 0.7359
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 227:
# TP_veg: 3505, FP_veg: 0, FN_veg: 2635, IoU_veg: 0.5708
# TP_non_veg: 10244, FP_non_veg: 0, FN_non_veg: 6140, IoU_non_veg: 0.6252
# Image 228:
# TP_veg: 3981, FP_veg: 0, FN_veg: 8588, IoU_veg: 0.3167
# TP_non_veg: 3815, FP_non_veg: 0, FN_non_veg: 12569, IoU_non_veg: 0.2328
# Image 229:
# TP_veg: 0, FP_veg: 0, FN_veg: 2739, IoU_veg: 0.0000
# TP_non_veg: 13645, FP_non_veg: 0, FN_non_veg: 2739, IoU_non_veg: 0.8328
# Image 230:
# TP_veg: 83, FP_veg: 0, FN_veg: 5100, IoU_veg: 0.0160
# TP_non_veg: 11201, FP_non_veg: 0, FN_non_veg: 5183, IoU_non_veg: 0.6837
# Image 231:
# TP_veg: 0, FP_veg: 0, FN_veg: 224, IoU_veg: 0.0000
# TP_non_veg: 16160, FP_non_veg: 0, FN_non_veg: 224, IoU_non_veg: 0.9863
# Image 232:
# TP_veg: 472, FP_veg: 0, FN_veg: 5503, IoU_veg: 0.0790
# TP_non_veg: 10409, FP_non_veg: 0, FN_non_veg: 5975, IoU_non_veg: 0.6353
# Image 233:
# TP_veg: 293, FP_veg: 0, FN_veg: 1158, IoU_veg: 0.2019
# TP_non_veg: 14933, FP_non_veg: 0, FN_non_veg: 1451, IoU_non_veg: 0.9114
# Image 234:
# TP_veg: 5817, FP_veg: 0, FN_veg: 3598, IoU_veg: 0.6178
# TP_non_veg: 6969, FP_non_veg: 0, FN_non_veg: 9415, IoU_non_veg: 0.4254
# Image 235:
# TP_veg: 2218, FP_veg: 1, FN_veg: 5423, IoU_veg: 0.2902
# TP_non_veg: 8743, FP_non_veg: 1, FN_non_veg: 7641, IoU_non_veg: 0.5336
# Image 236:
# TP_veg: 936, FP_veg: 20, FN_veg: 3073, IoU_veg: 0.2323
# TP_non_veg: 12375, FP_non_veg: 20, FN_non_veg: 4009, IoU_non_veg: 0.7544
# Image 237:
# TP_veg: 64, FP_veg: 0, FN_veg: 405, IoU_veg: 0.1365
# TP_non_veg: 15915, FP_non_veg: 0, FN_non_veg: 469, IoU_non_veg: 0.9714
# Image 238:
# TP_veg: 1867, FP_veg: 0, FN_veg: 4548, IoU_veg: 0.2910
# TP_non_veg: 9969, FP_non_veg: 0, FN_non_veg: 6415, IoU_non_veg: 0.6085
# Image 239:
# TP_veg: 7232, FP_veg: 0, FN_veg: 8739, IoU_veg: 0.4528
# TP_non_veg: 413, FP_non_veg: 0, FN_non_veg: 15971, IoU_non_veg: 0.0252
# Image 240:
# TP_veg: 3618, FP_veg: 34, FN_veg: 2372, IoU_veg: 0.6006
# TP_non_veg: 10394, FP_non_veg: 34, FN_non_veg: 5990, IoU_non_veg: 0.6331
# Image 241:
# TP_veg: 667, FP_veg: 17, FN_veg: 583, IoU_veg: 0.5264
# TP_non_veg: 15134, FP_non_veg: 17, FN_non_veg: 1250, IoU_non_veg: 0.9227
# Image 242:
# TP_veg: 380, FP_veg: 1, FN_veg: 222, IoU_veg: 0.6302
# TP_non_veg: 15782, FP_non_veg: 1, FN_non_veg: 602, IoU_non_veg: 0.9632
# Image 243:
# TP_veg: 13373, FP_veg: 36, FN_veg: 1285, IoU_veg: 0.9101
# TP_non_veg: 1726, FP_non_veg: 36, FN_non_veg: 14658, IoU_non_veg: 0.1051
# Image 244:
# TP_veg: 981, FP_veg: 27, FN_veg: 1041, IoU_veg: 0.4788
# TP_non_veg: 14362, FP_non_veg: 27, FN_non_veg: 2022, IoU_non_veg: 0.8751
# Image 245:
# TP_veg: 5934, FP_veg: 129, FN_veg: 1513, IoU_veg: 0.7833
# TP_non_veg: 8937, FP_non_veg: 129, FN_non_veg: 7447, IoU_non_veg: 0.5412
# Image 246:
# TP_veg: 945, FP_veg: 14, FN_veg: 1475, IoU_veg: 0.3882
# TP_non_veg: 13964, FP_non_veg: 14, FN_non_veg: 2420, IoU_non_veg: 0.8516
# Image 247:
# TP_veg: 4914, FP_veg: 0, FN_veg: 5096, IoU_veg: 0.4909
# TP_non_veg: 6374, FP_non_veg: 0, FN_non_veg: 10010, IoU_non_veg: 0.3890
# Image 248:
# TP_veg: 8001, FP_veg: 28, FN_veg: 5107, IoU_veg: 0.6091
# TP_non_veg: 3276, FP_non_veg: 28, FN_non_veg: 13108, IoU_non_veg: 0.1996
# Image 249:
# TP_veg: 13349, FP_veg: 9, FN_veg: 2126, IoU_veg: 0.8621
# TP_non_veg: 909, FP_non_veg: 9, FN_non_veg: 15475, IoU_non_veg: 0.0555
# Image 250:
# TP_veg: 10609, FP_veg: 7, FN_veg: 2702, IoU_veg: 0.7966
# TP_non_veg: 3073, FP_non_veg: 7, FN_non_veg: 13311, IoU_non_veg: 0.1875
# Image 251:
# TP_veg: 7719, FP_veg: 122, FN_veg: 334, IoU_veg: 0.9442
# TP_non_veg: 8331, FP_non_veg: 122, FN_non_veg: 8053, IoU_non_veg: 0.5047
# Image 252:
# TP_veg: 71, FP_veg: 56, FN_veg: 465, IoU_veg: 0.1199
# TP_non_veg: 15848, FP_non_veg: 56, FN_non_veg: 536, IoU_non_veg: 0.9640
# Image 253:
# TP_veg: 1504, FP_veg: 35, FN_veg: 635, IoU_veg: 0.6918
# TP_non_veg: 14245, FP_non_veg: 35, FN_non_veg: 2139, IoU_non_veg: 0.8676
# Image 254:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 255:
# TP_veg: 2375, FP_veg: 92, FN_veg: 691, IoU_veg: 0.7521
# TP_non_veg: 13318, FP_non_veg: 92, FN_non_veg: 3066, IoU_non_veg: 0.8083
# Image 256:
# TP_veg: 12281, FP_veg: 74, FN_veg: 2093, IoU_veg: 0.8500
# TP_non_veg: 2010, FP_non_veg: 74, FN_non_veg: 14374, IoU_non_veg: 0.1221
# Image 257:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 258:
# TP_veg: 10950, FP_veg: 0, FN_veg: 5434, IoU_veg: 0.6683
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 259:
# TP_veg: 13386, FP_veg: 0, FN_veg: 2998, IoU_veg: 0.8170
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 260:
# TP_veg: 3959, FP_veg: 0, FN_veg: 12425, IoU_veg: 0.2416
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 261:
# TP_veg: 12371, FP_veg: 0, FN_veg: 4013, IoU_veg: 0.7551
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 262:
# TP_veg: 29, FP_veg: 0, FN_veg: 275, IoU_veg: 0.0954
# TP_non_veg: 16080, FP_non_veg: 0, FN_non_veg: 304, IoU_non_veg: 0.9814
# Image 263:
# TP_veg: 614, FP_veg: 39, FN_veg: 1207, IoU_veg: 0.3301
# TP_non_veg: 14563, FP_non_veg: 39, FN_non_veg: 1821, IoU_non_veg: 0.8867
# Image 264:
# TP_veg: 74, FP_veg: 0, FN_veg: 222, IoU_veg: 0.2500
# TP_non_veg: 16088, FP_non_veg: 0, FN_non_veg: 296, IoU_non_veg: 0.9819
# Image 265:
# TP_veg: 35, FP_veg: 0, FN_veg: 512, IoU_veg: 0.0640
# TP_non_veg: 15837, FP_non_veg: 0, FN_non_veg: 547, IoU_non_veg: 0.9666
# Image 266:
# TP_veg: 3647, FP_veg: 0, FN_veg: 3051, IoU_veg: 0.5445
# TP_non_veg: 9686, FP_non_veg: 0, FN_non_veg: 6698, IoU_non_veg: 0.5912
# Image 267:
# TP_veg: 206, FP_veg: 0, FN_veg: 895, IoU_veg: 0.1871
# TP_non_veg: 15283, FP_non_veg: 0, FN_non_veg: 1101, IoU_non_veg: 0.9328
# Image 268:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 269:
# TP_veg: 781, FP_veg: 19, FN_veg: 3880, IoU_veg: 0.1669
# TP_non_veg: 11723, FP_non_veg: 19, FN_non_veg: 4661, IoU_non_veg: 0.7147
# Image 270:
# TP_veg: 3530, FP_veg: 95, FN_veg: 2875, IoU_veg: 0.5431
# TP_non_veg: 9979, FP_non_veg: 95, FN_non_veg: 6405, IoU_non_veg: 0.6056
# Image 271:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 272:
# TP_veg: 11849, FP_veg: 37, FN_veg: 1688, IoU_veg: 0.8729
# TP_non_veg: 2847, FP_non_veg: 37, FN_non_veg: 13537, IoU_non_veg: 0.1734
# Image 273:
# TP_veg: 9710, FP_veg: 1, FN_veg: 6487, IoU_veg: 0.5995
# TP_non_veg: 187, FP_non_veg: 1, FN_non_veg: 16197, IoU_non_veg: 0.0114
# Image 274:
# TP_veg: 12828, FP_veg: 0, FN_veg: 3556, IoU_veg: 0.7830
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 275:
# TP_veg: 8842, FP_veg: 0, FN_veg: 7542, IoU_veg: 0.5397
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 276:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 277:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 278:
# TP_veg: 775, FP_veg: 0, FN_veg: 774, IoU_veg: 0.5003
# TP_non_veg: 14835, FP_non_veg: 0, FN_non_veg: 1549, IoU_non_veg: 0.9055
# Image 279:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 280:
# TP_veg: 176, FP_veg: 0, FN_veg: 194, IoU_veg: 0.4757
# TP_non_veg: 16014, FP_non_veg: 0, FN_non_veg: 370, IoU_non_veg: 0.9774
# Image 281:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 282:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 283:
# TP_veg: 5781, FP_veg: 44, FN_veg: 4330, IoU_veg: 0.5693
# TP_non_veg: 6273, FP_non_veg: 44, FN_non_veg: 10111, IoU_non_veg: 0.3818
# Image 284:
# TP_veg: 3160, FP_veg: 114, FN_veg: 2620, IoU_veg: 0.5361
# TP_non_veg: 10604, FP_non_veg: 114, FN_non_veg: 5780, IoU_non_veg: 0.6427
# Image 285:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 286:
# TP_veg: 0, FP_veg: 0, FN_veg: 253, IoU_veg: 0.0000
# TP_non_veg: 16131, FP_non_veg: 0, FN_non_veg: 253, IoU_non_veg: 0.9846
# Image 287:
# TP_veg: 2238, FP_veg: 0, FN_veg: 5548, IoU_veg: 0.2874
# TP_non_veg: 8598, FP_non_veg: 0, FN_non_veg: 7786, IoU_non_veg: 0.5248
# Image 288:
# TP_veg: 9284, FP_veg: 0, FN_veg: 7100, IoU_veg: 0.5667
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 289:
# TP_veg: 14196, FP_veg: 10, FN_veg: 1451, IoU_veg: 0.9067
# TP_non_veg: 737, FP_non_veg: 10, FN_non_veg: 15647, IoU_non_veg: 0.0450
# Image 290:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 291:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 292:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 293:
# TP_veg: 219, FP_veg: 0, FN_veg: 417, IoU_veg: 0.3443
# TP_non_veg: 15748, FP_non_veg: 0, FN_non_veg: 636, IoU_non_veg: 0.9612
# Image 294:
# TP_veg: 163, FP_veg: 0, FN_veg: 140, IoU_veg: 0.5380
# TP_non_veg: 16081, FP_non_veg: 0, FN_non_veg: 303, IoU_non_veg: 0.9815
# Image 295:
# TP_veg: 431, FP_veg: 1, FN_veg: 156, IoU_veg: 0.7330
# TP_non_veg: 15797, FP_non_veg: 1, FN_non_veg: 587, IoU_non_veg: 0.9641
# Image 296:
# TP_veg: 4483, FP_veg: 3, FN_veg: 1865, IoU_veg: 0.7059
# TP_non_veg: 10036, FP_non_veg: 3, FN_non_veg: 6348, IoU_non_veg: 0.6124
# Image 297:
# TP_veg: 125, FP_veg: 1, FN_veg: 99, IoU_veg: 0.5556
# TP_non_veg: 16160, FP_non_veg: 1, FN_non_veg: 224, IoU_non_veg: 0.9863
# Image 298:
# TP_veg: 2665, FP_veg: 25, FN_veg: 5303, IoU_veg: 0.3334
# TP_non_veg: 8416, FP_non_veg: 25, FN_non_veg: 7968, IoU_non_veg: 0.5129
# Image 299:
# TP_veg: 1683, FP_veg: 8, FN_veg: 211, IoU_veg: 0.8849
# TP_non_veg: 14490, FP_non_veg: 8, FN_non_veg: 1894, IoU_non_veg: 0.8840
# Image 300:
# TP_veg: 1551, FP_veg: 0, FN_veg: 3514, IoU_veg: 0.3062
# TP_non_veg: 11319, FP_non_veg: 0, FN_non_veg: 5065, IoU_non_veg: 0.6909
# Image 301:
# TP_veg: 2374, FP_veg: 0, FN_veg: 2925, IoU_veg: 0.4480
# TP_non_veg: 11085, FP_non_veg: 0, FN_non_veg: 5299, IoU_non_veg: 0.6766
# Image 302:
# TP_veg: 1878, FP_veg: 40, FN_veg: 5427, IoU_veg: 0.2557
# TP_non_veg: 9079, FP_non_veg: 40, FN_non_veg: 7305, IoU_non_veg: 0.5528
# Image 303:
# TP_veg: 4321, FP_veg: 40, FN_veg: 1583, IoU_veg: 0.7270
# TP_non_veg: 10480, FP_non_veg: 40, FN_non_veg: 5904, IoU_non_veg: 0.6381
# Image 304:
# TP_veg: 4046, FP_veg: 4, FN_veg: 6913, IoU_veg: 0.3691
# TP_non_veg: 5425, FP_non_veg: 4, FN_non_veg: 10959, IoU_non_veg: 0.3310
# Image 305:
# TP_veg: 8675, FP_veg: 0, FN_veg: 7709, IoU_veg: 0.5295
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 306:
# TP_veg: 13933, FP_veg: 0, FN_veg: 2451, IoU_veg: 0.8504
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 307:
# TP_veg: 8059, FP_veg: 2, FN_veg: 7641, IoU_veg: 0.5132
# TP_non_veg: 684, FP_non_veg: 2, FN_non_veg: 15700, IoU_non_veg: 0.0417
# Image 308:
# TP_veg: 608, FP_veg: 0, FN_veg: 4668, IoU_veg: 0.1152
# TP_non_veg: 11108, FP_non_veg: 0, FN_non_veg: 5276, IoU_non_veg: 0.6780
# Image 309:
# TP_veg: 5255, FP_veg: 60, FN_veg: 1524, IoU_veg: 0.7684
# TP_non_veg: 9605, FP_non_veg: 60, FN_non_veg: 6779, IoU_non_veg: 0.5841
# Image 310:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 311:
# TP_veg: 1682, FP_veg: 6, FN_veg: 1723, IoU_veg: 0.4931
# TP_non_veg: 12979, FP_non_veg: 6, FN_non_veg: 3405, IoU_non_veg: 0.7919
# Image 312:
# TP_veg: 5993, FP_veg: 102, FN_veg: 3023, IoU_veg: 0.6573
# TP_non_veg: 7368, FP_non_veg: 102, FN_non_veg: 9016, IoU_non_veg: 0.4469
# Image 313:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 314:
# TP_veg: 5383, FP_veg: 47, FN_veg: 2586, IoU_veg: 0.6715
# TP_non_veg: 8415, FP_non_veg: 47, FN_non_veg: 7969, IoU_non_veg: 0.5121
# Image 315:
# TP_veg: 5520, FP_veg: 6, FN_veg: 5994, IoU_veg: 0.4792
# TP_non_veg: 4870, FP_non_veg: 6, FN_non_veg: 11514, IoU_non_veg: 0.2971
# Image 316:
# TP_veg: 16140, FP_veg: 0, FN_veg: 244, IoU_veg: 0.9851
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 317:
# TP_veg: 11492, FP_veg: 64, FN_veg: 948, IoU_veg: 0.9191
# TP_non_veg: 3944, FP_non_veg: 64, FN_non_veg: 12440, IoU_non_veg: 0.2398
# Image 318:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 319:
# TP_veg: 0, FP_veg: 0, FN_veg: 24, IoU_veg: 0.0000
# TP_non_veg: 16360, FP_non_veg: 0, FN_non_veg: 24, IoU_non_veg: 0.9985
# Image 320:
# TP_veg: 1758, FP_veg: 0, FN_veg: 4063, IoU_veg: 0.3020
# TP_non_veg: 10563, FP_non_veg: 0, FN_non_veg: 5821, IoU_non_veg: 0.6447
# Image 321:
# TP_veg: 139, FP_veg: 0, FN_veg: 463, IoU_veg: 0.2309
# TP_non_veg: 15782, FP_non_veg: 0, FN_non_veg: 602, IoU_non_veg: 0.9633
# Image 322:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 323:
# TP_veg: 590, FP_veg: 0, FN_veg: 908, IoU_veg: 0.3939
# TP_non_veg: 14886, FP_non_veg: 0, FN_non_veg: 1498, IoU_non_veg: 0.9086
# Image 324:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 325:
# TP_veg: 8829, FP_veg: 0, FN_veg: 1070, IoU_veg: 0.8919
# TP_non_veg: 6485, FP_non_veg: 0, FN_non_veg: 9899, IoU_non_veg: 0.3958
# Image 326:
# TP_veg: 601, FP_veg: 1, FN_veg: 507, IoU_veg: 0.5419
# TP_non_veg: 15276, FP_non_veg: 1, FN_non_veg: 1108, IoU_non_veg: 0.9323
# Image 327:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 328:
# TP_veg: 151, FP_veg: 12, FN_veg: 197, IoU_veg: 0.4194
# TP_non_veg: 16036, FP_non_veg: 12, FN_non_veg: 348, IoU_non_veg: 0.9780
# Image 329:
# TP_veg: 8060, FP_veg: 0, FN_veg: 5127, IoU_veg: 0.6112
# TP_non_veg: 3197, FP_non_veg: 0, FN_non_veg: 13187, IoU_non_veg: 0.1951
# Image 330:
# TP_veg: 12288, FP_veg: 0, FN_veg: 4096, IoU_veg: 0.7500
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 331:
# TP_veg: 3200, FP_veg: 0, FN_veg: 2373, IoU_veg: 0.5742
# TP_non_veg: 10811, FP_non_veg: 0, FN_non_veg: 5573, IoU_non_veg: 0.6599
# Image 332:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 333:
# TP_veg: 42, FP_veg: 2, FN_veg: 338, IoU_veg: 0.1099
# TP_non_veg: 16004, FP_non_veg: 2, FN_non_veg: 380, IoU_non_veg: 0.9767
# Image 334:
# TP_veg: 1449, FP_veg: 0, FN_veg: 1640, IoU_veg: 0.4691
# TP_non_veg: 13295, FP_non_veg: 0, FN_non_veg: 3089, IoU_non_veg: 0.8115
# Image 335:
# TP_veg: 2102, FP_veg: 3, FN_veg: 1671, IoU_veg: 0.5567
# TP_non_veg: 12611, FP_non_veg: 3, FN_non_veg: 3773, IoU_non_veg: 0.7696
# Image 336:
# TP_veg: 618, FP_veg: 37, FN_veg: 1076, IoU_veg: 0.3570
# TP_non_veg: 14690, FP_non_veg: 37, FN_non_veg: 1694, IoU_non_veg: 0.8946
# Image 337:
# TP_veg: 14305, FP_veg: 1, FN_veg: 1460, IoU_veg: 0.9073
# TP_non_veg: 619, FP_non_veg: 1, FN_non_veg: 15765, IoU_non_veg: 0.0378
# Image 338:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 339:
# TP_veg: 9178, FP_veg: 0, FN_veg: 7206, IoU_veg: 0.5602
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 340:
# TP_veg: 7798, FP_veg: 89, FN_veg: 2216, IoU_veg: 0.7718
# TP_non_veg: 6370, FP_non_veg: 89, FN_non_veg: 10014, IoU_non_veg: 0.3867
# Image 341:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 342:
# TP_veg: 3991, FP_veg: 1, FN_veg: 686, IoU_veg: 0.8531
# TP_non_veg: 11707, FP_non_veg: 1, FN_non_veg: 4677, IoU_non_veg: 0.7145
# Image 343:
# TP_veg: 656, FP_veg: 14, FN_veg: 1092, IoU_veg: 0.3723
# TP_non_veg: 14636, FP_non_veg: 14, FN_non_veg: 1748, IoU_non_veg: 0.8925
# Image 344:
# TP_veg: 2649, FP_veg: 0, FN_veg: 5801, IoU_veg: 0.3135
# TP_non_veg: 7934, FP_non_veg: 0, FN_non_veg: 8450, IoU_non_veg: 0.4843
# Image 345:
# TP_veg: 0, FP_veg: 0, FN_veg: 1453, IoU_veg: 0.0000
# TP_non_veg: 14931, FP_non_veg: 0, FN_non_veg: 1453, IoU_non_veg: 0.9113
# Image 346:
# TP_veg: 0, FP_veg: 0, FN_veg: 57, IoU_veg: 0.0000
# TP_non_veg: 16327, FP_non_veg: 0, FN_non_veg: 57, IoU_non_veg: 0.9965
# Image 347:
# TP_veg: 0, FP_veg: 0, FN_veg: 264, IoU_veg: 0.0000
# TP_non_veg: 16120, FP_non_veg: 0, FN_non_veg: 264, IoU_non_veg: 0.9839
# Image 348:
# TP_veg: 0, FP_veg: 0, FN_veg: 156, IoU_veg: 0.0000
# TP_non_veg: 16228, FP_non_veg: 0, FN_non_veg: 156, IoU_non_veg: 0.9905
# Image 349:
# TP_veg: 107, FP_veg: 7, FN_veg: 609, IoU_veg: 0.1480
# TP_non_veg: 15668, FP_non_veg: 7, FN_non_veg: 716, IoU_non_veg: 0.9559
# Image 350:
# TP_veg: 7362, FP_veg: 6, FN_veg: 896, IoU_veg: 0.8909
# TP_non_veg: 8126, FP_non_veg: 6, FN_non_veg: 8258, IoU_non_veg: 0.4958
# Image 351:
# TP_veg: 15052, FP_veg: 0, FN_veg: 1332, IoU_veg: 0.9187
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 352:
# TP_veg: 0, FP_veg: 0, FN_veg: 111, IoU_veg: 0.0000
# ...
# Image 388:
# TP_veg: 1124, FP_veg: 30, FN_veg: 777, IoU_veg: 0.5821
# TP_non_veg: 14483, FP_non_veg: 30, FN_non_veg: 1901, IoU_non_veg: 0.8824
# Image 389:
# TP_veg: 0, FP_veg: 0, FN_veg: 994, IoU_veg: 0.0000
# TP_non_veg: 15390, FP_non_veg: 0, FN_non_veg: 994, IoU_non_veg: 0.9393
# Image 390:
# TP_veg: 4490, FP_veg: 92, FN_veg: 1762, IoU_veg: 0.7078
# TP_non_veg: 10132, FP_non_veg: 92, FN_non_veg: 6252, IoU_non_veg: 0.6150
# Image 391:
# TP_veg: 4078, FP_veg: 35, FN_veg: 2525, IoU_veg: 0.6143
# TP_non_veg: 9781, FP_non_veg: 35, FN_non_veg: 6603, IoU_non_veg: 0.5957
# Image 392:
# TP_veg: 15552, FP_veg: 0, FN_veg: 832, IoU_veg: 0.9492
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 393:
# TP_veg: 12106, FP_veg: 0, FN_veg: 4278, IoU_veg: 0.7389
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 394:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 395:
# TP_veg: 6487, FP_veg: 0, FN_veg: 9897, IoU_veg: 0.3959
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 396:
# TP_veg: 12509, FP_veg: 0, FN_veg: 3874, IoU_veg: 0.7635
# TP_non_veg: 1, FP_non_veg: 0, FN_non_veg: 16383, IoU_non_veg: 0.0001
# Image 397:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 398:
# TP_veg: 9250, FP_veg: 0, FN_veg: 1925, IoU_veg: 0.8277
# TP_non_veg: 5209, FP_non_veg: 0, FN_non_veg: 11175, IoU_non_veg: 0.3179
# Image 399:
# TP_veg: 1068, FP_veg: 0, FN_veg: 661, IoU_veg: 0.6177
# TP_non_veg: 14655, FP_non_veg: 0, FN_non_veg: 1729, IoU_non_veg: 0.8945
# Image 400:
# TP_veg: 50, FP_veg: 0, FN_veg: 1734, IoU_veg: 0.0280
# TP_non_veg: 14600, FP_non_veg: 0, FN_non_veg: 1784, IoU_non_veg: 0.8911
# Image 401:
# TP_veg: 1358, FP_veg: 17, FN_veg: 1222, IoU_veg: 0.5229
# TP_non_veg: 13804, FP_non_veg: 17, FN_non_veg: 2580, IoU_non_veg: 0.8417
# Image 402:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 403:
# TP_veg: 0, FP_veg: 0, FN_veg: 739, IoU_veg: 0.0000
# TP_non_veg: 15645, FP_non_veg: 0, FN_non_veg: 739, IoU_non_veg: 0.9549
# Image 404:
# TP_veg: 1873, FP_veg: 0, FN_veg: 1383, IoU_veg: 0.5752
# TP_non_veg: 13128, FP_non_veg: 0, FN_non_veg: 3256, IoU_non_veg: 0.8013
# Image 405:
# TP_veg: 8573, FP_veg: 68, FN_veg: 1657, IoU_veg: 0.8325
# TP_non_veg: 6154, FP_non_veg: 68, FN_non_veg: 10230, IoU_non_veg: 0.3741
# Image 406:
# TP_veg: 11316, FP_veg: 0, FN_veg: 5068, IoU_veg: 0.6907
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 407:
# TP_veg: 11999, FP_veg: 0, FN_veg: 4385, IoU_veg: 0.7324
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 408:
# TP_veg: 2963, FP_veg: 0, FN_veg: 741, IoU_veg: 0.7999
# TP_non_veg: 12680, FP_non_veg: 0, FN_non_veg: 3704, IoU_non_veg: 0.7739
# Image 409:
# TP_veg: 3399, FP_veg: 73, FN_veg: 4369, IoU_veg: 0.4335
# TP_non_veg: 8616, FP_non_veg: 73, FN_non_veg: 7768, IoU_non_veg: 0.5235
# Image 410:
# TP_veg: 11694, FP_veg: 0, FN_veg: 2607, IoU_veg: 0.8177
# TP_non_veg: 2083, FP_non_veg: 0, FN_non_veg: 14301, IoU_non_veg: 0.1271
# Image 411:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 412:
# TP_veg: 15314, FP_veg: 0, FN_veg: 1070, IoU_veg: 0.9347
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 413:
# TP_veg: 1547, FP_veg: 0, FN_veg: 1182, IoU_veg: 0.5669
# TP_non_veg: 13655, FP_non_veg: 0, FN_non_veg: 2729, IoU_non_veg: 0.8334
# Image 414:
# TP_veg: 455, FP_veg: 0, FN_veg: 2017, IoU_veg: 0.1841
# TP_non_veg: 13912, FP_non_veg: 0, FN_non_veg: 2472, IoU_non_veg: 0.8491
# Image 415:
# TP_veg: 7081, FP_veg: 12, FN_veg: 8537, IoU_veg: 0.4530
# TP_non_veg: 766, FP_non_veg: 12, FN_non_veg: 15618, IoU_non_veg: 0.0467
# Image 416:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 417:
# TP_veg: 0, FP_veg: 0, FN_veg: 87, IoU_veg: 0.0000
# TP_non_veg: 16297, FP_non_veg: 0, FN_non_veg: 87, IoU_non_veg: 0.9947
# Image 418:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 419:
# TP_veg: 2061, FP_veg: 0, FN_veg: 1426, IoU_veg: 0.5911
# TP_non_veg: 12897, FP_non_veg: 0, FN_non_veg: 3487, IoU_non_veg: 0.7872
# Image 420:
# TP_veg: 7711, FP_veg: 23, FN_veg: 4351, IoU_veg: 0.6381
# TP_non_veg: 4322, FP_non_veg: 23, FN_non_veg: 12062, IoU_non_veg: 0.2634
# Image 421:
# TP_veg: 4726, FP_veg: 92, FN_veg: 1114, IoU_veg: 0.7967
# TP_non_veg: 10544, FP_non_veg: 92, FN_non_veg: 5840, IoU_non_veg: 0.6400
# Image 422:
# TP_veg: 0, FP_veg: 0, FN_veg: 2442, IoU_veg: 0.0000
# TP_non_veg: 13942, FP_non_veg: 0, FN_non_veg: 2442, IoU_non_veg: 0.8510
# Image 423:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 424:
# TP_veg: 1987, FP_veg: 0, FN_veg: 3671, IoU_veg: 0.3512
# TP_non_veg: 10726, FP_non_veg: 0, FN_non_veg: 5658, IoU_non_veg: 0.6547
# Image 425:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 426:
# TP_veg: 8055, FP_veg: 0, FN_veg: 8281, IoU_veg: 0.4931
# TP_non_veg: 48, FP_non_veg: 0, FN_non_veg: 16336, IoU_non_veg: 0.0029
# Image 427:
# TP_veg: 6803, FP_veg: 0, FN_veg: 9570, IoU_veg: 0.4155
# TP_non_veg: 11, FP_non_veg: 0, FN_non_veg: 16373, IoU_non_veg: 0.0007
# Image 428:
# TP_veg: 2324, FP_veg: 2, FN_veg: 4040, IoU_veg: 0.3651
# TP_non_veg: 10020, FP_non_veg: 2, FN_non_veg: 6364, IoU_non_veg: 0.6115
# Image 429:
# TP_veg: 6910, FP_veg: 0, FN_veg: 8677, IoU_veg: 0.4433
# TP_non_veg: 797, FP_non_veg: 0, FN_non_veg: 15587, IoU_non_veg: 0.0486
# Image 430:
# TP_veg: 3613, FP_veg: 50, FN_veg: 3476, IoU_veg: 0.5061
# TP_non_veg: 9295, FP_non_veg: 50, FN_non_veg: 7089, IoU_non_veg: 0.5656
# Image 431:
# TP_veg: 6009, FP_veg: 98, FN_veg: 4744, IoU_veg: 0.5538
# TP_non_veg: 5631, FP_non_veg: 98, FN_non_veg: 10753, IoU_non_veg: 0.3416
# Image 432:
# TP_veg: 11805, FP_veg: 0, FN_veg: 4260, IoU_veg: 0.7348
# TP_non_veg: 319, FP_non_veg: 0, FN_non_veg: 16065, IoU_non_veg: 0.0195
# Image 433:
# TP_veg: 6648, FP_veg: 0, FN_veg: 9736, IoU_veg: 0.4058
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 434:
# TP_veg: 11073, FP_veg: 0, FN_veg: 5311, IoU_veg: 0.6758
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 435:
# TP_veg: 5329, FP_veg: 2, FN_veg: 1402, IoU_veg: 0.7915
# TP_non_veg: 9653, FP_non_veg: 2, FN_non_veg: 6731, IoU_non_veg: 0.5891
# Image 436:
# TP_veg: 0, FP_veg: 0, FN_veg: 278, IoU_veg: 0.0000
# TP_non_veg: 16106, FP_non_veg: 0, FN_non_veg: 278, IoU_non_veg: 0.9830
# Image 437:
# TP_veg: 0, FP_veg: 0, FN_veg: 336, IoU_veg: 0.0000
# TP_non_veg: 16048, FP_non_veg: 0, FN_non_veg: 336, IoU_non_veg: 0.9795
# Image 438:
# TP_veg: 2482, FP_veg: 0, FN_veg: 6720, IoU_veg: 0.2697
# TP_non_veg: 7182, FP_non_veg: 0, FN_non_veg: 9202, IoU_non_veg: 0.4384
# Image 439:
# TP_veg: 0, FP_veg: 0, FN_veg: 3, IoU_veg: 0.0000
# TP_non_veg: 16381, FP_non_veg: 0, FN_non_veg: 3, IoU_non_veg: 0.9998
# Image 440:
# TP_veg: 5718, FP_veg: 0, FN_veg: 10666, IoU_veg: 0.3490
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 441:
# TP_veg: 6008, FP_veg: 0, FN_veg: 10376, IoU_veg: 0.3667
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 442:
# TP_veg: 10931, FP_veg: 0, FN_veg: 5453, IoU_veg: 0.6672
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 443:
# TP_veg: 14697, FP_veg: 0, FN_veg: 1687, IoU_veg: 0.8970
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 444:
# TP_veg: 5252, FP_veg: 35, FN_veg: 3793, IoU_veg: 0.5784
# TP_non_veg: 7339, FP_non_veg: 35, FN_non_veg: 9045, IoU_non_veg: 0.4470
# Image 445:
# TP_veg: 221, FP_veg: 25, FN_veg: 224, IoU_veg: 0.4702
# TP_non_veg: 15939, FP_non_veg: 25, FN_non_veg: 445, IoU_non_veg: 0.9714
# Image 446:
# TP_veg: 0, FP_veg: 0, FN_veg: 2751, IoU_veg: 0.0000
# TP_non_veg: 13633, FP_non_veg: 0, FN_non_veg: 2751, IoU_non_veg: 0.8321
# Image 447:
# TP_veg: 605, FP_veg: 0, FN_veg: 11800, IoU_veg: 0.0488
# TP_non_veg: 3979, FP_non_veg: 0, FN_non_veg: 12405, IoU_non_veg: 0.2429
# Image 448:
# TP_veg: 13107, FP_veg: 20, FN_veg: 1323, IoU_veg: 0.9071
# TP_non_veg: 1954, FP_non_veg: 20, FN_non_veg: 14430, IoU_non_veg: 0.1191
# Image 449:
# TP_veg: 273, FP_veg: 5, FN_veg: 1543, IoU_veg: 0.1499
# TP_non_veg: 14568, FP_non_veg: 5, FN_non_veg: 1816, IoU_non_veg: 0.8889
# Image 450:
# TP_veg: 0, FP_veg: 0, FN_veg: 186, IoU_veg: 0.0000
# TP_non_veg: 16198, FP_non_veg: 0, FN_non_veg: 186, IoU_non_veg: 0.9886
# Image 451:
# TP_veg: 0, FP_veg: 0, FN_veg: 462, IoU_veg: 0.0000
# TP_non_veg: 15922, FP_non_veg: 0, FN_non_veg: 462, IoU_non_veg: 0.9718
# Image 452:
# TP_veg: 4192, FP_veg: 0, FN_veg: 6105, IoU_veg: 0.4071
# TP_non_veg: 6087, FP_non_veg: 0, FN_non_veg: 10297, IoU_non_veg: 0.3715
# Image 453:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 454:
# TP_veg: 46, FP_veg: 0, FN_veg: 7689, IoU_veg: 0.0059
# TP_non_veg: 8649, FP_non_veg: 0, FN_non_veg: 7735, IoU_non_veg: 0.5279
# Image 455:
# TP_veg: 8510, FP_veg: 0, FN_veg: 7874, IoU_veg: 0.5194
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 456:
# TP_veg: 16376, FP_veg: 0, FN_veg: 8, IoU_veg: 0.9995
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 457:
# TP_veg: 11468, FP_veg: 0, FN_veg: 4916, IoU_veg: 0.7000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 458:
# TP_veg: 226, FP_veg: 0, FN_veg: 3642, IoU_veg: 0.0584
# TP_non_veg: 12516, FP_non_veg: 0, FN_non_veg: 3868, IoU_non_veg: 0.7639
# Image 459:
# TP_veg: 4913, FP_veg: 94, FN_veg: 3958, IoU_veg: 0.5480
# TP_non_veg: 7513, FP_non_veg: 94, FN_non_veg: 8871, IoU_non_veg: 0.4559
# Image 460:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 461:
# TP_veg: 132, FP_veg: 0, FN_veg: 306, IoU_veg: 0.3014
# TP_non_veg: 15946, FP_non_veg: 0, FN_non_veg: 438, IoU_non_veg: 0.9733
# Image 462:
# TP_veg: 2448, FP_veg: 60, FN_veg: 253, IoU_veg: 0.8866
# TP_non_veg: 13683, FP_non_veg: 60, FN_non_veg: 2701, IoU_non_veg: 0.8321
# Image 463:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 464:
# TP_veg: 35, FP_veg: 0, FN_veg: 823, IoU_veg: 0.0408
# TP_non_veg: 15526, FP_non_veg: 0, FN_non_veg: 858, IoU_non_veg: 0.9476
# Image 465:
# TP_veg: 9648, FP_veg: 5, FN_veg: 3970, IoU_veg: 0.7082
# TP_non_veg: 2766, FP_non_veg: 5, FN_non_veg: 13618, IoU_non_veg: 0.1688
# Image 466:
# TP_veg: 6041, FP_veg: 10, FN_veg: 5703, IoU_veg: 0.5140
# TP_non_veg: 4640, FP_non_veg: 10, FN_non_veg: 11744, IoU_non_veg: 0.2830
# Image 467:
# TP_veg: 792, FP_veg: 0, FN_veg: 830, IoU_veg: 0.4883
# TP_non_veg: 14762, FP_non_veg: 0, FN_non_veg: 1622, IoU_non_veg: 0.9010
# Image 468:
# TP_veg: 10291, FP_veg: 0, FN_veg: 5314, IoU_veg: 0.6595
# TP_non_veg: 779, FP_non_veg: 0, FN_non_veg: 15605, IoU_non_veg: 0.0475
# Image 469:
# TP_veg: 14263, FP_veg: 0, FN_veg: 2121, IoU_veg: 0.8705
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 470:
# TP_veg: 16384, FP_veg: 0, FN_veg: 0, IoU_veg: 1.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 471:
# TP_veg: 13086, FP_veg: 0, FN_veg: 3298, IoU_veg: 0.7987
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 472:
# TP_veg: 1551, FP_veg: 0, FN_veg: 3781, IoU_veg: 0.2909
# TP_non_veg: 11052, FP_non_veg: 0, FN_non_veg: 5332, IoU_non_veg: 0.6746
# Image 473:
# TP_veg: 1074, FP_veg: 1, FN_veg: 2137, IoU_veg: 0.3344
# TP_non_veg: 13173, FP_non_veg: 1, FN_non_veg: 3211, IoU_non_veg: 0.8040
# Image 474:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 475:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 476:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 477:
# TP_veg: 283, FP_veg: 0, FN_veg: 1523, IoU_veg: 0.1567
# TP_non_veg: 14578, FP_non_veg: 0, FN_non_veg: 1806, IoU_non_veg: 0.8898
# Image 478:
# TP_veg: 451, FP_veg: 0, FN_veg: 720, IoU_veg: 0.3851
# TP_non_veg: 15213, FP_non_veg: 0, FN_non_veg: 1171, IoU_non_veg: 0.9285
# Image 479:
# TP_veg: 10782, FP_veg: 0, FN_veg: 2675, IoU_veg: 0.8012
# TP_non_veg: 2927, FP_non_veg: 0, FN_non_veg: 13457, IoU_non_veg: 0.1786
# Image 480:
# TP_veg: 7036, FP_veg: 0, FN_veg: 9348, IoU_veg: 0.4294
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 481:
# TP_veg: 0, FP_veg: 0, FN_veg: 2842, IoU_veg: 0.0000
# TP_non_veg: 13542, FP_non_veg: 0, FN_non_veg: 2842, IoU_non_veg: 0.8265
# Image 482:
# TP_veg: 14047, FP_veg: 0, FN_veg: 2337, IoU_veg: 0.8574
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 483:
# TP_veg: 13797, FP_veg: 0, FN_veg: 2587, IoU_veg: 0.8421
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 484:
# TP_veg: 13990, FP_veg: 0, FN_veg: 2394, IoU_veg: 0.8539
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 485:
# TP_veg: 4988, FP_veg: 0, FN_veg: 11396, IoU_veg: 0.3044
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 486:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 487:
# TP_veg: 611, FP_veg: 0, FN_veg: 222, IoU_veg: 0.7335
# TP_non_veg: 15551, FP_non_veg: 0, FN_non_veg: 833, IoU_non_veg: 0.9492
# Image 488:
# TP_veg: 1292, FP_veg: 61, FN_veg: 2661, IoU_veg: 0.3219
# TP_non_veg: 12431, FP_non_veg: 61, FN_non_veg: 3953, IoU_non_veg: 0.7559
# Image 489:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 490:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 491:
# TP_veg: 2699, FP_veg: 12, FN_veg: 2044, IoU_veg: 0.5676
# TP_non_veg: 11641, FP_non_veg: 12, FN_non_veg: 4743, IoU_non_veg: 0.7100
# Image 492:
# TP_veg: 203, FP_veg: 0, FN_veg: 378, IoU_veg: 0.3494
# TP_non_veg: 15803, FP_non_veg: 0, FN_non_veg: 581, IoU_non_veg: 0.9645
# Image 493:
# TP_veg: 11, FP_veg: 0, FN_veg: 936, IoU_veg: 0.0116
# TP_non_veg: 15437, FP_non_veg: 0, FN_non_veg: 947, IoU_non_veg: 0.9422
# Image 494:
# TP_veg: 12364, FP_veg: 0, FN_veg: 1796, IoU_veg: 0.8732
# TP_non_veg: 2224, FP_non_veg: 0, FN_non_veg: 14160, IoU_non_veg: 0.1357
# Image 495:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 496:
# TP_veg: 13693, FP_veg: 0, FN_veg: 2691, IoU_veg: 0.8358
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 497:
# TP_veg: 16165, FP_veg: 0, FN_veg: 219, IoU_veg: 0.9866
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 498:
# TP_veg: 7259, FP_veg: 0, FN_veg: 9125, IoU_veg: 0.4431
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 499:
# TP_veg: 6204, FP_veg: 0, FN_veg: 10180, IoU_veg: 0.3787
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 500:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 501:
# TP_veg: 1, FP_veg: 0, FN_veg: 35, IoU_veg: 0.0278
# TP_non_veg: 16348, FP_non_veg: 0, FN_non_veg: 36, IoU_non_veg: 0.9978
# Image 502:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 503:
# TP_veg: 1268, FP_veg: 6, FN_veg: 2920, IoU_veg: 0.3023
# TP_non_veg: 12196, FP_non_veg: 6, FN_non_veg: 4188, IoU_non_veg: 0.7441
# Image 504:
# TP_veg: 396, FP_veg: 0, FN_veg: 2066, IoU_veg: 0.1608
# TP_non_veg: 13922, FP_non_veg: 0, FN_non_veg: 2462, IoU_non_veg: 0.8497
# Image 505:
# TP_veg: 205, FP_veg: 0, FN_veg: 480, IoU_veg: 0.2993
# TP_non_veg: 15699, FP_non_veg: 0, FN_non_veg: 685, IoU_non_veg: 0.9582

# %%
# Initialize lists for TP, FP, FN, TN, and IoU
TP_vegetation = []
FP_vegetation = []
FN_vegetation = []
TN_vegetation = []

TP_non_vegetation = []
FP_non_vegetation = []
FN_non_vegetation = []
TN_non_vegetation = []

# Loop over testing images
for i in range(len(image_test)):
    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN, TN counts for both vegetation and non-vegetation classes
    TP_veg = np.sum(np.logical_and(vegetation_ground_truth, predicted_mask))
    FP_veg = np.sum(predicted_mask & ~vegetation_ground_truth)
    FN_veg = np.sum(vegetation_ground_truth & ~predicted_mask)
    TN_veg = np.sum(~vegetation_ground_truth & ~predicted_mask)
    
    TP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, ~predicted_mask))
    FP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, predicted_mask))
    FN_non_veg = np.sum(np.logical_and(vegetation_ground_truth, ~predicted_mask))
    TN_non_veg = np.sum(vegetation_ground_truth & predicted_mask)

    # Append TP, FP, FN, TN counts for vegetation and non-vegetation classes
    TP_vegetation.append(TP_veg)
    FP_vegetation.append(FP_veg)
    FN_vegetation.append(FN_veg)
    TN_vegetation.append(TN_veg)
    
    TP_non_vegetation.append(TP_non_veg)
    FP_non_vegetation.append(FP_non_veg)
    FN_non_vegetation.append(FN_non_veg)
    TN_non_vegetation.append(TN_non_veg)

    # Print the confusion matrix for this image
    print("============================================================================================")
    print("Confusion Matrix for Image {}:".format(i+1))
    print("\t\t\tPredicted Vegetation\tPredicted Non-Vegetation")
    print("Actual Vegetation\t\t{}\t\t\t{}".format(TP_veg, FP_non_veg))
    print("Actual Non-Vegetation\t\t{}\t\t\t{}".format(FN_veg, TN_non_veg))
    print()
    print("TP_Vegetation:{},\t FP_Vegetation:{},     FN_Vegetation:{},      TN_Vegetation:{}".format(TP_veg,FP_veg,FN_veg,TN_veg))  
    print("TP_Non_Vegetation:{}, FP_Non_Vegetation:{}, FN_Non_Vegetation:{}, TN_Non_Vegetation:{}".format(TP_non_veg,FP_non_veg,FN_non_veg,TN_non_veg))
# Out:
# ============================================================================================
# Confusion Matrix for Image 1:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1164			0
# Actual Non-Vegetation		3295			1164
#
# TP_Vegetation:1164,	 FP_Vegetation:0,     FN_Vegetation:3295,      TN_Vegetation:11925
# TP_Non_Vegetation:11925, FP_Non_Vegetation:0, FN_Non_Vegetation:4459, TN_Non_Vegetation:1164
# ============================================================================================
# Confusion Matrix for Image 2:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		9684			0
# Actual Non-Vegetation		4256			9684
#
# TP_Vegetation:9684,	 FP_Vegetation:0,     FN_Vegetation:4256,      TN_Vegetation:2444
# TP_Non_Vegetation:2444, FP_Non_Vegetation:0, FN_Non_Vegetation:13940, TN_Non_Vegetation:9684
# ============================================================================================
# Confusion Matrix for Image 3:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2628			0
# Actual Non-Vegetation		3267			2628
#
# TP_Vegetation:2628,	 FP_Vegetation:0,     FN_Vegetation:3267,      TN_Vegetation:10489
# TP_Non_Vegetation:10489, FP_Non_Vegetation:0, FN_Non_Vegetation:5895, TN_Non_Vegetation:2628
# ============================================================================================
# Confusion Matrix for Image 4:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1678			0
# Actual Non-Vegetation		5614			1678
#
# TP_Vegetation:1678,	 FP_Vegetation:0,     FN_Vegetation:5614,      TN_Vegetation:9092
# TP_Non_Vegetation:9092, FP_Non_Vegetation:0, FN_Non_Vegetation:7292, TN_Non_Vegetation:1678
# ============================================================================================
# Confusion Matrix for Image 5:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 6:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		559			0
# Actual Non-Vegetation		250			559
#
# TP_Vegetation:559,	 FP_Vegetation:0,     FN_Vegetation:250,      TN_Vegetation:15575
# TP_Non_Vegetation:15575, FP_Non_Vegetation:0, FN_Non_Vegetation:809, TN_Non_Vegetation:559
# ============================================================================================
# Confusion Matrix for Image 7:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1407			3
# Actual Non-Vegetation		646			1407
#
# TP_Vegetation:1407,	 FP_Vegetation:3,     FN_Vegetation:646,      TN_Vegetation:14328
# TP_Non_Vegetation:14331, FP_Non_Vegetation:3, FN_Non_Vegetation:2053, TN_Non_Vegetation:1407
# ============================================================================================
# Confusion Matrix for Image 8:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		88			0
# Actual Non-Vegetation		92			88
#
# TP_Vegetation:88,	 FP_Vegetation:0,     FN_Vegetation:92,      TN_Vegetation:16204
# TP_Non_Vegetation:16204, FP_Non_Vegetation:0, FN_Non_Vegetation:180, TN_Non_Vegetation:88
# ============================================================================================
# Confusion Matrix for Image 9:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		5162			0
# Actual Non-Vegetation		3731			5162
#
# TP_Vegetation:5162,	 FP_Vegetation:0,     FN_Vegetation:3731,      TN_Vegetation:7491
# TP_Non_Vegetation:7491, FP_Non_Vegetation:0, FN_Non_Vegetation:8893, TN_Non_Vegetation:5162
# ============================================================================================
# Confusion Matrix for Image 10:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1299			0
# Actual Non-Vegetation		5971			1299
#
# TP_Vegetation:1299,	 FP_Vegetation:0,     FN_Vegetation:5971,      TN_Vegetation:9114
# TP_Non_Vegetation:9114, FP_Non_Vegetation:0, FN_Non_Vegetation:7270, TN_Non_Vegetation:1299
# ============================================================================================
# Confusion Matrix for Image 11:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2598			0
# Actual Non-Vegetation		1366			2598
#
# TP_Vegetation:2598,	 FP_Vegetation:0,     FN_Vegetation:1366,      TN_Vegetation:12420
# TP_Non_Vegetation:12420, FP_Non_Vegetation:0, FN_Non_Vegetation:3964, TN_Non_Vegetation:2598
# ============================================================================================
# Confusion Matrix for Image 12:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		552			0
# Actual Non-Vegetation		3059			552
#
# TP_Vegetation:552,	 FP_Vegetation:0,     FN_Vegetation:3059,      TN_Vegetation:12773
# TP_Non_Vegetation:12773, FP_Non_Vegetation:0, FN_Non_Vegetation:3611, TN_Non_Vegetation:552
# ============================================================================================
# Confusion Matrix for Image 13:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		1			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:1,      TN_Vegetation:16383
# TP_Non_Vegetation:16383, FP_Non_Vegetation:0, FN_Non_Vegetation:1, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 14:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		3989			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:3989,      TN_Vegetation:12395
# TP_Non_Vegetation:12395, FP_Non_Vegetation:0, FN_Non_Vegetation:3989, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 15:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4793			0
# Actual Non-Vegetation		2651			4793
#
# TP_Vegetation:4793,	 FP_Vegetation:0,     FN_Vegetation:2651,      TN_Vegetation:8940
# TP_Non_Vegetation:8940, FP_Non_Vegetation:0, FN_Non_Vegetation:7444, TN_Non_Vegetation:4793
# ============================================================================================
# Confusion Matrix for Image 16:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6580			0
# Actual Non-Vegetation		3867			6580
#
# TP_Vegetation:6580,	 FP_Vegetation:0,     FN_Vegetation:3867,      TN_Vegetation:5937
# TP_Non_Vegetation:5937, FP_Non_Vegetation:0, FN_Non_Vegetation:10447, TN_Non_Vegetation:6580
# ============================================================================================
# Confusion Matrix for Image 17:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6706			198
# Actual Non-Vegetation		1871			6706
#
# TP_Vegetation:6706,	 FP_Vegetation:198,     FN_Vegetation:1871,      TN_Vegetation:7609
# TP_Non_Vegetation:7807, FP_Non_Vegetation:198, FN_Non_Vegetation:8577, TN_Non_Vegetation:6706
# ============================================================================================
# Confusion Matrix for Image 18:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		7433			13
# Actual Non-Vegetation		4332			7433
#
# TP_Vegetation:7433,	 FP_Vegetation:13,     FN_Vegetation:4332,      TN_Vegetation:4606
# TP_Non_Vegetation:4619, FP_Non_Vegetation:13, FN_Non_Vegetation:11765, TN_Non_Vegetation:7433
# ============================================================================================
# Confusion Matrix for Image 19:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			21
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:21,     FN_Vegetation:0,      TN_Vegetation:16363
# TP_Non_Vegetation:16384, FP_Non_Vegetation:21, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 20:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		32			8
# Actual Non-Vegetation		3			32
#
# TP_Vegetation:32,	 FP_Vegetation:8,     FN_Vegetation:3,      TN_Vegetation:16341
# TP_Non_Vegetation:16349, FP_Non_Vegetation:8, FN_Non_Vegetation:35, TN_Non_Vegetation:32
# ============================================================================================
# Confusion Matrix for Image 21:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 22:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		5038			0
# Actual Non-Vegetation		9198			5038
#
# TP_Vegetation:5038,	 FP_Vegetation:0,     FN_Vegetation:9198,      TN_Vegetation:2148
# TP_Non_Vegetation:2148, FP_Non_Vegetation:0, FN_Non_Vegetation:14236, TN_Non_Vegetation:5038
# ============================================================================================
# Confusion Matrix for Image 23:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		5387			1
# Actual Non-Vegetation		5399			5387
#
# TP_Vegetation:5387,	 FP_Vegetation:1,     FN_Vegetation:5399,      TN_Vegetation:5597
# TP_Non_Vegetation:5598, FP_Non_Vegetation:1, FN_Non_Vegetation:10786, TN_Non_Vegetation:5387
# ============================================================================================
# Confusion Matrix for Image 24:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		907			5
# Actual Non-Vegetation		1354			907
#
# TP_Vegetation:907,	 FP_Vegetation:5,     FN_Vegetation:1354,      TN_Vegetation:14118
# TP_Non_Vegetation:14123, FP_Non_Vegetation:5, FN_Non_Vegetation:2261, TN_Non_Vegetation:907
# ============================================================================================
# Confusion Matrix for Image 25:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1266			26
# Actual Non-Vegetation		7210			1266
#
# TP_Vegetation:1266,	 FP_Vegetation:26,     FN_Vegetation:7210,      TN_Vegetation:7882
# TP_Non_Vegetation:7908, FP_Non_Vegetation:26, FN_Non_Vegetation:8476, TN_Non_Vegetation:1266
# ============================================================================================
# Confusion Matrix for Image 26:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1118			14
# Actual Non-Vegetation		1256			1118
#
# TP_Vegetation:1118,	 FP_Vegetation:14,     FN_Vegetation:1256,      TN_Vegetation:13996
# TP_Non_Vegetation:14010, FP_Non_Vegetation:14, FN_Non_Vegetation:2374, TN_Non_Vegetation:1118
# ============================================================================================
# Confusion Matrix for Image 27:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		5560			5
# Actual Non-Vegetation		4354			5560
#
# TP_Vegetation:5560,	 FP_Vegetation:5,     FN_Vegetation:4354,      TN_Vegetation:6465
# TP_Non_Vegetation:6470, FP_Non_Vegetation:5, FN_Non_Vegetation:9914, TN_Non_Vegetation:5560
# ============================================================================================
# Confusion Matrix for Image 28:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1			0
# Actual Non-Vegetation		13786			1
#
# TP_Vegetation:1,	 FP_Vegetation:0,     FN_Vegetation:13786,      TN_Vegetation:2597
# TP_Non_Vegetation:2597, FP_Non_Vegetation:0, FN_Non_Vegetation:13787, TN_Non_Vegetation:1
# ============================================================================================
# Confusion Matrix for Image 29:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1737			3
# Actual Non-Vegetation		6288			1737
#
# TP_Vegetation:1737,	 FP_Vegetation:3,     FN_Vegetation:6288,      TN_Vegetation:8356
# TP_Non_Vegetation:8359, FP_Non_Vegetation:3, FN_Non_Vegetation:8025, TN_Non_Vegetation:1737
# ============================================================================================
# Confusion Matrix for Image 30:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2722			0
# Actual Non-Vegetation		6253			2722
#
# TP_Vegetation:2722,	 FP_Vegetation:0,     FN_Vegetation:6253,      TN_Vegetation:7409
# TP_Non_Vegetation:7409, FP_Non_Vegetation:0, FN_Non_Vegetation:8975, TN_Non_Vegetation:2722
# ============================================================================================
# Confusion Matrix for Image 31:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3772			0
# Actual Non-Vegetation		8910			3772
#
# TP_Vegetation:3772,	 FP_Vegetation:0,     FN_Vegetation:8910,      TN_Vegetation:3702
# TP_Non_Vegetation:3702, FP_Non_Vegetation:0, FN_Non_Vegetation:12682, TN_Non_Vegetation:3772
# ============================================================================================
# Confusion Matrix for Image 32:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2483			0
# Actual Non-Vegetation		4517			2483
#
# TP_Vegetation:2483,	 FP_Vegetation:0,     FN_Vegetation:4517,      TN_Vegetation:9384
# TP_Non_Vegetation:9384, FP_Non_Vegetation:0, FN_Non_Vegetation:7000, TN_Non_Vegetation:2483
# ============================================================================================
# Confusion Matrix for Image 33:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3553			5
# Actual Non-Vegetation		7216			3553
#
# TP_Vegetation:3553,	 FP_Vegetation:5,     FN_Vegetation:7216,      TN_Vegetation:5610
# TP_Non_Vegetation:5615, FP_Non_Vegetation:5, FN_Non_Vegetation:10769, TN_Non_Vegetation:3553
# ============================================================================================
# Confusion Matrix for Image 34:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6071			0
# Actual Non-Vegetation		6988			6071
#
# TP_Vegetation:6071,	 FP_Vegetation:0,     FN_Vegetation:6988,      TN_Vegetation:3325
# TP_Non_Vegetation:3325, FP_Non_Vegetation:0, FN_Non_Vegetation:13059, TN_Non_Vegetation:6071
# ============================================================================================
# Confusion Matrix for Image 35:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		5509			38
# Actual Non-Vegetation		6773			5509
#
# TP_Vegetation:5509,	 FP_Vegetation:38,     FN_Vegetation:6773,      TN_Vegetation:4064
# TP_Non_Vegetation:4102, FP_Non_Vegetation:38, FN_Non_Vegetation:12282, TN_Non_Vegetation:5509
# ============================================================================================
# Confusion Matrix for Image 36:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2359			24
# Actual Non-Vegetation		8842			2359
#
# TP_Vegetation:2359,	 FP_Vegetation:24,     FN_Vegetation:8842,      TN_Vegetation:5159
# TP_Non_Vegetation:5183, FP_Non_Vegetation:24, FN_Non_Vegetation:11201, TN_Non_Vegetation:2359
# ============================================================================================
# Confusion Matrix for Image 37:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2936			0
# Actual Non-Vegetation		1963			2936
#
# TP_Vegetation:2936,	 FP_Vegetation:0,     FN_Vegetation:1963,      TN_Vegetation:11485
# TP_Non_Vegetation:11485, FP_Non_Vegetation:0, FN_Non_Vegetation:4899, TN_Non_Vegetation:2936
# ============================================================================================
# Confusion Matrix for Image 38:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6713			7
# Actual Non-Vegetation		3101			6713
#
# TP_Vegetation:6713,	 FP_Vegetation:7,     FN_Vegetation:3101,      TN_Vegetation:6563
# TP_Non_Vegetation:6570, FP_Non_Vegetation:7, FN_Non_Vegetation:9814, TN_Non_Vegetation:6713
# ============================================================================================
# Confusion Matrix for Image 39:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3663			9
# Actual Non-Vegetation		3788			3663
#
# TP_Vegetation:3663,	 FP_Vegetation:9,     FN_Vegetation:3788,      TN_Vegetation:8924
# TP_Non_Vegetation:8933, FP_Non_Vegetation:9, FN_Non_Vegetation:7451, TN_Non_Vegetation:3663
# ============================================================================================
# Confusion Matrix for Image 40:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1467			0
# Actual Non-Vegetation		5718			1467
#
# TP_Vegetation:1467,	 FP_Vegetation:0,     FN_Vegetation:5718,      TN_Vegetation:9199
# TP_Non_Vegetation:9199, FP_Non_Vegetation:0, FN_Non_Vegetation:7185, TN_Non_Vegetation:1467
# ============================================================================================
# Confusion Matrix for Image 41:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1150			0
# Actual Non-Vegetation		4392			1150
#
# TP_Vegetation:1150,	 FP_Vegetation:0,     FN_Vegetation:4392,      TN_Vegetation:10842
# TP_Non_Vegetation:10842, FP_Non_Vegetation:0, FN_Non_Vegetation:5542, TN_Non_Vegetation:1150
# ============================================================================================
# Confusion Matrix for Image 42:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		19			1
# Actual Non-Vegetation		2605			19
#
# TP_Vegetation:19,	 FP_Vegetation:1,     FN_Vegetation:2605,      TN_Vegetation:13759
# TP_Non_Vegetation:13760, FP_Non_Vegetation:1, FN_Non_Vegetation:2624, TN_Non_Vegetation:19
# ============================================================================================
# Confusion Matrix for Image 43:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4			0
# Actual Non-Vegetation		1203			4
#
# TP_Vegetation:4,	 FP_Vegetation:0,     FN_Vegetation:1203,      TN_Vegetation:15177
# TP_Non_Vegetation:15177, FP_Non_Vegetation:0, FN_Non_Vegetation:1207, TN_Non_Vegetation:4
# ============================================================================================
# Confusion Matrix for Image 44:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		249			0
# Actual Non-Vegetation		3597			249
#
# TP_Vegetation:249,	 FP_Vegetation:0,     FN_Vegetation:3597,      TN_Vegetation:12538
# TP_Non_Vegetation:12538, FP_Non_Vegetation:0, FN_Non_Vegetation:3846, TN_Non_Vegetation:249
# ============================================================================================
# Confusion Matrix for Image 45:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		342			2
# Actual Non-Vegetation		5118			342
#
# TP_Vegetation:342,	 FP_Vegetation:2,     FN_Vegetation:5118,      TN_Vegetation:10922
# TP_Non_Vegetation:10924, FP_Non_Vegetation:2, FN_Non_Vegetation:5460, TN_Non_Vegetation:342
# ============================================================================================
# Confusion Matrix for Image 46:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		183			0
# Actual Non-Vegetation		2225			183
#
# TP_Vegetation:183,	 FP_Vegetation:0,     FN_Vegetation:2225,      TN_Vegetation:13976
# TP_Non_Vegetation:13976, FP_Non_Vegetation:0, FN_Non_Vegetation:2408, TN_Non_Vegetation:183
# ============================================================================================
# Confusion Matrix for Image 47:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		613			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:613,      TN_Vegetation:15771
# TP_Non_Vegetation:15771, FP_Non_Vegetation:0, FN_Non_Vegetation:613, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 48:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1206			9
# Actual Non-Vegetation		4919			1206
#
# TP_Vegetation:1206,	 FP_Vegetation:9,     FN_Vegetation:4919,      TN_Vegetation:10250
# TP_Non_Vegetation:10259, FP_Non_Vegetation:9, FN_Non_Vegetation:6125, TN_Non_Vegetation:1206
# ============================================================================================
# Confusion Matrix for Image 49:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4655			8
# Actual Non-Vegetation		2470			4655
#
# TP_Vegetation:4655,	 FP_Vegetation:8,     FN_Vegetation:2470,      TN_Vegetation:9251
# TP_Non_Vegetation:9259, FP_Non_Vegetation:8, FN_Non_Vegetation:7125, TN_Non_Vegetation:4655
# ============================================================================================
# Confusion Matrix for Image 50:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2525			3
# Actual Non-Vegetation		4245			2525
#
# TP_Vegetation:2525,	 FP_Vegetation:3,     FN_Vegetation:4245,      TN_Vegetation:9611
# TP_Non_Vegetation:9614, FP_Non_Vegetation:3, FN_Non_Vegetation:6770, TN_Non_Vegetation:2525
# ============================================================================================
# Confusion Matrix for Image 51:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3523			12
# Actual Non-Vegetation		5726			3523
#
# TP_Vegetation:3523,	 FP_Vegetation:12,     FN_Vegetation:5726,      TN_Vegetation:7123
# TP_Non_Vegetation:7135, FP_Non_Vegetation:12, FN_Non_Vegetation:9249, TN_Non_Vegetation:3523
# ============================================================================================
# Confusion Matrix for Image 52:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1035			0
# Actual Non-Vegetation		1676			1035
#
# TP_Vegetation:1035,	 FP_Vegetation:0,     FN_Vegetation:1676,      TN_Vegetation:13673
# TP_Non_Vegetation:13673, FP_Non_Vegetation:0, FN_Non_Vegetation:2711, TN_Non_Vegetation:1035
# ============================================================================================
# Confusion Matrix for Image 53:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4314			0
# Actual Non-Vegetation		3024			4314
#
# TP_Vegetation:4314,	 FP_Vegetation:0,     FN_Vegetation:3024,      TN_Vegetation:9046
# TP_Non_Vegetation:9046, FP_Non_Vegetation:0, FN_Non_Vegetation:7338, TN_Non_Vegetation:4314
# ============================================================================================
# Confusion Matrix for Image 54:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4225			0
# Actual Non-Vegetation		2128			4225
#
# TP_Vegetation:4225,	 FP_Vegetation:0,     FN_Vegetation:2128,      TN_Vegetation:10031
# TP_Non_Vegetation:10031, FP_Non_Vegetation:0, FN_Non_Vegetation:6353, TN_Non_Vegetation:4225
# ============================================================================================
# Confusion Matrix for Image 55:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		209			0
# Actual Non-Vegetation		2435			209
#
# TP_Vegetation:209,	 FP_Vegetation:0,     FN_Vegetation:2435,      TN_Vegetation:13740
# TP_Non_Vegetation:13740, FP_Non_Vegetation:0, FN_Non_Vegetation:2644, TN_Non_Vegetation:209
# ============================================================================================
# Confusion Matrix for Image 56:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		392			0
# Actual Non-Vegetation		2592			392
#
# TP_Vegetation:392,	 FP_Vegetation:0,     FN_Vegetation:2592,      TN_Vegetation:13400
# TP_Non_Vegetation:13400, FP_Non_Vegetation:0, FN_Non_Vegetation:2984, TN_Non_Vegetation:392
# ============================================================================================
# Confusion Matrix for Image 57:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1674			0
# Actual Non-Vegetation		10101			1674
#
# TP_Vegetation:1674,	 FP_Vegetation:0,     FN_Vegetation:10101,      TN_Vegetation:4609
# TP_Non_Vegetation:4609, FP_Non_Vegetation:0, FN_Non_Vegetation:11775, TN_Non_Vegetation:1674
# ============================================================================================
# Confusion Matrix for Image 58:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		6106			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:6106,      TN_Vegetation:10278
# TP_Non_Vegetation:10278, FP_Non_Vegetation:0, FN_Non_Vegetation:6106, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 59:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		119			2
# Actual Non-Vegetation		3004			119
#
# TP_Vegetation:119,	 FP_Vegetation:2,     FN_Vegetation:3004,      TN_Vegetation:13259
# TP_Non_Vegetation:13261, FP_Non_Vegetation:2, FN_Non_Vegetation:3123, TN_Non_Vegetation:119
# ============================================================================================
# Confusion Matrix for Image 60:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4726			0
# Actual Non-Vegetation		11546			4726
#
# TP_Vegetation:4726,	 FP_Vegetation:0,     FN_Vegetation:11546,      TN_Vegetation:112
# TP_Non_Vegetation:112, FP_Non_Vegetation:0, FN_Non_Vegetation:16272, TN_Non_Vegetation:4726
# ============================================================================================
# Confusion Matrix for Image 61:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		167			8
# Actual Non-Vegetation		3195			167
#
# TP_Vegetation:167,	 FP_Vegetation:8,     FN_Vegetation:3195,      TN_Vegetation:13014
# TP_Non_Vegetation:13022, FP_Non_Vegetation:8, FN_Non_Vegetation:3362, TN_Non_Vegetation:167
# ============================================================================================
# Confusion Matrix for Image 62:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		453			0
# Actual Non-Vegetation		1971			453
#
# TP_Vegetation:453,	 FP_Vegetation:0,     FN_Vegetation:1971,      TN_Vegetation:13960
# TP_Non_Vegetation:13960, FP_Non_Vegetation:0, FN_Non_Vegetation:2424, TN_Non_Vegetation:453
# ============================================================================================
# Confusion Matrix for Image 63:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1417			0
# Actual Non-Vegetation		8739			1417
#
# TP_Vegetation:1417,	 FP_Vegetation:0,     FN_Vegetation:8739,      TN_Vegetation:6228
# TP_Non_Vegetation:6228, FP_Non_Vegetation:0, FN_Non_Vegetation:10156, TN_Non_Vegetation:1417
# ============================================================================================
# Confusion Matrix for Image 64:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		756			0
# Actual Non-Vegetation		1528			756
#
# TP_Vegetation:756,	 FP_Vegetation:0,     FN_Vegetation:1528,      TN_Vegetation:14100
# TP_Non_Vegetation:14100, FP_Non_Vegetation:0, FN_Non_Vegetation:2284, TN_Non_Vegetation:756
# ============================================================================================
# Confusion Matrix for Image 65:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		95			0
# Actual Non-Vegetation		4105			95
#
# TP_Vegetation:95,	 FP_Vegetation:0,     FN_Vegetation:4105,      TN_Vegetation:12184
# TP_Non_Vegetation:12184, FP_Non_Vegetation:0, FN_Non_Vegetation:4200, TN_Non_Vegetation:95
# ============================================================================================
# Confusion Matrix for Image 66:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		1315			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:1315,      TN_Vegetation:15069
# TP_Non_Vegetation:15069, FP_Non_Vegetation:0, FN_Non_Vegetation:1315, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 67:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		1422			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:1422,      TN_Vegetation:14962
# TP_Non_Vegetation:14962, FP_Non_Vegetation:0, FN_Non_Vegetation:1422, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 68:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		614			0
# Actual Non-Vegetation		5474			614
#
# TP_Vegetation:614,	 FP_Vegetation:0,     FN_Vegetation:5474,      TN_Vegetation:10296
# TP_Non_Vegetation:10296, FP_Non_Vegetation:0, FN_Non_Vegetation:6088, TN_Non_Vegetation:614
# ============================================================================================
# Confusion Matrix for Image 69:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		184			0
# Actual Non-Vegetation		155			184
#
# TP_Vegetation:184,	 FP_Vegetation:0,     FN_Vegetation:155,      TN_Vegetation:16045
# TP_Non_Vegetation:16045, FP_Non_Vegetation:0, FN_Non_Vegetation:339, TN_Non_Vegetation:184
# ============================================================================================
# Confusion Matrix for Image 70:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		65			0
# Actual Non-Vegetation		7482			65
#
# TP_Vegetation:65,	 FP_Vegetation:0,     FN_Vegetation:7482,      TN_Vegetation:8837
# TP_Non_Vegetation:8837, FP_Non_Vegetation:0, FN_Non_Vegetation:7547, TN_Non_Vegetation:65
# ============================================================================================
# Confusion Matrix for Image 71:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		236			0
# Actual Non-Vegetation		773			236
#
# TP_Vegetation:236,	 FP_Vegetation:0,     FN_Vegetation:773,      TN_Vegetation:15375
# TP_Non_Vegetation:15375, FP_Non_Vegetation:0, FN_Non_Vegetation:1009, TN_Non_Vegetation:236
# ============================================================================================
# Confusion Matrix for Image 72:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4996			0
# Actual Non-Vegetation		11308			4996
#
# TP_Vegetation:4996,	 FP_Vegetation:0,     FN_Vegetation:11308,      TN_Vegetation:80
# TP_Non_Vegetation:80, FP_Non_Vegetation:0, FN_Non_Vegetation:16304, TN_Non_Vegetation:4996
# ============================================================================================
# Confusion Matrix for Image 73:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4134			0
# Actual Non-Vegetation		4752			4134
#
# TP_Vegetation:4134,	 FP_Vegetation:0,     FN_Vegetation:4752,      TN_Vegetation:7498
# TP_Non_Vegetation:7498, FP_Non_Vegetation:0, FN_Non_Vegetation:8886, TN_Non_Vegetation:4134
# ============================================================================================
# Confusion Matrix for Image 74:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2429			31
# Actual Non-Vegetation		6460			2429
#
# TP_Vegetation:2429,	 FP_Vegetation:31,     FN_Vegetation:6460,      TN_Vegetation:7464
# TP_Non_Vegetation:7495, FP_Non_Vegetation:31, FN_Non_Vegetation:8889, TN_Non_Vegetation:2429
# ============================================================================================
# Confusion Matrix for Image 75:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		463			2
# Actual Non-Vegetation		312			463
#
# TP_Vegetation:463,	 FP_Vegetation:2,     FN_Vegetation:312,      TN_Vegetation:15607
# TP_Non_Vegetation:15609, FP_Non_Vegetation:2, FN_Non_Vegetation:775, TN_Non_Vegetation:463
# ============================================================================================
# Confusion Matrix for Image 76:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1207			0
# Actual Non-Vegetation		6760			1207
#
# TP_Vegetation:1207,	 FP_Vegetation:0,     FN_Vegetation:6760,      TN_Vegetation:8417
# TP_Non_Vegetation:8417, FP_Non_Vegetation:0, FN_Non_Vegetation:7967, TN_Non_Vegetation:1207
# ============================================================================================
# Confusion Matrix for Image 77:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		7236			13
# Actual Non-Vegetation		4358			7236
#
# TP_Vegetation:7236,	 FP_Vegetation:13,     FN_Vegetation:4358,      TN_Vegetation:4777
# TP_Non_Vegetation:4790, FP_Non_Vegetation:13, FN_Non_Vegetation:11594, TN_Non_Vegetation:7236
# ============================================================================================
# Confusion Matrix for Image 78:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1371			0
# Actual Non-Vegetation		1014			1371
#
# TP_Vegetation:1371,	 FP_Vegetation:0,     FN_Vegetation:1014,      TN_Vegetation:13999
# TP_Non_Vegetation:13999, FP_Non_Vegetation:0, FN_Non_Vegetation:2385, TN_Non_Vegetation:1371
# ============================================================================================
# Confusion Matrix for Image 79:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1856			45
# Actual Non-Vegetation		8663			1856
#
# TP_Vegetation:1856,	 FP_Vegetation:45,     FN_Vegetation:8663,      TN_Vegetation:5820
# TP_Non_Vegetation:5865, FP_Non_Vegetation:45, FN_Non_Vegetation:10519, TN_Non_Vegetation:1856
# ============================================================================================
# Confusion Matrix for Image 80:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		10569			31
# Actual Non-Vegetation		4144			10569
#
# TP_Vegetation:10569,	 FP_Vegetation:31,     FN_Vegetation:4144,      TN_Vegetation:1640
# TP_Non_Vegetation:1671, FP_Non_Vegetation:31, FN_Non_Vegetation:14713, TN_Non_Vegetation:10569
# ============================================================================================
# Confusion Matrix for Image 81:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6669			33
# Actual Non-Vegetation		2336			6669
#
# TP_Vegetation:6669,	 FP_Vegetation:33,     FN_Vegetation:2336,      TN_Vegetation:7346
# TP_Non_Vegetation:7379, FP_Non_Vegetation:33, FN_Non_Vegetation:9005, TN_Non_Vegetation:6669
# ============================================================================================
# Confusion Matrix for Image 82:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		11235			4
# Actual Non-Vegetation		3172			11235
#
# TP_Vegetation:11235,	 FP_Vegetation:4,     FN_Vegetation:3172,      TN_Vegetation:1973
# TP_Non_Vegetation:1977, FP_Non_Vegetation:4, FN_Non_Vegetation:14407, TN_Non_Vegetation:11235
# ============================================================================================
# Confusion Matrix for Image 83:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		7639			5
# Actual Non-Vegetation		3731			7639
#
# TP_Vegetation:7639,	 FP_Vegetation:5,     FN_Vegetation:3731,      TN_Vegetation:5009
# TP_Non_Vegetation:5014, FP_Non_Vegetation:5, FN_Non_Vegetation:11370, TN_Non_Vegetation:7639
# ============================================================================================
# Confusion Matrix for Image 84:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1998			0
# Actual Non-Vegetation		1901			1998
#
# TP_Vegetation:1998,	 FP_Vegetation:0,     FN_Vegetation:1901,      TN_Vegetation:12485
# TP_Non_Vegetation:12485, FP_Non_Vegetation:0, FN_Non_Vegetation:3899, TN_Non_Vegetation:1998
# ============================================================================================
# Confusion Matrix for Image 85:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		690			0
# Actual Non-Vegetation		5660			690
#
# TP_Vegetation:690,	 FP_Vegetation:0,     FN_Vegetation:5660,      TN_Vegetation:10034
# TP_Non_Vegetation:10034, FP_Non_Vegetation:0, FN_Non_Vegetation:6350, TN_Non_Vegetation:690
# ============================================================================================
# Confusion Matrix for Image 86:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		88			0
# Actual Non-Vegetation		9205			88
#
# TP_Vegetation:88,	 FP_Vegetation:0,     FN_Vegetation:9205,      TN_Vegetation:7091
# TP_Non_Vegetation:7091, FP_Non_Vegetation:0, FN_Non_Vegetation:9293, TN_Non_Vegetation:88
# ============================================================================================
# Confusion Matrix for Image 87:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		3912			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:3912,      TN_Vegetation:12472
# TP_Non_Vegetation:12472, FP_Non_Vegetation:0, FN_Non_Vegetation:3912, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 88:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3			0
# Actual Non-Vegetation		10502			3
#
# TP_Vegetation:3,	 FP_Vegetation:0,     FN_Vegetation:10502,      TN_Vegetation:5879
# TP_Non_Vegetation:5879, FP_Non_Vegetation:0, FN_Non_Vegetation:10505, TN_Non_Vegetation:3
# ============================================================================================
# Confusion Matrix for Image 89:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		3051			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:3051,      TN_Vegetation:13333
# TP_Non_Vegetation:13333, FP_Non_Vegetation:0, FN_Non_Vegetation:3051, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 90:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4355			26
# Actual Non-Vegetation		7109			4355
#
# TP_Vegetation:4355,	 FP_Vegetation:26,     FN_Vegetation:7109,      TN_Vegetation:4894
# TP_Non_Vegetation:4920, FP_Non_Vegetation:26, FN_Non_Vegetation:11464, TN_Non_Vegetation:4355
# ============================================================================================
# Confusion Matrix for Image 91:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1906			27
# Actual Non-Vegetation		4030			1906
#
# TP_Vegetation:1906,	 FP_Vegetation:27,     FN_Vegetation:4030,      TN_Vegetation:10421
# TP_Non_Vegetation:10448, FP_Non_Vegetation:27, FN_Non_Vegetation:5936, TN_Non_Vegetation:1906
# ============================================================================================
# Confusion Matrix for Image 92:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3482			7
# Actual Non-Vegetation		2897			3482
#
# TP_Vegetation:3482,	 FP_Vegetation:7,     FN_Vegetation:2897,      TN_Vegetation:9998
# TP_Non_Vegetation:10005, FP_Non_Vegetation:7, FN_Non_Vegetation:6379, TN_Non_Vegetation:3482
# ============================================================================================
# Confusion Matrix for Image 93:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3183			28
# Actual Non-Vegetation		9611			3183
#
# TP_Vegetation:3183,	 FP_Vegetation:28,     FN_Vegetation:9611,      TN_Vegetation:3562
# TP_Non_Vegetation:3590, FP_Non_Vegetation:28, FN_Non_Vegetation:12794, TN_Non_Vegetation:3183
# ============================================================================================
# Confusion Matrix for Image 94:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1088			42
# Actual Non-Vegetation		991			1088
#
# TP_Vegetation:1088,	 FP_Vegetation:42,     FN_Vegetation:991,      TN_Vegetation:14263
# TP_Non_Vegetation:14305, FP_Non_Vegetation:42, FN_Non_Vegetation:2079, TN_Non_Vegetation:1088
# ============================================================================================
# Confusion Matrix for Image 95:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3053			82
# Actual Non-Vegetation		7121			3053
#
# TP_Vegetation:3053,	 FP_Vegetation:82,     FN_Vegetation:7121,      TN_Vegetation:6128
# TP_Non_Vegetation:6210, FP_Non_Vegetation:82, FN_Non_Vegetation:10174, TN_Non_Vegetation:3053
# ============================================================================================
# Confusion Matrix for Image 96:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		148			0
# Actual Non-Vegetation		5793			148
#
# TP_Vegetation:148,	 FP_Vegetation:0,     FN_Vegetation:5793,      TN_Vegetation:10443
# TP_Non_Vegetation:10443, FP_Non_Vegetation:0, FN_Non_Vegetation:5941, TN_Non_Vegetation:148
# ============================================================================================
# Confusion Matrix for Image 97:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		38			0
# Actual Non-Vegetation		1860			38
#
# TP_Vegetation:38,	 FP_Vegetation:0,     FN_Vegetation:1860,      TN_Vegetation:14486
# TP_Non_Vegetation:14486, FP_Non_Vegetation:0, FN_Non_Vegetation:1898, TN_Non_Vegetation:38
# ============================================================================================
# Confusion Matrix for Image 98:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4886			2
# Actual Non-Vegetation		4448			4886
#
# TP_Vegetation:4886,	 FP_Vegetation:2,     FN_Vegetation:4448,      TN_Vegetation:7048
# TP_Non_Vegetation:7050, FP_Non_Vegetation:2, FN_Non_Vegetation:9334, TN_Non_Vegetation:4886
# ============================================================================================
# Confusion Matrix for Image 99:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		47			0
# Actual Non-Vegetation		2155			47
#
# TP_Vegetation:47,	 FP_Vegetation:0,     FN_Vegetation:2155,      TN_Vegetation:14182
# TP_Non_Vegetation:14182, FP_Non_Vegetation:0, FN_Non_Vegetation:2202, TN_Non_Vegetation:47
# ============================================================================================
# Confusion Matrix for Image 100:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		509			0
# Actual Non-Vegetation		10343			509
#
# TP_Vegetation:509,	 FP_Vegetation:0,     FN_Vegetation:10343,      TN_Vegetation:5532
# TP_Non_Vegetation:5532, FP_Non_Vegetation:0, FN_Non_Vegetation:10852, TN_Non_Vegetation:509
# ============================================================================================
# Confusion Matrix for Image 101:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		217			0
# Actual Non-Vegetation		14904			217
#
# TP_Vegetation:217,	 FP_Vegetation:0,     FN_Vegetation:14904,      TN_Vegetation:1263
# TP_Non_Vegetation:1263, FP_Non_Vegetation:0, FN_Non_Vegetation:15121, TN_Non_Vegetation:217
# ============================================================================================
# Confusion Matrix for Image 102:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1648			0
# Actual Non-Vegetation		14736			1648
#
# TP_Vegetation:1648,	 FP_Vegetation:0,     FN_Vegetation:14736,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:1648
# ============================================================================================
# Confusion Matrix for Image 103:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6791			0
# Actual Non-Vegetation		9593			6791
#
# TP_Vegetation:6791,	 FP_Vegetation:0,     FN_Vegetation:9593,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:6791
# ============================================================================================
# Confusion Matrix for Image 104:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6368			0
# Actual Non-Vegetation		6429			6368
#
# TP_Vegetation:6368,	 FP_Vegetation:0,     FN_Vegetation:6429,      TN_Vegetation:3587
# TP_Non_Vegetation:3587, FP_Non_Vegetation:0, FN_Non_Vegetation:12797, TN_Non_Vegetation:6368
# ============================================================================================
# Confusion Matrix for Image 105:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		3768			0
# Actual Non-Vegetation		9437			3768
#
# TP_Vegetation:3768,	 FP_Vegetation:0,     FN_Vegetation:9437,      TN_Vegetation:3179
# TP_Non_Vegetation:3179, FP_Non_Vegetation:0, FN_Non_Vegetation:13205, TN_Non_Vegetation:3768
# ============================================================================================
# Confusion Matrix for Image 106:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2			0
# Actual Non-Vegetation		1286			2
#
# TP_Vegetation:2,	 FP_Vegetation:0,     FN_Vegetation:1286,      TN_Vegetation:15096
# TP_Non_Vegetation:15096, FP_Non_Vegetation:0, FN_Non_Vegetation:1288, TN_Non_Vegetation:2
# ============================================================================================
# Confusion Matrix for Image 107:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		188			0
# Actual Non-Vegetation		1697			188
#
# TP_Vegetation:188,	 FP_Vegetation:0,     FN_Vegetation:1697,      TN_Vegetation:14499
# TP_Non_Vegetation:14499, FP_Non_Vegetation:0, FN_Non_Vegetation:1885, TN_Non_Vegetation:188
# ============================================================================================
# Confusion Matrix for Image 108:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		5002			0
# Actual Non-Vegetation		11382			5002
#
# TP_Vegetation:5002,	 FP_Vegetation:0,     FN_Vegetation:11382,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:5002
# ============================================================================================
# Confusion Matrix for Image 109:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2254			0
# Actual Non-Vegetation		1409			2254
#
# TP_Vegetation:2254,	 FP_Vegetation:0,     FN_Vegetation:1409,      TN_Vegetation:12721
# TP_Non_Vegetation:12721, FP_Non_Vegetation:0, FN_Non_Vegetation:3663, TN_Non_Vegetation:2254
# ============================================================================================
# Confusion Matrix for Image 110:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		7241			12
# Actual Non-Vegetation		6818			7241
#
# TP_Vegetation:7241,	 FP_Vegetation:12,     FN_Vegetation:6818,      TN_Vegetation:2313
# TP_Non_Vegetation:2325, FP_Non_Vegetation:12, FN_Non_Vegetation:14059, TN_Non_Vegetation:7241
# ============================================================================================
# Confusion Matrix for Image 111:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		549			0
# Actual Non-Vegetation		6486			549
#
# TP_Vegetation:549,	 FP_Vegetation:0,     FN_Vegetation:6486,      TN_Vegetation:9349
# TP_Non_Vegetation:9349, FP_Non_Vegetation:0, FN_Non_Vegetation:7035, TN_Non_Vegetation:549
# ============================================================================================
# Confusion Matrix for Image 112:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		160			12
# Actual Non-Vegetation		1552			160
#
# TP_Vegetation:160,	 FP_Vegetation:12,     FN_Vegetation:1552,      TN_Vegetation:14660
# TP_Non_Vegetation:14672, FP_Non_Vegetation:12, FN_Non_Vegetation:1712, TN_Non_Vegetation:160
# ============================================================================================
# Confusion Matrix for Image 113:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		861			0
# Actual Non-Vegetation		4663			861
#
# TP_Vegetation:861,	 FP_Vegetation:0,     FN_Vegetation:4663,      TN_Vegetation:10860
# TP_Non_Vegetation:10860, FP_Non_Vegetation:0, FN_Non_Vegetation:5524, TN_Non_Vegetation:861
# ============================================================================================
# Confusion Matrix for Image 114:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2204			0
# Actual Non-Vegetation		13454			2204
#
# TP_Vegetation:2204,	 FP_Vegetation:0,     FN_Vegetation:13454,      TN_Vegetation:726
# TP_Non_Vegetation:726, FP_Non_Vegetation:0, FN_Non_Vegetation:15658, TN_Non_Vegetation:2204
# ============================================================================================
# Confusion Matrix for Image 115:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2908			0
# Actual Non-Vegetation		13476			2908
#
# TP_Vegetation:2908,	 FP_Vegetation:0,     FN_Vegetation:13476,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:2908
# ============================================================================================
# Confusion Matrix for Image 116:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2804			0
# Actual Non-Vegetation		13580			2804
#
# TP_Vegetation:2804,	 FP_Vegetation:0,     FN_Vegetation:13580,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:2804
# ...
# ============================================================================================
# Confusion Matrix for Image 467:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		792			0
# Actual Non-Vegetation		830			792
#
# TP_Vegetation:792,	 FP_Vegetation:0,     FN_Vegetation:830,      TN_Vegetation:14762
# TP_Non_Vegetation:14762, FP_Non_Vegetation:0, FN_Non_Vegetation:1622, TN_Non_Vegetation:792
# ============================================================================================
# Confusion Matrix for Image 468:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		10291			0
# Actual Non-Vegetation		5314			10291
#
# TP_Vegetation:10291,	 FP_Vegetation:0,     FN_Vegetation:5314,      TN_Vegetation:779
# TP_Non_Vegetation:779, FP_Non_Vegetation:0, FN_Non_Vegetation:15605, TN_Non_Vegetation:10291
# ============================================================================================
# Confusion Matrix for Image 469:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		14263			0
# Actual Non-Vegetation		2121			14263
#
# TP_Vegetation:14263,	 FP_Vegetation:0,     FN_Vegetation:2121,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:14263
# ============================================================================================
# Confusion Matrix for Image 470:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		16384			0
# Actual Non-Vegetation		0			16384
#
# TP_Vegetation:16384,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:16384
# ============================================================================================
# Confusion Matrix for Image 471:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		13086			0
# Actual Non-Vegetation		3298			13086
#
# TP_Vegetation:13086,	 FP_Vegetation:0,     FN_Vegetation:3298,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:13086
# ============================================================================================
# Confusion Matrix for Image 472:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1551			0
# Actual Non-Vegetation		3781			1551
#
# TP_Vegetation:1551,	 FP_Vegetation:0,     FN_Vegetation:3781,      TN_Vegetation:11052
# TP_Non_Vegetation:11052, FP_Non_Vegetation:0, FN_Non_Vegetation:5332, TN_Non_Vegetation:1551
# ============================================================================================
# Confusion Matrix for Image 473:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1074			1
# Actual Non-Vegetation		2137			1074
#
# TP_Vegetation:1074,	 FP_Vegetation:1,     FN_Vegetation:2137,      TN_Vegetation:13172
# TP_Non_Vegetation:13173, FP_Non_Vegetation:1, FN_Non_Vegetation:3211, TN_Non_Vegetation:1074
# ============================================================================================
# Confusion Matrix for Image 474:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 475:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 476:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 477:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		283			0
# Actual Non-Vegetation		1523			283
#
# TP_Vegetation:283,	 FP_Vegetation:0,     FN_Vegetation:1523,      TN_Vegetation:14578
# TP_Non_Vegetation:14578, FP_Non_Vegetation:0, FN_Non_Vegetation:1806, TN_Non_Vegetation:283
# ============================================================================================
# Confusion Matrix for Image 478:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		451			0
# Actual Non-Vegetation		720			451
#
# TP_Vegetation:451,	 FP_Vegetation:0,     FN_Vegetation:720,      TN_Vegetation:15213
# TP_Non_Vegetation:15213, FP_Non_Vegetation:0, FN_Non_Vegetation:1171, TN_Non_Vegetation:451
# ============================================================================================
# Confusion Matrix for Image 479:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		10782			0
# Actual Non-Vegetation		2675			10782
#
# TP_Vegetation:10782,	 FP_Vegetation:0,     FN_Vegetation:2675,      TN_Vegetation:2927
# TP_Non_Vegetation:2927, FP_Non_Vegetation:0, FN_Non_Vegetation:13457, TN_Non_Vegetation:10782
# ============================================================================================
# Confusion Matrix for Image 480:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		7036			0
# Actual Non-Vegetation		9348			7036
#
# TP_Vegetation:7036,	 FP_Vegetation:0,     FN_Vegetation:9348,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:7036
# ============================================================================================
# Confusion Matrix for Image 481:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		2842			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:2842,      TN_Vegetation:13542
# TP_Non_Vegetation:13542, FP_Non_Vegetation:0, FN_Non_Vegetation:2842, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 482:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		14047			0
# Actual Non-Vegetation		2337			14047
#
# TP_Vegetation:14047,	 FP_Vegetation:0,     FN_Vegetation:2337,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:14047
# ============================================================================================
# Confusion Matrix for Image 483:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		13797			0
# Actual Non-Vegetation		2587			13797
#
# TP_Vegetation:13797,	 FP_Vegetation:0,     FN_Vegetation:2587,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:13797
# ============================================================================================
# Confusion Matrix for Image 484:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		13990			0
# Actual Non-Vegetation		2394			13990
#
# TP_Vegetation:13990,	 FP_Vegetation:0,     FN_Vegetation:2394,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:13990
# ============================================================================================
# Confusion Matrix for Image 485:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		4988			0
# Actual Non-Vegetation		11396			4988
#
# TP_Vegetation:4988,	 FP_Vegetation:0,     FN_Vegetation:11396,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:4988
# ============================================================================================
# Confusion Matrix for Image 486:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 487:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		611			0
# Actual Non-Vegetation		222			611
#
# TP_Vegetation:611,	 FP_Vegetation:0,     FN_Vegetation:222,      TN_Vegetation:15551
# TP_Non_Vegetation:15551, FP_Non_Vegetation:0, FN_Non_Vegetation:833, TN_Non_Vegetation:611
# ============================================================================================
# Confusion Matrix for Image 488:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1292			61
# Actual Non-Vegetation		2661			1292
#
# TP_Vegetation:1292,	 FP_Vegetation:61,     FN_Vegetation:2661,      TN_Vegetation:12370
# TP_Non_Vegetation:12431, FP_Non_Vegetation:61, FN_Non_Vegetation:3953, TN_Non_Vegetation:1292
# ============================================================================================
# Confusion Matrix for Image 489:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 490:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 491:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		2699			12
# Actual Non-Vegetation		2044			2699
#
# TP_Vegetation:2699,	 FP_Vegetation:12,     FN_Vegetation:2044,      TN_Vegetation:11629
# TP_Non_Vegetation:11641, FP_Non_Vegetation:12, FN_Non_Vegetation:4743, TN_Non_Vegetation:2699
# ============================================================================================
# Confusion Matrix for Image 492:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		203			0
# Actual Non-Vegetation		378			203
#
# TP_Vegetation:203,	 FP_Vegetation:0,     FN_Vegetation:378,      TN_Vegetation:15803
# TP_Non_Vegetation:15803, FP_Non_Vegetation:0, FN_Non_Vegetation:581, TN_Non_Vegetation:203
# ============================================================================================
# Confusion Matrix for Image 493:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		11			0
# Actual Non-Vegetation		936			11
#
# TP_Vegetation:11,	 FP_Vegetation:0,     FN_Vegetation:936,      TN_Vegetation:15437
# TP_Non_Vegetation:15437, FP_Non_Vegetation:0, FN_Non_Vegetation:947, TN_Non_Vegetation:11
# ============================================================================================
# Confusion Matrix for Image 494:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		12364			0
# Actual Non-Vegetation		1796			12364
#
# TP_Vegetation:12364,	 FP_Vegetation:0,     FN_Vegetation:1796,      TN_Vegetation:2224
# TP_Non_Vegetation:2224, FP_Non_Vegetation:0, FN_Non_Vegetation:14160, TN_Non_Vegetation:12364
# ============================================================================================
# Confusion Matrix for Image 495:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 496:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		13693			0
# Actual Non-Vegetation		2691			13693
#
# TP_Vegetation:13693,	 FP_Vegetation:0,     FN_Vegetation:2691,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:13693
# ============================================================================================
# Confusion Matrix for Image 497:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		16165			0
# Actual Non-Vegetation		219			16165
#
# TP_Vegetation:16165,	 FP_Vegetation:0,     FN_Vegetation:219,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:16165
# ============================================================================================
# Confusion Matrix for Image 498:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		7259			0
# Actual Non-Vegetation		9125			7259
#
# TP_Vegetation:7259,	 FP_Vegetation:0,     FN_Vegetation:9125,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:7259
# ============================================================================================
# Confusion Matrix for Image 499:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		6204			0
# Actual Non-Vegetation		10180			6204
#
# TP_Vegetation:6204,	 FP_Vegetation:0,     FN_Vegetation:10180,      TN_Vegetation:0
# TP_Non_Vegetation:0, FP_Non_Vegetation:0, FN_Non_Vegetation:16384, TN_Non_Vegetation:6204
# ============================================================================================
# Confusion Matrix for Image 500:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 501:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1			0
# Actual Non-Vegetation		35			1
#
# TP_Vegetation:1,	 FP_Vegetation:0,     FN_Vegetation:35,      TN_Vegetation:16348
# TP_Non_Vegetation:16348, FP_Non_Vegetation:0, FN_Non_Vegetation:36, TN_Non_Vegetation:1
# ============================================================================================
# Confusion Matrix for Image 502:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		0			0
# Actual Non-Vegetation		0			0
#
# TP_Vegetation:0,	 FP_Vegetation:0,     FN_Vegetation:0,      TN_Vegetation:16384
# TP_Non_Vegetation:16384, FP_Non_Vegetation:0, FN_Non_Vegetation:0, TN_Non_Vegetation:0
# ============================================================================================
# Confusion Matrix for Image 503:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		1268			6
# Actual Non-Vegetation		2920			1268
#
# TP_Vegetation:1268,	 FP_Vegetation:6,     FN_Vegetation:2920,      TN_Vegetation:12190
# TP_Non_Vegetation:12196, FP_Non_Vegetation:6, FN_Non_Vegetation:4188, TN_Non_Vegetation:1268
# ============================================================================================
# Confusion Matrix for Image 504:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		396			0
# Actual Non-Vegetation		2066			396
#
# TP_Vegetation:396,	 FP_Vegetation:0,     FN_Vegetation:2066,      TN_Vegetation:13922
# TP_Non_Vegetation:13922, FP_Non_Vegetation:0, FN_Non_Vegetation:2462, TN_Non_Vegetation:396
# ============================================================================================
# Confusion Matrix for Image 505:
# 			Predicted Vegetation	Predicted Non-Vegetation
# Actual Vegetation		205			0
# Actual Non-Vegetation		480			205
#
# TP_Vegetation:205,	 FP_Vegetation:0,     FN_Vegetation:480,      TN_Vegetation:15699
# TP_Non_Vegetation:15699, FP_Non_Vegetation:0, FN_Non_Vegetation:685, TN_Non_Vegetation:205

# %%
# mean_iou_vegetation = np.mean(IoU_vegetation)
# mean_iou_non_vegetation = np.mean(IoU_non_vegetation)
# mean_all_iou = (mean_iou_vegetation + mean_iou_non_vegetation) / 2
# print("Mean IoU for Vegetation Class: {:.4f}".format(mean_iou_vegetation ))
# print("Mean IoU for Non-Vegetation Class: {:.4f}".format(mean_iou_non_vegetation))
# print("Mean IoU Overall: {:.4f}".format(mean_all_iou))

# %%
tp_veg_overall = np.sum(TP_vegetation)
fp_veg_overall = np.sum(FP_vegetation)
fn_veg_overall = np.sum(FN_vegetation)
tn_veg_overall = np.sum(TN_vegetation)
print("TP Vegetation: ", tp_veg_overall)
print("FP Vegetation: ", fp_veg_overall)
print("FN Vegetation: ", fn_veg_overall)
print("TN Vegetation: ", tn_veg_overall)

prec_veg = tp_veg_overall/ (tp_veg_overall+fp_veg_overall)
recall_veg = tp_veg_overall/(tp_veg_overall+fn_veg_overall)
accuracy_veg = (tp_veg_overall + tn_veg_overall) / (tp_veg_overall+fp_veg_overall+fn_veg_overall+tn_veg_overall)
f1_veg = 2*(prec_veg*recall_veg)/(prec_veg+recall_veg)

print("precission vegetation: ", prec_veg)
print("recall vegetation: ",recall_veg)
print("accuracy vegetation: ",accuracy_veg)
print("f1 score: ",f1_veg)
# Out:
# TP Vegetation:  1750570
# FP Vegetation:  5194
# FN Vegetation:  2011664
# TN Vegetation:  4506492
# precission vegetation:  0.9970417436511969
# recall vegetation:  0.4653006697616363
# accuracy vegetation:  0.756239122447401
# f1 score:  0.6344946119951475

# %%
tp_veg_overall = np.sum(TP_vegetation)
fp_veg_overall = np.sum(FP_vegetation)
fn_veg_overall = np.sum(FN_vegetation)

print("TP Vegetation: ", tp_veg_overall)
print("FP Vegetation: ", fp_veg_overall)
print("FN Vegetation: ", fn_veg_overall)

IoU_veg_overall = tp_veg_overall / (tp_veg_overall + fp_veg_overall + fn_veg_overall)
print("IoU Vegetation: ", IoU_veg_overall)

tp_non_veg_overall = np.sum(TP_non_vegetation)
fp_non_veg_overall = np.sum(FP_non_vegetation)
fn_non_veg_overall = np.sum(FN_non_vegetation)

print("\nTP Non-Vegetation: ", tp_non_veg_overall)
print("FP Non-Vegetation: ", fp_non_veg_overall)
print("FN Non-Vegetation: ", fn_non_veg_overall)

IoU_non_veg_overall = tp_non_veg_overall / (tp_non_veg_overall + fp_non_veg_overall + fn_non_veg_overall)
print("IoU Non-Vegetation: ", IoU_non_veg_overall)

IoU_overall = (IoU_veg_overall + IoU_non_veg_overall)/2
print("\nIoU Overall: ", IoU_overall)
# Out:
# TP Vegetation:  1750570
# FP Vegetation:  5194
# FN Vegetation:  2011664
# IoU Vegetation:  0.46465917862265715
#
# TP Non-Vegetation:  4511686
# FP Non-Vegetation:  5194
# FN Non-Vegetation:  3762234
# IoU Non-Vegetation:  0.5449479255872065
#
# IoU Overall:  0.5048035521049319

# %% [markdown]
# ========================================================================================================

# %%
vegetation_color = [0, 255, 0]  # Green
non_vegetation_color = [0, 0, 255] # Blue

indexing = 250
input_image = images_load[indexing]
ground_truth = ground_truths[indexing]
features_get = fe.extract(input_image)

# Preprocess the input image
input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_reshaped.reshape(-1, 3)  # Remove the transpose operation here

# Predict segmentation mask
predicted_mask = model_loaded.forward(features)
predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)

# Create segmented image
segmented_image[predicted_mask == 0] = non_vegetation_color
segmented_image[predicted_mask == 1] = vegetation_color

# Visualize input image, ground truth, and segmented image
plt.figure(figsize=(12, 5))
plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Input Image')

plt.subplot(1, 3, 2)
plt.imshow(ground_truth)
plt.title('Ground Truth')

# print("IoU Vegetation: {:.4f}".format(IoU_vegetation[indexing]))
# print("IoU Non-Vegetation: {:.4f}".format(IoU_non_vegetation[indexing]))
# print("Mean IoU: {:.4f}".format((IoU_vegetation[indexing] + IoU_non_vegetation[indexing])/2))
plt.subplot(1, 3, 3)
plt.imshow(segmented_image)
# IoU = (IoU_vegetation[indexing] + IoU_non_vegetation[indexing]) / 2
plt.title('Segmented Image')

plt.show()

# %%
# vegetation_color = [0, 255, 0]  # Green
# non_vegetation_color = [0, 0, 255] # Blue

# # Initialize lists for TP, FP, FN, and IoU
# vegetation_TP = []
# vegetation_FP = []
# vegetation_FN = []
# non_vegetation_TP = []
# non_vegetation_FP = []
# non_vegetation_FN = []
# IoU_vegetation = []
# IoU_non_vegetation = []

# # Loop over testing images
# for i in range(len(image_test)):
#     # Reset counts for each image
#     TP_vegetation = 0
#     FP_vegetation = 0
#     FN_vegetation = 0
#     TP_non_vegetation = 0
#     FP_non_vegetation = 0
#     FN_non_vegetation = 0
    
#     input_image = image_test[i]
#     ground_truth = image_label_test[i]

#     # Preprocess the input image
#     input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
#     features = input_image_reshaped.reshape(-1, 3)

#     # Predict segmentation mask
#     predicted_mask = model_loaded.forward(features)
#     predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

#     # Convert ground truth to single-channel binary masks for vegetation and non-vegetation
#     vegetation_ground_truth = (ground_truth == [0, 255, 0]).all(axis=2)
#     non_vegetation_ground_truth = ~vegetation_ground_truth

#     # Iterate over each pixel in the patch
#     for y in range(128):
#         for x in range(128):
#             # Check if the pixel is vegetation in both prediction and ground truth
#             if vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 TP_vegetation += 1
#             # Check if the pixel is non-vegetation in both prediction and ground truth
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 TP_non_vegetation += 1
#             # Check if the pixel is vegetation in ground truth but non-vegetation in prediction
#             elif vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 FN_vegetation += 1
#             # Check if the pixel is non-vegetation in ground truth but vegetation in prediction
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 FP_non_vegetation += 1
                
#     # Append TP, FP, FN counts for both classes
#     vegetation_TP.append(TP_vegetation)
#     vegetation_FP.append(FP_vegetation)
#     vegetation_FN.append(FN_vegetation)
#     non_vegetation_TP.append(TP_non_vegetation)
#     non_vegetation_FP.append(FP_non_vegetation)
#     non_vegetation_FN.append(FN_non_vegetation)

#     # Calculate IoU for both classes if the denominator is not zero
#     if (TP_vegetation + FP_vegetation + FN_vegetation) != 0:
#         IoU_vegetation.append(TP_vegetation / (TP_vegetation + FP_vegetation + FN_vegetation))
#     else:
#         IoU_vegetation.append(0.0)

#     if (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation) != 0:
#         IoU_non_vegetation.append(TP_non_vegetation / (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation))
#     else:
#         IoU_non_vegetation.append(0.0)

#     print("===============================Image {}==================================".format(i+1))
#     print("vegetation_TP: {}, vegetation_FP: {}, vegetation_FN: {}\nnon_vegetation_TP: {}, non_vegetation_FP: {}, non_vegetation_FN: {}".format(TP_vegetation, FP_vegetation, FN_vegetation, TP_non_vegetation, FP_non_vegetation, FN_non_vegetation))
#     print("Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}, Mean IoU: {:.4f}".format(IoU_vegetation[-1], IoU_non_vegetation[-1], (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2))
#     # Visualize input image, ground truth, and segmented image
#     # plt.figure(figsize=(12, 5))
#     # plt.subplot(1, 3, 1)
#     # plt.imshow(input_image)
#     # plt.title('Input Image')
    
#     # plt.subplot(1, 3, 2)
#     # plt.imshow(ground_truth)
#     # plt.title('Ground Truth')
    
#     # # Create segmented image
#     # segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)
#     # segmented_image[predicted_mask == 0] = non_vegetation_color
#     # segmented_image[predicted_mask == 1] = vegetation_color
    
#     # # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
#     # plt.subplot(1, 3, 3)
#     # plt.imshow(segmented_image)
#     # IoU = (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2
#     # plt.title('Segmented Image (Mean IoU: {:.4f})'.format(IoU))
    
#     # plt.show()

# %%
# # Compute mean IoU across all images for vegetation and non-vegetation classes
# mean_IoU_vegetation_class = sum(IoU_vegetation) / len(IoU_vegetation)
# mean_IoU_non_vegetation_class = sum(IoU_non_vegetation) / len(IoU_non_vegetation)
# mean_IoU_overall = (mean_IoU_vegetation_class + mean_IoU_non_vegetation_class) / 2

# # Print mean IoU for both classes
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_IoU_vegetation_class * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_IoU_non_vegetation_class * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_IoU_overall * 100), "%")
