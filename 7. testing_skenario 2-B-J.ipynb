# %%
from utils import conv
from utils import NN as nn
from utils import dataprepare as dp
from utils import Feature_extract as fe

import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
# Load the saved weights
def load_weights(filename):
    with open(filename, 'rb') as f:
        data = np.load(f)
        weights_hidden_output = data['weights_hidden_output']
        bias_hidden_output = data['bias_hidden_output']
        weights_input_hidden = data['weights_input_hidden']
        bias_input_hidden = data['bias_input_hidden']
    return weights_hidden_output, bias_hidden_output, weights_input_hidden, bias_input_hidden

# %%
# Load images and ground truth labels
images_path = 'patching_fix/patch_image'
feature_images_path = 'patching_fix/feature_extract'
ground_truths_path = 'patching_fix/patch_ground'

images_load = dp.load_images_from_folder(images_path)
feature_images_load = dp.load_images_from_folder(feature_images_path)
ground_truths = dp.load_ground_truth_from_folder(ground_truths_path)

# %%
feature_images_train = feature_images_load[:math.ceil(len(feature_images_load)*0.7)] 
image_label_train = ground_truths[:math.ceil(len(ground_truths)*0.7)]

image_test = images_load[math.ceil(len(images_load)*0.7):]
image_label_test = ground_truths[math.ceil(len(ground_truths)*0.7):]

# %%
plt.imshow(image_label_train[10])
print(image_label_train[10].shape)
# Out:
# (128, 128, 3)

# %%
# Prepare data
X_test, y_test = dp.prepare_data(image_test, image_label_test)
# Normalize the features
X__test_normalized = X_test / 255.0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Prepare data
# ----> 2 X_test, y_test = dp.prepare_data(image_test, image_label_test)
#       3 # Normalize the features
#       4 X__test_normalized = X_test / 255.0
#
# File d:\Kuliah S2\Semester 2\BI\program\utils\dataprepare.py:48, in prepare_data(feature_maps, ground_truths)
#      45 for h in range(height):
#      46     for w in range(width):
#      47         # Flatten the feature map for each pixel
# ---> 48         features = feature_map[h, w, :].flatten()
#      49         X.append(features)
#      51         # Check ground truth to assign label
#
# KeyboardInterrupt:

# %%
# input_size = X__test_normalized.shape[0]
input_size = 3
hidden_size = 2  # hidden neuron
output_size = 2  # 2 classes: vegetation and non-vegetation

# %%
# Load weights for testing
weights_hidden_output, bias_hidden_output, weights_input_hidden, bias_input_hidden = load_weights('7. Bobot_skenario_7.npz')

# Initialize the neural network with the loaded weights
model_loaded = nn.NeuralNetwork(input_size, hidden_size, output_size)
model_loaded.weights_hidden_output = weights_hidden_output
model_loaded.bias_hidden_output = bias_hidden_output
model_loaded.weights_input_hidden = weights_input_hidden
model_loaded.bias_input_hidden = bias_input_hidden

# %%
print('Load Bobot dan bias optimal')
print('Bobot hidden-output:')
print(model_loaded.weights_hidden_output)
print('Bias hidden-output:')
print(model_loaded.bias_hidden_output[0][0])
print('Bobot input-hidden:')
print(model_loaded.weights_input_hidden)
print('Bias input-hidden:')
print(model_loaded.bias_input_hidden[0][0])
# Out:
# Load Bobot dan bias optimal
# Bobot hidden-output:
# [[ 0.91149051 -0.91149051]
#  [-3.33781983  3.33781983]]
# Bias hidden-output:
# 3.3638529045149355
# Bobot input-hidden:
# [[-31.51137651  14.25243725]
#  [ 45.71730842   7.41812271]
#  [ 27.83728239   1.51435524]]
# Bias input-hidden:
# -1.2287894824291643

# %%
TP = 0  # True Positives
FP = 0  # False Positives
FN = 0  # False Negatives
TN = 0  # True Negatives

# Loop over testing images
for i in range(len(image_test)):
    TPi = 0  # True Positives index
    FPi = 0  # False Positives index
    FNi = 0  # False Negatives index
    TNi = 0  # True Negatives index

    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN, TN for the current image
    for row in range(predicted_mask.shape[0]):
        for col in range(predicted_mask.shape[1]):
            if predicted_mask[row, col] == 1 and vegetation_ground_truth[row, col]:
                TPi += 1
                TP += 1
            elif predicted_mask[row, col] == 1 and not vegetation_ground_truth[row, col]:
                FPi += 1
                FP += 1
            elif predicted_mask[row, col] == 0 and vegetation_ground_truth[row, col]:
                FNi += 1
                FN += 1
            elif predicted_mask[row, col] == 0 and not vegetation_ground_truth[row, col]:
                TNi += 1
                TN += 1
    
    # Print the values for TP, FP, FN, TN for the current image
    print("Image {}: TP = {}, FP = {}, FN = {}, TN = {}".format(i+1, TPi, FPi, FNi, TNi))
# Out:
# Image 1: TP = 0, FP = 0, FN = 45, TN = 16339
# Image 2: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 3: TP = 253, FP = 0, FN = 269, TN = 15862
# Image 4: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 5: TP = 0, FP = 0, FN = 10, TN = 16374
# Image 6: TP = 255, FP = 0, FN = 361, TN = 15768
# Image 7: TP = 2696, FP = 0, FN = 2873, TN = 10815
# Image 8: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 9: TP = 58, FP = 0, FN = 113, TN = 16213
# Image 10: TP = 1908, FP = 0, FN = 7258, TN = 7218
# Image 11: TP = 182, FP = 0, FN = 1482, TN = 14720
# Image 12: TP = 2286, FP = 0, FN = 6645, TN = 7453
# Image 13: TP = 23, FP = 0, FN = 203, TN = 16158
# Image 14: TP = 156, FP = 37, FN = 241, TN = 15950
# Image 15: TP = 2063, FP = 0, FN = 986, TN = 13335
# Image 16: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 17: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 18: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 19: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 20: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 21: TP = 14, FP = 0, FN = 201, TN = 16169
# Image 22: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 23: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 24: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 25: TP = 1127, FP = 0, FN = 2350, TN = 12907
# Image 26: TP = 5718, FP = 0, FN = 3831, TN = 6835
# Image 27: TP = 761, FP = 4, FN = 2115, TN = 13504
# Image 28: TP = 5689, FP = 55, FN = 1306, TN = 9334
# Image 29: TP = 2282, FP = 18, FN = 1236, TN = 12848
# Image 30: TP = 1536, FP = 0, FN = 4577, TN = 10271
# Image 31: TP = 1454, FP = 14, FN = 244, TN = 14672
# Image 32: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 33: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 34: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 35: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 36: TP = 677, FP = 0, FN = 1096, TN = 14611
# Image 37: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 38: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 39: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 40: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 41: TP = 676, FP = 0, FN = 1822, TN = 13886
# Image 42: TP = 53, FP = 0, FN = 2907, TN = 13424
# Image 43: TP = 13, FP = 0, FN = 4392, TN = 11979
# Image 44: TP = 63, FP = 0, FN = 396, TN = 15925
# Image 45: TP = 6182, FP = 0, FN = 3068, TN = 7134
# Image 46: TP = 1911, FP = 16, FN = 865, TN = 13592
# Image 47: TP = 1664, FP = 10, FN = 598, TN = 14112
# Image 48: TP = 0, FP = 0, FN = 1581, TN = 14803
# Image 49: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 50: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 51: TP = 5049, FP = 0, FN = 6241, TN = 5094
# Image 52: TP = 10051, FP = 0, FN = 6333, TN = 0
# Image 53: TP = 303, FP = 0, FN = 4617, TN = 11464
# Image 54: TP = 238, FP = 0, FN = 4836, TN = 11310
# Image 55: TP = 1647, FP = 0, FN = 4741, TN = 9996
# Image 56: TP = 245, FP = 0, FN = 1919, TN = 14220
# Image 57: TP = 664, FP = 0, FN = 2529, TN = 13191
# Image 58: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 59: TP = 3555, FP = 23, FN = 4898, TN = 7908
# Image 60: TP = 245, FP = 0, FN = 1924, TN = 14215
# Image 61: TP = 8057, FP = 13, FN = 5764, TN = 2550
# Image 62: TP = 901, FP = 18, FN = 416, TN = 15049
# Image 63: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 64: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 65: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 66: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 67: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 68: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 69: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 70: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 71: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 72: TP = 615, FP = 3, FN = 1841, TN = 13925
# Image 73: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 74: TP = 46, FP = 2, FN = 744, TN = 15592
# Image 75: TP = 149, FP = 1, FN = 638, TN = 15596
# Image 76: TP = 1947, FP = 1, FN = 8359, TN = 6077
# Image 77: TP = 7689, FP = 42, FN = 5812, TN = 2841
# Image 78: TP = 1627, FP = 192, FN = 217, TN = 14348
# Image 79: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 80: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 81: TP = 128, FP = 0, FN = 1094, TN = 15162
# Image 82: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 83: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 84: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 85: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 86: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 87: TP = 475, FP = 0, FN = 1783, TN = 14126
# Image 88: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 89: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 90: TP = 116, FP = 0, FN = 879, TN = 15389
# Image 91: TP = 3771, FP = 1, FN = 2107, TN = 10505
# Image 92: TP = 7472, FP = 0, FN = 4828, TN = 4084
# Image 93: TP = 7388, FP = 105, FN = 5186, TN = 3705
# Image 94: TP = 1259, FP = 4, FN = 372, TN = 14749
# Image 95: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 96: TP = 42, FP = 0, FN = 634, TN = 15708
# Image 97: TP = 599, FP = 0, FN = 1265, TN = 14520
# Image 98: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 99: TP = 892, FP = 0, FN = 989, TN = 14503
# Image 100: TP = 0, FP = 0, FN = 37, TN = 16347
# Image 101: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 102: TP = 3, FP = 2, FN = 244, TN = 16135
# Image 103: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 104: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 105: TP = 224, FP = 0, FN = 1244, TN = 14916
# Image 106: TP = 60, FP = 4, FN = 158, TN = 16162
# Image 107: TP = 2985, FP = 17, FN = 7832, TN = 5550
# Image 108: TP = 93, FP = 0, FN = 2541, TN = 13750
# Image 109: TP = 3422, FP = 55, FN = 3516, TN = 9391
# Image 110: TP = 3963, FP = 74, FN = 691, TN = 11656
# Image 111: TP = 3, FP = 0, FN = 500, TN = 15881
# Image 112: TP = 218, FP = 0, FN = 895, TN = 15271
# Image 113: TP = 494, FP = 0, FN = 1320, TN = 14570
# Image 114: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 115: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 116: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 117: TP = 189, FP = 0, FN = 10791, TN = 5404
# Image 118: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 119: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 120: TP = 0, FP = 0, FN = 35, TN = 16349
# Image 121: TP = 678, FP = 2, FN = 409, TN = 15295
# Image 122: TP = 9835, FP = 0, FN = 3901, TN = 2648
# Image 123: TP = 7380, FP = 0, FN = 5014, TN = 3990
# Image 124: TP = 9661, FP = 0, FN = 5733, TN = 990
# Image 125: TP = 5525, FP = 0, FN = 4114, TN = 6745
# Image 126: TP = 226, FP = 0, FN = 1167, TN = 14991
# Image 127: TP = 408, FP = 0, FN = 1539, TN = 14437
# Image 128: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 129: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 130: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 131: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 132: TP = 3938, FP = 0, FN = 10838, TN = 1608
# Image 133: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 134: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 135: TP = 3603, FP = 91, FN = 696, TN = 11994
# Image 136: TP = 1318, FP = 5, FN = 3334, TN = 11727
# Image 137: TP = 1384, FP = 0, FN = 1706, TN = 13294
# Image 138: TP = 3935, FP = 142, FN = 3971, TN = 8336
# Image 139: TP = 3282, FP = 0, FN = 5654, TN = 7448
# Image 140: TP = 654, FP = 0, FN = 10991, TN = 4739
# Image 141: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 142: TP = 0, FP = 0, FN = 213, TN = 16171
# Image 143: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 144: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 145: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 146: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 147: TP = 1225, FP = 0, FN = 2653, TN = 12506
# Image 148: TP = 213, FP = 0, FN = 87, TN = 16084
# Image 149: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 150: TP = 10056, FP = 27, FN = 4376, TN = 1925
# Image 151: TP = 1135, FP = 12, FN = 3145, TN = 12092
# Image 152: TP = 3391, FP = 5, FN = 1521, TN = 11467
# Image 153: TP = 4904, FP = 38, FN = 2166, TN = 9276
# Image 154: TP = 1, FP = 0, FN = 1772, TN = 14611
# Image 155: TP = 5015, FP = 0, FN = 6220, TN = 5149
# Image 156: TP = 4070, FP = 145, FN = 236, TN = 11933
# Image 157: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 158: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 159: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 160: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 161: TP = 2728, FP = 8, FN = 1245, TN = 12403
# Image 162: TP = 1169, FP = 1, FN = 1654, TN = 13560
# Image 163: TP = 7197, FP = 39, FN = 379, TN = 8769
# Image 164: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 165: TP = 2209, FP = 0, FN = 1186, TN = 12989
# Image 166: TP = 23, FP = 0, FN = 1718, TN = 14643
# Image 167: TP = 2815, FP = 4, FN = 3446, TN = 10119
# Image 168: TP = 1, FP = 0, FN = 5, TN = 16378
# Image 169: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 170: TP = 586, FP = 2, FN = 149, TN = 15647
# Image 171: TP = 9986, FP = 4, FN = 5122, TN = 1272
# Image 172: TP = 4231, FP = 155, FN = 192, TN = 11806
# Image 173: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 174: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 175: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 176: TP = 1787, FP = 37, FN = 378, TN = 14182
# Image 177: TP = 385, FP = 0, FN = 1233, TN = 14766
# Image 178: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 179: TP = 205, FP = 0, FN = 504, TN = 15675
# Image 180: TP = 7676, FP = 27, FN = 4084, TN = 4597
# Image 181: TP = 314, FP = 0, FN = 611, TN = 15459
# Image 182: TP = 1143, FP = 6, FN = 2055, TN = 13180
# Image 183: TP = 85, FP = 0, FN = 1884, TN = 14415
# Image 184: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 185: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 186: TP = 11095, FP = 0, FN = 4715, TN = 574
# Image 187: TP = 8442, FP = 0, FN = 7942, TN = 0
# Image 188: TP = 713, FP = 0, FN = 1012, TN = 14659
# Image 189: TP = 0, FP = 0, FN = 3278, TN = 13106
# Image 190: TP = 287, FP = 0, FN = 1285, TN = 14812
# Image 191: TP = 2453, FP = 1, FN = 2460, TN = 11470
# Image 192: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 193: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 194: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 195: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 196: TP = 6, FP = 0, FN = 364, TN = 16014
# Image 197: TP = 619, FP = 0, FN = 874, TN = 14891
# Image 198: TP = 1272, FP = 71, FN = 1017, TN = 14024
# Image 199: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 200: TP = 0, FP = 0, FN = 109, TN = 16275
# Image 201: TP = 1980, FP = 0, FN = 3268, TN = 11136
# Image 202: TP = 5596, FP = 0, FN = 7185, TN = 3603
# Image 203: TP = 0, FP = 0, FN = 1038, TN = 15346
# Image 204: TP = 1040, FP = 0, FN = 5713, TN = 9631
# Image 205: TP = 0, FP = 0, FN = 193, TN = 16191
# Image 206: TP = 0, FP = 0, FN = 1, TN = 16383
# Image 207: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 208: TP = 0, FP = 0, FN = 1492, TN = 14892
# Image 209: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 210: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 211: TP = 1619, FP = 17, FN = 3348, TN = 11400
# Image 212: TP = 1139, FP = 7, FN = 561, TN = 14677
# Image 213: TP = 450, FP = 0, FN = 642, TN = 15292
# Image 214: TP = 660, FP = 0, FN = 2273, TN = 13451
# Image 215: TP = 4344, FP = 21, FN = 2986, TN = 9033
# Image 216: TP = 199, FP = 0, FN = 1577, TN = 14608
# Image 217: TP = 2518, FP = 0, FN = 4710, TN = 9156
# Image 218: TP = 1044, FP = 0, FN = 1712, TN = 13628
# Image 219: TP = 5663, FP = 0, FN = 4245, TN = 6476
# Image 220: TP = 0, FP = 0, FN = 182, TN = 16202
# Image 221: TP = 0, FP = 0, FN = 406, TN = 15978
# Image 222: TP = 624, FP = 0, FN = 2441, TN = 13319
# Image 223: TP = 152, FP = 9, FN = 11380, TN = 4843
# Image 224: TP = 2210, FP = 22, FN = 6458, TN = 7694
# Image 225: TP = 401, FP = 0, FN = 620, TN = 15363
# Image 226: TP = 707, FP = 2, FN = 2792, TN = 12883
# Image 227: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 228: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 229: TP = 148, FP = 0, FN = 897, TN = 15339
# Image 230: TP = 7110, FP = 87, FN = 1335, TN = 7852
# Image 231: TP = 1018, FP = 0, FN = 5669, TN = 9697
# Image 232: TP = 2398, FP = 0, FN = 2676, TN = 11310
# Image 233: TP = 1433, FP = 4, FN = 3898, TN = 11049
# Image 234: TP = 1463, FP = 6, FN = 489, TN = 14426
# Image 235: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 236: TP = 0, FP = 0, FN = 10933, TN = 5451
# Image 237: TP = 201, FP = 0, FN = 1494, TN = 14689
# Image 238: TP = 841, FP = 0, FN = 14869, TN = 674
# Image 239: TP = 4641, FP = 0, FN = 8746, TN = 2997
# Image 240: TP = 16, FP = 0, FN = 546, TN = 15822
# Image 241: TP = 14, FP = 0, FN = 918, TN = 15452
# Image 242: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 243: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 244: TP = 572, FP = 10, FN = 107, TN = 15695
# Image 245: TP = 0, FP = 0, FN = 76, TN = 16308
# Image 246: TP = 761, FP = 4, FN = 3555, TN = 12064
# Image 247: TP = 483, FP = 0, FN = 1054, TN = 14847
# Image 248: TP = 210, FP = 0, FN = 1598, TN = 14576
# Image 249: TP = 0, FP = 0, FN = 4, TN = 16380
# Image 250: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 251: TP = 0, FP = 0, FN = 1240, TN = 15144
# Image 252: TP = 1458, FP = 0, FN = 2312, TN = 12614
# Image 253: TP = 155, FP = 0, FN = 4304, TN = 11925
# Image 254: TP = 6213, FP = 0, FN = 7727, TN = 2444
# Image 255: TP = 2248, FP = 0, FN = 3647, TN = 10489
# Image 256: TP = 1003, FP = 0, FN = 6289, TN = 9092
# Image 257: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 258: TP = 530, FP = 0, FN = 279, TN = 15575
# Image 259: TP = 1352, FP = 3, FN = 701, TN = 14328
# Image 260: TP = 79, FP = 0, FN = 101, TN = 16204
# Image 261: TP = 4280, FP = 0, FN = 4613, TN = 7491
# Image 262: TP = 814, FP = 0, FN = 6456, TN = 9114
# Image 263: TP = 2343, FP = 0, FN = 1621, TN = 12420
# Image 264: TP = 225, FP = 0, FN = 3386, TN = 12773
# Image 265: TP = 0, FP = 0, FN = 1, TN = 16383
# Image 266: TP = 0, FP = 0, FN = 3989, TN = 12395
# Image 267: TP = 4711, FP = 0, FN = 2733, TN = 8940
# Image 268: TP = 6342, FP = 0, FN = 4105, TN = 5937
# Image 269: TP = 6579, FP = 169, FN = 1998, TN = 7638
# Image 270: TP = 6752, FP = 11, FN = 5013, TN = 4608
# Image 271: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 272: TP = 26, FP = 5, FN = 9, TN = 16344
# Image 273: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 274: TP = 4403, FP = 0, FN = 9833, TN = 2148
# Image 275: TP = 5269, FP = 0, FN = 5517, TN = 5598
# Image 276: TP = 811, FP = 2, FN = 1450, TN = 14121
# Image 277: TP = 1222, FP = 26, FN = 7254, TN = 7882
# Image 278: TP = 1023, FP = 8, FN = 1351, TN = 14002
# Image 279: TP = 5119, FP = 3, FN = 4795, TN = 6467
# Image 280: TP = 7, FP = 0, FN = 13780, TN = 2597
# Image 281: TP = 1623, FP = 3, FN = 6402, TN = 8356
# Image 282: TP = 2491, FP = 0, FN = 6484, TN = 7409
# Image 283: TP = 2419, FP = 0, FN = 10263, TN = 3702
# Image 284: TP = 1181, FP = 0, FN = 5819, TN = 9384
# Image 285: TP = 2938, FP = 0, FN = 7831, TN = 5615
# Image 286: TP = 4368, FP = 0, FN = 8691, TN = 3325
# Image 287: TP = 4614, FP = 23, FN = 7668, TN = 4079
# Image 288: TP = 1740, FP = 26, FN = 9461, TN = 5157
# Image 289: TP = 2352, FP = 0, FN = 2547, TN = 11485
# Image 290: TP = 4861, FP = 2, FN = 4953, TN = 6568
# Image 291: TP = 3053, FP = 3, FN = 4398, TN = 8930
# Image 292: TP = 1241, FP = 0, FN = 5944, TN = 9199
# Image 293: TP = 1025, FP = 0, FN = 4517, TN = 10842
# Image 294: TP = 7, FP = 0, FN = 2617, TN = 13760
# Image 295: TP = 2, FP = 0, FN = 1205, TN = 15177
# Image 296: TP = 169, FP = 0, FN = 3677, TN = 12538
# Image 297: TP = 239, FP = 1, FN = 5221, TN = 10923
# Image 298: TP = 112, FP = 0, FN = 2296, TN = 13976
# Image 299: TP = 0, FP = 0, FN = 613, TN = 15771
# Image 300: TP = 1048, FP = 6, FN = 5077, TN = 10253
# Image 301: TP = 4136, FP = 6, FN = 2989, TN = 9253
# Image 302: TP = 1990, FP = 1, FN = 4780, TN = 9613
# Image 303: TP = 3087, FP = 8, FN = 6162, TN = 7127
# Image 304: TP = 807, FP = 0, FN = 1904, TN = 13673
# Image 305: TP = 3532, FP = 0, FN = 3806, TN = 9046
# Image 306: TP = 3674, FP = 0, FN = 2679, TN = 10031
# Image 307: TP = 142, FP = 0, FN = 2502, TN = 13740
# Image 308: TP = 248, FP = 0, FN = 2736, TN = 13400
# Image 309: TP = 1392, FP = 0, FN = 10383, TN = 4609
# Image 310: TP = 0, FP = 0, FN = 6106, TN = 10278
# Image 311: TP = 91, FP = 1, FN = 3032, TN = 13260
# Image 312: TP = 3355, FP = 0, FN = 12917, TN = 112
# Image 313: TP = 140, FP = 1, FN = 3222, TN = 13021
# Image 314: TP = 320, FP = 0, FN = 2104, TN = 13960
# Image 315: TP = 1276, FP = 0, FN = 8880, TN = 6228
# Image 316: TP = 635, FP = 0, FN = 1649, TN = 14100
# Image 317: TP = 79, FP = 0, FN = 4121, TN = 12184
# Image 318: TP = 0, FP = 0, FN = 1315, TN = 15069
# Image 319: TP = 0, FP = 0, FN = 1422, TN = 14962
# Image 320: TP = 529, FP = 0, FN = 5559, TN = 10296
# Image 321: TP = 171, FP = 0, FN = 168, TN = 16045
# Image 322: TP = 74, FP = 0, FN = 7473, TN = 8837
# Image 323: TP = 199, FP = 0, FN = 810, TN = 15375
# Image 324: TP = 4271, FP = 0, FN = 12033, TN = 80
# Image 325: TP = 3239, FP = 0, FN = 5647, TN = 7498
# Image 326: TP = 1913, FP = 31, FN = 6976, TN = 7464
# Image 327: TP = 449, FP = 2, FN = 326, TN = 15607
# Image 328: TP = 945, FP = 0, FN = 7022, TN = 8417
# Image 329: TP = 6685, FP = 11, FN = 4909, TN = 4779
# Image 330: TP = 1261, FP = 0, FN = 1124, TN = 13999
# Image 331: TP = 1527, FP = 17, FN = 8992, TN = 5848
# Image 332: TP = 10094, FP = 22, FN = 4619, TN = 1649
# Image 333: TP = 6430, FP = 32, FN = 2575, TN = 7347
# Image 334: TP = 11046, FP = 3, FN = 3361, TN = 1974
# Image 335: TP = 7368, FP = 5, FN = 4002, TN = 5009
# Image 336: TP = 1879, FP = 0, FN = 2020, TN = 12485
# Image 337: TP = 605, FP = 0, FN = 5745, TN = 10034
# Image 338: TP = 74, FP = 0, FN = 9219, TN = 7091
# Image 339: TP = 0, FP = 0, FN = 3912, TN = 12472
# Image 340: TP = 0, FP = 0, FN = 10505, TN = 5879
# Image 341: TP = 0, FP = 0, FN = 3051, TN = 13333
# Image 342: TP = 3195, FP = 22, FN = 8269, TN = 4898
# Image 343: TP = 1173, FP = 19, FN = 4763, TN = 10429
# Image 344: TP = 3050, FP = 5, FN = 3329, TN = 10000
# Image 345: TP = 2951, FP = 30, FN = 9843, TN = 3560
# Image 346: TP = 787, FP = 27, FN = 1292, TN = 14278
# Image 347: TP = 2807, FP = 67, FN = 7367, TN = 6143
# Image 348: TP = 87, FP = 0, FN = 5854, TN = 10443
# Image 349: TP = 7, FP = 0, FN = 1891, TN = 14486
# Image 350: TP = 4228, FP = 0, FN = 5106, TN = 7050
# Image 351: TP = 7, FP = 0, FN = 2195, TN = 14182
# Image 352: TP = 319, FP = 0, FN = 10533, TN = 5532
# Image 353: TP = 78, FP = 0, FN = 15043, TN = 1263
# Image 354: TP = 1037, FP = 0, FN = 15347, TN = 0
# Image 355: TP = 5790, FP = 0, FN = 10594, TN = 0
# Image 356: TP = 5443, FP = 0, FN = 7354, TN = 3587
# Image 357: TP = 2534, FP = 0, FN = 10671, TN = 3179
# Image 358: TP = 0, FP = 0, FN = 1288, TN = 15096
# Image 359: TP = 174, FP = 0, FN = 1711, TN = 14499
# Image 360: TP = 4192, FP = 0, FN = 12192, TN = 0
# Image 361: TP = 2049, FP = 0, FN = 1614, TN = 12721
# Image 362: TP = 6783, FP = 5, FN = 7276, TN = 2320
# Image 363: TP = 532, FP = 0, FN = 6503, TN = 9349
# Image 364: TP = 122, FP = 9, FN = 1590, TN = 14663
# Image 365: TP = 778, FP = 0, FN = 4746, TN = 10860
# Image 366: TP = 1644, FP = 0, FN = 14014, TN = 726
# Image 367: TP = 2381, FP = 0, FN = 14003, TN = 0
# Image 368: TP = 2183, FP = 0, FN = 14201, TN = 0
# Image 369: TP = 2188, FP = 0, FN = 14196, TN = 0
# Image 370: TP = 1320, FP = 0, FN = 13665, TN = 1399
# Image 371: TP = 274, FP = 0, FN = 6029, TN = 10081
# Image 372: TP = 2236, FP = 0, FN = 12191, TN = 1957
# Image 373: TP = 3112, FP = 0, FN = 3434, TN = 9838
# Image 374: TP = 4877, FP = 12, FN = 2610, TN = 8885
# Image 375: TP = 2991, FP = 0, FN = 12077, TN = 1316
# Image 376: TP = 2197, FP = 39, FN = 1709, TN = 12439
# Image 377: TP = 6961, FP = 0, FN = 5286, TN = 4137
# Image 378: TP = 30, FP = 0, FN = 4234, TN = 12120
# Image 379: TP = 0, FP = 0, FN = 34, TN = 16350
# Image 380: TP = 4, FP = 0, FN = 2470, TN = 13910
# Image 381: TP = 2689, FP = 0, FN = 13529, TN = 166
# Image 382: TP = 529, FP = 0, FN = 7979, TN = 7876
# Image 383: TP = 11, FP = 0, FN = 14574, TN = 1799
# Image 384: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 385: TP = 46, FP = 0, FN = 11573, TN = 4765
# Image 386: TP = 1292, FP = 0, FN = 8684, TN = 6408
# Image 387: TP = 4971, FP = 0, FN = 11413, TN = 0
# Image 388: TP = 935, FP = 0, FN = 1347, TN = 14102
# Image 389: TP = 1624, FP = 1, FN = 4656, TN = 10103
# Image 390: TP = 1719, FP = 0, FN = 11419, TN = 3246
# Image 391: TP = 2968, FP = 0, FN = 2419, TN = 10997
# Image 392: TP = 2836, FP = 0, FN = 6874, TN = 6674
# Image 393: TP = 125, FP = 0, FN = 4395, TN = 11864
# Image 394: TP = 247, FP = 0, FN = 1828, TN = 14309
# Image 395: TP = 852, FP = 0, FN = 13712, TN = 1820
# Image 396: TP = 0, FP = 0, FN = 13944, TN = 2440
# Image 397: TP = 0, FP = 0, FN = 8077, TN = 8307
# Image 398: TP = 0, FP = 0, FN = 16322, TN = 62
# Image 399: TP = 5, FP = 0, FN = 16379, TN = 0
# Image 400: TP = 667, FP = 0, FN = 15717, TN = 0
# Image 401: TP = 930, FP = 0, FN = 15137, TN = 317
# Image 402: TP = 7365, FP = 52, FN = 3398, TN = 5569
# Image 403: TP = 98, FP = 0, FN = 6222, TN = 10064
# Image 404: TP = 7061, FP = 206, FN = 2872, TN = 6245
# Image 405: TP = 1673, FP = 15, FN = 610, TN = 14086
# Image 406: TP = 601, FP = 0, FN = 237, TN = 15546
# Image 407: TP = 1565, FP = 101, FN = 1827, TN = 12891
# Image 408: TP = 1061, FP = 1, FN = 6720, TN = 8602
# Image 409: TP = 23, FP = 0, FN = 1413, TN = 14948
# Image 410: TP = 0, FP = 0, FN = 1126, TN = 15258
# Image 411: TP = 3533, FP = 102, FN = 2602, TN = 10147
# Image 412: TP = 301, FP = 2, FN = 2259, TN = 13822
# Image 413: TP = 986, FP = 0, FN = 7901, TN = 7497
# Image 414: TP = 2701, FP = 7, FN = 883, TN = 12793
# Image 415: TP = 4274, FP = 0, FN = 8162, TN = 3948
# Image 416: TP = 914, FP = 2, FN = 3874, TN = 11594
# Image 417: TP = 5852, FP = 11, FN = 3012, TN = 7509
# Image 418: TP = 4410, FP = 8, FN = 8020, TN = 3946
# Image 419: TP = 6322, FP = 12, FN = 8287, TN = 1763
# Image 420: TP = 6336, FP = 16, FN = 2198, TN = 7834
# Image 421: TP = 3972, FP = 5, FN = 7761, TN = 4646
# Image 422: TP = 3748, FP = 11, FN = 2891, TN = 9734
# Image 423: TP = 3945, FP = 2, FN = 3988, TN = 8449
# Image 424: TP = 4099, FP = 78, FN = 6995, TN = 5212
# Image 425: TP = 3864, FP = 25, FN = 5587, TN = 6908
# Image 426: TP = 9889, FP = 154, FN = 3444, TN = 2897
# Image 427: TP = 241, FP = 53, FN = 352, TN = 15738
# Image 428: TP = 1513, FP = 0, FN = 6532, TN = 8339
# Image 429: TP = 707, FP = 0, FN = 7818, TN = 7859
# Image 430: TP = 279, FP = 0, FN = 3410, TN = 12695
# Image 431: TP = 2426, FP = 0, FN = 8948, TN = 5010
# Image 432: TP = 14253, FP = 100, FN = 1411, TN = 620
# Image 433: TP = 1306, FP = 13, FN = 3466, TN = 11599
# Image 434: TP = 2575, FP = 0, FN = 9753, TN = 4056
# Image 435: TP = 7683, FP = 0, FN = 7111, TN = 1590
# Image 436: TP = 5667, FP = 0, FN = 8543, TN = 2174
# Image 437: TP = 3764, FP = 39, FN = 9672, TN = 2909
# Image 438: TP = 4851, FP = 6, FN = 8699, TN = 2828
# Image 439: TP = 3105, FP = 2, FN = 9852, TN = 3425
# Image 440: TP = 2395, FP = 3, FN = 11291, TN = 2695
# Image 441: TP = 2073, FP = 0, FN = 3030, TN = 11281
# Image 442: TP = 1413, FP = 19, FN = 2537, TN = 12415
# Image 443: TP = 0, FP = 0, FN = 1783, TN = 14601
# Image 444: TP = 213, FP = 0, FN = 9202, TN = 6969
# Image 445: TP = 235, FP = 21, FN = 3825, TN = 12303
# Image 446: TP = 1360, FP = 0, FN = 11664, TN = 3360
# Image 447: TP = 2587, FP = 83, FN = 5992, TN = 7722
# Image 448: TP = 1351, FP = 0, FN = 12118, TN = 2915
# Image 449: TP = 294, FP = 0, FN = 5961, TN = 10129
# Image 450: TP = 3860, FP = 0, FN = 6674, TN = 5850
# Image 451: TP = 91, FP = 0, FN = 16293, TN = 0
# Image 452: TP = 1754, FP = 0, FN = 14630, TN = 0
# Image 453: TP = 30, FP = 0, FN = 16354, TN = 0
# Image 454: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 455: TP = 292, FP = 0, FN = 16092, TN = 0
# Image 456: TP = 1900, FP = 12, FN = 4221, TN = 10251
# Image 457: TP = 174, FP = 0, FN = 8423, TN = 7787
# Image 458: TP = 227, FP = 32, FN = 975, TN = 15150
# Image 459: TP = 543, FP = 0, FN = 9522, TN = 6319
# Image 460: TP = 2107, FP = 0, FN = 14277, TN = 0
# Image 461: TP = 7660, FP = 0, FN = 8724, TN = 0
# Image 462: TP = 2085, FP = 2, FN = 5488, TN = 8809
# Image 463: TP = 10828, FP = 0, FN = 5525, TN = 31
# Image 464: TP = 979, FP = 0, FN = 5921, TN = 9484
# Image 465: TP = 4416, FP = 15, FN = 3512, TN = 8441
# Image 466: TP = 1062, FP = 0, FN = 13904, TN = 1418
# Image 467: TP = 98, FP = 0, FN = 15051, TN = 1235
# Image 468: TP = 227, FP = 0, FN = 15961, TN = 196
# Image 469: TP = 331, FP = 0, FN = 14908, TN = 1145
# Image 470: TP = 2, FP = 0, FN = 11460, TN = 4922
# Image 471: TP = 6676, FP = 0, FN = 9369, TN = 339
# Image 472: TP = 0, FP = 0, FN = 2348, TN = 14036
# Image 473: TP = 306, FP = 0, FN = 1618, TN = 14460
# Image 474: TP = 449, FP = 0, FN = 3952, TN = 11983
# Image 475: TP = 9665, FP = 0, FN = 6650, TN = 69
# Image 476: TP = 11507, FP = 0, FN = 4877, TN = 0
# Image 477: TP = 5710, FP = 0, FN = 2739, TN = 7935
# Image 478: TP = 10237, FP = 0, FN = 6147, TN = 0
# Image 479: TP = 2966, FP = 0, FN = 3174, TN = 10244
# Image 480: TP = 3653, FP = 0, FN = 8916, TN = 3815
# Image 481: TP = 0, FP = 0, FN = 2739, TN = 13645
# Image 482: TP = 60, FP = 0, FN = 5123, TN = 11201
# Image 483: TP = 0, FP = 0, FN = 224, TN = 16160
# Image 484: TP = 350, FP = 1, FN = 5625, TN = 10408
# Image 485: TP = 116, FP = 0, FN = 1335, TN = 14933
# Image 486: TP = 5421, FP = 0, FN = 3994, TN = 6969
# Image 487: TP = 2098, FP = 1, FN = 5543, TN = 8742
# Image 488: TP = 907, FP = 23, FN = 3102, TN = 12352
# Image 489: TP = 47, FP = 0, FN = 422, TN = 15915
# Image 490: TP = 1267, FP = 0, FN = 5148, TN = 9969
# Image 491: TP = 5636, FP = 0, FN = 10335, TN = 413
# Image 492: TP = 3503, FP = 24, FN = 2487, TN = 10370
# Image 493: TP = 611, FP = 12, FN = 639, TN = 15122
# Image 494: TP = 356, FP = 0, FN = 246, TN = 15782
# Image 495: TP = 13392, FP = 32, FN = 1266, TN = 1694
# Image 496: TP = 975, FP = 25, FN = 1047, TN = 14337
# Image 497: TP = 5799, FP = 116, FN = 1648, TN = 8821
# Image 498: TP = 854, FP = 7, FN = 1566, TN = 13957
# Image 499: TP = 4538, FP = 0, FN = 5472, TN = 6374
# Image 500: TP = 8076, FP = 23, FN = 5032, TN = 3253
# Image 501: TP = 13263, FP = 7, FN = 2212, TN = 902
# Image 502: TP = 10584, FP = 8, FN = 2727, TN = 3065
# Image 503: TP = 7695, FP = 106, FN = 358, TN = 8225
# Image 504: TP = 58, FP = 54, FN = 478, TN = 15794
# Image 505: TP = 1457, FP = 19, FN = 682, TN = 14226
# Image 506: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 507: TP = 2362, FP = 75, FN = 704, TN = 13243
# Image 508: TP = 12062, FP = 75, FN = 2312, TN = 1935
# Image 509: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 510: TP = 10674, FP = 0, FN = 5710, TN = 0
# Image 511: TP = 13247, FP = 0, FN = 3137, TN = 0
# Image 512: TP = 3947, FP = 0, FN = 12437, TN = 0
# Image 513: TP = 12483, FP = 0, FN = 3901, TN = 0
# Image 514: TP = 11, FP = 0, FN = 293, TN = 16080
# Image 515: TP = 535, FP = 31, FN = 1286, TN = 14532
# Image 516: TP = 68, FP = 1, FN = 228, TN = 16087
# Image 517: TP = 32, FP = 0, FN = 515, TN = 15837
# Image 518: TP = 3529, FP = 0, FN = 3169, TN = 9686
# Image 519: TP = 181, FP = 0, FN = 920, TN = 15283
# Image 520: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 521: TP = 779, FP = 14, FN = 3882, TN = 11709
# Image 522: TP = 3462, FP = 86, FN = 2943, TN = 9893
# Image 523: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 524: TP = 11773, FP = 31, FN = 1764, TN = 2816
# Image 525: TP = 9757, FP = 0, FN = 6440, TN = 187
# Image 526: TP = 12877, FP = 0, FN = 3507, TN = 0
# Image 527: TP = 9015, FP = 0, FN = 7369, TN = 0
# Image 528: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 529: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 530: TP = 736, FP = 0, FN = 813, TN = 14835
# Image 531: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 532: TP = 168, FP = 0, FN = 202, TN = 16014
# Image 533: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 534: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 535: TP = 5388, FP = 35, FN = 4723, TN = 6238
# Image 536: TP = 3105, FP = 85, FN = 2675, TN = 10519
# Image 537: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 538: TP = 0, FP = 0, FN = 253, TN = 16131
# Image 539: TP = 2276, FP = 0, FN = 5510, TN = 8598
# Image 540: TP = 9385, FP = 0, FN = 6999, TN = 0
# Image 541: TP = 14239, FP = 10, FN = 1408, TN = 727
# Image 542: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 543: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 544: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 545: TP = 192, FP = 0, FN = 444, TN = 15748
# Image 546: TP = 150, FP = 0, FN = 153, TN = 16081
# Image 547: TP = 431, FP = 0, FN = 156, TN = 15797
# Image 548: TP = 4458, FP = 4, FN = 1890, TN = 10032
# Image 549: TP = 90, FP = 0, FN = 134, TN = 16160
# Image 550: TP = 2340, FP = 6, FN = 5628, TN = 8410
# Image 551: TP = 1662, FP = 7, FN = 232, TN = 14483
# Image 552: TP = 1454, FP = 0, FN = 3611, TN = 11319
# Image 553: TP = 2331, FP = 0, FN = 2968, TN = 11085
# Image 554: TP = 1858, FP = 37, FN = 5447, TN = 9042
# Image 555: TP = 4238, FP = 25, FN = 1666, TN = 10455
# Image 556: TP = 3806, FP = 1, FN = 7153, TN = 5424
# Image 557: TP = 7813, FP = 0, FN = 8571, TN = 0
# Image 558: TP = 13960, FP = 0, FN = 2424, TN = 0
# Image 559: TP = 7907, FP = 0, FN = 7793, TN = 684
# Image 560: TP = 564, FP = 0, FN = 4712, TN = 11108
# Image 561: TP = 5202, FP = 37, FN = 1577, TN = 9568
# Image 562: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 563: TP = 1342, FP = 3, FN = 2063, TN = 12976
# Image 564: TP = 5485, FP = 70, FN = 3531, TN = 7298
# Image 565: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 566: TP = 5333, FP = 45, FN = 2636, TN = 8370
# Image 567: TP = 5485, FP = 4, FN = 6029, TN = 4866
# Image 568: TP = 16164, FP = 0, FN = 220, TN = 0
# Image 569: TP = 11510, FP = 57, FN = 930, TN = 3887
# Image 570: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 571: TP = 0, FP = 0, FN = 24, TN = 16360
# Image 572: TP = 1511, FP = 0, FN = 4310, TN = 10563
# Image 573: TP = 93, FP = 0, FN = 509, TN = 15782
# Image 574: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 575: TP = 562, FP = 0, FN = 936, TN = 14886
# Image 576: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 577: TP = 8814, FP = 0, FN = 1085, TN = 6485
# Image 578: TP = 549, FP = 0, FN = 559, TN = 15276
# Image 579: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 580: TP = 145, FP = 11, FN = 203, TN = 16025
# Image 581: TP = 7818, FP = 0, FN = 5369, TN = 3197
# Image 582: TP = 12391, FP = 0, FN = 3993, TN = 0
# Image 583: TP = 3207, FP = 0, FN = 2366, TN = 10811
# Image 584: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 585: TP = 21, FP = 1, FN = 359, TN = 16003
# Image 586: TP = 1426, FP = 0, FN = 1663, TN = 13295
# Image 587: TP = 2014, FP = 3, FN = 1759, TN = 12608
# Image 588: TP = 582, FP = 33, FN = 1112, TN = 14657
# Image 589: TP = 14003, FP = 1, FN = 1762, TN = 618
# Image 590: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 591: TP = 9169, FP = 0, FN = 7215, TN = 0
# Image 592: TP = 7785, FP = 81, FN = 2229, TN = 6289
# Image 593: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 594: TP = 3956, FP = 0, FN = 721, TN = 11707
# Image 595: TP = 606, FP = 11, FN = 1142, TN = 14625
# Image 596: TP = 2671, FP = 0, FN = 5779, TN = 7934
# Image 597: TP = 0, FP = 0, FN = 1453, TN = 14931
# Image 598: TP = 0, FP = 0, FN = 57, TN = 16327
# Image 599: TP = 0, FP = 0, FN = 264, TN = 16120
# Image 600: TP = 0, FP = 0, FN = 156, TN = 16228
# Image 601: TP = 74, FP = 6, FN = 642, TN = 15662
# Image 602: TP = 7319, FP = 4, FN = 939, TN = 8122
# Image 603: TP = 15078, FP = 0, FN = 1306, TN = 0
# Image 604: TP = 0, FP = 0, FN = 111, TN = 16273
# Image 605: TP = 11729, FP = 0, FN = 4655, TN = 0
# Image 606: TP = 7336, FP = 110, FN = 4472, TN = 4466
# Image 607: TP = 0, FP = 0, FN = 178, TN = 16206
# Image 608: TP = 7947, FP = 0, FN = 7984, TN = 453
# Image 609: TP = 5491, FP = 20, FN = 1965, TN = 8908
# Image 610: TP = 195, FP = 0, FN = 421, TN = 15768
# Image 611: TP = 242, FP = 0, FN = 579, TN = 15563
# Image 612: TP = 1125, FP = 0, FN = 1892, TN = 13367
# Image 613: TP = 5597, FP = 0, FN = 8643, TN = 2144
# Image 614: TP = 859, FP = 0, FN = 3307, TN = 12218
# Image 615: TP = 0, FP = 0, FN = 571, TN = 15813
# Image 616: TP = 13092, FP = 0, FN = 2041, TN = 1251
# Image 617: TP = 12973, FP = 0, FN = 3411, TN = 0
# Image 618: TP = 107, FP = 0, FN = 1218, TN = 15059
# Image 619: TP = 16003, FP = 0, FN = 381, TN = 0
# Image 620: TP = 4202, FP = 0, FN = 6675, TN = 5507
# Image 621: TP = 1518, FP = 0, FN = 2275, TN = 12591
# Image 622: TP = 3382, FP = 0, FN = 4924, TN = 8078
# Image 623: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 624: TP = 0, FP = 0, FN = 3146, TN = 13238
# Image 625: TP = 23, FP = 8, FN = 501, TN = 15852
# Image 626: TP = 8335, FP = 0, FN = 2934, TN = 5115
# Image 627: TP = 4995, FP = 44, FN = 4387, TN = 6958
# Image 628: TP = 5550, FP = 50, FN = 1759, TN = 9025
# Image 629: TP = 5406, FP = 0, FN = 3832, TN = 7146
# Image 630: TP = 15450, FP = 0, FN = 934, TN = 0
# Image 631: TP = 12134, FP = 0, FN = 4250, TN = 0
# Image 632: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 633: TP = 11373, FP = 0, FN = 5011, TN = 0
# Image 634: TP = 6124, FP = 0, FN = 5086, TN = 5174
# Image 635: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 636: TP = 0, FP = 0, FN = 524, TN = 15860
# Image 637: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 638: TP = 0, FP = 0, FN = 3278, TN = 13106
# Image 639: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 640: TP = 1117, FP = 26, FN = 784, TN = 14457
# Image 641: TP = 0, FP = 0, FN = 994, TN = 15390
# Image 642: TP = 4485, FP = 74, FN = 1767, TN = 10058
# Image 643: TP = 4029, FP = 20, FN = 2574, TN = 9761
# Image 644: TP = 15405, FP = 0, FN = 979, TN = 0
# Image 645: TP = 11914, FP = 0, FN = 4470, TN = 0
# Image 646: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 647: TP = 5583, FP = 0, FN = 10801, TN = 0
# Image 648: TP = 12496, FP = 0, FN = 3887, TN = 1
# Image 649: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 650: TP = 9201, FP = 0, FN = 1974, TN = 5209
# Image 651: TP = 1015, FP = 0, FN = 714, TN = 14655
# Image 652: TP = 28, FP = 0, FN = 1756, TN = 14600
# Image 653: TP = 1329, FP = 16, FN = 1251, TN = 13788
# Image 654: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 655: TP = 0, FP = 0, FN = 739, TN = 15645
# Image 656: TP = 1825, FP = 0, FN = 1431, TN = 13128
# Image 657: TP = 8403, FP = 52, FN = 1827, TN = 6102
# Image 658: TP = 10889, FP = 0, FN = 5495, TN = 0
# Image 659: TP = 11650, FP = 0, FN = 4734, TN = 0
# Image 660: TP = 2901, FP = 0, FN = 803, TN = 12680
# Image 661: TP = 3391, FP = 75, FN = 4377, TN = 8541
# Image 662: TP = 11606, FP = 0, FN = 2695, TN = 2083
# Image 663: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 664: TP = 15297, FP = 0, FN = 1087, TN = 0
# Image 665: TP = 1475, FP = 0, FN = 1254, TN = 13655
# Image 666: TP = 434, FP = 0, FN = 2038, TN = 13912
# Image 667: TP = 6478, FP = 5, FN = 9140, TN = 761
# Image 668: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 669: TP = 0, FP = 0, FN = 87, TN = 16297
# Image 670: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 671: TP = 2057, FP = 0, FN = 1430, TN = 12897
# Image 672: TP = 7561, FP = 22, FN = 4501, TN = 4300
# Image 673: TP = 4608, FP = 71, FN = 1232, TN = 10473
# Image 674: TP = 0, FP = 0, FN = 2442, TN = 13942
# Image 675: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 676: TP = 1844, FP = 0, FN = 3814, TN = 10726
# Image 677: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 678: TP = 7810, FP = 0, FN = 8526, TN = 48
# Image 679: TP = 6807, FP = 0, FN = 9566, TN = 11
# Image 680: TP = 2293, FP = 0, FN = 4071, TN = 10020
# Image 681: TP = 6774, FP = 0, FN = 8813, TN = 797
# Image 682: TP = 3551, FP = 38, FN = 3538, TN = 9257
# Image 683: TP = 5800, FP = 90, FN = 4953, TN = 5541
# Image 684: TP = 11718, FP = 0, FN = 4347, TN = 319
# Image 685: TP = 6489, FP = 0, FN = 9895, TN = 0
# Image 686: TP = 11028, FP = 0, FN = 5356, TN = 0
# Image 687: TP = 5219, FP = 3, FN = 1512, TN = 9650
# Image 688: TP = 0, FP = 0, FN = 278, TN = 16106
# Image 689: TP = 0, FP = 0, FN = 336, TN = 16048
# Image 690: TP = 2104, FP = 0, FN = 7098, TN = 7182
# Image 691: TP = 0, FP = 0, FN = 3, TN = 16381
# Image 692: TP = 5513, FP = 0, FN = 10871, TN = 0
# Image 693: TP = 5730, FP = 0, FN = 10654, TN = 0
# Image 694: TP = 10694, FP = 0, FN = 5690, TN = 0
# Image 695: TP = 14645, FP = 0, FN = 1739, TN = 0
# Image 696: TP = 5118, FP = 28, FN = 3927, TN = 7311
# Image 697: TP = 210, FP = 21, FN = 235, TN = 15918
# Image 698: TP = 0, FP = 0, FN = 2751, TN = 13633
# Image 699: TP = 552, FP = 0, FN = 11853, TN = 3979
# Image 700: TP = 12950, FP = 12, FN = 1480, TN = 1942
# Image 701: TP = 240, FP = 3, FN = 1576, TN = 14565
# Image 702: TP = 0, FP = 0, FN = 186, TN = 16198
# Image 703: TP = 0, FP = 0, FN = 462, TN = 15922
# Image 704: TP = 4059, FP = 0, FN = 6238, TN = 6087
# Image 705: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 706: TP = 22, FP = 0, FN = 7713, TN = 8649
# Image 707: TP = 8539, FP = 0, FN = 7845, TN = 0
# Image 708: TP = 16376, FP = 0, FN = 8, TN = 0
# Image 709: TP = 11430, FP = 0, FN = 4954, TN = 0
# Image 710: TP = 188, FP = 0, FN = 3680, TN = 12516
# Image 711: TP = 4882, FP = 73, FN = 3989, TN = 7440
# Image 712: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 713: TP = 110, FP = 0, FN = 328, TN = 15946
# Image 714: TP = 2409, FP = 52, FN = 292, TN = 13631
# Image 715: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 716: TP = 7, FP = 0, FN = 851, TN = 15526
# Image 717: TP = 9443, FP = 3, FN = 4175, TN = 2763
# Image 718: TP = 5885, FP = 6, FN = 5859, TN = 4634
# Image 719: TP = 735, FP = 0, FN = 887, TN = 14762
# Image 720: TP = 10319, FP = 0, FN = 5286, TN = 779
# Image 721: TP = 14302, FP = 0, FN = 2082, TN = 0
# Image 722: TP = 16384, FP = 0, FN = 0, TN = 0
# Image 723: TP = 13237, FP = 0, FN = 3147, TN = 0
# Image 724: TP = 1444, FP = 0, FN = 3888, TN = 11052
# Image 725: TP = 1035, FP = 1, FN = 2176, TN = 13172
# Image 726: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 727: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 728: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 729: TP = 221, FP = 0, FN = 1585, TN = 14578
# Image 730: TP = 385, FP = 0, FN = 786, TN = 15213
# Image 731: TP = 10609, FP = 0, FN = 2848, TN = 2927
# Image 732: TP = 6742, FP = 0, FN = 9642, TN = 0
# Image 733: TP = 0, FP = 0, FN = 2842, TN = 13542
# Image 734: TP = 13796, FP = 0, FN = 2588, TN = 0
# Image 735: TP = 13786, FP = 0, FN = 2598, TN = 0
# Image 736: TP = 13998, FP = 0, FN = 2386, TN = 0
# Image 737: TP = 5085, FP = 0, FN = 11299, TN = 0
# Image 738: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 739: TP = 595, FP = 0, FN = 238, TN = 15551
# Image 740: TP = 1135, FP = 52, FN = 2818, TN = 12379
# Image 741: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 742: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 743: TP = 2643, FP = 10, FN = 2100, TN = 11631
# Image 744: TP = 188, FP = 0, FN = 393, TN = 15803
# Image 745: TP = 10, FP = 0, FN = 937, TN = 15437
# Image 746: TP = 12333, FP = 0, FN = 1827, TN = 2224
# Image 747: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 748: TP = 13774, FP = 0, FN = 2610, TN = 0
# Image 749: TP = 16198, FP = 0, FN = 186, TN = 0
# Image 750: TP = 7304, FP = 0, FN = 9080, TN = 0
# Image 751: TP = 6244, FP = 0, FN = 10140, TN = 0
# Image 752: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 753: TP = 1, FP = 0, FN = 35, TN = 16348
# Image 754: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 755: TP = 1068, FP = 4, FN = 3120, TN = 12192
# Image 756: TP = 365, FP = 0, FN = 2097, TN = 13922
# Image 757: TP = 148, FP = 0, FN = 537, TN = 15699

# %%
recall = TP / (TP + FN)
precision = TP / (TP + FP)
accuracy = (TP + TN) / (TP + FP + FN + TN)
f1_score = 2 * (precision * recall) / (precision + recall)
IoU = TP / (TP + FP + FN)

print('TP:', TP)
print('FP:', FP)
print('FN:', FN)
print('TN:', TN)

print()
print('Recall: {:.3f}'.format(recall))
print('Precision: {:.3f}'.format(precision))
print('Accuracy: {:.3f}'.format(accuracy))
print('F1 Score: {:.3f}'.format(f1_score))

print()
print("IoU Overall: {:.3f} ".format(IoU))
# Out:
# TP: 1960850
# FP: 5936
# FN: 2542122
# TN: 7893780
#
# Recall: 0.435
# Precision: 0.997
# Accuracy: 0.795
# F1 Score: 0.606
#
# IoU Overall: 0.435

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
conf_matrix = np.array([[TP, FP],
                        [FN, TN]])

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted Vegetation', 'Predicted Non-Vegetation'], 
            yticklabels=['Actual Vegetation', 'Actual Non-Vegetation'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Initialize lists for TP, FP, FN, and IoU
TP_vegetation = []
FP_vegetation = []
FN_vegetation = []
IoU_vegetation = []

TP_non_vegetation = []
FP_non_vegetation = []
FN_non_vegetation = []
IoU_non_vegetation = []

# Loop over testing images
for i in range(len(image_test)):
    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN counts for both vegetation and non-vegetation classes
    TP_veg = np.sum(np.logical_and(vegetation_ground_truth, predicted_mask))
    FP_veg = np.sum(predicted_mask & ~vegetation_ground_truth)
    FN_veg = np.sum(vegetation_ground_truth & ~predicted_mask)
    
    TP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, ~predicted_mask))
    FP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, predicted_mask))
    FN_non_veg = np.sum(np.logical_and(vegetation_ground_truth, ~predicted_mask))

    # Append TP, FP, FN counts for vegetation and non-vegetation classes
    TP_vegetation.append(TP_veg)
    FP_vegetation.append(FP_veg)
    FN_vegetation.append(FN_veg)
    
    TP_non_vegetation.append(TP_non_veg)
    FP_non_vegetation.append(FP_non_veg)
    FN_non_vegetation.append(FN_non_veg)

    # Calculate IoU for vegetation and non-vegetation classes if the denominator is not zero
    denominator_veg = TP_veg + FP_veg + FN_veg
    denominator_non_veg = TP_non_veg + FP_non_veg + FN_non_veg

    IoU_vegetation.append(TP_veg / denominator_veg if denominator_veg != 0 else 0.0)
    IoU_non_vegetation.append(TP_non_veg / denominator_non_veg if denominator_non_veg != 0 else 0.0)

    # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
    print("Image {}:".format(i+1))
    print("TP_veg: {}, FP_veg: {}, FN_veg: {}, IoU_veg: {:.4f}".format(TP_veg, FP_veg, FN_veg, IoU_vegetation[-1]))
    print("TP_non_veg: {}, FP_non_veg: {}, FN_non_veg: {}, IoU_non_veg: {:.4f}".format(TP_non_veg, FP_non_veg, FN_non_veg, IoU_non_vegetation[-1]))
# Out:
# Image 1:
# TP_veg: 0, FP_veg: 0, FN_veg: 45, IoU_veg: 0.0000
# TP_non_veg: 16339, FP_non_veg: 0, FN_non_veg: 45, IoU_non_veg: 0.9973
# Image 2:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 3:
# TP_veg: 253, FP_veg: 0, FN_veg: 269, IoU_veg: 0.4847
# TP_non_veg: 15862, FP_non_veg: 0, FN_non_veg: 522, IoU_non_veg: 0.9681
# Image 4:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 5:
# TP_veg: 0, FP_veg: 0, FN_veg: 10, IoU_veg: 0.0000
# TP_non_veg: 16374, FP_non_veg: 0, FN_non_veg: 10, IoU_non_veg: 0.9994
# Image 6:
# TP_veg: 255, FP_veg: 0, FN_veg: 361, IoU_veg: 0.4140
# TP_non_veg: 15768, FP_non_veg: 0, FN_non_veg: 616, IoU_non_veg: 0.9624
# Image 7:
# TP_veg: 2696, FP_veg: 0, FN_veg: 2873, IoU_veg: 0.4841
# TP_non_veg: 10815, FP_non_veg: 0, FN_non_veg: 5569, IoU_non_veg: 0.6601
# Image 8:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 9:
# TP_veg: 58, FP_veg: 0, FN_veg: 113, IoU_veg: 0.3392
# TP_non_veg: 16213, FP_non_veg: 0, FN_non_veg: 171, IoU_non_veg: 0.9896
# Image 10:
# TP_veg: 1908, FP_veg: 0, FN_veg: 7258, IoU_veg: 0.2082
# TP_non_veg: 7218, FP_non_veg: 0, FN_non_veg: 9166, IoU_non_veg: 0.4406
# Image 11:
# TP_veg: 182, FP_veg: 0, FN_veg: 1482, IoU_veg: 0.1094
# TP_non_veg: 14720, FP_non_veg: 0, FN_non_veg: 1664, IoU_non_veg: 0.8984
# Image 12:
# TP_veg: 2286, FP_veg: 0, FN_veg: 6645, IoU_veg: 0.2560
# TP_non_veg: 7453, FP_non_veg: 0, FN_non_veg: 8931, IoU_non_veg: 0.4549
# Image 13:
# TP_veg: 23, FP_veg: 0, FN_veg: 203, IoU_veg: 0.1018
# TP_non_veg: 16158, FP_non_veg: 0, FN_non_veg: 226, IoU_non_veg: 0.9862
# Image 14:
# TP_veg: 156, FP_veg: 37, FN_veg: 241, IoU_veg: 0.3594
# TP_non_veg: 15987, FP_non_veg: 37, FN_non_veg: 397, IoU_non_veg: 0.9736
# Image 15:
# TP_veg: 2063, FP_veg: 0, FN_veg: 986, IoU_veg: 0.6766
# TP_non_veg: 13335, FP_non_veg: 0, FN_non_veg: 3049, IoU_non_veg: 0.8139
# Image 16:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 17:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 18:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 19:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 20:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 21:
# TP_veg: 14, FP_veg: 0, FN_veg: 201, IoU_veg: 0.0651
# TP_non_veg: 16169, FP_non_veg: 0, FN_non_veg: 215, IoU_non_veg: 0.9869
# Image 22:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 23:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 24:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 25:
# TP_veg: 1127, FP_veg: 0, FN_veg: 2350, IoU_veg: 0.3241
# TP_non_veg: 12907, FP_non_veg: 0, FN_non_veg: 3477, IoU_non_veg: 0.7878
# Image 26:
# TP_veg: 5718, FP_veg: 0, FN_veg: 3831, IoU_veg: 0.5988
# TP_non_veg: 6835, FP_non_veg: 0, FN_non_veg: 9549, IoU_non_veg: 0.4172
# Image 27:
# TP_veg: 761, FP_veg: 4, FN_veg: 2115, IoU_veg: 0.2642
# TP_non_veg: 13508, FP_non_veg: 4, FN_non_veg: 2876, IoU_non_veg: 0.8243
# Image 28:
# TP_veg: 5689, FP_veg: 55, FN_veg: 1306, IoU_veg: 0.8070
# TP_non_veg: 9389, FP_non_veg: 55, FN_non_veg: 6995, IoU_non_veg: 0.5711
# Image 29:
# TP_veg: 2282, FP_veg: 18, FN_veg: 1236, IoU_veg: 0.6454
# TP_non_veg: 12866, FP_non_veg: 18, FN_non_veg: 3518, IoU_non_veg: 0.7844
# Image 30:
# TP_veg: 1536, FP_veg: 0, FN_veg: 4577, IoU_veg: 0.2513
# TP_non_veg: 10271, FP_non_veg: 0, FN_non_veg: 6113, IoU_non_veg: 0.6269
# Image 31:
# TP_veg: 1454, FP_veg: 14, FN_veg: 244, IoU_veg: 0.8493
# TP_non_veg: 14686, FP_non_veg: 14, FN_non_veg: 1698, IoU_non_veg: 0.8956
# Image 32:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 33:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 34:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 35:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 36:
# TP_veg: 677, FP_veg: 0, FN_veg: 1096, IoU_veg: 0.3818
# TP_non_veg: 14611, FP_non_veg: 0, FN_non_veg: 1773, IoU_non_veg: 0.8918
# Image 37:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 38:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 39:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 40:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 41:
# TP_veg: 676, FP_veg: 0, FN_veg: 1822, IoU_veg: 0.2706
# TP_non_veg: 13886, FP_non_veg: 0, FN_non_veg: 2498, IoU_non_veg: 0.8475
# Image 42:
# TP_veg: 53, FP_veg: 0, FN_veg: 2907, IoU_veg: 0.0179
# TP_non_veg: 13424, FP_non_veg: 0, FN_non_veg: 2960, IoU_non_veg: 0.8193
# Image 43:
# TP_veg: 13, FP_veg: 0, FN_veg: 4392, IoU_veg: 0.0030
# TP_non_veg: 11979, FP_non_veg: 0, FN_non_veg: 4405, IoU_non_veg: 0.7311
# Image 44:
# TP_veg: 63, FP_veg: 0, FN_veg: 396, IoU_veg: 0.1373
# TP_non_veg: 15925, FP_non_veg: 0, FN_non_veg: 459, IoU_non_veg: 0.9720
# Image 45:
# TP_veg: 6182, FP_veg: 0, FN_veg: 3068, IoU_veg: 0.6683
# TP_non_veg: 7134, FP_non_veg: 0, FN_non_veg: 9250, IoU_non_veg: 0.4354
# Image 46:
# TP_veg: 1911, FP_veg: 16, FN_veg: 865, IoU_veg: 0.6845
# TP_non_veg: 13608, FP_non_veg: 16, FN_non_veg: 2776, IoU_non_veg: 0.8298
# Image 47:
# TP_veg: 1664, FP_veg: 10, FN_veg: 598, IoU_veg: 0.7324
# TP_non_veg: 14122, FP_non_veg: 10, FN_non_veg: 2262, IoU_non_veg: 0.8614
# Image 48:
# TP_veg: 0, FP_veg: 0, FN_veg: 1581, IoU_veg: 0.0000
# TP_non_veg: 14803, FP_non_veg: 0, FN_non_veg: 1581, IoU_non_veg: 0.9035
# Image 49:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 50:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 51:
# TP_veg: 5049, FP_veg: 0, FN_veg: 6241, IoU_veg: 0.4472
# TP_non_veg: 5094, FP_non_veg: 0, FN_non_veg: 11290, IoU_non_veg: 0.3109
# Image 52:
# TP_veg: 10051, FP_veg: 0, FN_veg: 6333, IoU_veg: 0.6135
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 53:
# TP_veg: 303, FP_veg: 0, FN_veg: 4617, IoU_veg: 0.0616
# TP_non_veg: 11464, FP_non_veg: 0, FN_non_veg: 4920, IoU_non_veg: 0.6997
# Image 54:
# TP_veg: 238, FP_veg: 0, FN_veg: 4836, IoU_veg: 0.0469
# TP_non_veg: 11310, FP_non_veg: 0, FN_non_veg: 5074, IoU_non_veg: 0.6903
# Image 55:
# TP_veg: 1647, FP_veg: 0, FN_veg: 4741, IoU_veg: 0.2578
# TP_non_veg: 9996, FP_non_veg: 0, FN_non_veg: 6388, IoU_non_veg: 0.6101
# Image 56:
# TP_veg: 245, FP_veg: 0, FN_veg: 1919, IoU_veg: 0.1132
# TP_non_veg: 14220, FP_non_veg: 0, FN_non_veg: 2164, IoU_non_veg: 0.8679
# Image 57:
# TP_veg: 664, FP_veg: 0, FN_veg: 2529, IoU_veg: 0.2080
# TP_non_veg: 13191, FP_non_veg: 0, FN_non_veg: 3193, IoU_non_veg: 0.8051
# Image 58:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 59:
# TP_veg: 3555, FP_veg: 23, FN_veg: 4898, IoU_veg: 0.4194
# TP_non_veg: 7931, FP_non_veg: 23, FN_non_veg: 8453, IoU_non_veg: 0.4834
# Image 60:
# TP_veg: 245, FP_veg: 0, FN_veg: 1924, IoU_veg: 0.1130
# TP_non_veg: 14215, FP_non_veg: 0, FN_non_veg: 2169, IoU_non_veg: 0.8676
# Image 61:
# TP_veg: 8057, FP_veg: 13, FN_veg: 5764, IoU_veg: 0.5824
# TP_non_veg: 2563, FP_non_veg: 13, FN_non_veg: 13821, IoU_non_veg: 0.1563
# Image 62:
# TP_veg: 901, FP_veg: 18, FN_veg: 416, IoU_veg: 0.6749
# TP_non_veg: 15067, FP_non_veg: 18, FN_non_veg: 1317, IoU_non_veg: 0.9186
# Image 63:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 64:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 65:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 66:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 67:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 68:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 69:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 70:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 71:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 72:
# TP_veg: 615, FP_veg: 3, FN_veg: 1841, IoU_veg: 0.2501
# TP_non_veg: 13928, FP_non_veg: 3, FN_non_veg: 2456, IoU_non_veg: 0.8499
# Image 73:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 74:
# TP_veg: 46, FP_veg: 2, FN_veg: 744, IoU_veg: 0.0581
# TP_non_veg: 15594, FP_non_veg: 2, FN_non_veg: 790, IoU_non_veg: 0.9517
# Image 75:
# TP_veg: 149, FP_veg: 1, FN_veg: 638, IoU_veg: 0.1891
# TP_non_veg: 15597, FP_non_veg: 1, FN_non_veg: 787, IoU_non_veg: 0.9519
# Image 76:
# TP_veg: 1947, FP_veg: 1, FN_veg: 8359, IoU_veg: 0.1889
# TP_non_veg: 6078, FP_non_veg: 1, FN_non_veg: 10306, IoU_non_veg: 0.3709
# Image 77:
# TP_veg: 7689, FP_veg: 42, FN_veg: 5812, IoU_veg: 0.5677
# TP_non_veg: 2883, FP_non_veg: 42, FN_non_veg: 13501, IoU_non_veg: 0.1755
# Image 78:
# TP_veg: 1627, FP_veg: 192, FN_veg: 217, IoU_veg: 0.7991
# TP_non_veg: 14540, FP_non_veg: 192, FN_non_veg: 1844, IoU_non_veg: 0.8772
# Image 79:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 80:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 81:
# TP_veg: 128, FP_veg: 0, FN_veg: 1094, IoU_veg: 0.1047
# TP_non_veg: 15162, FP_non_veg: 0, FN_non_veg: 1222, IoU_non_veg: 0.9254
# Image 82:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 83:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 84:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 85:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 86:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 87:
# TP_veg: 475, FP_veg: 0, FN_veg: 1783, IoU_veg: 0.2104
# TP_non_veg: 14126, FP_non_veg: 0, FN_non_veg: 2258, IoU_non_veg: 0.8622
# Image 88:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 89:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 90:
# TP_veg: 116, FP_veg: 0, FN_veg: 879, IoU_veg: 0.1166
# TP_non_veg: 15389, FP_non_veg: 0, FN_non_veg: 995, IoU_non_veg: 0.9393
# Image 91:
# TP_veg: 3771, FP_veg: 1, FN_veg: 2107, IoU_veg: 0.6414
# TP_non_veg: 10506, FP_non_veg: 1, FN_non_veg: 5878, IoU_non_veg: 0.6412
# Image 92:
# TP_veg: 7472, FP_veg: 0, FN_veg: 4828, IoU_veg: 0.6075
# TP_non_veg: 4084, FP_non_veg: 0, FN_non_veg: 12300, IoU_non_veg: 0.2493
# Image 93:
# TP_veg: 7388, FP_veg: 105, FN_veg: 5186, IoU_veg: 0.5827
# TP_non_veg: 3810, FP_non_veg: 105, FN_non_veg: 12574, IoU_non_veg: 0.2311
# Image 94:
# TP_veg: 1259, FP_veg: 4, FN_veg: 372, IoU_veg: 0.7700
# TP_non_veg: 14753, FP_non_veg: 4, FN_non_veg: 1631, IoU_non_veg: 0.9002
# Image 95:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 96:
# TP_veg: 42, FP_veg: 0, FN_veg: 634, IoU_veg: 0.0621
# TP_non_veg: 15708, FP_non_veg: 0, FN_non_veg: 676, IoU_non_veg: 0.9587
# Image 97:
# TP_veg: 599, FP_veg: 0, FN_veg: 1265, IoU_veg: 0.3214
# TP_non_veg: 14520, FP_non_veg: 0, FN_non_veg: 1864, IoU_non_veg: 0.8862
# Image 98:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 99:
# TP_veg: 892, FP_veg: 0, FN_veg: 989, IoU_veg: 0.4742
# TP_non_veg: 14503, FP_non_veg: 0, FN_non_veg: 1881, IoU_non_veg: 0.8852
# Image 100:
# TP_veg: 0, FP_veg: 0, FN_veg: 37, IoU_veg: 0.0000
# TP_non_veg: 16347, FP_non_veg: 0, FN_non_veg: 37, IoU_non_veg: 0.9977
# Image 101:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 102:
# TP_veg: 3, FP_veg: 2, FN_veg: 244, IoU_veg: 0.0120
# TP_non_veg: 16137, FP_non_veg: 2, FN_non_veg: 247, IoU_non_veg: 0.9848
# Image 103:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 104:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 105:
# TP_veg: 224, FP_veg: 0, FN_veg: 1244, IoU_veg: 0.1526
# TP_non_veg: 14916, FP_non_veg: 0, FN_non_veg: 1468, IoU_non_veg: 0.9104
# Image 106:
# TP_veg: 60, FP_veg: 4, FN_veg: 158, IoU_veg: 0.2703
# TP_non_veg: 16166, FP_non_veg: 4, FN_non_veg: 218, IoU_non_veg: 0.9865
# Image 107:
# TP_veg: 2985, FP_veg: 17, FN_veg: 7832, IoU_veg: 0.2755
# TP_non_veg: 5567, FP_non_veg: 17, FN_non_veg: 10817, IoU_non_veg: 0.3394
# Image 108:
# TP_veg: 93, FP_veg: 0, FN_veg: 2541, IoU_veg: 0.0353
# TP_non_veg: 13750, FP_non_veg: 0, FN_non_veg: 2634, IoU_non_veg: 0.8392
# Image 109:
# TP_veg: 3422, FP_veg: 55, FN_veg: 3516, IoU_veg: 0.4893
# TP_non_veg: 9446, FP_non_veg: 55, FN_non_veg: 6938, IoU_non_veg: 0.5746
# Image 110:
# TP_veg: 3963, FP_veg: 74, FN_veg: 691, IoU_veg: 0.8382
# TP_non_veg: 11730, FP_non_veg: 74, FN_non_veg: 4654, IoU_non_veg: 0.7127
# Image 111:
# TP_veg: 3, FP_veg: 0, FN_veg: 500, IoU_veg: 0.0060
# TP_non_veg: 15881, FP_non_veg: 0, FN_non_veg: 503, IoU_non_veg: 0.9693
# Image 112:
# TP_veg: 218, FP_veg: 0, FN_veg: 895, IoU_veg: 0.1959
# TP_non_veg: 15271, FP_non_veg: 0, FN_non_veg: 1113, IoU_non_veg: 0.9321
# Image 113:
# TP_veg: 494, FP_veg: 0, FN_veg: 1320, IoU_veg: 0.2723
# TP_non_veg: 14570, FP_non_veg: 0, FN_non_veg: 1814, IoU_non_veg: 0.8893
# Image 114:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 115:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 116:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 117:
# TP_veg: 189, FP_veg: 0, FN_veg: 10791, IoU_veg: 0.0172
# TP_non_veg: 5404, FP_non_veg: 0, FN_non_veg: 10980, IoU_non_veg: 0.3298
# Image 118:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 119:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 120:
# TP_veg: 0, FP_veg: 0, FN_veg: 35, IoU_veg: 0.0000
# TP_non_veg: 16349, FP_non_veg: 0, FN_non_veg: 35, IoU_non_veg: 0.9979
# Image 121:
# TP_veg: 678, FP_veg: 2, FN_veg: 409, IoU_veg: 0.6226
# TP_non_veg: 15297, FP_non_veg: 2, FN_non_veg: 1087, IoU_non_veg: 0.9335
# Image 122:
# TP_veg: 9835, FP_veg: 0, FN_veg: 3901, IoU_veg: 0.7160
# TP_non_veg: 2648, FP_non_veg: 0, FN_non_veg: 13736, IoU_non_veg: 0.1616
# Image 123:
# TP_veg: 7380, FP_veg: 0, FN_veg: 5014, IoU_veg: 0.5954
# TP_non_veg: 3990, FP_non_veg: 0, FN_non_veg: 12394, IoU_non_veg: 0.2435
# Image 124:
# TP_veg: 9661, FP_veg: 0, FN_veg: 5733, IoU_veg: 0.6276
# TP_non_veg: 990, FP_non_veg: 0, FN_non_veg: 15394, IoU_non_veg: 0.0604
# Image 125:
# TP_veg: 5525, FP_veg: 0, FN_veg: 4114, IoU_veg: 0.5732
# TP_non_veg: 6745, FP_non_veg: 0, FN_non_veg: 9639, IoU_non_veg: 0.4117
# Image 126:
# TP_veg: 226, FP_veg: 0, FN_veg: 1167, IoU_veg: 0.1622
# TP_non_veg: 14991, FP_non_veg: 0, FN_non_veg: 1393, IoU_non_veg: 0.9150
# Image 127:
# TP_veg: 408, FP_veg: 0, FN_veg: 1539, IoU_veg: 0.2096
# TP_non_veg: 14437, FP_non_veg: 0, FN_non_veg: 1947, IoU_non_veg: 0.8812
# Image 128:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 129:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 130:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 131:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 132:
# TP_veg: 3938, FP_veg: 0, FN_veg: 10838, IoU_veg: 0.2665
# TP_non_veg: 1608, FP_non_veg: 0, FN_non_veg: 14776, IoU_non_veg: 0.0981
# Image 133:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 134:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 135:
# TP_veg: 3603, FP_veg: 91, FN_veg: 696, IoU_veg: 0.8207
# TP_non_veg: 12085, FP_non_veg: 91, FN_non_veg: 4299, IoU_non_veg: 0.7335
# Image 136:
# TP_veg: 1318, FP_veg: 5, FN_veg: 3334, IoU_veg: 0.2830
# TP_non_veg: 11732, FP_non_veg: 5, FN_non_veg: 4652, IoU_non_veg: 0.7158
# Image 137:
# TP_veg: 1384, FP_veg: 0, FN_veg: 1706, IoU_veg: 0.4479
# TP_non_veg: 13294, FP_non_veg: 0, FN_non_veg: 3090, IoU_non_veg: 0.8114
# Image 138:
# TP_veg: 3935, FP_veg: 142, FN_veg: 3971, IoU_veg: 0.4889
# TP_non_veg: 8478, FP_non_veg: 142, FN_non_veg: 7906, IoU_non_veg: 0.5130
# Image 139:
# TP_veg: 3282, FP_veg: 0, FN_veg: 5654, IoU_veg: 0.3673
# TP_non_veg: 7448, FP_non_veg: 0, FN_non_veg: 8936, IoU_non_veg: 0.4546
# Image 140:
# TP_veg: 654, FP_veg: 0, FN_veg: 10991, IoU_veg: 0.0562
# TP_non_veg: 4739, FP_non_veg: 0, FN_non_veg: 11645, IoU_non_veg: 0.2892
# Image 141:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 142:
# TP_veg: 0, FP_veg: 0, FN_veg: 213, IoU_veg: 0.0000
# TP_non_veg: 16171, FP_non_veg: 0, FN_non_veg: 213, IoU_non_veg: 0.9870
# Image 143:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 144:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 145:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 146:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 147:
# TP_veg: 1225, FP_veg: 0, FN_veg: 2653, IoU_veg: 0.3159
# TP_non_veg: 12506, FP_non_veg: 0, FN_non_veg: 3878, IoU_non_veg: 0.7633
# Image 148:
# TP_veg: 213, FP_veg: 0, FN_veg: 87, IoU_veg: 0.7100
# TP_non_veg: 16084, FP_non_veg: 0, FN_non_veg: 300, IoU_non_veg: 0.9817
# Image 149:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 150:
# TP_veg: 10056, FP_veg: 27, FN_veg: 4376, IoU_veg: 0.6955
# TP_non_veg: 1952, FP_non_veg: 27, FN_non_veg: 14432, IoU_non_veg: 0.1189
# Image 151:
# TP_veg: 1135, FP_veg: 12, FN_veg: 3145, IoU_veg: 0.2644
# TP_non_veg: 12104, FP_non_veg: 12, FN_non_veg: 4280, IoU_non_veg: 0.7382
# Image 152:
# TP_veg: 3391, FP_veg: 5, FN_veg: 1521, IoU_veg: 0.6896
# TP_non_veg: 11472, FP_non_veg: 5, FN_non_veg: 4912, IoU_non_veg: 0.7000
# Image 153:
# TP_veg: 4904, FP_veg: 38, FN_veg: 2166, IoU_veg: 0.6899
# TP_non_veg: 9314, FP_non_veg: 38, FN_non_veg: 7070, IoU_non_veg: 0.5672
# Image 154:
# TP_veg: 1, FP_veg: 0, FN_veg: 1772, IoU_veg: 0.0006
# TP_non_veg: 14611, FP_non_veg: 0, FN_non_veg: 1773, IoU_non_veg: 0.8918
# Image 155:
# TP_veg: 5015, FP_veg: 0, FN_veg: 6220, IoU_veg: 0.4464
# TP_non_veg: 5149, FP_non_veg: 0, FN_non_veg: 11235, IoU_non_veg: 0.3143
# Image 156:
# TP_veg: 4070, FP_veg: 145, FN_veg: 236, IoU_veg: 0.9144
# TP_non_veg: 12078, FP_non_veg: 145, FN_non_veg: 4306, IoU_non_veg: 0.7307
# Image 157:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 158:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 159:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 160:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 161:
# TP_veg: 2728, FP_veg: 8, FN_veg: 1245, IoU_veg: 0.6853
# TP_non_veg: 12411, FP_non_veg: 8, FN_non_veg: 3973, IoU_non_veg: 0.7571
# Image 162:
# TP_veg: 1169, FP_veg: 1, FN_veg: 1654, IoU_veg: 0.4140
# TP_non_veg: 13561, FP_non_veg: 1, FN_non_veg: 2823, IoU_non_veg: 0.8276
# Image 163:
# TP_veg: 7197, FP_veg: 39, FN_veg: 379, IoU_veg: 0.9451
# TP_non_veg: 8808, FP_non_veg: 39, FN_non_veg: 7576, IoU_non_veg: 0.5363
# Image 164:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 165:
# TP_veg: 2209, FP_veg: 0, FN_veg: 1186, IoU_veg: 0.6507
# TP_non_veg: 12989, FP_non_veg: 0, FN_non_veg: 3395, IoU_non_veg: 0.7928
# Image 166:
# TP_veg: 23, FP_veg: 0, FN_veg: 1718, IoU_veg: 0.0132
# TP_non_veg: 14643, FP_non_veg: 0, FN_non_veg: 1741, IoU_non_veg: 0.8937
# Image 167:
# TP_veg: 2815, FP_veg: 4, FN_veg: 3446, IoU_veg: 0.4493
# TP_non_veg: 10123, FP_non_veg: 4, FN_non_veg: 6261, IoU_non_veg: 0.6177
# Image 168:
# TP_veg: 1, FP_veg: 0, FN_veg: 5, IoU_veg: 0.1667
# TP_non_veg: 16378, FP_non_veg: 0, FN_non_veg: 6, IoU_non_veg: 0.9996
# Image 169:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 170:
# TP_veg: 586, FP_veg: 2, FN_veg: 149, IoU_veg: 0.7951
# TP_non_veg: 15649, FP_non_veg: 2, FN_non_veg: 735, IoU_non_veg: 0.9550
# Image 171:
# TP_veg: 9986, FP_veg: 4, FN_veg: 5122, IoU_veg: 0.6608
# TP_non_veg: 1276, FP_non_veg: 4, FN_non_veg: 15108, IoU_non_veg: 0.0779
# Image 172:
# TP_veg: 4231, FP_veg: 155, FN_veg: 192, IoU_veg: 0.9242
# TP_non_veg: 11961, FP_non_veg: 155, FN_non_veg: 4423, IoU_non_veg: 0.7232
# Image 173:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 174:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 175:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 176:
# TP_veg: 1787, FP_veg: 37, FN_veg: 378, IoU_veg: 0.8115
# TP_non_veg: 14219, FP_non_veg: 37, FN_non_veg: 2165, IoU_non_veg: 0.8659
# Image 177:
# TP_veg: 385, FP_veg: 0, FN_veg: 1233, IoU_veg: 0.2379
# TP_non_veg: 14766, FP_non_veg: 0, FN_non_veg: 1618, IoU_non_veg: 0.9012
# Image 178:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 179:
# TP_veg: 205, FP_veg: 0, FN_veg: 504, IoU_veg: 0.2891
# TP_non_veg: 15675, FP_non_veg: 0, FN_non_veg: 709, IoU_non_veg: 0.9567
# Image 180:
# TP_veg: 7676, FP_veg: 27, FN_veg: 4084, IoU_veg: 0.6512
# TP_non_veg: 4624, FP_non_veg: 27, FN_non_veg: 11760, IoU_non_veg: 0.2818
# Image 181:
# TP_veg: 314, FP_veg: 0, FN_veg: 611, IoU_veg: 0.3395
# TP_non_veg: 15459, FP_non_veg: 0, FN_non_veg: 925, IoU_non_veg: 0.9435
# Image 182:
# TP_veg: 1143, FP_veg: 6, FN_veg: 2055, IoU_veg: 0.3567
# TP_non_veg: 13186, FP_non_veg: 6, FN_non_veg: 3198, IoU_non_veg: 0.8045
# Image 183:
# TP_veg: 85, FP_veg: 0, FN_veg: 1884, IoU_veg: 0.0432
# TP_non_veg: 14415, FP_non_veg: 0, FN_non_veg: 1969, IoU_non_veg: 0.8798
# Image 184:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 185:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 186:
# TP_veg: 11095, FP_veg: 0, FN_veg: 4715, IoU_veg: 0.7018
# TP_non_veg: 574, FP_non_veg: 0, FN_non_veg: 15810, IoU_non_veg: 0.0350
# Image 187:
# TP_veg: 8442, FP_veg: 0, FN_veg: 7942, IoU_veg: 0.5153
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 188:
# TP_veg: 713, FP_veg: 0, FN_veg: 1012, IoU_veg: 0.4133
# TP_non_veg: 14659, FP_non_veg: 0, FN_non_veg: 1725, IoU_non_veg: 0.8947
# Image 189:
# TP_veg: 0, FP_veg: 0, FN_veg: 3278, IoU_veg: 0.0000
# TP_non_veg: 13106, FP_non_veg: 0, FN_non_veg: 3278, IoU_non_veg: 0.7999
# Image 190:
# TP_veg: 287, FP_veg: 0, FN_veg: 1285, IoU_veg: 0.1826
# TP_non_veg: 14812, FP_non_veg: 0, FN_non_veg: 1572, IoU_non_veg: 0.9041
# Image 191:
# TP_veg: 2453, FP_veg: 1, FN_veg: 2460, IoU_veg: 0.4992
# TP_non_veg: 11471, FP_non_veg: 1, FN_non_veg: 4913, IoU_non_veg: 0.7001
# Image 192:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 193:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 194:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 195:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 196:
# TP_veg: 6, FP_veg: 0, FN_veg: 364, IoU_veg: 0.0162
# TP_non_veg: 16014, FP_non_veg: 0, FN_non_veg: 370, IoU_non_veg: 0.9774
# Image 197:
# TP_veg: 619, FP_veg: 0, FN_veg: 874, IoU_veg: 0.4146
# TP_non_veg: 14891, FP_non_veg: 0, FN_non_veg: 1493, IoU_non_veg: 0.9089
# Image 198:
# TP_veg: 1272, FP_veg: 71, FN_veg: 1017, IoU_veg: 0.5390
# TP_non_veg: 14095, FP_non_veg: 71, FN_non_veg: 2289, IoU_non_veg: 0.8566
# Image 199:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 200:
# TP_veg: 0, FP_veg: 0, FN_veg: 109, IoU_veg: 0.0000
# TP_non_veg: 16275, FP_non_veg: 0, FN_non_veg: 109, IoU_non_veg: 0.9933
# Image 201:
# TP_veg: 1980, FP_veg: 0, FN_veg: 3268, IoU_veg: 0.3773
# TP_non_veg: 11136, FP_non_veg: 0, FN_non_veg: 5248, IoU_non_veg: 0.6797
# Image 202:
# TP_veg: 5596, FP_veg: 0, FN_veg: 7185, IoU_veg: 0.4378
# TP_non_veg: 3603, FP_non_veg: 0, FN_non_veg: 12781, IoU_non_veg: 0.2199
# Image 203:
# TP_veg: 0, FP_veg: 0, FN_veg: 1038, IoU_veg: 0.0000
# TP_non_veg: 15346, FP_non_veg: 0, FN_non_veg: 1038, IoU_non_veg: 0.9366
# Image 204:
# TP_veg: 1040, FP_veg: 0, FN_veg: 5713, IoU_veg: 0.1540
# TP_non_veg: 9631, FP_non_veg: 0, FN_non_veg: 6753, IoU_non_veg: 0.5878
# Image 205:
# TP_veg: 0, FP_veg: 0, FN_veg: 193, IoU_veg: 0.0000
# TP_non_veg: 16191, FP_non_veg: 0, FN_non_veg: 193, IoU_non_veg: 0.9882
# Image 206:
# TP_veg: 0, FP_veg: 0, FN_veg: 1, IoU_veg: 0.0000
# TP_non_veg: 16383, FP_non_veg: 0, FN_non_veg: 1, IoU_non_veg: 0.9999
# Image 207:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 208:
# TP_veg: 0, FP_veg: 0, FN_veg: 1492, IoU_veg: 0.0000
# TP_non_veg: 14892, FP_non_veg: 0, FN_non_veg: 1492, IoU_non_veg: 0.9089
# Image 209:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 210:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 211:
# TP_veg: 1619, FP_veg: 17, FN_veg: 3348, IoU_veg: 0.3248
# TP_non_veg: 11417, FP_non_veg: 17, FN_non_veg: 4967, IoU_non_veg: 0.6961
# Image 212:
# TP_veg: 1139, FP_veg: 7, FN_veg: 561, IoU_veg: 0.6673
# TP_non_veg: 14684, FP_non_veg: 7, FN_non_veg: 1700, IoU_non_veg: 0.8959
# Image 213:
# TP_veg: 450, FP_veg: 0, FN_veg: 642, IoU_veg: 0.4121
# TP_non_veg: 15292, FP_non_veg: 0, FN_non_veg: 1092, IoU_non_veg: 0.9333
# Image 214:
# TP_veg: 660, FP_veg: 0, FN_veg: 2273, IoU_veg: 0.2250
# TP_non_veg: 13451, FP_non_veg: 0, FN_non_veg: 2933, IoU_non_veg: 0.8210
# Image 215:
# TP_veg: 4344, FP_veg: 21, FN_veg: 2986, IoU_veg: 0.5909
# TP_non_veg: 9054, FP_non_veg: 21, FN_non_veg: 7330, IoU_non_veg: 0.5519
# Image 216:
# TP_veg: 199, FP_veg: 0, FN_veg: 1577, IoU_veg: 0.1120
# TP_non_veg: 14608, FP_non_veg: 0, FN_non_veg: 1776, IoU_non_veg: 0.8916
# Image 217:
# TP_veg: 2518, FP_veg: 0, FN_veg: 4710, IoU_veg: 0.3484
# TP_non_veg: 9156, FP_non_veg: 0, FN_non_veg: 7228, IoU_non_veg: 0.5588
# Image 218:
# TP_veg: 1044, FP_veg: 0, FN_veg: 1712, IoU_veg: 0.3788
# TP_non_veg: 13628, FP_non_veg: 0, FN_non_veg: 2756, IoU_non_veg: 0.8318
# Image 219:
# TP_veg: 5663, FP_veg: 0, FN_veg: 4245, IoU_veg: 0.5716
# TP_non_veg: 6476, FP_non_veg: 0, FN_non_veg: 9908, IoU_non_veg: 0.3953
# Image 220:
# TP_veg: 0, FP_veg: 0, FN_veg: 182, IoU_veg: 0.0000
# TP_non_veg: 16202, FP_non_veg: 0, FN_non_veg: 182, IoU_non_veg: 0.9889
# Image 221:
# TP_veg: 0, FP_veg: 0, FN_veg: 406, IoU_veg: 0.0000
# TP_non_veg: 15978, FP_non_veg: 0, FN_non_veg: 406, IoU_non_veg: 0.9752
# Image 222:
# TP_veg: 624, FP_veg: 0, FN_veg: 2441, IoU_veg: 0.2036
# TP_non_veg: 13319, FP_non_veg: 0, FN_non_veg: 3065, IoU_non_veg: 0.8129
# Image 223:
# TP_veg: 152, FP_veg: 9, FN_veg: 11380, IoU_veg: 0.0132
# TP_non_veg: 4852, FP_non_veg: 9, FN_non_veg: 11532, IoU_non_veg: 0.2960
# Image 224:
# TP_veg: 2210, FP_veg: 22, FN_veg: 6458, IoU_veg: 0.2543
# TP_non_veg: 7716, FP_non_veg: 22, FN_non_veg: 8668, IoU_non_veg: 0.4703
# Image 225:
# TP_veg: 401, FP_veg: 0, FN_veg: 620, IoU_veg: 0.3928
# TP_non_veg: 15363, FP_non_veg: 0, FN_non_veg: 1021, IoU_non_veg: 0.9377
# Image 226:
# TP_veg: 707, FP_veg: 2, FN_veg: 2792, IoU_veg: 0.2019
# TP_non_veg: 12885, FP_non_veg: 2, FN_non_veg: 3499, IoU_non_veg: 0.7863
# Image 227:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 228:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 229:
# TP_veg: 148, FP_veg: 0, FN_veg: 897, IoU_veg: 0.1416
# TP_non_veg: 15339, FP_non_veg: 0, FN_non_veg: 1045, IoU_non_veg: 0.9362
# Image 230:
# TP_veg: 7110, FP_veg: 87, FN_veg: 1335, IoU_veg: 0.8333
# TP_non_veg: 7939, FP_non_veg: 87, FN_non_veg: 8445, IoU_non_veg: 0.4820
# Image 231:
# TP_veg: 1018, FP_veg: 0, FN_veg: 5669, IoU_veg: 0.1522
# TP_non_veg: 9697, FP_non_veg: 0, FN_non_veg: 6687, IoU_non_veg: 0.5919
# Image 232:
# TP_veg: 2398, FP_veg: 0, FN_veg: 2676, IoU_veg: 0.4726
# TP_non_veg: 11310, FP_non_veg: 0, FN_non_veg: 5074, IoU_non_veg: 0.6903
# Image 233:
# TP_veg: 1433, FP_veg: 4, FN_veg: 3898, IoU_veg: 0.2686
# TP_non_veg: 11053, FP_non_veg: 4, FN_non_veg: 5331, IoU_non_veg: 0.6745
# Image 234:
# TP_veg: 1463, FP_veg: 6, FN_veg: 489, IoU_veg: 0.7472
# TP_non_veg: 14432, FP_non_veg: 6, FN_non_veg: 1952, IoU_non_veg: 0.8805
# Image 235:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 236:
# TP_veg: 0, FP_veg: 0, FN_veg: 10933, IoU_veg: 0.0000
# TP_non_veg: 5451, FP_non_veg: 0, FN_non_veg: 10933, IoU_non_veg: 0.3327
# Image 237:
# TP_veg: 201, FP_veg: 0, FN_veg: 1494, IoU_veg: 0.1186
# TP_non_veg: 14689, FP_non_veg: 0, FN_non_veg: 1695, IoU_non_veg: 0.8965
# Image 238:
# TP_veg: 841, FP_veg: 0, FN_veg: 14869, IoU_veg: 0.0535
# TP_non_veg: 674, FP_non_veg: 0, FN_non_veg: 15710, IoU_non_veg: 0.0411
# Image 239:
# TP_veg: 4641, FP_veg: 0, FN_veg: 8746, IoU_veg: 0.3467
# TP_non_veg: 2997, FP_non_veg: 0, FN_non_veg: 13387, IoU_non_veg: 0.1829
# Image 240:
# TP_veg: 16, FP_veg: 0, FN_veg: 546, IoU_veg: 0.0285
# TP_non_veg: 15822, FP_non_veg: 0, FN_non_veg: 562, IoU_non_veg: 0.9657
# Image 241:
# TP_veg: 14, FP_veg: 0, FN_veg: 918, IoU_veg: 0.0150
# TP_non_veg: 15452, FP_non_veg: 0, FN_non_veg: 932, IoU_non_veg: 0.9431
# Image 242:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 243:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 244:
# TP_veg: 572, FP_veg: 10, FN_veg: 107, IoU_veg: 0.8302
# TP_non_veg: 15705, FP_non_veg: 10, FN_non_veg: 679, IoU_non_veg: 0.9580
# Image 245:
# TP_veg: 0, FP_veg: 0, FN_veg: 76, IoU_veg: 0.0000
# TP_non_veg: 16308, FP_non_veg: 0, FN_non_veg: 76, IoU_non_veg: 0.9954
# Image 246:
# TP_veg: 761, FP_veg: 4, FN_veg: 3555, IoU_veg: 0.1762
# TP_non_veg: 12068, FP_non_veg: 4, FN_non_veg: 4316, IoU_non_veg: 0.7364
# Image 247:
# TP_veg: 483, FP_veg: 0, FN_veg: 1054, IoU_veg: 0.3142
# TP_non_veg: 14847, FP_non_veg: 0, FN_non_veg: 1537, IoU_non_veg: 0.9062
# Image 248:
# TP_veg: 210, FP_veg: 0, FN_veg: 1598, IoU_veg: 0.1162
# TP_non_veg: 14576, FP_non_veg: 0, FN_non_veg: 1808, IoU_non_veg: 0.8896
# Image 249:
# TP_veg: 0, FP_veg: 0, FN_veg: 4, IoU_veg: 0.0000
# TP_non_veg: 16380, FP_non_veg: 0, FN_non_veg: 4, IoU_non_veg: 0.9998
# Image 250:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 251:
# TP_veg: 0, FP_veg: 0, FN_veg: 1240, IoU_veg: 0.0000
# TP_non_veg: 15144, FP_non_veg: 0, FN_non_veg: 1240, IoU_non_veg: 0.9243
# Image 252:
# TP_veg: 1458, FP_veg: 0, FN_veg: 2312, IoU_veg: 0.3867
# TP_non_veg: 12614, FP_non_veg: 0, FN_non_veg: 3770, IoU_non_veg: 0.7699
# Image 253:
# TP_veg: 155, FP_veg: 0, FN_veg: 4304, IoU_veg: 0.0348
# TP_non_veg: 11925, FP_non_veg: 0, FN_non_veg: 4459, IoU_non_veg: 0.7278
# Image 254:
# TP_veg: 6213, FP_veg: 0, FN_veg: 7727, IoU_veg: 0.4457
# TP_non_veg: 2444, FP_non_veg: 0, FN_non_veg: 13940, IoU_non_veg: 0.1492
# Image 255:
# TP_veg: 2248, FP_veg: 0, FN_veg: 3647, IoU_veg: 0.3813
# TP_non_veg: 10489, FP_non_veg: 0, FN_non_veg: 5895, IoU_non_veg: 0.6402
# Image 256:
# TP_veg: 1003, FP_veg: 0, FN_veg: 6289, IoU_veg: 0.1375
# TP_non_veg: 9092, FP_non_veg: 0, FN_non_veg: 7292, IoU_non_veg: 0.5549
# Image 257:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 258:
# TP_veg: 530, FP_veg: 0, FN_veg: 279, IoU_veg: 0.6551
# TP_non_veg: 15575, FP_non_veg: 0, FN_non_veg: 809, IoU_non_veg: 0.9506
# Image 259:
# TP_veg: 1352, FP_veg: 3, FN_veg: 701, IoU_veg: 0.6576
# TP_non_veg: 14331, FP_non_veg: 3, FN_non_veg: 2053, IoU_non_veg: 0.8745
# Image 260:
# TP_veg: 79, FP_veg: 0, FN_veg: 101, IoU_veg: 0.4389
# TP_non_veg: 16204, FP_non_veg: 0, FN_non_veg: 180, IoU_non_veg: 0.9890
# Image 261:
# TP_veg: 4280, FP_veg: 0, FN_veg: 4613, IoU_veg: 0.4813
# TP_non_veg: 7491, FP_non_veg: 0, FN_non_veg: 8893, IoU_non_veg: 0.4572
# Image 262:
# TP_veg: 814, FP_veg: 0, FN_veg: 6456, IoU_veg: 0.1120
# TP_non_veg: 9114, FP_non_veg: 0, FN_non_veg: 7270, IoU_non_veg: 0.5563
# Image 263:
# TP_veg: 2343, FP_veg: 0, FN_veg: 1621, IoU_veg: 0.5911
# TP_non_veg: 12420, FP_non_veg: 0, FN_non_veg: 3964, IoU_non_veg: 0.7581
# Image 264:
# TP_veg: 225, FP_veg: 0, FN_veg: 3386, IoU_veg: 0.0623
# TP_non_veg: 12773, FP_non_veg: 0, FN_non_veg: 3611, IoU_non_veg: 0.7796
# Image 265:
# TP_veg: 0, FP_veg: 0, FN_veg: 1, IoU_veg: 0.0000
# TP_non_veg: 16383, FP_non_veg: 0, FN_non_veg: 1, IoU_non_veg: 0.9999
# Image 266:
# TP_veg: 0, FP_veg: 0, FN_veg: 3989, IoU_veg: 0.0000
# TP_non_veg: 12395, FP_non_veg: 0, FN_non_veg: 3989, IoU_non_veg: 0.7565
# Image 267:
# TP_veg: 4711, FP_veg: 0, FN_veg: 2733, IoU_veg: 0.6329
# TP_non_veg: 8940, FP_non_veg: 0, FN_non_veg: 7444, IoU_non_veg: 0.5457
# Image 268:
# TP_veg: 6342, FP_veg: 0, FN_veg: 4105, IoU_veg: 0.6071
# TP_non_veg: 5937, FP_non_veg: 0, FN_non_veg: 10447, IoU_non_veg: 0.3624
# Image 269:
# TP_veg: 6579, FP_veg: 169, FN_veg: 1998, IoU_veg: 0.7522
# TP_non_veg: 7807, FP_non_veg: 169, FN_non_veg: 8577, IoU_non_veg: 0.4716
# Image 270:
# TP_veg: 6752, FP_veg: 11, FN_veg: 5013, IoU_veg: 0.5734
# TP_non_veg: 4619, FP_non_veg: 11, FN_non_veg: 11765, IoU_non_veg: 0.2817
# Image 271:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 272:
# TP_veg: 26, FP_veg: 5, FN_veg: 9, IoU_veg: 0.6500
# TP_non_veg: 16349, FP_non_veg: 5, FN_non_veg: 35, IoU_non_veg: 0.9976
# Image 273:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 274:
# TP_veg: 4403, FP_veg: 0, FN_veg: 9833, IoU_veg: 0.3093
# TP_non_veg: 2148, FP_non_veg: 0, FN_non_veg: 14236, IoU_non_veg: 0.1311
# Image 275:
# TP_veg: 5269, FP_veg: 0, FN_veg: 5517, IoU_veg: 0.4885
# TP_non_veg: 5598, FP_non_veg: 0, FN_non_veg: 10786, IoU_non_veg: 0.3417
# Image 276:
# TP_veg: 811, FP_veg: 2, FN_veg: 1450, IoU_veg: 0.3584
# TP_non_veg: 14123, FP_non_veg: 2, FN_non_veg: 2261, IoU_non_veg: 0.8619
# Image 277:
# TP_veg: 1222, FP_veg: 26, FN_veg: 7254, IoU_veg: 0.1437
# TP_non_veg: 7908, FP_non_veg: 26, FN_non_veg: 8476, IoU_non_veg: 0.4819
# Image 278:
# TP_veg: 1023, FP_veg: 8, FN_veg: 1351, IoU_veg: 0.4295
# TP_non_veg: 14010, FP_non_veg: 8, FN_non_veg: 2374, IoU_non_veg: 0.8547
# Image 279:
# TP_veg: 5119, FP_veg: 3, FN_veg: 4795, IoU_veg: 0.5162
# TP_non_veg: 6470, FP_non_veg: 3, FN_non_veg: 9914, IoU_non_veg: 0.3948
# Image 280:
# TP_veg: 7, FP_veg: 0, FN_veg: 13780, IoU_veg: 0.0005
# TP_non_veg: 2597, FP_non_veg: 0, FN_non_veg: 13787, IoU_non_veg: 0.1585
# Image 281:
# TP_veg: 1623, FP_veg: 3, FN_veg: 6402, IoU_veg: 0.2022
# TP_non_veg: 8359, FP_non_veg: 3, FN_non_veg: 8025, IoU_non_veg: 0.5101
# Image 282:
# TP_veg: 2491, FP_veg: 0, FN_veg: 6484, IoU_veg: 0.2775
# TP_non_veg: 7409, FP_non_veg: 0, FN_non_veg: 8975, IoU_non_veg: 0.4522
# Image 283:
# TP_veg: 2419, FP_veg: 0, FN_veg: 10263, IoU_veg: 0.1907
# TP_non_veg: 3702, FP_non_veg: 0, FN_non_veg: 12682, IoU_non_veg: 0.2260
# Image 284:
# TP_veg: 1181, FP_veg: 0, FN_veg: 5819, IoU_veg: 0.1687
# TP_non_veg: 9384, FP_non_veg: 0, FN_non_veg: 7000, IoU_non_veg: 0.5728
# Image 285:
# TP_veg: 2938, FP_veg: 0, FN_veg: 7831, IoU_veg: 0.2728
# TP_non_veg: 5615, FP_non_veg: 0, FN_non_veg: 10769, IoU_non_veg: 0.3427
# Image 286:
# TP_veg: 4368, FP_veg: 0, FN_veg: 8691, IoU_veg: 0.3345
# TP_non_veg: 3325, FP_non_veg: 0, FN_non_veg: 13059, IoU_non_veg: 0.2029
# Image 287:
# TP_veg: 4614, FP_veg: 23, FN_veg: 7668, IoU_veg: 0.3750
# TP_non_veg: 4102, FP_non_veg: 23, FN_non_veg: 12282, IoU_non_veg: 0.2500
# Image 288:
# TP_veg: 1740, FP_veg: 26, FN_veg: 9461, IoU_veg: 0.1550
# TP_non_veg: 5183, FP_non_veg: 26, FN_non_veg: 11201, IoU_non_veg: 0.3158
# Image 289:
# TP_veg: 2352, FP_veg: 0, FN_veg: 2547, IoU_veg: 0.4801
# TP_non_veg: 11485, FP_non_veg: 0, FN_non_veg: 4899, IoU_non_veg: 0.7010
# Image 290:
# TP_veg: 4861, FP_veg: 2, FN_veg: 4953, IoU_veg: 0.4952
# TP_non_veg: 6570, FP_non_veg: 2, FN_non_veg: 9814, IoU_non_veg: 0.4010
# Image 291:
# TP_veg: 3053, FP_veg: 3, FN_veg: 4398, IoU_veg: 0.4096
# TP_non_veg: 8933, FP_non_veg: 3, FN_non_veg: 7451, IoU_non_veg: 0.5451
# Image 292:
# TP_veg: 1241, FP_veg: 0, FN_veg: 5944, IoU_veg: 0.1727
# TP_non_veg: 9199, FP_non_veg: 0, FN_non_veg: 7185, IoU_non_veg: 0.5615
# Image 293:
# TP_veg: 1025, FP_veg: 0, FN_veg: 4517, IoU_veg: 0.1850
# TP_non_veg: 10842, FP_non_veg: 0, FN_non_veg: 5542, IoU_non_veg: 0.6617
# Image 294:
# TP_veg: 7, FP_veg: 0, FN_veg: 2617, IoU_veg: 0.0027
# TP_non_veg: 13760, FP_non_veg: 0, FN_non_veg: 2624, IoU_non_veg: 0.8398
# Image 295:
# TP_veg: 2, FP_veg: 0, FN_veg: 1205, IoU_veg: 0.0017
# TP_non_veg: 15177, FP_non_veg: 0, FN_non_veg: 1207, IoU_non_veg: 0.9263
# Image 296:
# TP_veg: 169, FP_veg: 0, FN_veg: 3677, IoU_veg: 0.0439
# TP_non_veg: 12538, FP_non_veg: 0, FN_non_veg: 3846, IoU_non_veg: 0.7653
# Image 297:
# TP_veg: 239, FP_veg: 1, FN_veg: 5221, IoU_veg: 0.0438
# TP_non_veg: 10924, FP_non_veg: 1, FN_non_veg: 5460, IoU_non_veg: 0.6667
# Image 298:
# TP_veg: 112, FP_veg: 0, FN_veg: 2296, IoU_veg: 0.0465
# TP_non_veg: 13976, FP_non_veg: 0, FN_non_veg: 2408, IoU_non_veg: 0.8530
# Image 299:
# TP_veg: 0, FP_veg: 0, FN_veg: 613, IoU_veg: 0.0000
# TP_non_veg: 15771, FP_non_veg: 0, FN_non_veg: 613, IoU_non_veg: 0.9626
# Image 300:
# TP_veg: 1048, FP_veg: 6, FN_veg: 5077, IoU_veg: 0.1709
# TP_non_veg: 10259, FP_non_veg: 6, FN_non_veg: 6125, IoU_non_veg: 0.6259
# Image 301:
# TP_veg: 4136, FP_veg: 6, FN_veg: 2989, IoU_veg: 0.5800
# TP_non_veg: 9259, FP_non_veg: 6, FN_non_veg: 7125, IoU_non_veg: 0.5649
# Image 302:
# TP_veg: 1990, FP_veg: 1, FN_veg: 4780, IoU_veg: 0.2939
# TP_non_veg: 9614, FP_non_veg: 1, FN_non_veg: 6770, IoU_non_veg: 0.5868
# Image 303:
# TP_veg: 3087, FP_veg: 8, FN_veg: 6162, IoU_veg: 0.3335
# TP_non_veg: 7135, FP_non_veg: 8, FN_non_veg: 9249, IoU_non_veg: 0.4353
# Image 304:
# TP_veg: 807, FP_veg: 0, FN_veg: 1904, IoU_veg: 0.2977
# TP_non_veg: 13673, FP_non_veg: 0, FN_non_veg: 2711, IoU_non_veg: 0.8345
# Image 305:
# TP_veg: 3532, FP_veg: 0, FN_veg: 3806, IoU_veg: 0.4813
# TP_non_veg: 9046, FP_non_veg: 0, FN_non_veg: 7338, IoU_non_veg: 0.5521
# Image 306:
# TP_veg: 3674, FP_veg: 0, FN_veg: 2679, IoU_veg: 0.5783
# TP_non_veg: 10031, FP_non_veg: 0, FN_non_veg: 6353, IoU_non_veg: 0.6122
# Image 307:
# TP_veg: 142, FP_veg: 0, FN_veg: 2502, IoU_veg: 0.0537
# TP_non_veg: 13740, FP_non_veg: 0, FN_non_veg: 2644, IoU_non_veg: 0.8386
# Image 308:
# TP_veg: 248, FP_veg: 0, FN_veg: 2736, IoU_veg: 0.0831
# TP_non_veg: 13400, FP_non_veg: 0, FN_non_veg: 2984, IoU_non_veg: 0.8179
# Image 309:
# TP_veg: 1392, FP_veg: 0, FN_veg: 10383, IoU_veg: 0.1182
# TP_non_veg: 4609, FP_non_veg: 0, FN_non_veg: 11775, IoU_non_veg: 0.2813
# Image 310:
# TP_veg: 0, FP_veg: 0, FN_veg: 6106, IoU_veg: 0.0000
# TP_non_veg: 10278, FP_non_veg: 0, FN_non_veg: 6106, IoU_non_veg: 0.6273
# Image 311:
# TP_veg: 91, FP_veg: 1, FN_veg: 3032, IoU_veg: 0.0291
# TP_non_veg: 13261, FP_non_veg: 1, FN_non_veg: 3123, IoU_non_veg: 0.8093
# Image 312:
# TP_veg: 3355, FP_veg: 0, FN_veg: 12917, IoU_veg: 0.2062
# TP_non_veg: 112, FP_non_veg: 0, FN_non_veg: 16272, IoU_non_veg: 0.0068
# Image 313:
# TP_veg: 140, FP_veg: 1, FN_veg: 3222, IoU_veg: 0.0416
# TP_non_veg: 13022, FP_non_veg: 1, FN_non_veg: 3362, IoU_non_veg: 0.7948
# Image 314:
# TP_veg: 320, FP_veg: 0, FN_veg: 2104, IoU_veg: 0.1320
# TP_non_veg: 13960, FP_non_veg: 0, FN_non_veg: 2424, IoU_non_veg: 0.8521
# Image 315:
# TP_veg: 1276, FP_veg: 0, FN_veg: 8880, IoU_veg: 0.1256
# TP_non_veg: 6228, FP_non_veg: 0, FN_non_veg: 10156, IoU_non_veg: 0.3801
# Image 316:
# TP_veg: 635, FP_veg: 0, FN_veg: 1649, IoU_veg: 0.2780
# TP_non_veg: 14100, FP_non_veg: 0, FN_non_veg: 2284, IoU_non_veg: 0.8606
# Image 317:
# TP_veg: 79, FP_veg: 0, FN_veg: 4121, IoU_veg: 0.0188
# TP_non_veg: 12184, FP_non_veg: 0, FN_non_veg: 4200, IoU_non_veg: 0.7437
# Image 318:
# TP_veg: 0, FP_veg: 0, FN_veg: 1315, IoU_veg: 0.0000
# TP_non_veg: 15069, FP_non_veg: 0, FN_non_veg: 1315, IoU_non_veg: 0.9197
# Image 319:
# TP_veg: 0, FP_veg: 0, FN_veg: 1422, IoU_veg: 0.0000
# TP_non_veg: 14962, FP_non_veg: 0, FN_non_veg: 1422, IoU_non_veg: 0.9132
# Image 320:
# TP_veg: 529, FP_veg: 0, FN_veg: 5559, IoU_veg: 0.0869
# TP_non_veg: 10296, FP_non_veg: 0, FN_non_veg: 6088, IoU_non_veg: 0.6284
# Image 321:
# TP_veg: 171, FP_veg: 0, FN_veg: 168, IoU_veg: 0.5044
# TP_non_veg: 16045, FP_non_veg: 0, FN_non_veg: 339, IoU_non_veg: 0.9793
# Image 322:
# TP_veg: 74, FP_veg: 0, FN_veg: 7473, IoU_veg: 0.0098
# TP_non_veg: 8837, FP_non_veg: 0, FN_non_veg: 7547, IoU_non_veg: 0.5394
# Image 323:
# TP_veg: 199, FP_veg: 0, FN_veg: 810, IoU_veg: 0.1972
# TP_non_veg: 15375, FP_non_veg: 0, FN_non_veg: 1009, IoU_non_veg: 0.9384
# Image 324:
# TP_veg: 4271, FP_veg: 0, FN_veg: 12033, IoU_veg: 0.2620
# TP_non_veg: 80, FP_non_veg: 0, FN_non_veg: 16304, IoU_non_veg: 0.0049
# Image 325:
# TP_veg: 3239, FP_veg: 0, FN_veg: 5647, IoU_veg: 0.3645
# TP_non_veg: 7498, FP_non_veg: 0, FN_non_veg: 8886, IoU_non_veg: 0.4576
# Image 326:
# TP_veg: 1913, FP_veg: 31, FN_veg: 6976, IoU_veg: 0.2145
# TP_non_veg: 7495, FP_non_veg: 31, FN_non_veg: 8889, IoU_non_veg: 0.4566
# Image 327:
# TP_veg: 449, FP_veg: 2, FN_veg: 326, IoU_veg: 0.5779
# TP_non_veg: 15609, FP_non_veg: 2, FN_non_veg: 775, IoU_non_veg: 0.9526
# Image 328:
# TP_veg: 945, FP_veg: 0, FN_veg: 7022, IoU_veg: 0.1186
# TP_non_veg: 8417, FP_non_veg: 0, FN_non_veg: 7967, IoU_non_veg: 0.5137
# Image 329:
# TP_veg: 6685, FP_veg: 11, FN_veg: 4909, IoU_veg: 0.5760
# TP_non_veg: 4790, FP_non_veg: 11, FN_non_veg: 11594, IoU_non_veg: 0.2922
# Image 330:
# TP_veg: 1261, FP_veg: 0, FN_veg: 1124, IoU_veg: 0.5287
# TP_non_veg: 13999, FP_non_veg: 0, FN_non_veg: 2385, IoU_non_veg: 0.8544
# Image 331:
# TP_veg: 1527, FP_veg: 17, FN_veg: 8992, IoU_veg: 0.1449
# TP_non_veg: 5865, FP_non_veg: 17, FN_non_veg: 10519, IoU_non_veg: 0.3576
# Image 332:
# TP_veg: 10094, FP_veg: 22, FN_veg: 4619, IoU_veg: 0.6850
# TP_non_veg: 1671, FP_non_veg: 22, FN_non_veg: 14713, IoU_non_veg: 0.1019
# Image 333:
# TP_veg: 6430, FP_veg: 32, FN_veg: 2575, IoU_veg: 0.7115
# TP_non_veg: 7379, FP_non_veg: 32, FN_non_veg: 9005, IoU_non_veg: 0.4495
# Image 334:
# TP_veg: 11046, FP_veg: 3, FN_veg: 3361, IoU_veg: 0.7666
# TP_non_veg: 1977, FP_non_veg: 3, FN_non_veg: 14407, IoU_non_veg: 0.1206
# Image 335:
# TP_veg: 7368, FP_veg: 5, FN_veg: 4002, IoU_veg: 0.6477
# TP_non_veg: 5014, FP_non_veg: 5, FN_non_veg: 11370, IoU_non_veg: 0.3059
# Image 336:
# TP_veg: 1879, FP_veg: 0, FN_veg: 2020, IoU_veg: 0.4819
# TP_non_veg: 12485, FP_non_veg: 0, FN_non_veg: 3899, IoU_non_veg: 0.7620
# Image 337:
# TP_veg: 605, FP_veg: 0, FN_veg: 5745, IoU_veg: 0.0953
# TP_non_veg: 10034, FP_non_veg: 0, FN_non_veg: 6350, IoU_non_veg: 0.6124
# Image 338:
# TP_veg: 74, FP_veg: 0, FN_veg: 9219, IoU_veg: 0.0080
# TP_non_veg: 7091, FP_non_veg: 0, FN_non_veg: 9293, IoU_non_veg: 0.4328
# Image 339:
# TP_veg: 0, FP_veg: 0, FN_veg: 3912, IoU_veg: 0.0000
# TP_non_veg: 12472, FP_non_veg: 0, FN_non_veg: 3912, IoU_non_veg: 0.7612
# Image 340:
# TP_veg: 0, FP_veg: 0, FN_veg: 10505, IoU_veg: 0.0000
# TP_non_veg: 5879, FP_non_veg: 0, FN_non_veg: 10505, IoU_non_veg: 0.3588
# Image 341:
# TP_veg: 0, FP_veg: 0, FN_veg: 3051, IoU_veg: 0.0000
# TP_non_veg: 13333, FP_non_veg: 0, FN_non_veg: 3051, IoU_non_veg: 0.8138
# Image 342:
# TP_veg: 3195, FP_veg: 22, FN_veg: 8269, IoU_veg: 0.2782
# TP_non_veg: 4920, FP_non_veg: 22, FN_non_veg: 11464, IoU_non_veg: 0.2999
# Image 343:
# TP_veg: 1173, FP_veg: 19, FN_veg: 4763, IoU_veg: 0.1970
# TP_non_veg: 10448, FP_non_veg: 19, FN_non_veg: 5936, IoU_non_veg: 0.6370
# Image 344:
# TP_veg: 3050, FP_veg: 5, FN_veg: 3329, IoU_veg: 0.4778
# TP_non_veg: 10005, FP_non_veg: 5, FN_non_veg: 6379, IoU_non_veg: 0.6105
# Image 345:
# TP_veg: 2951, FP_veg: 30, FN_veg: 9843, IoU_veg: 0.2301
# TP_non_veg: 3590, FP_non_veg: 30, FN_non_veg: 12794, IoU_non_veg: 0.2187
# Image 346:
# TP_veg: 787, FP_veg: 27, FN_veg: 1292, IoU_veg: 0.3737
# TP_non_veg: 14305, FP_non_veg: 27, FN_non_veg: 2079, IoU_non_veg: 0.8717
# Image 347:
# TP_veg: 2807, FP_veg: 67, FN_veg: 7367, IoU_veg: 0.2741
# TP_non_veg: 6210, FP_non_veg: 67, FN_non_veg: 10174, IoU_non_veg: 0.3775
# Image 348:
# TP_veg: 87, FP_veg: 0, FN_veg: 5854, IoU_veg: 0.0146
# TP_non_veg: 10443, FP_non_veg: 0, FN_non_veg: 5941, IoU_non_veg: 0.6374
# Image 349:
# TP_veg: 7, FP_veg: 0, FN_veg: 1891, IoU_veg: 0.0037
# TP_non_veg: 14486, FP_non_veg: 0, FN_non_veg: 1898, IoU_non_veg: 0.8842
# Image 350:
# TP_veg: 4228, FP_veg: 0, FN_veg: 5106, IoU_veg: 0.4530
# TP_non_veg: 7050, FP_non_veg: 0, FN_non_veg: 9334, IoU_non_veg: 0.4303
# Image 351:
# TP_veg: 7, FP_veg: 0, FN_veg: 2195, IoU_veg: 0.0032
# TP_non_veg: 14182, FP_non_veg: 0, FN_non_veg: 2202, IoU_non_veg: 0.8656
# Image 352:
# TP_veg: 319, FP_veg: 0, FN_veg: 10533, IoU_veg: 0.0294
# TP_non_veg: 5532, FP_non_veg: 0, FN_non_veg: 10852, IoU_non_veg: 0.3376
# Image 353:
# TP_veg: 78, FP_veg: 0, FN_veg: 15043, IoU_veg: 0.0052
# TP_non_veg: 1263, FP_non_veg: 0, FN_non_veg: 15121, IoU_non_veg: 0.0771
# Image 354:
# TP_veg: 1037, FP_veg: 0, FN_veg: 15347, IoU_veg: 0.0633
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 355:
# TP_veg: 5790, FP_veg: 0, FN_veg: 10594, IoU_veg: 0.3534
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 356:
# TP_veg: 5443, FP_veg: 0, FN_veg: 7354, IoU_veg: 0.4253
# TP_non_veg: 3587, FP_non_veg: 0, FN_non_veg: 12797, IoU_non_veg: 0.2189
# Image 357:
# TP_veg: 2534, FP_veg: 0, FN_veg: 10671, IoU_veg: 0.1919
# ...
# Image 640:
# TP_veg: 1117, FP_veg: 26, FN_veg: 784, IoU_veg: 0.5797
# TP_non_veg: 14483, FP_non_veg: 26, FN_non_veg: 1901, IoU_non_veg: 0.8826
# Image 641:
# TP_veg: 0, FP_veg: 0, FN_veg: 994, IoU_veg: 0.0000
# TP_non_veg: 15390, FP_non_veg: 0, FN_non_veg: 994, IoU_non_veg: 0.9393
# Image 642:
# TP_veg: 4485, FP_veg: 74, FN_veg: 1767, IoU_veg: 0.7090
# TP_non_veg: 10132, FP_non_veg: 74, FN_non_veg: 6252, IoU_non_veg: 0.6156
# Image 643:
# TP_veg: 4029, FP_veg: 20, FN_veg: 2574, IoU_veg: 0.6083
# TP_non_veg: 9781, FP_non_veg: 20, FN_non_veg: 6603, IoU_non_veg: 0.5963
# Image 644:
# TP_veg: 15405, FP_veg: 0, FN_veg: 979, IoU_veg: 0.9402
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 645:
# TP_veg: 11914, FP_veg: 0, FN_veg: 4470, IoU_veg: 0.7272
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 646:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 647:
# TP_veg: 5583, FP_veg: 0, FN_veg: 10801, IoU_veg: 0.3408
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 648:
# TP_veg: 12496, FP_veg: 0, FN_veg: 3887, IoU_veg: 0.7627
# TP_non_veg: 1, FP_non_veg: 0, FN_non_veg: 16383, IoU_non_veg: 0.0001
# Image 649:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 650:
# TP_veg: 9201, FP_veg: 0, FN_veg: 1974, IoU_veg: 0.8234
# TP_non_veg: 5209, FP_non_veg: 0, FN_non_veg: 11175, IoU_non_veg: 0.3179
# Image 651:
# TP_veg: 1015, FP_veg: 0, FN_veg: 714, IoU_veg: 0.5870
# TP_non_veg: 14655, FP_non_veg: 0, FN_non_veg: 1729, IoU_non_veg: 0.8945
# Image 652:
# TP_veg: 28, FP_veg: 0, FN_veg: 1756, IoU_veg: 0.0157
# TP_non_veg: 14600, FP_non_veg: 0, FN_non_veg: 1784, IoU_non_veg: 0.8911
# Image 653:
# TP_veg: 1329, FP_veg: 16, FN_veg: 1251, IoU_veg: 0.5119
# TP_non_veg: 13804, FP_non_veg: 16, FN_non_veg: 2580, IoU_non_veg: 0.8417
# Image 654:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 655:
# TP_veg: 0, FP_veg: 0, FN_veg: 739, IoU_veg: 0.0000
# TP_non_veg: 15645, FP_non_veg: 0, FN_non_veg: 739, IoU_non_veg: 0.9549
# Image 656:
# TP_veg: 1825, FP_veg: 0, FN_veg: 1431, IoU_veg: 0.5605
# TP_non_veg: 13128, FP_non_veg: 0, FN_non_veg: 3256, IoU_non_veg: 0.8013
# Image 657:
# TP_veg: 8403, FP_veg: 52, FN_veg: 1827, IoU_veg: 0.8173
# TP_non_veg: 6154, FP_non_veg: 52, FN_non_veg: 10230, IoU_non_veg: 0.3744
# Image 658:
# TP_veg: 10889, FP_veg: 0, FN_veg: 5495, IoU_veg: 0.6646
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 659:
# TP_veg: 11650, FP_veg: 0, FN_veg: 4734, IoU_veg: 0.7111
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 660:
# TP_veg: 2901, FP_veg: 0, FN_veg: 803, IoU_veg: 0.7832
# TP_non_veg: 12680, FP_non_veg: 0, FN_non_veg: 3704, IoU_non_veg: 0.7739
# Image 661:
# TP_veg: 3391, FP_veg: 75, FN_veg: 4377, IoU_veg: 0.4324
# TP_non_veg: 8616, FP_non_veg: 75, FN_non_veg: 7768, IoU_non_veg: 0.5235
# Image 662:
# TP_veg: 11606, FP_veg: 0, FN_veg: 2695, IoU_veg: 0.8116
# TP_non_veg: 2083, FP_non_veg: 0, FN_non_veg: 14301, IoU_non_veg: 0.1271
# Image 663:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 664:
# TP_veg: 15297, FP_veg: 0, FN_veg: 1087, IoU_veg: 0.9337
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 665:
# TP_veg: 1475, FP_veg: 0, FN_veg: 1254, IoU_veg: 0.5405
# TP_non_veg: 13655, FP_non_veg: 0, FN_non_veg: 2729, IoU_non_veg: 0.8334
# Image 666:
# TP_veg: 434, FP_veg: 0, FN_veg: 2038, IoU_veg: 0.1756
# TP_non_veg: 13912, FP_non_veg: 0, FN_non_veg: 2472, IoU_non_veg: 0.8491
# Image 667:
# TP_veg: 6478, FP_veg: 5, FN_veg: 9140, IoU_veg: 0.4146
# TP_non_veg: 766, FP_non_veg: 5, FN_non_veg: 15618, IoU_non_veg: 0.0467
# Image 668:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 669:
# TP_veg: 0, FP_veg: 0, FN_veg: 87, IoU_veg: 0.0000
# TP_non_veg: 16297, FP_non_veg: 0, FN_non_veg: 87, IoU_non_veg: 0.9947
# Image 670:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 671:
# TP_veg: 2057, FP_veg: 0, FN_veg: 1430, IoU_veg: 0.5899
# TP_non_veg: 12897, FP_non_veg: 0, FN_non_veg: 3487, IoU_non_veg: 0.7872
# Image 672:
# TP_veg: 7561, FP_veg: 22, FN_veg: 4501, IoU_veg: 0.6257
# TP_non_veg: 4322, FP_non_veg: 22, FN_non_veg: 12062, IoU_non_veg: 0.2634
# Image 673:
# TP_veg: 4608, FP_veg: 71, FN_veg: 1232, IoU_veg: 0.7796
# TP_non_veg: 10544, FP_non_veg: 71, FN_non_veg: 5840, IoU_non_veg: 0.6408
# Image 674:
# TP_veg: 0, FP_veg: 0, FN_veg: 2442, IoU_veg: 0.0000
# TP_non_veg: 13942, FP_non_veg: 0, FN_non_veg: 2442, IoU_non_veg: 0.8510
# Image 675:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 676:
# TP_veg: 1844, FP_veg: 0, FN_veg: 3814, IoU_veg: 0.3259
# TP_non_veg: 10726, FP_non_veg: 0, FN_non_veg: 5658, IoU_non_veg: 0.6547
# Image 677:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 678:
# TP_veg: 7810, FP_veg: 0, FN_veg: 8526, IoU_veg: 0.4781
# TP_non_veg: 48, FP_non_veg: 0, FN_non_veg: 16336, IoU_non_veg: 0.0029
# Image 679:
# TP_veg: 6807, FP_veg: 0, FN_veg: 9566, IoU_veg: 0.4157
# TP_non_veg: 11, FP_non_veg: 0, FN_non_veg: 16373, IoU_non_veg: 0.0007
# Image 680:
# TP_veg: 2293, FP_veg: 0, FN_veg: 4071, IoU_veg: 0.3603
# TP_non_veg: 10020, FP_non_veg: 0, FN_non_veg: 6364, IoU_non_veg: 0.6116
# Image 681:
# TP_veg: 6774, FP_veg: 0, FN_veg: 8813, IoU_veg: 0.4346
# TP_non_veg: 797, FP_non_veg: 0, FN_non_veg: 15587, IoU_non_veg: 0.0486
# Image 682:
# TP_veg: 3551, FP_veg: 38, FN_veg: 3538, IoU_veg: 0.4982
# TP_non_veg: 9295, FP_non_veg: 38, FN_non_veg: 7089, IoU_non_veg: 0.5660
# Image 683:
# TP_veg: 5800, FP_veg: 90, FN_veg: 4953, IoU_veg: 0.5349
# TP_non_veg: 5631, FP_non_veg: 90, FN_non_veg: 10753, IoU_non_veg: 0.3418
# Image 684:
# TP_veg: 11718, FP_veg: 0, FN_veg: 4347, IoU_veg: 0.7294
# TP_non_veg: 319, FP_non_veg: 0, FN_non_veg: 16065, IoU_non_veg: 0.0195
# Image 685:
# TP_veg: 6489, FP_veg: 0, FN_veg: 9895, IoU_veg: 0.3961
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 686:
# TP_veg: 11028, FP_veg: 0, FN_veg: 5356, IoU_veg: 0.6731
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 687:
# TP_veg: 5219, FP_veg: 3, FN_veg: 1512, IoU_veg: 0.7750
# TP_non_veg: 9653, FP_non_veg: 3, FN_non_veg: 6731, IoU_non_veg: 0.5891
# Image 688:
# TP_veg: 0, FP_veg: 0, FN_veg: 278, IoU_veg: 0.0000
# TP_non_veg: 16106, FP_non_veg: 0, FN_non_veg: 278, IoU_non_veg: 0.9830
# Image 689:
# TP_veg: 0, FP_veg: 0, FN_veg: 336, IoU_veg: 0.0000
# TP_non_veg: 16048, FP_non_veg: 0, FN_non_veg: 336, IoU_non_veg: 0.9795
# Image 690:
# TP_veg: 2104, FP_veg: 0, FN_veg: 7098, IoU_veg: 0.2286
# TP_non_veg: 7182, FP_non_veg: 0, FN_non_veg: 9202, IoU_non_veg: 0.4384
# Image 691:
# TP_veg: 0, FP_veg: 0, FN_veg: 3, IoU_veg: 0.0000
# TP_non_veg: 16381, FP_non_veg: 0, FN_non_veg: 3, IoU_non_veg: 0.9998
# Image 692:
# TP_veg: 5513, FP_veg: 0, FN_veg: 10871, IoU_veg: 0.3365
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 693:
# TP_veg: 5730, FP_veg: 0, FN_veg: 10654, IoU_veg: 0.3497
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 694:
# TP_veg: 10694, FP_veg: 0, FN_veg: 5690, IoU_veg: 0.6527
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 695:
# TP_veg: 14645, FP_veg: 0, FN_veg: 1739, IoU_veg: 0.8939
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 696:
# TP_veg: 5118, FP_veg: 28, FN_veg: 3927, IoU_veg: 0.5641
# TP_non_veg: 7339, FP_non_veg: 28, FN_non_veg: 9045, IoU_non_veg: 0.4472
# Image 697:
# TP_veg: 210, FP_veg: 21, FN_veg: 235, IoU_veg: 0.4506
# TP_non_veg: 15939, FP_non_veg: 21, FN_non_veg: 445, IoU_non_veg: 0.9716
# Image 698:
# TP_veg: 0, FP_veg: 0, FN_veg: 2751, IoU_veg: 0.0000
# TP_non_veg: 13633, FP_non_veg: 0, FN_non_veg: 2751, IoU_non_veg: 0.8321
# Image 699:
# TP_veg: 552, FP_veg: 0, FN_veg: 11853, IoU_veg: 0.0445
# TP_non_veg: 3979, FP_non_veg: 0, FN_non_veg: 12405, IoU_non_veg: 0.2429
# Image 700:
# TP_veg: 12950, FP_veg: 12, FN_veg: 1480, IoU_veg: 0.8967
# TP_non_veg: 1954, FP_non_veg: 12, FN_non_veg: 14430, IoU_non_veg: 0.1192
# Image 701:
# TP_veg: 240, FP_veg: 3, FN_veg: 1576, IoU_veg: 0.1319
# TP_non_veg: 14568, FP_non_veg: 3, FN_non_veg: 1816, IoU_non_veg: 0.8890
# Image 702:
# TP_veg: 0, FP_veg: 0, FN_veg: 186, IoU_veg: 0.0000
# TP_non_veg: 16198, FP_non_veg: 0, FN_non_veg: 186, IoU_non_veg: 0.9886
# Image 703:
# TP_veg: 0, FP_veg: 0, FN_veg: 462, IoU_veg: 0.0000
# TP_non_veg: 15922, FP_non_veg: 0, FN_non_veg: 462, IoU_non_veg: 0.9718
# Image 704:
# TP_veg: 4059, FP_veg: 0, FN_veg: 6238, IoU_veg: 0.3942
# TP_non_veg: 6087, FP_non_veg: 0, FN_non_veg: 10297, IoU_non_veg: 0.3715
# Image 705:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 706:
# TP_veg: 22, FP_veg: 0, FN_veg: 7713, IoU_veg: 0.0028
# TP_non_veg: 8649, FP_non_veg: 0, FN_non_veg: 7735, IoU_non_veg: 0.5279
# Image 707:
# TP_veg: 8539, FP_veg: 0, FN_veg: 7845, IoU_veg: 0.5212
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 708:
# TP_veg: 16376, FP_veg: 0, FN_veg: 8, IoU_veg: 0.9995
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 709:
# TP_veg: 11430, FP_veg: 0, FN_veg: 4954, IoU_veg: 0.6976
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 710:
# TP_veg: 188, FP_veg: 0, FN_veg: 3680, IoU_veg: 0.0486
# TP_non_veg: 12516, FP_non_veg: 0, FN_non_veg: 3868, IoU_non_veg: 0.7639
# Image 711:
# TP_veg: 4882, FP_veg: 73, FN_veg: 3989, IoU_veg: 0.5458
# TP_non_veg: 7513, FP_non_veg: 73, FN_non_veg: 8871, IoU_non_veg: 0.4565
# Image 712:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 713:
# TP_veg: 110, FP_veg: 0, FN_veg: 328, IoU_veg: 0.2511
# TP_non_veg: 15946, FP_non_veg: 0, FN_non_veg: 438, IoU_non_veg: 0.9733
# Image 714:
# TP_veg: 2409, FP_veg: 52, FN_veg: 292, IoU_veg: 0.8750
# TP_non_veg: 13683, FP_non_veg: 52, FN_non_veg: 2701, IoU_non_veg: 0.8325
# Image 715:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 716:
# TP_veg: 7, FP_veg: 0, FN_veg: 851, IoU_veg: 0.0082
# TP_non_veg: 15526, FP_non_veg: 0, FN_non_veg: 858, IoU_non_veg: 0.9476
# Image 717:
# TP_veg: 9443, FP_veg: 3, FN_veg: 4175, IoU_veg: 0.6933
# TP_non_veg: 2766, FP_non_veg: 3, FN_non_veg: 13618, IoU_non_veg: 0.1688
# Image 718:
# TP_veg: 5885, FP_veg: 6, FN_veg: 5859, IoU_veg: 0.5009
# TP_non_veg: 4640, FP_non_veg: 6, FN_non_veg: 11744, IoU_non_veg: 0.2831
# Image 719:
# TP_veg: 735, FP_veg: 0, FN_veg: 887, IoU_veg: 0.4531
# TP_non_veg: 14762, FP_non_veg: 0, FN_non_veg: 1622, IoU_non_veg: 0.9010
# Image 720:
# TP_veg: 10319, FP_veg: 0, FN_veg: 5286, IoU_veg: 0.6613
# TP_non_veg: 779, FP_non_veg: 0, FN_non_veg: 15605, IoU_non_veg: 0.0475
# Image 721:
# TP_veg: 14302, FP_veg: 0, FN_veg: 2082, IoU_veg: 0.8729
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 722:
# TP_veg: 16384, FP_veg: 0, FN_veg: 0, IoU_veg: 1.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 723:
# TP_veg: 13237, FP_veg: 0, FN_veg: 3147, IoU_veg: 0.8079
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 724:
# TP_veg: 1444, FP_veg: 0, FN_veg: 3888, IoU_veg: 0.2708
# TP_non_veg: 11052, FP_non_veg: 0, FN_non_veg: 5332, IoU_non_veg: 0.6746
# Image 725:
# TP_veg: 1035, FP_veg: 1, FN_veg: 2176, IoU_veg: 0.3222
# TP_non_veg: 13173, FP_non_veg: 1, FN_non_veg: 3211, IoU_non_veg: 0.8040
# Image 726:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 727:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 728:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 729:
# TP_veg: 221, FP_veg: 0, FN_veg: 1585, IoU_veg: 0.1224
# TP_non_veg: 14578, FP_non_veg: 0, FN_non_veg: 1806, IoU_non_veg: 0.8898
# Image 730:
# TP_veg: 385, FP_veg: 0, FN_veg: 786, IoU_veg: 0.3288
# TP_non_veg: 15213, FP_non_veg: 0, FN_non_veg: 1171, IoU_non_veg: 0.9285
# Image 731:
# TP_veg: 10609, FP_veg: 0, FN_veg: 2848, IoU_veg: 0.7884
# TP_non_veg: 2927, FP_non_veg: 0, FN_non_veg: 13457, IoU_non_veg: 0.1786
# Image 732:
# TP_veg: 6742, FP_veg: 0, FN_veg: 9642, IoU_veg: 0.4115
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 733:
# TP_veg: 0, FP_veg: 0, FN_veg: 2842, IoU_veg: 0.0000
# TP_non_veg: 13542, FP_non_veg: 0, FN_non_veg: 2842, IoU_non_veg: 0.8265
# Image 734:
# TP_veg: 13796, FP_veg: 0, FN_veg: 2588, IoU_veg: 0.8420
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 735:
# TP_veg: 13786, FP_veg: 0, FN_veg: 2598, IoU_veg: 0.8414
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 736:
# TP_veg: 13998, FP_veg: 0, FN_veg: 2386, IoU_veg: 0.8544
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 737:
# TP_veg: 5085, FP_veg: 0, FN_veg: 11299, IoU_veg: 0.3104
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 738:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 739:
# TP_veg: 595, FP_veg: 0, FN_veg: 238, IoU_veg: 0.7143
# TP_non_veg: 15551, FP_non_veg: 0, FN_non_veg: 833, IoU_non_veg: 0.9492
# Image 740:
# TP_veg: 1135, FP_veg: 52, FN_veg: 2818, IoU_veg: 0.2834
# TP_non_veg: 12431, FP_non_veg: 52, FN_non_veg: 3953, IoU_non_veg: 0.7563
# Image 741:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 742:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 743:
# TP_veg: 2643, FP_veg: 10, FN_veg: 2100, IoU_veg: 0.5561
# TP_non_veg: 11641, FP_non_veg: 10, FN_non_veg: 4743, IoU_non_veg: 0.7101
# Image 744:
# TP_veg: 188, FP_veg: 0, FN_veg: 393, IoU_veg: 0.3236
# TP_non_veg: 15803, FP_non_veg: 0, FN_non_veg: 581, IoU_non_veg: 0.9645
# Image 745:
# TP_veg: 10, FP_veg: 0, FN_veg: 937, IoU_veg: 0.0106
# TP_non_veg: 15437, FP_non_veg: 0, FN_non_veg: 947, IoU_non_veg: 0.9422
# Image 746:
# TP_veg: 12333, FP_veg: 0, FN_veg: 1827, IoU_veg: 0.8710
# TP_non_veg: 2224, FP_non_veg: 0, FN_non_veg: 14160, IoU_non_veg: 0.1357
# Image 747:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 748:
# TP_veg: 13774, FP_veg: 0, FN_veg: 2610, IoU_veg: 0.8407
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 749:
# TP_veg: 16198, FP_veg: 0, FN_veg: 186, IoU_veg: 0.9886
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 750:
# TP_veg: 7304, FP_veg: 0, FN_veg: 9080, IoU_veg: 0.4458
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 751:
# TP_veg: 6244, FP_veg: 0, FN_veg: 10140, IoU_veg: 0.3811
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 752:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 753:
# TP_veg: 1, FP_veg: 0, FN_veg: 35, IoU_veg: 0.0278
# TP_non_veg: 16348, FP_non_veg: 0, FN_non_veg: 36, IoU_non_veg: 0.9978
# Image 754:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 755:
# TP_veg: 1068, FP_veg: 4, FN_veg: 3120, IoU_veg: 0.2548
# TP_non_veg: 12196, FP_non_veg: 4, FN_non_veg: 4188, IoU_non_veg: 0.7442
# Image 756:
# TP_veg: 365, FP_veg: 0, FN_veg: 2097, IoU_veg: 0.1483
# TP_non_veg: 13922, FP_non_veg: 0, FN_non_veg: 2462, IoU_non_veg: 0.8497
# Image 757:
# TP_veg: 148, FP_veg: 0, FN_veg: 537, IoU_veg: 0.2161
# TP_non_veg: 15699, FP_non_veg: 0, FN_non_veg: 685, IoU_non_veg: 0.9582

# %%
# mean_iou_vegetation = np.mean(IoU_vegetation)
# mean_iou_non_vegetation = np.mean(IoU_non_vegetation)
# mean_all_iou = (mean_iou_vegetation + mean_iou_non_vegetation) / 2
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_iou_vegetation * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_iou_non_vegetation * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_all_iou * 100), "%")

# %%
tp_veg_overall = np.sum(TP_vegetation)
fp_veg_overall = np.sum(FP_vegetation)
fn_veg_overall = np.sum(FN_vegetation)

print("TP Vegetation: ", tp_veg_overall)
print("FP Vegetation: ", fp_veg_overall)
print("FN Vegetation: ", fn_veg_overall)

IoU_veg_overall = tp_veg_overall / (tp_veg_overall + fp_veg_overall + fn_veg_overall)
print("IoU Vegetation: ", IoU_veg_overall)

tp_non_veg_overall = np.sum(TP_non_vegetation)
fp_non_veg_overall = np.sum(FP_non_vegetation)
fn_non_veg_overall = np.sum(FN_non_vegetation)

print("\nTP Non-Vegetation: ", tp_non_veg_overall)
print("FP Non-Vegetation: ", fp_non_veg_overall)
print("FN Non-Vegetation: ", fn_non_veg_overall)

IoU_non_veg_overall = tp_non_veg_overall / (tp_non_veg_overall + fp_non_veg_overall + fn_non_veg_overall)
print("IoU Non-Vegetation: ", IoU_non_veg_overall)

IoU_overall = (IoU_veg_overall + IoU_non_veg_overall)/2
print("\nIoU Overall: ", IoU_overall)
# Out:
# TP Vegetation:  1960850
# FP Vegetation:  5936
# FN Vegetation:  2542122
# IoU Vegetation:  0.4348835682608738
#
# TP Non-Vegetation:  7899716
# FP Non-Vegetation:  5936
# FN Non-Vegetation:  4502972
# IoU Non-Vegetation:  0.6366311043029429
#
# IoU Overall:  0.5357573362819084

# %% [markdown]
# ========================================================================================================

# %%
vegetation_color = [0, 255, 0]  # Green
non_vegetation_color = [0, 0, 255] # Blue

indexing = 5
input_image = images_load[indexing]
ground_truth = ground_truths[indexing]
features_get = fe.extract(input_image)

# Preprocess the input image
input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_reshaped.reshape(-1, 3)  # Remove the transpose operation here

# Predict segmentation mask
predicted_mask = model_loaded.forward(features)
predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)

# Create segmented image
segmented_image[predicted_mask == 0] = non_vegetation_color
segmented_image[predicted_mask == 1] = vegetation_color

# Visualize input image, ground truth, and segmented image
plt.figure(figsize=(12, 5))
plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Input Image')

plt.subplot(1, 3, 2)
plt.imshow(segmented_image)
plt.title('Segmented Image')

plt.subplot(1, 3, 3)
plt.imshow(ground_truth)
plt.title('Ground Truth')

# print("IoU Vegetation: {:.4f}".format(IoU_vegetation[indexing]))
# print("IoU Non-Vegetation: {:.4f}".format(IoU_non_vegetation[indexing]))
# print("Mean IoU: {:.4f}".format((IoU_vegetation[indexing] + IoU_non_vegetation[indexing])/2))

# plt.subplot(1, 3, 3)
# plt.imshow(segmented_image)
# plt.title('Segmented Image')
# IoU = (IoU_vegetation[indexing] + IoU_non_vegetation[indexing]) / 2


print("Shape Segmented Image:", segmented_image.shape)
print("Shape Ground Truth:", ground_truth.shape)
plt.show()
# Out:
# Shape Segmented Image: (128, 128, 3)
# Shape Ground Truth: (128, 128, 3)

# %%
# vegetation_color = [0, 255, 0]  # Green
# non_vegetation_color = [0, 0, 255] # Blue

# # Initialize lists for TP, FP, FN, and IoU
# vegetation_TP = []
# vegetation_FP = []
# vegetation_FN = []
# non_vegetation_TP = []
# non_vegetation_FP = []
# non_vegetation_FN = []
# IoU_vegetation = []
# IoU_non_vegetation = []

# # Loop over testing images
# for i in range(len(image_test)):
#     # Reset counts for each image
#     TP_vegetation = 0
#     FP_vegetation = 0
#     FN_vegetation = 0
#     TP_non_vegetation = 0
#     FP_non_vegetation = 0
#     FN_non_vegetation = 0
    
#     input_image = image_test[i]
#     ground_truth = image_label_test[i]

#     # Preprocess the input image
#     input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
#     features = input_image_reshaped.reshape(-1, 3)

#     # Predict segmentation mask
#     predicted_mask = model_loaded.forward(features)
#     predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

#     # Convert ground truth to single-channel binary masks for vegetation and non-vegetation
#     vegetation_ground_truth = (ground_truth == [0, 255, 0]).all(axis=2)
#     non_vegetation_ground_truth = ~vegetation_ground_truth

#     # Iterate over each pixel in the patch
#     for y in range(128):
#         for x in range(128):
#             # Check if the pixel is vegetation in both prediction and ground truth
#             if vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 TP_vegetation += 1
#             # Check if the pixel is non-vegetation in both prediction and ground truth
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 TP_non_vegetation += 1
#             # Check if the pixel is vegetation in ground truth but non-vegetation in prediction
#             elif vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 FN_vegetation += 1
#             # Check if the pixel is non-vegetation in ground truth but vegetation in prediction
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 FP_non_vegetation += 1
                
#     # Append TP, FP, FN counts for both classes
#     vegetation_TP.append(TP_vegetation)
#     vegetation_FP.append(FP_vegetation)
#     vegetation_FN.append(FN_vegetation)
#     non_vegetation_TP.append(TP_non_vegetation)
#     non_vegetation_FP.append(FP_non_vegetation)
#     non_vegetation_FN.append(FN_non_vegetation)

#     # Calculate IoU for both classes if the denominator is not zero
#     if (TP_vegetation + FP_vegetation + FN_vegetation) != 0:
#         IoU_vegetation.append(TP_vegetation / (TP_vegetation + FP_vegetation + FN_vegetation))
#     else:
#         IoU_vegetation.append(0.0)

#     if (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation) != 0:
#         IoU_non_vegetation.append(TP_non_vegetation / (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation))
#     else:
#         IoU_non_vegetation.append(0.0)

#     print("===============================Image {}==================================".format(i+1))
#     print("vegetation_TP: {}, vegetation_FP: {}, vegetation_FN: {}\nnon_vegetation_TP: {}, non_vegetation_FP: {}, non_vegetation_FN: {}".format(TP_vegetation, FP_vegetation, FN_vegetation, TP_non_vegetation, FP_non_vegetation, FN_non_vegetation))
#     print("Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}, Mean IoU: {:.4f}".format(IoU_vegetation[-1], IoU_non_vegetation[-1], (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2))
#     # Visualize input image, ground truth, and segmented image
#     # plt.figure(figsize=(12, 5))
#     # plt.subplot(1, 3, 1)
#     # plt.imshow(input_image)
#     # plt.title('Input Image')
    
#     # plt.subplot(1, 3, 2)
#     # plt.imshow(ground_truth)
#     # plt.title('Ground Truth')
    
#     # # Create segmented image
#     # segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)
#     # segmented_image[predicted_mask == 0] = non_vegetation_color
#     # segmented_image[predicted_mask == 1] = vegetation_color
    
#     # # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
#     # plt.subplot(1, 3, 3)
#     # plt.imshow(segmented_image)
#     # IoU = (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2
#     # plt.title('Segmented Image (Mean IoU: {:.4f})'.format(IoU))
    
#     # plt.show()

# %%
# # Compute mean IoU across all images for vegetation and non-vegetation classes
# mean_IoU_vegetation_class = sum(IoU_vegetation) / len(IoU_vegetation)
# mean_IoU_non_vegetation_class = sum(IoU_non_vegetation) / len(IoU_non_vegetation)
# mean_IoU_overall = (mean_IoU_vegetation_class + mean_IoU_non_vegetation_class) / 2

# # Print mean IoU for both classes
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_IoU_vegetation_class * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_IoU_non_vegetation_class * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_IoU_overall * 100), "%")
