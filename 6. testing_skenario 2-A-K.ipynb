# %%
from utils import conv
from utils import NN2hidden as nn2
from utils import dataprepare as dp
from utils import Feature_extract as fe

import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
def load_weights(filename):
    with open(filename, 'rb') as f:
        data = np.load(f)
        weights_hidden2_output = data['weights_hidden2_output']
        bias_hidden2_output = data['bias_hidden2_output']
        weights_hidden1_hidden2 = data['weights_hidden1_hidden2']
        bias_hidden1_hidden2 = data['bias_hidden1_hidden2']
        weights_input_hidden1 = data['weights_input_hidden1']
        bias_input_hidden1 = data['bias_input_hidden1']
    return weights_hidden2_output, bias_hidden2_output, weights_hidden1_hidden2, bias_hidden1_hidden2, weights_input_hidden1, bias_input_hidden1

# %%
# Load images and ground truth labels
images_path = 'patching_fix/patch_image'
feature_images_path = 'patching_fix/feature_extract'
ground_truths_path = 'patching_fix/patch_ground'

images_load = dp.load_images_from_folder(images_path)
feature_images_load = dp.load_images_from_folder(feature_images_path)
ground_truths = dp.load_ground_truth_from_folder(ground_truths_path)

# %%
feature_images_train = feature_images_load[:math.ceil(len(feature_images_load)*0.7)] 
image_label_train = ground_truths[:math.ceil(len(ground_truths)*0.7)]

image_test = images_load[math.ceil(len(images_load)*0.7):]
image_label_test = ground_truths[math.ceil(len(ground_truths)*0.7):]

# %%
# # Prepare data
# X_test, y_test = dp.prepare_data(image_test, image_label_test)
# # Normalize the features
# X__test_normalized = X_test / 255.0

# %%
# input_size = X__test_normalized.shape[0]
input_size = 3
hidden_size1 = 3  # neuron hidden layer 1
hidden_size2 = 2  # neuron hidden layer 2
output_size = 2  # 2 classes: vegetation and non-vegetation

# %%
# Load weights for testing
weights_hidden2_output, bias_hidden2_output, weights_hidden1_hidden2, bias_hidden1_hidden2, weights_input_hidden1, bias_input_hidden1 = load_weights("6. Bobot_skenario_6.npz")


# Initialize the neural network with the loaded weights
model_loaded = nn2.NeuralNetwork(input_size, hidden_size1, hidden_size2, output_size)
model_loaded.weights_hidden2_output = weights_hidden2_output
model_loaded.bias_hidden2_output = bias_hidden2_output
model_loaded.weights_hidden1_hidden2 = weights_hidden1_hidden2
model_loaded.bias_hidden1_hidden2 = bias_hidden1_hidden2
model_loaded.weights_input_hidden1 = weights_input_hidden1
model_loaded.bias_input_hidden1 = bias_input_hidden1

# %%
print('Bobot dan bias yang diload:')
print('Bobot hidden layer 1:\n', model_loaded.weights_input_hidden1)
print('Bias hidden layer 1:\n', model_loaded.bias_input_hidden1[0][0])
print('Bobot hidden layer 2:\n', model_loaded.weights_hidden1_hidden2)
print('Bias hidden layer 2:\n', model_loaded.bias_hidden1_hidden2[0][0])
print('Bobot output layer:\n', model_loaded.weights_hidden2_output)
print('Bias output layer:\n', model_loaded.bias_hidden2_output[0][0])
# Out:
# Bobot dan bias yang diload:
# Bobot hidden layer 1:
#  [[  9.82482718   9.90564083  10.54672675]
#  [-12.61320665 -12.71202733 -13.54938776]
#  [ -7.63166258  -7.70996419  -8.20904912]]
# Bias hidden layer 1:
#  -0.4651106399283047
# Bobot hidden layer 2:
#  [[-9.20212658 -8.95796672]
#  [-9.26871999 -9.0637113 ]
#  [-9.86473236 -9.80772181]]
# Bias hidden layer 2:
#  8.779761661187278
# Bobot output layer:
#  [[ 0.77480982 -0.77480982]
#  [ 0.15134877 -0.15134877]]
# Bias output layer:
#  0.05433228622306542

# %%
TP = 0  # True Positives
FP = 0  # False Positives
FN = 0  # False Negatives
TN = 0  # True Negatives

# Loop over testing images
for i in range(len(image_test)):
    TPi = 0  # True Positives index
    FPi = 0  # False Positives index
    FNi = 0  # False Negatives index
    TNi = 0  # True Negatives index

    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN, TN for the current image
    for row in range(predicted_mask.shape[0]):
        for col in range(predicted_mask.shape[1]):
            if predicted_mask[row, col] == 1 and vegetation_ground_truth[row, col]:
                TPi += 1
                TP += 1
            elif predicted_mask[row, col] == 1 and not vegetation_ground_truth[row, col]:
                FPi += 1
                FP += 1
            elif predicted_mask[row, col] == 0 and vegetation_ground_truth[row, col]:
                FNi += 1
                FN += 1
            elif predicted_mask[row, col] == 0 and not vegetation_ground_truth[row, col]:
                TNi += 1
                TN += 1
    
    # Print the values for TP, FP, FN, TN for the current image
    print("Image {}: TP = {}, FP = {}, FN = {}, TN = {}".format(i+1, TPi, FPi, FNi, TNi))
# Out:
# Image 1: TP = 6, FP = 0, FN = 39, TN = 16339
# Image 2: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 3: TP = 317, FP = 0, FN = 205, TN = 15862
# Image 4: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 5: TP = 4, FP = 0, FN = 6, TN = 16374
# Image 6: TP = 365, FP = 0, FN = 251, TN = 15768
# Image 7: TP = 3425, FP = 0, FN = 2144, TN = 10815
# Image 8: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 9: TP = 97, FP = 0, FN = 74, TN = 16213
# Image 10: TP = 2891, FP = 1, FN = 6275, TN = 7217
# Image 11: TP = 314, FP = 0, FN = 1350, TN = 14720
# Image 12: TP = 3670, FP = 0, FN = 5261, TN = 7453
# Image 13: TP = 56, FP = 0, FN = 170, TN = 16158
# Image 14: TP = 230, FP = 49, FN = 167, TN = 15938
# Image 15: TP = 2329, FP = 0, FN = 720, TN = 13335
# Image 16: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 17: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 18: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 19: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 20: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 21: TP = 31, FP = 0, FN = 184, TN = 16169
# Image 22: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 23: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 24: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 25: TP = 1444, FP = 0, FN = 2033, TN = 12907
# Image 26: TP = 6480, FP = 4, FN = 3069, TN = 6831
# Image 27: TP = 1375, FP = 13, FN = 1501, TN = 13495
# Image 28: TP = 6155, FP = 82, FN = 840, TN = 9307
# Image 29: TP = 2546, FP = 23, FN = 972, TN = 12843
# Image 30: TP = 2898, FP = 0, FN = 3215, TN = 10271
# Image 31: TP = 1538, FP = 48, FN = 160, TN = 14638
# Image 32: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 33: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 34: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 35: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 36: TP = 892, FP = 0, FN = 881, TN = 14611
# Image 37: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 38: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 39: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 40: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 41: TP = 891, FP = 0, FN = 1607, TN = 13886
# Image 42: TP = 271, FP = 0, FN = 2689, TN = 13424
# Image 43: TP = 1103, FP = 0, FN = 3302, TN = 11979
# Image 44: TP = 170, FP = 3, FN = 289, TN = 15922
# Image 45: TP = 8319, FP = 4, FN = 931, TN = 7130
# Image 46: TP = 2293, FP = 47, FN = 483, TN = 13561
# Image 47: TP = 1854, FP = 24, FN = 408, TN = 14098
# Image 48: TP = 0, FP = 0, FN = 1581, TN = 14803
# Image 49: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 50: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 51: TP = 6162, FP = 0, FN = 5128, TN = 5094
# Image 52: TP = 11741, FP = 0, FN = 4643, TN = 0
# Image 53: TP = 2001, FP = 0, FN = 2919, TN = 11464
# Image 54: TP = 2005, FP = 0, FN = 3069, TN = 11310
# Image 55: TP = 3298, FP = 0, FN = 3090, TN = 9996
# Image 56: TP = 584, FP = 0, FN = 1580, TN = 14220
# Image 57: TP = 1730, FP = 0, FN = 1463, TN = 13191
# Image 58: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 59: TP = 4209, FP = 42, FN = 4244, TN = 7889
# Image 60: TP = 808, FP = 0, FN = 1361, TN = 14215
# Image 61: TP = 9116, FP = 41, FN = 4705, TN = 2522
# Image 62: TP = 1092, FP = 31, FN = 225, TN = 15036
# Image 63: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 64: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 65: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 66: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 67: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 68: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 69: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 70: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 71: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 72: TP = 1153, FP = 5, FN = 1303, TN = 13923
# Image 73: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 74: TP = 108, FP = 10, FN = 682, TN = 15584
# Image 75: TP = 285, FP = 7, FN = 502, TN = 15590
# Image 76: TP = 2808, FP = 3, FN = 7498, TN = 6075
# Image 77: TP = 9480, FP = 87, FN = 4021, TN = 2796
# Image 78: TP = 1735, FP = 244, FN = 109, TN = 14296
# Image 79: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 80: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 81: TP = 302, FP = 5, FN = 920, TN = 15157
# Image 82: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 83: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 84: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 85: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 86: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 87: TP = 1011, FP = 0, FN = 1247, TN = 14126
# Image 88: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 89: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 90: TP = 451, FP = 0, FN = 544, TN = 15389
# Image 91: TP = 4218, FP = 1, FN = 1660, TN = 10505
# Image 92: TP = 8686, FP = 8, FN = 3614, TN = 4076
# Image 93: TP = 9809, FP = 142, FN = 2765, TN = 3668
# Image 94: TP = 1364, FP = 5, FN = 267, TN = 14748
# Image 95: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 96: TP = 163, FP = 0, FN = 513, TN = 15708
# Image 97: TP = 1028, FP = 0, FN = 836, TN = 14520
# Image 98: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 99: TP = 1102, FP = 0, FN = 779, TN = 14503
# Image 100: TP = 5, FP = 0, FN = 32, TN = 16347
# Image 101: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 102: TP = 6, FP = 6, FN = 241, TN = 16131
# Image 103: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 104: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 105: TP = 544, FP = 0, FN = 924, TN = 14916
# Image 106: TP = 119, FP = 11, FN = 99, TN = 16155
# Image 107: TP = 3826, FP = 79, FN = 6991, TN = 5488
# Image 108: TP = 141, FP = 1, FN = 2493, TN = 13749
# Image 109: TP = 4132, FP = 72, FN = 2806, TN = 9374
# Image 110: TP = 4167, FP = 108, FN = 487, TN = 11622
# Image 111: TP = 23, FP = 0, FN = 480, TN = 15881
# Image 112: TP = 360, FP = 0, FN = 753, TN = 15271
# Image 113: TP = 826, FP = 1, FN = 988, TN = 14569
# Image 114: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 115: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 116: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 117: TP = 750, FP = 0, FN = 10230, TN = 5404
# Image 118: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 119: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 120: TP = 0, FP = 0, FN = 35, TN = 16349
# Image 121: TP = 738, FP = 16, FN = 349, TN = 15281
# Image 122: TP = 10569, FP = 3, FN = 3167, TN = 2645
# Image 123: TP = 9146, FP = 4, FN = 3248, TN = 3986
# Image 124: TP = 10845, FP = 0, FN = 4549, TN = 990
# Image 125: TP = 6013, FP = 0, FN = 3626, TN = 6745
# Image 126: TP = 355, FP = 1, FN = 1038, TN = 14990
# Image 127: TP = 794, FP = 0, FN = 1153, TN = 14437
# Image 128: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 129: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 130: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 131: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 132: TP = 5621, FP = 7, FN = 9155, TN = 1601
# Image 133: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 134: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 135: TP = 3965, FP = 114, FN = 334, TN = 11971
# Image 136: TP = 1708, FP = 12, FN = 2944, TN = 11720
# Image 137: TP = 1562, FP = 1, FN = 1528, TN = 13293
# Image 138: TP = 4779, FP = 214, FN = 3127, TN = 8264
# Image 139: TP = 4155, FP = 0, FN = 4781, TN = 7448
# Image 140: TP = 898, FP = 0, FN = 10747, TN = 4739
# Image 141: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 142: TP = 0, FP = 0, FN = 213, TN = 16171
# Image 143: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 144: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 145: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 146: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 147: TP = 1756, FP = 0, FN = 2122, TN = 12506
# Image 148: TP = 250, FP = 0, FN = 50, TN = 16084
# Image 149: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 150: TP = 10881, FP = 35, FN = 3551, TN = 1917
# Image 151: TP = 2043, FP = 29, FN = 2237, TN = 12075
# Image 152: TP = 3593, FP = 9, FN = 1319, TN = 11463
# Image 153: TP = 5319, FP = 81, FN = 1751, TN = 9233
# Image 154: TP = 20, FP = 0, FN = 1753, TN = 14611
# Image 155: TP = 5195, FP = 0, FN = 6040, TN = 5149
# Image 156: TP = 4178, FP = 254, FN = 128, TN = 11824
# Image 157: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 158: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 159: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 160: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 161: TP = 3150, FP = 35, FN = 823, TN = 12376
# Image 162: TP = 1453, FP = 3, FN = 1370, TN = 13558
# Image 163: TP = 7393, FP = 115, FN = 183, TN = 8693
# Image 164: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 165: TP = 2572, FP = 0, FN = 823, TN = 12989
# Image 166: TP = 64, FP = 0, FN = 1677, TN = 14643
# Image 167: TP = 3126, FP = 11, FN = 3135, TN = 10112
# Image 168: TP = 3, FP = 0, FN = 3, TN = 16378
# Image 169: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 170: TP = 632, FP = 14, FN = 103, TN = 15635
# Image 171: TP = 11070, FP = 20, FN = 4038, TN = 1256
# Image 172: TP = 4342, FP = 207, FN = 81, TN = 11754
# Image 173: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 174: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 175: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 176: TP = 1892, FP = 67, FN = 273, TN = 14152
# Image 177: TP = 722, FP = 0, FN = 896, TN = 14766
# Image 178: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 179: TP = 354, FP = 8, FN = 355, TN = 15667
# Image 180: TP = 9200, FP = 67, FN = 2560, TN = 4557
# Image 181: TP = 483, FP = 0, FN = 442, TN = 15459
# Image 182: TP = 1828, FP = 8, FN = 1370, TN = 13178
# Image 183: TP = 240, FP = 0, FN = 1729, TN = 14415
# Image 184: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 185: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 186: TP = 12787, FP = 2, FN = 3023, TN = 572
# Image 187: TP = 10230, FP = 0, FN = 6154, TN = 0
# Image 188: TP = 904, FP = 0, FN = 821, TN = 14659
# Image 189: TP = 0, FP = 0, FN = 3278, TN = 13106
# Image 190: TP = 459, FP = 8, FN = 1113, TN = 14804
# Image 191: TP = 3122, FP = 38, FN = 1791, TN = 11433
# Image 192: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 193: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 194: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 195: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 196: TP = 93, FP = 0, FN = 277, TN = 16014
# Image 197: TP = 900, FP = 0, FN = 593, TN = 14891
# Image 198: TP = 1681, FP = 100, FN = 608, TN = 13995
# Image 199: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 200: TP = 0, FP = 0, FN = 109, TN = 16275
# Image 201: TP = 2824, FP = 0, FN = 2424, TN = 11136
# Image 202: TP = 6905, FP = 0, FN = 5876, TN = 3603
# Image 203: TP = 0, FP = 0, FN = 1038, TN = 15346
# Image 204: TP = 1692, FP = 0, FN = 5061, TN = 9631
# Image 205: TP = 0, FP = 0, FN = 193, TN = 16191
# Image 206: TP = 0, FP = 0, FN = 1, TN = 16383
# Image 207: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 208: TP = 0, FP = 0, FN = 1492, TN = 14892
# Image 209: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 210: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 211: TP = 2125, FP = 33, FN = 2842, TN = 11384
# Image 212: TP = 1299, FP = 27, FN = 401, TN = 14657
# Image 213: TP = 622, FP = 0, FN = 470, TN = 15292
# Image 214: TP = 1176, FP = 2, FN = 1757, TN = 13449
# Image 215: TP = 4859, FP = 38, FN = 2471, TN = 9016
# Image 216: TP = 692, FP = 0, FN = 1084, TN = 14608
# Image 217: TP = 4020, FP = 8, FN = 3208, TN = 9148
# Image 218: TP = 1344, FP = 0, FN = 1412, TN = 13628
# Image 219: TP = 6785, FP = 0, FN = 3123, TN = 6476
# Image 220: TP = 0, FP = 0, FN = 182, TN = 16202
# Image 221: TP = 0, FP = 0, FN = 406, TN = 15978
# Image 222: TP = 1164, FP = 0, FN = 1901, TN = 13319
# Image 223: TP = 808, FP = 18, FN = 10724, TN = 4834
# Image 224: TP = 3348, FP = 57, FN = 5320, TN = 7659
# Image 225: TP = 541, FP = 0, FN = 480, TN = 15363
# Image 226: TP = 791, FP = 4, FN = 2708, TN = 12881
# Image 227: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 228: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 229: TP = 259, FP = 0, FN = 786, TN = 15339
# Image 230: TP = 7607, FP = 172, FN = 838, TN = 7767
# Image 231: TP = 2616, FP = 0, FN = 4071, TN = 9697
# Image 232: TP = 3779, FP = 0, FN = 1295, TN = 11310
# Image 233: TP = 1786, FP = 25, FN = 3545, TN = 11028
# Image 234: TP = 1601, FP = 39, FN = 351, TN = 14393
# Image 235: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 236: TP = 193, FP = 0, FN = 10740, TN = 5451
# Image 237: TP = 326, FP = 0, FN = 1369, TN = 14689
# Image 238: TP = 4802, FP = 0, FN = 10908, TN = 674
# Image 239: TP = 8646, FP = 0, FN = 4741, TN = 2997
# Image 240: TP = 60, FP = 0, FN = 502, TN = 15822
# Image 241: TP = 59, FP = 0, FN = 873, TN = 15452
# Image 242: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 243: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 244: TP = 630, FP = 26, FN = 49, TN = 15679
# Image 245: TP = 5, FP = 0, FN = 71, TN = 16308
# Image 246: TP = 1096, FP = 6, FN = 3220, TN = 12062
# Image 247: TP = 718, FP = 0, FN = 819, TN = 14847
# Image 248: TP = 473, FP = 0, FN = 1335, TN = 14576
# Image 249: TP = 0, FP = 0, FN = 4, TN = 16380
# Image 250: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 251: TP = 0, FP = 0, FN = 1240, TN = 15144
# Image 252: TP = 1998, FP = 20, FN = 1772, TN = 12594
# Image 253: TP = 2624, FP = 0, FN = 1835, TN = 11925
# Image 254: TP = 12446, FP = 9, FN = 1494, TN = 2435
# Image 255: TP = 3224, FP = 0, FN = 2671, TN = 10489
# Image 256: TP = 3074, FP = 0, FN = 4218, TN = 9092
# Image 257: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 258: TP = 625, FP = 0, FN = 184, TN = 15575
# Image 259: TP = 1562, FP = 11, FN = 491, TN = 14320
# Image 260: TP = 110, FP = 0, FN = 70, TN = 16204
# Image 261: TP = 6398, FP = 0, FN = 2495, TN = 7491
# Image 262: TP = 2658, FP = 0, FN = 4612, TN = 9114
# Image 263: TP = 2892, FP = 0, FN = 1072, TN = 12420
# Image 264: TP = 1025, FP = 0, FN = 2586, TN = 12773
# Image 265: TP = 0, FP = 0, FN = 1, TN = 16383
# Image 266: TP = 0, FP = 0, FN = 3989, TN = 12395
# Image 267: TP = 5125, FP = 0, FN = 2319, TN = 8940
# Image 268: TP = 6954, FP = 5, FN = 3493, TN = 5932
# Image 269: TP = 7110, FP = 271, FN = 1467, TN = 7536
# Image 270: TP = 8590, FP = 16, FN = 3175, TN = 4603
# Image 271: TP = 0, FP = 503, FN = 0, TN = 15881
# Image 272: TP = 34, FP = 25, FN = 1, TN = 16324
# Image 273: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 274: TP = 6282, FP = 0, FN = 7954, TN = 2148
# Image 275: TP = 6074, FP = 3, FN = 4712, TN = 5595
# Image 276: TP = 1091, FP = 16, FN = 1170, TN = 14107
# Image 277: TP = 1503, FP = 29, FN = 6973, TN = 7879
# Image 278: TP = 1334, FP = 24, FN = 1040, TN = 13986
# Image 279: TP = 6276, FP = 14, FN = 3638, TN = 6456
# Image 280: TP = 196, FP = 0, FN = 13591, TN = 2597
# Image 281: TP = 1915, FP = 3, FN = 6110, TN = 8356
# Image 282: TP = 3183, FP = 0, FN = 5792, TN = 7409
# Image 283: TP = 6139, FP = 0, FN = 6543, TN = 3702
# Image 284: TP = 4885, FP = 0, FN = 2115, TN = 9384
# Image 285: TP = 4049, FP = 108, FN = 6720, TN = 5507
# Image 286: TP = 8947, FP = 6, FN = 4112, TN = 3319
# Image 287: TP = 7171, FP = 83, FN = 5111, TN = 4019
# Image 288: TP = 4316, FP = 39, FN = 6885, TN = 5144
# Image 289: TP = 3458, FP = 2, FN = 1441, TN = 11483
# Image 290: TP = 8184, FP = 24, FN = 1630, TN = 6546
# Image 291: TP = 4795, FP = 23, FN = 2656, TN = 8910
# Image 292: TP = 1909, FP = 0, FN = 5276, TN = 9199
# Image 293: TP = 1459, FP = 1, FN = 4083, TN = 10841
# Image 294: TP = 74, FP = 1, FN = 2550, TN = 13759
# Image 295: TP = 32, FP = 0, FN = 1175, TN = 15177
# Image 296: TP = 440, FP = 0, FN = 3406, TN = 12538
# Image 297: TP = 757, FP = 5, FN = 4703, TN = 10919
# Image 298: TP = 378, FP = 2, FN = 2030, TN = 13974
# Image 299: TP = 4, FP = 0, FN = 609, TN = 15771
# Image 300: TP = 1533, FP = 25, FN = 4592, TN = 10234
# Image 301: TP = 5258, FP = 24, FN = 1867, TN = 9235
# Image 302: TP = 3392, FP = 4, FN = 3378, TN = 9610
# Image 303: TP = 4544, FP = 20, FN = 4705, TN = 7115
# Image 304: TP = 1385, FP = 0, FN = 1326, TN = 13673
# Image 305: TP = 5277, FP = 3, FN = 2061, TN = 9043
# Image 306: TP = 4940, FP = 1, FN = 1413, TN = 10030
# Image 307: TP = 346, FP = 0, FN = 2298, TN = 13740
# Image 308: TP = 1230, FP = 0, FN = 1754, TN = 13400
# Image 309: TP = 2570, FP = 2, FN = 9205, TN = 4607
# Image 310: TP = 0, FP = 0, FN = 6106, TN = 10278
# Image 311: TP = 181, FP = 10, FN = 2942, TN = 13251
# Image 312: TP = 8831, FP = 1, FN = 7441, TN = 111
# Image 313: TP = 231, FP = 15, FN = 3131, TN = 13007
# Image 314: TP = 617, FP = 0, FN = 1807, TN = 13960
# Image 315: TP = 1830, FP = 4, FN = 8326, TN = 6224
# Image 316: TP = 976, FP = 0, FN = 1308, TN = 14100
# Image 317: TP = 135, FP = 0, FN = 4065, TN = 12184
# Image 318: TP = 0, FP = 0, FN = 1315, TN = 15069
# Image 319: TP = 26, FP = 0, FN = 1396, TN = 14962
# Image 320: TP = 810, FP = 3, FN = 5278, TN = 10293
# Image 321: TP = 198, FP = 0, FN = 141, TN = 16045
# Image 322: TP = 187, FP = 1, FN = 7360, TN = 8836
# Image 323: TP = 312, FP = 0, FN = 697, TN = 15375
# Image 324: TP = 7804, FP = 0, FN = 8500, TN = 80
# Image 325: TP = 5252, FP = 91, FN = 3634, TN = 7407
# Image 326: TP = 2828, FP = 40, FN = 6061, TN = 7455
# Image 327: TP = 523, FP = 5, FN = 252, TN = 15604
# Image 328: TP = 1888, FP = 0, FN = 6079, TN = 8417
# Image 329: TP = 8218, FP = 29, FN = 3376, TN = 4761
# Image 330: TP = 1695, FP = 0, FN = 690, TN = 13999
# Image 331: TP = 2633, FP = 233, FN = 7886, TN = 5632
# Image 332: TP = 11466, FP = 74, FN = 3247, TN = 1597
# Image 333: TP = 7227, FP = 54, FN = 1778, TN = 7325
# Image 334: TP = 11842, FP = 5, FN = 2565, TN = 1972
# Image 335: TP = 8206, FP = 13, FN = 3164, TN = 5001
# Image 336: TP = 2307, FP = 0, FN = 1592, TN = 12485
# Image 337: TP = 910, FP = 0, FN = 5440, TN = 10034
# Image 338: TP = 124, FP = 0, FN = 9169, TN = 7091
# Image 339: TP = 0, FP = 0, FN = 3912, TN = 12472
# Image 340: TP = 12, FP = 0, FN = 10493, TN = 5879
# Image 341: TP = 0, FP = 0, FN = 3051, TN = 13333
# Image 342: TP = 7181, FP = 45, FN = 4283, TN = 4875
# Image 343: TP = 2748, FP = 41, FN = 3188, TN = 10407
# Image 344: TP = 4184, FP = 28, FN = 2195, TN = 9977
# Image 345: TP = 3962, FP = 39, FN = 8832, TN = 3551
# Image 346: TP = 1525, FP = 74, FN = 554, TN = 14231
# Image 347: TP = 3626, FP = 102, FN = 6548, TN = 6108
# Image 348: TP = 389, FP = 0, FN = 5552, TN = 10443
# Image 349: TP = 80, FP = 3, FN = 1818, TN = 14483
# Image 350: TP = 5792, FP = 11, FN = 3542, TN = 7039
# Image 351: TP = 161, FP = 2, FN = 2041, TN = 14180
# Image 352: TP = 798, FP = 1, FN = 10054, TN = 5531
# Image 353: TP = 740, FP = 0, FN = 14381, TN = 1263
# Image 354: TP = 3834, FP = 0, FN = 12550, TN = 0
# Image 355: TP = 8673, FP = 0, FN = 7711, TN = 0
# Image 356: TP = 7439, FP = 0, FN = 5358, TN = 3587
# Image 357: TP = 7020, FP = 0, FN = 6185, TN = 3179
# Image 358: TP = 8, FP = 0, FN = 1280, TN = 15096
# Image 359: TP = 250, FP = 0, FN = 1635, TN = 14499
# Image 360: TP = 6893, FP = 0, FN = 9491, TN = 0
# Image 361: TP = 2594, FP = 0, FN = 1069, TN = 12721
# Image 362: TP = 8307, FP = 27, FN = 5752, TN = 2298
# Image 363: TP = 1094, FP = 0, FN = 5941, TN = 9349
# Image 364: TP = 274, FP = 13, FN = 1438, TN = 14659
# Image 365: TP = 1005, FP = 0, FN = 4519, TN = 10860
# Image 366: TP = 3719, FP = 1, FN = 11939, TN = 725
# Image 367: TP = 4603, FP = 0, FN = 11781, TN = 0
# Image 368: TP = 4567, FP = 0, FN = 11817, TN = 0
# Image 369: TP = 5417, FP = 0, FN = 10967, TN = 0
# Image 370: TP = 2947, FP = 0, FN = 12038, TN = 1399
# Image 371: TP = 803, FP = 3, FN = 5500, TN = 10078
# Image 372: TP = 8373, FP = 0, FN = 6054, TN = 1957
# Image 373: TP = 3728, FP = 1, FN = 2818, TN = 9837
# Image 374: TP = 5922, FP = 27, FN = 1565, TN = 8870
# Image 375: TP = 9925, FP = 1, FN = 5143, TN = 1315
# Image 376: TP = 2585, FP = 78, FN = 1321, TN = 12400
# Image 377: TP = 7698, FP = 4, FN = 4549, TN = 4133
# Image 378: TP = 100, FP = 0, FN = 4164, TN = 12120
# Image 379: TP = 0, FP = 0, FN = 34, TN = 16350
# Image 380: TP = 95, FP = 0, FN = 2379, TN = 13910
# Image 381: TP = 8496, FP = 1, FN = 7722, TN = 165
# Image 382: TP = 2178, FP = 0, FN = 6330, TN = 7876
# Image 383: TP = 108, FP = 0, FN = 14477, TN = 1799
# Image 384: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 385: TP = 303, FP = 0, FN = 11316, TN = 4765
# Image 386: TP = 3480, FP = 0, FN = 6496, TN = 6408
# Image 387: TP = 8234, FP = 0, FN = 8150, TN = 0
# Image 388: TP = 1116, FP = 0, FN = 1166, TN = 14102
# Image 389: TP = 2301, FP = 15, FN = 3979, TN = 10089
# Image 390: TP = 6854, FP = 0, FN = 6284, TN = 3246
# Image 391: TP = 3934, FP = 0, FN = 1453, TN = 10997
# Image 392: TP = 3372, FP = 4, FN = 6338, TN = 6670
# Image 393: TP = 240, FP = 0, FN = 4280, TN = 11864
# Image 394: TP = 412, FP = 23, FN = 1663, TN = 14286
# Image 395: TP = 1600, FP = 0, FN = 12964, TN = 1820
# Image 396: TP = 624, FP = 0, FN = 13320, TN = 2440
# Image 397: TP = 0, FP = 0, FN = 8077, TN = 8307
# Image 398: TP = 44, FP = 0, FN = 16278, TN = 62
# Image 399: TP = 216, FP = 0, FN = 16168, TN = 0
# Image 400: TP = 3164, FP = 0, FN = 13220, TN = 0
# Image 401: TP = 3491, FP = 0, FN = 12576, TN = 317
# Image 402: TP = 8094, FP = 93, FN = 2669, TN = 5528
# Image 403: TP = 897, FP = 0, FN = 5423, TN = 10064
# Image 404: TP = 7462, FP = 254, FN = 2471, TN = 6197
# Image 405: TP = 1882, FP = 30, FN = 401, TN = 14071
# Image 406: TP = 699, FP = 10, FN = 139, TN = 15536
# Image 407: TP = 1931, FP = 191, FN = 1461, TN = 12801
# Image 408: TP = 1858, FP = 20, FN = 5923, TN = 8583
# Image 409: TP = 66, FP = 0, FN = 1370, TN = 14948
# Image 410: TP = 0, FP = 0, FN = 1126, TN = 15258
# Image 411: TP = 4335, FP = 122, FN = 1800, TN = 10127
# Image 412: TP = 614, FP = 14, FN = 1946, TN = 13810
# Image 413: TP = 1180, FP = 0, FN = 7707, TN = 7497
# Image 414: TP = 2982, FP = 27, FN = 602, TN = 12773
# Image 415: TP = 4830, FP = 1, FN = 7606, TN = 3947
# Image 416: TP = 1902, FP = 6, FN = 2886, TN = 11590
# Image 417: TP = 6361, FP = 34, FN = 2503, TN = 7486
# Image 418: TP = 7805, FP = 29, FN = 4625, TN = 3925
# Image 419: TP = 7899, FP = 19, FN = 6710, TN = 1756
# Image 420: TP = 6731, FP = 30, FN = 1803, TN = 7820
# Image 421: TP = 5524, FP = 25, FN = 6209, TN = 4626
# Image 422: TP = 4663, FP = 35, FN = 1976, TN = 9710
# Image 423: TP = 4804, FP = 7, FN = 3129, TN = 8444
# Image 424: TP = 5218, FP = 121, FN = 5876, TN = 5169
# Image 425: TP = 5853, FP = 41, FN = 3598, TN = 6892
# Image 426: TP = 11268, FP = 207, FN = 2065, TN = 2844
# Image 427: TP = 272, FP = 82, FN = 321, TN = 15709
# Image 428: TP = 1990, FP = 0, FN = 6055, TN = 8339
# Image 429: TP = 936, FP = 5, FN = 7589, TN = 7854
# Image 430: TP = 622, FP = 4, FN = 3067, TN = 12691
# Image 431: TP = 6297, FP = 0, FN = 5077, TN = 5010
# Image 432: TP = 14428, FP = 140, FN = 1236, TN = 580
# Image 433: TP = 2297, FP = 39, FN = 2475, TN = 11573
# Image 434: TP = 4380, FP = 5, FN = 7948, TN = 4051
# Image 435: TP = 8764, FP = 0, FN = 6030, TN = 1590
# Image 436: TP = 7527, FP = 5, FN = 6683, TN = 2169
# Image 437: TP = 6449, FP = 105, FN = 6987, TN = 2843
# Image 438: TP = 6069, FP = 34, FN = 7481, TN = 2800
# Image 439: TP = 3583, FP = 6, FN = 9374, TN = 3421
# Image 440: TP = 2736, FP = 14, FN = 10950, TN = 2684
# Image 441: TP = 2575, FP = 6, FN = 2528, TN = 11275
# Image 442: TP = 2207, FP = 36, FN = 1743, TN = 12398
# Image 443: TP = 42, FP = 0, FN = 1741, TN = 14601
# Image 444: TP = 478, FP = 0, FN = 8937, TN = 6969
# Image 445: TP = 1085, FP = 31, FN = 2975, TN = 12293
# Image 446: TP = 3934, FP = 0, FN = 9090, TN = 3360
# Image 447: TP = 2934, FP = 215, FN = 5645, TN = 7590
# Image 448: TP = 4085, FP = 0, FN = 9384, TN = 2915
# Image 449: TP = 814, FP = 0, FN = 5441, TN = 10129
# Image 450: TP = 5494, FP = 4, FN = 5040, TN = 5846
# Image 451: TP = 1329, FP = 0, FN = 15055, TN = 0
# Image 452: TP = 3417, FP = 0, FN = 12967, TN = 0
# Image 453: TP = 172, FP = 0, FN = 16212, TN = 0
# Image 454: TP = 4, FP = 0, FN = 16380, TN = 0
# Image 455: TP = 556, FP = 0, FN = 15828, TN = 0
# Image 456: TP = 2402, FP = 19, FN = 3719, TN = 10244
# Image 457: TP = 1770, FP = 2, FN = 6827, TN = 7785
# Image 458: TP = 333, FP = 56, FN = 869, TN = 15126
# Image 459: TP = 2156, FP = 0, FN = 7909, TN = 6319
# Image 460: TP = 7278, FP = 0, FN = 9106, TN = 0
# Image 461: TP = 11404, FP = 0, FN = 4980, TN = 0
# Image 462: TP = 2591, FP = 15, FN = 4982, TN = 8796
# Image 463: TP = 14659, FP = 0, FN = 1694, TN = 31
# Image 464: TP = 2556, FP = 0, FN = 4344, TN = 9484
# Image 465: TP = 5887, FP = 71, FN = 2041, TN = 8385
# Image 466: TP = 5479, FP = 0, FN = 9487, TN = 1418
# Image 467: TP = 702, FP = 0, FN = 14447, TN = 1235
# Image 468: TP = 1000, FP = 0, FN = 15188, TN = 196
# Image 469: TP = 1412, FP = 0, FN = 13827, TN = 1145
# Image 470: TP = 168, FP = 0, FN = 11294, TN = 4922
# Image 471: TP = 7140, FP = 0, FN = 8905, TN = 339
# Image 472: TP = 8, FP = 0, FN = 2340, TN = 14036
# Image 473: TP = 508, FP = 14, FN = 1416, TN = 14446
# Image 474: TP = 1904, FP = 0, FN = 2497, TN = 11983
# Image 475: TP = 14708, FP = 0, FN = 1607, TN = 69
# Image 476: TP = 15302, FP = 0, FN = 1082, TN = 0
# Image 477: TP = 6979, FP = 0, FN = 1470, TN = 7935
# Image 478: TP = 14758, FP = 0, FN = 1626, TN = 0
# Image 479: TP = 4262, FP = 0, FN = 1878, TN = 10244
# Image 480: TP = 4782, FP = 0, FN = 7787, TN = 3815
# Image 481: TP = 0, FP = 4, FN = 2739, TN = 13641
# Image 482: TP = 162, FP = 3, FN = 5021, TN = 11198
# Image 483: TP = 0, FP = 0, FN = 224, TN = 16160
# Image 484: TP = 679, FP = 5, FN = 5296, TN = 10404
# Image 485: TP = 522, FP = 4, FN = 929, TN = 14929
# Image 486: TP = 6458, FP = 2, FN = 2957, TN = 6967
# Image 487: TP = 2903, FP = 4, FN = 4738, TN = 8739
# Image 488: TP = 1025, FP = 32, FN = 2984, TN = 12343
# Image 489: TP = 103, FP = 0, FN = 366, TN = 15915
# Image 490: TP = 2711, FP = 0, FN = 3704, TN = 9969
# Image 491: TP = 9750, FP = 0, FN = 6221, TN = 413
# Image 492: TP = 4122, FP = 69, FN = 1868, TN = 10325
# Image 493: TP = 803, FP = 48, FN = 447, TN = 15086
# Image 494: TP = 431, FP = 9, FN = 171, TN = 15773
# Image 495: TP = 13969, FP = 44, FN = 689, TN = 1682
# Image 496: TP = 1112, FP = 36, FN = 910, TN = 14326
# Image 497: TP = 6291, FP = 189, FN = 1156, TN = 8748
# Image 498: TP = 1381, FP = 31, FN = 1039, TN = 13933
# Image 499: TP = 5797, FP = 8, FN = 4213, TN = 6366
# Image 500: TP = 9402, FP = 67, FN = 3706, TN = 3209
# Image 501: TP = 13947, FP = 16, FN = 1528, TN = 893
# Image 502: TP = 11343, FP = 14, FN = 1968, TN = 3059
# Image 503: TP = 7844, FP = 203, FN = 209, TN = 8128
# Image 504: TP = 89, FP = 69, FN = 447, TN = 15779
# Image 505: TP = 1572, FP = 53, FN = 567, TN = 14192
# Image 506: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 507: TP = 2476, FP = 114, FN = 590, TN = 13204
# Image 508: TP = 13182, FP = 90, FN = 1192, TN = 1920
# Image 509: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 510: TP = 12638, FP = 0, FN = 3746, TN = 0
# Image 511: TP = 13976, FP = 0, FN = 2408, TN = 0
# Image 512: TP = 4813, FP = 0, FN = 11571, TN = 0
# Image 513: TP = 13027, FP = 0, FN = 3357, TN = 0
# Image 514: TP = 57, FP = 0, FN = 247, TN = 16080
# Image 515: TP = 748, FP = 50, FN = 1073, TN = 14513
# Image 516: TP = 101, FP = 1, FN = 195, TN = 16087
# Image 517: TP = 58, FP = 0, FN = 489, TN = 15837
# Image 518: TP = 3997, FP = 0, FN = 2701, TN = 9686
# Image 519: TP = 253, FP = 1, FN = 848, TN = 15282
# Image 520: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 521: TP = 854, FP = 29, FN = 3807, TN = 11694
# Image 522: TP = 3749, FP = 134, FN = 2656, TN = 9845
# Image 523: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 524: TP = 12116, FP = 71, FN = 1421, TN = 2776
# Image 525: TP = 10659, FP = 5, FN = 5538, TN = 182
# Image 526: TP = 13565, FP = 0, FN = 2819, TN = 0
# Image 527: TP = 10414, FP = 0, FN = 5970, TN = 0
# Image 528: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 529: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 530: TP = 895, FP = 10, FN = 654, TN = 14825
# Image 531: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 532: TP = 204, FP = 0, FN = 166, TN = 16014
# Image 533: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 534: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 535: TP = 7007, FP = 110, FN = 3104, TN = 6163
# Image 536: TP = 3614, FP = 187, FN = 2166, TN = 10417
# Image 537: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 538: TP = 13, FP = 10, FN = 240, TN = 16121
# Image 539: TP = 3218, FP = 0, FN = 4568, TN = 8598
# Image 540: TP = 11256, FP = 0, FN = 5128, TN = 0
# Image 541: TP = 14626, FP = 23, FN = 1021, TN = 714
# Image 542: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 543: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 544: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 545: TP = 276, FP = 0, FN = 360, TN = 15748
# Image 546: TP = 182, FP = 0, FN = 121, TN = 16081
# Image 547: TP = 466, FP = 6, FN = 121, TN = 15791
# Image 548: TP = 4751, FP = 15, FN = 1597, TN = 10021
# Image 549: TP = 153, FP = 1, FN = 71, TN = 16159
# Image 550: TP = 3516, FP = 52, FN = 4452, TN = 8364
# Image 551: TP = 1724, FP = 21, FN = 170, TN = 14469
# Image 552: TP = 1839, FP = 5, FN = 3226, TN = 11314
# Image 553: TP = 2781, FP = 0, FN = 2518, TN = 11085
# Image 554: TP = 2467, FP = 59, FN = 4838, TN = 9020
# Image 555: TP = 4944, FP = 76, FN = 960, TN = 10404
# Image 556: TP = 4957, FP = 8, FN = 6002, TN = 5417
# Image 557: TP = 10305, FP = 0, FN = 6079, TN = 0
# Image 558: TP = 14815, FP = 0, FN = 1569, TN = 0
# Image 559: TP = 8812, FP = 5, FN = 6888, TN = 679
# Image 560: TP = 796, FP = 0, FN = 4480, TN = 11108
# Image 561: TP = 5512, FP = 105, FN = 1267, TN = 9500
# Image 562: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 563: TP = 2425, FP = 28, FN = 980, TN = 12951
# Image 564: TP = 7137, FP = 167, FN = 1879, TN = 7201
# Image 565: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 566: TP = 5821, FP = 82, FN = 2148, TN = 8333
# Image 567: TP = 6506, FP = 49, FN = 5008, TN = 4821
# Image 568: TP = 16380, FP = 0, FN = 4, TN = 0
# Image 569: TP = 11643, FP = 98, FN = 797, TN = 3846
# Image 570: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 571: TP = 0, FP = 0, FN = 24, TN = 16360
# Image 572: TP = 2481, FP = 4, FN = 3340, TN = 10559
# Image 573: TP = 187, FP = 0, FN = 415, TN = 15782
# Image 574: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 575: TP = 702, FP = 0, FN = 796, TN = 14886
# Image 576: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 577: TP = 9212, FP = 4, FN = 687, TN = 6481
# Image 578: TP = 688, FP = 6, FN = 420, TN = 15270
# Image 579: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 580: TP = 167, FP = 17, FN = 181, TN = 16019
# Image 581: TP = 9363, FP = 0, FN = 3824, TN = 3197
# Image 582: TP = 13711, FP = 0, FN = 2673, TN = 0
# Image 583: TP = 3404, FP = 0, FN = 2169, TN = 10811
# Image 584: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 585: TP = 86, FP = 3, FN = 294, TN = 16001
# Image 586: TP = 1606, FP = 1, FN = 1483, TN = 13294
# Image 587: TP = 2247, FP = 15, FN = 1526, TN = 12596
# Image 588: TP = 715, FP = 40, FN = 979, TN = 14650
# Image 589: TP = 15006, FP = 2, FN = 759, TN = 617
# Image 590: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 591: TP = 10381, FP = 0, FN = 6003, TN = 0
# Image 592: TP = 8542, FP = 160, FN = 1472, TN = 6210
# Image 593: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 594: TP = 4114, FP = 7, FN = 563, TN = 11700
# Image 595: TP = 800, FP = 21, FN = 948, TN = 14615
# Image 596: TP = 2904, FP = 0, FN = 5546, TN = 7934
# Image 597: TP = 0, FP = 0, FN = 1453, TN = 14931
# Image 598: TP = 0, FP = 0, FN = 57, TN = 16327
# Image 599: TP = 0, FP = 0, FN = 264, TN = 16120
# Image 600: TP = 0, FP = 0, FN = 156, TN = 16228
# Image 601: TP = 177, FP = 21, FN = 539, TN = 15647
# Image 602: TP = 7545, FP = 17, FN = 713, TN = 8109
# Image 603: TP = 15496, FP = 0, FN = 888, TN = 0
# Image 604: TP = 0, FP = 0, FN = 111, TN = 16273
# Image 605: TP = 12467, FP = 0, FN = 3917, TN = 0
# Image 606: TP = 7756, FP = 135, FN = 4052, TN = 4441
# Image 607: TP = 0, FP = 0, FN = 178, TN = 16206
# Image 608: TP = 8505, FP = 0, FN = 7426, TN = 453
# Image 609: TP = 6107, FP = 64, FN = 1349, TN = 8864
# Image 610: TP = 297, FP = 0, FN = 319, TN = 15768
# Image 611: TP = 353, FP = 4, FN = 468, TN = 15559
# Image 612: TP = 1346, FP = 5, FN = 1671, TN = 13362
# Image 613: TP = 7163, FP = 0, FN = 7077, TN = 2144
# Image 614: TP = 1110, FP = 0, FN = 3056, TN = 12218
# Image 615: TP = 29, FP = 0, FN = 542, TN = 15813
# Image 616: TP = 14148, FP = 0, FN = 985, TN = 1251
# Image 617: TP = 14409, FP = 0, FN = 1975, TN = 0
# Image 618: TP = 439, FP = 3, FN = 886, TN = 15056
# Image 619: TP = 16317, FP = 0, FN = 67, TN = 0
# Image 620: TP = 5081, FP = 20, FN = 5796, TN = 5487
# Image 621: TP = 1902, FP = 2, FN = 1891, TN = 12589
# Image 622: TP = 3622, FP = 0, FN = 4684, TN = 8078
# Image 623: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 624: TP = 0, FP = 0, FN = 3146, TN = 13238
# Image 625: TP = 58, FP = 12, FN = 466, TN = 15848
# Image 626: TP = 8952, FP = 0, FN = 2317, TN = 5115
# Image 627: TP = 5980, FP = 109, FN = 3402, TN = 6893
# Image 628: TP = 5645, FP = 82, FN = 1664, TN = 8993
# Image 629: TP = 6039, FP = 0, FN = 3199, TN = 7146
# Image 630: TP = 16073, FP = 0, FN = 311, TN = 0
# Image 631: TP = 13768, FP = 0, FN = 2616, TN = 0
# Image 632: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 633: TP = 13492, FP = 0, FN = 2892, TN = 0
# Image 634: TP = 7156, FP = 0, FN = 4054, TN = 5174
# Image 635: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 636: TP = 0, FP = 0, FN = 524, TN = 15860
# Image 637: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 638: TP = 0, FP = 0, FN = 3278, TN = 13106
# Image 639: TP = 0, FP = 3, FN = 0, TN = 16381
# Image 640: TP = 1244, FP = 38, FN = 657, TN = 14445
# Image 641: TP = 0, FP = 0, FN = 994, TN = 15390
# Image 642: TP = 4692, FP = 146, FN = 1560, TN = 9986
# Image 643: TP = 4455, FP = 63, FN = 2148, TN = 9718
# Image 644: TP = 15844, FP = 0, FN = 540, TN = 0
# Image 645: TP = 13271, FP = 0, FN = 3113, TN = 0
# Image 646: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 647: TP = 8763, FP = 0, FN = 7621, TN = 0
# Image 648: TP = 13046, FP = 0, FN = 3337, TN = 1
# Image 649: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 650: TP = 9672, FP = 0, FN = 1503, TN = 5209
# Image 651: TP = 1211, FP = 0, FN = 518, TN = 14655
# Image 652: TP = 133, FP = 1, FN = 1651, TN = 14599
# Image 653: TP = 1486, FP = 39, FN = 1094, TN = 13765
# Image 654: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 655: TP = 0, FP = 0, FN = 739, TN = 15645
# Image 656: TP = 2009, FP = 0, FN = 1247, TN = 13128
# Image 657: TP = 8908, FP = 98, FN = 1322, TN = 6056
# Image 658: TP = 12342, FP = 0, FN = 4042, TN = 0
# Image 659: TP = 13236, FP = 0, FN = 3148, TN = 0
# Image 660: TP = 3170, FP = 0, FN = 534, TN = 12680
# Image 661: TP = 3650, FP = 87, FN = 4118, TN = 8529
# Image 662: TP = 11998, FP = 0, FN = 2303, TN = 2083
# Image 663: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 664: TP = 15823, FP = 0, FN = 561, TN = 0
# Image 665: TP = 1706, FP = 0, FN = 1023, TN = 13655
# Image 666: TP = 616, FP = 0, FN = 1856, TN = 13912
# Image 667: TP = 8982, FP = 20, FN = 6636, TN = 746
# Image 668: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 669: TP = 0, FP = 0, FN = 87, TN = 16297
# Image 670: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 671: TP = 2168, FP = 0, FN = 1319, TN = 12897
# Image 672: TP = 8257, FP = 37, FN = 3805, TN = 4285
# Image 673: TP = 5051, FP = 166, FN = 789, TN = 10378
# Image 674: TP = 0, FP = 0, FN = 2442, TN = 13942
# Image 675: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 676: TP = 2373, FP = 11, FN = 3285, TN = 10715
# Image 677: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 678: TP = 9157, FP = 0, FN = 7179, TN = 48
# Image 679: TP = 8194, FP = 0, FN = 8179, TN = 11
# Image 680: TP = 2677, FP = 8, FN = 3687, TN = 10012
# Image 681: TP = 8094, FP = 0, FN = 7493, TN = 797
# Image 682: TP = 4329, FP = 55, FN = 2760, TN = 9240
# Image 683: TP = 6668, FP = 128, FN = 4085, TN = 5503
# Image 684: TP = 13001, FP = 2, FN = 3064, TN = 317
# Image 685: TP = 7657, FP = 0, FN = 8727, TN = 0
# Image 686: TP = 12085, FP = 0, FN = 4299, TN = 0
# Image 687: TP = 5677, FP = 9, FN = 1054, TN = 9644
# Image 688: TP = 9, FP = 0, FN = 269, TN = 16106
# Image 689: TP = 0, FP = 0, FN = 336, TN = 16048
# Image 690: TP = 3405, FP = 2, FN = 5797, TN = 7180
# Image 691: TP = 0, FP = 0, FN = 3, TN = 16381
# Image 692: TP = 6836, FP = 0, FN = 9548, TN = 0
# Image 693: TP = 7318, FP = 0, FN = 9066, TN = 0
# Image 694: TP = 12861, FP = 0, FN = 3523, TN = 0
# Image 695: TP = 16019, FP = 0, FN = 365, TN = 0
# Image 696: TP = 5841, FP = 65, FN = 3204, TN = 7274
# Image 697: TP = 246, FP = 34, FN = 199, TN = 15905
# Image 698: TP = 0, FP = 0, FN = 2751, TN = 13633
# Image 699: TP = 1160, FP = 0, FN = 11245, TN = 3979
# Image 700: TP = 13703, FP = 28, FN = 727, TN = 1926
# Image 701: TP = 316, FP = 40, FN = 1500, TN = 14528
# Image 702: TP = 0, FP = 0, FN = 186, TN = 16198
# Image 703: TP = 0, FP = 0, FN = 462, TN = 15922
# Image 704: TP = 4514, FP = 4, FN = 5783, TN = 6083
# Image 705: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 706: TP = 150, FP = 0, FN = 7585, TN = 8649
# Image 707: TP = 10976, FP = 0, FN = 5408, TN = 0
# Image 708: TP = 16380, FP = 0, FN = 4, TN = 0
# Image 709: TP = 12394, FP = 0, FN = 3990, TN = 0
# Image 710: TP = 485, FP = 0, FN = 3383, TN = 12516
# Image 711: TP = 5107, FP = 139, FN = 3764, TN = 7374
# Image 712: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 713: TP = 199, FP = 0, FN = 239, TN = 15946
# Image 714: TP = 2503, FP = 98, FN = 198, TN = 13585
# Image 715: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 716: TP = 126, FP = 0, FN = 732, TN = 15526
# Image 717: TP = 10258, FP = 7, FN = 3360, TN = 2759
# Image 718: TP = 6733, FP = 40, FN = 5011, TN = 4600
# Image 719: TP = 898, FP = 2, FN = 724, TN = 14760
# Image 720: TP = 11553, FP = 0, FN = 4052, TN = 779
# Image 721: TP = 14860, FP = 0, FN = 1524, TN = 0
# Image 722: TP = 16384, FP = 0, FN = 0, TN = 0
# Image 723: TP = 14613, FP = 0, FN = 1771, TN = 0
# Image 724: TP = 1914, FP = 0, FN = 3418, TN = 11052
# Image 725: TP = 1302, FP = 10, FN = 1909, TN = 13163
# Image 726: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 727: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 728: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 729: TP = 365, FP = 0, FN = 1441, TN = 14578
# Image 730: TP = 550, FP = 1, FN = 621, TN = 15212
# Image 731: TP = 11355, FP = 0, FN = 2102, TN = 2927
# Image 732: TP = 8123, FP = 0, FN = 8261, TN = 0
# Image 733: TP = 7, FP = 0, FN = 2835, TN = 13542
# Image 734: TP = 15111, FP = 0, FN = 1273, TN = 0
# Image 735: TP = 14812, FP = 0, FN = 1572, TN = 0
# Image 736: TP = 14281, FP = 0, FN = 2103, TN = 0
# Image 737: TP = 7426, FP = 0, FN = 8958, TN = 0
# Image 738: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 739: TP = 675, FP = 5, FN = 158, TN = 15546
# Image 740: TP = 1744, FP = 79, FN = 2209, TN = 12352
# Image 741: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 742: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 743: TP = 2893, FP = 18, FN = 1850, TN = 11623
# Image 744: TP = 246, FP = 2, FN = 335, TN = 15801
# Image 745: TP = 12, FP = 0, FN = 935, TN = 15437
# Image 746: TP = 12629, FP = 0, FN = 1531, TN = 2224
# Image 747: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 748: TP = 14435, FP = 0, FN = 1949, TN = 0
# Image 749: TP = 16353, FP = 0, FN = 31, TN = 0
# Image 750: TP = 7942, FP = 0, FN = 8442, TN = 0
# Image 751: TP = 6948, FP = 0, FN = 9436, TN = 0
# Image 752: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 753: TP = 3, FP = 1, FN = 33, TN = 16347
# Image 754: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 755: TP = 1737, FP = 22, FN = 2451, TN = 12174
# Image 756: TP = 533, FP = 0, FN = 1929, TN = 13922
# Image 757: TP = 266, FP = 2, FN = 419, TN = 15697

# %%
recall = TP / (TP + FN)
precision = TP / (TP + FP)
accuracy = (TP + TN) / (TP + FP + FN + TN)
f1_score = 2 * (precision * recall) / (precision + recall)
IoU = TP / (TP + FP + FN)

print('TP:', TP)
print('FP:', FP)
print('FN:', FN)
print('TN:', TN)

print()
print('Recall: {:.3f}'.format(recall))
print('Precision: {:.3f}'.format(precision))
print('Accuracy: {:.3f}'.format(accuracy))
print('F1 Score: {:.3f}'.format(f1_score))

print()
print("IoU Overall: {:.3f} ".format(IoU))
# Out:
# TP: 2445840
# FP: 12599
# FN: 2057132
# TN: 7887117
#
# Recall: 0.543
# Precision: 0.995
# Accuracy: 0.833
# F1 Score: 0.703
#
# IoU Overall: 0.542

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
conf_matrix = np.array([[TP, FP],
                        [FN, TN]])

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted Vegetation', 'Predicted Non-Vegetation'], 
            yticklabels=['Actual Vegetation', 'Actual Non-Vegetation'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Initialize lists for TP, FP, FN, and IoU
TP_vegetation = []
FP_vegetation = []
FN_vegetation = []
IoU_vegetation = []

TP_non_vegetation = []
FP_non_vegetation = []
FN_non_vegetation = []
IoU_non_vegetation = []

# Loop over testing images
for i in range(len(image_test)):
    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN counts for both vegetation and non-vegetation classes
    TP_veg = np.sum(np.logical_and(vegetation_ground_truth, predicted_mask))
    FP_veg = np.sum(predicted_mask & ~vegetation_ground_truth)
    FN_veg = np.sum(vegetation_ground_truth & ~predicted_mask)
    
    TP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, ~predicted_mask))
    FP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, predicted_mask))
    FN_non_veg = np.sum(np.logical_and(vegetation_ground_truth, ~predicted_mask))

    # Append TP, FP, FN counts for vegetation and non-vegetation classes
    TP_vegetation.append(TP_veg)
    FP_vegetation.append(FP_veg)
    FN_vegetation.append(FN_veg)
    
    TP_non_vegetation.append(TP_non_veg)
    FP_non_vegetation.append(FP_non_veg)
    FN_non_vegetation.append(FN_non_veg)

    # Calculate IoU for vegetation and non-vegetation classes if the denominator is not zero
    denominator_veg = TP_veg + FP_veg + FN_veg
    denominator_non_veg = TP_non_veg + FP_non_veg + FN_non_veg

    IoU_vegetation.append(TP_veg / denominator_veg if denominator_veg != 0 else 0.0)
    IoU_non_vegetation.append(TP_non_veg / denominator_non_veg if denominator_non_veg != 0 else 0.0)

    # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
    print("Image {}:".format(i+1))
    print("TP_veg: {}, FP_veg: {}, FN_veg: {}, IoU_veg: {:.4f}".format(TP_veg, FP_veg, FN_veg, IoU_vegetation[-1]))
    print("TP_non_veg: {}, FP_non_veg: {}, FN_non_veg: {}, IoU_non_veg: {:.4f}".format(TP_non_veg, FP_non_veg, FN_non_veg, IoU_non_vegetation[-1]))
# Out:
# Image 1:
# TP_veg: 6, FP_veg: 0, FN_veg: 39, IoU_veg: 0.1333
# TP_non_veg: 16339, FP_non_veg: 0, FN_non_veg: 45, IoU_non_veg: 0.9973
# Image 2:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 3:
# TP_veg: 317, FP_veg: 0, FN_veg: 205, IoU_veg: 0.6073
# TP_non_veg: 15862, FP_non_veg: 0, FN_non_veg: 522, IoU_non_veg: 0.9681
# Image 4:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 5:
# TP_veg: 4, FP_veg: 0, FN_veg: 6, IoU_veg: 0.4000
# TP_non_veg: 16374, FP_non_veg: 0, FN_non_veg: 10, IoU_non_veg: 0.9994
# Image 6:
# TP_veg: 365, FP_veg: 0, FN_veg: 251, IoU_veg: 0.5925
# TP_non_veg: 15768, FP_non_veg: 0, FN_non_veg: 616, IoU_non_veg: 0.9624
# Image 7:
# TP_veg: 3425, FP_veg: 0, FN_veg: 2144, IoU_veg: 0.6150
# TP_non_veg: 10815, FP_non_veg: 0, FN_non_veg: 5569, IoU_non_veg: 0.6601
# Image 8:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 9:
# TP_veg: 97, FP_veg: 0, FN_veg: 74, IoU_veg: 0.5673
# TP_non_veg: 16213, FP_non_veg: 0, FN_non_veg: 171, IoU_non_veg: 0.9896
# Image 10:
# TP_veg: 2891, FP_veg: 1, FN_veg: 6275, IoU_veg: 0.3154
# TP_non_veg: 7218, FP_non_veg: 1, FN_non_veg: 9166, IoU_non_veg: 0.4405
# Image 11:
# TP_veg: 314, FP_veg: 0, FN_veg: 1350, IoU_veg: 0.1887
# TP_non_veg: 14720, FP_non_veg: 0, FN_non_veg: 1664, IoU_non_veg: 0.8984
# Image 12:
# TP_veg: 3670, FP_veg: 0, FN_veg: 5261, IoU_veg: 0.4109
# TP_non_veg: 7453, FP_non_veg: 0, FN_non_veg: 8931, IoU_non_veg: 0.4549
# Image 13:
# TP_veg: 56, FP_veg: 0, FN_veg: 170, IoU_veg: 0.2478
# TP_non_veg: 16158, FP_non_veg: 0, FN_non_veg: 226, IoU_non_veg: 0.9862
# Image 14:
# TP_veg: 230, FP_veg: 49, FN_veg: 167, IoU_veg: 0.5157
# TP_non_veg: 15987, FP_non_veg: 49, FN_non_veg: 397, IoU_non_veg: 0.9729
# Image 15:
# TP_veg: 2329, FP_veg: 0, FN_veg: 720, IoU_veg: 0.7639
# TP_non_veg: 13335, FP_non_veg: 0, FN_non_veg: 3049, IoU_non_veg: 0.8139
# Image 16:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 17:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 18:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 19:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 20:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 21:
# TP_veg: 31, FP_veg: 0, FN_veg: 184, IoU_veg: 0.1442
# TP_non_veg: 16169, FP_non_veg: 0, FN_non_veg: 215, IoU_non_veg: 0.9869
# Image 22:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 23:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 24:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 25:
# TP_veg: 1444, FP_veg: 0, FN_veg: 2033, IoU_veg: 0.4153
# TP_non_veg: 12907, FP_non_veg: 0, FN_non_veg: 3477, IoU_non_veg: 0.7878
# Image 26:
# TP_veg: 6480, FP_veg: 4, FN_veg: 3069, IoU_veg: 0.6783
# TP_non_veg: 6835, FP_non_veg: 4, FN_non_veg: 9549, IoU_non_veg: 0.4171
# Image 27:
# TP_veg: 1375, FP_veg: 13, FN_veg: 1501, IoU_veg: 0.4759
# TP_non_veg: 13508, FP_non_veg: 13, FN_non_veg: 2876, IoU_non_veg: 0.8238
# Image 28:
# TP_veg: 6155, FP_veg: 82, FN_veg: 840, IoU_veg: 0.8697
# TP_non_veg: 9389, FP_non_veg: 82, FN_non_veg: 6995, IoU_non_veg: 0.5702
# Image 29:
# TP_veg: 2546, FP_veg: 23, FN_veg: 972, IoU_veg: 0.7190
# TP_non_veg: 12866, FP_non_veg: 23, FN_non_veg: 3518, IoU_non_veg: 0.7842
# Image 30:
# TP_veg: 2898, FP_veg: 0, FN_veg: 3215, IoU_veg: 0.4741
# TP_non_veg: 10271, FP_non_veg: 0, FN_non_veg: 6113, IoU_non_veg: 0.6269
# Image 31:
# TP_veg: 1538, FP_veg: 48, FN_veg: 160, IoU_veg: 0.8809
# TP_non_veg: 14686, FP_non_veg: 48, FN_non_veg: 1698, IoU_non_veg: 0.8937
# Image 32:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 33:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 34:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 35:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 36:
# TP_veg: 892, FP_veg: 0, FN_veg: 881, IoU_veg: 0.5031
# TP_non_veg: 14611, FP_non_veg: 0, FN_non_veg: 1773, IoU_non_veg: 0.8918
# Image 37:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 38:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 39:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 40:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 41:
# TP_veg: 891, FP_veg: 0, FN_veg: 1607, IoU_veg: 0.3567
# TP_non_veg: 13886, FP_non_veg: 0, FN_non_veg: 2498, IoU_non_veg: 0.8475
# Image 42:
# TP_veg: 271, FP_veg: 0, FN_veg: 2689, IoU_veg: 0.0916
# TP_non_veg: 13424, FP_non_veg: 0, FN_non_veg: 2960, IoU_non_veg: 0.8193
# Image 43:
# TP_veg: 1103, FP_veg: 0, FN_veg: 3302, IoU_veg: 0.2504
# TP_non_veg: 11979, FP_non_veg: 0, FN_non_veg: 4405, IoU_non_veg: 0.7311
# Image 44:
# TP_veg: 170, FP_veg: 3, FN_veg: 289, IoU_veg: 0.3680
# TP_non_veg: 15925, FP_non_veg: 3, FN_non_veg: 459, IoU_non_veg: 0.9718
# Image 45:
# TP_veg: 8319, FP_veg: 4, FN_veg: 931, IoU_veg: 0.8990
# TP_non_veg: 7134, FP_non_veg: 4, FN_non_veg: 9250, IoU_non_veg: 0.4353
# Image 46:
# TP_veg: 2293, FP_veg: 47, FN_veg: 483, IoU_veg: 0.8123
# TP_non_veg: 13608, FP_non_veg: 47, FN_non_veg: 2776, IoU_non_veg: 0.8282
# Image 47:
# TP_veg: 1854, FP_veg: 24, FN_veg: 408, IoU_veg: 0.8110
# TP_non_veg: 14122, FP_non_veg: 24, FN_non_veg: 2262, IoU_non_veg: 0.8607
# Image 48:
# TP_veg: 0, FP_veg: 0, FN_veg: 1581, IoU_veg: 0.0000
# TP_non_veg: 14803, FP_non_veg: 0, FN_non_veg: 1581, IoU_non_veg: 0.9035
# Image 49:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 50:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 51:
# TP_veg: 6162, FP_veg: 0, FN_veg: 5128, IoU_veg: 0.5458
# TP_non_veg: 5094, FP_non_veg: 0, FN_non_veg: 11290, IoU_non_veg: 0.3109
# Image 52:
# TP_veg: 11741, FP_veg: 0, FN_veg: 4643, IoU_veg: 0.7166
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 53:
# TP_veg: 2001, FP_veg: 0, FN_veg: 2919, IoU_veg: 0.4067
# TP_non_veg: 11464, FP_non_veg: 0, FN_non_veg: 4920, IoU_non_veg: 0.6997
# Image 54:
# TP_veg: 2005, FP_veg: 0, FN_veg: 3069, IoU_veg: 0.3952
# TP_non_veg: 11310, FP_non_veg: 0, FN_non_veg: 5074, IoU_non_veg: 0.6903
# Image 55:
# TP_veg: 3298, FP_veg: 0, FN_veg: 3090, IoU_veg: 0.5163
# TP_non_veg: 9996, FP_non_veg: 0, FN_non_veg: 6388, IoU_non_veg: 0.6101
# Image 56:
# TP_veg: 584, FP_veg: 0, FN_veg: 1580, IoU_veg: 0.2699
# TP_non_veg: 14220, FP_non_veg: 0, FN_non_veg: 2164, IoU_non_veg: 0.8679
# Image 57:
# TP_veg: 1730, FP_veg: 0, FN_veg: 1463, IoU_veg: 0.5418
# TP_non_veg: 13191, FP_non_veg: 0, FN_non_veg: 3193, IoU_non_veg: 0.8051
# Image 58:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 59:
# TP_veg: 4209, FP_veg: 42, FN_veg: 4244, IoU_veg: 0.4955
# TP_non_veg: 7931, FP_non_veg: 42, FN_non_veg: 8453, IoU_non_veg: 0.4828
# Image 60:
# TP_veg: 808, FP_veg: 0, FN_veg: 1361, IoU_veg: 0.3725
# TP_non_veg: 14215, FP_non_veg: 0, FN_non_veg: 2169, IoU_non_veg: 0.8676
# Image 61:
# TP_veg: 9116, FP_veg: 41, FN_veg: 4705, IoU_veg: 0.6576
# TP_non_veg: 2563, FP_non_veg: 41, FN_non_veg: 13821, IoU_non_veg: 0.1560
# Image 62:
# TP_veg: 1092, FP_veg: 31, FN_veg: 225, IoU_veg: 0.8101
# TP_non_veg: 15067, FP_non_veg: 31, FN_non_veg: 1317, IoU_non_veg: 0.9179
# Image 63:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 64:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 65:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 66:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 67:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 68:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 69:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 70:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 71:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 72:
# TP_veg: 1153, FP_veg: 5, FN_veg: 1303, IoU_veg: 0.4685
# TP_non_veg: 13928, FP_non_veg: 5, FN_non_veg: 2456, IoU_non_veg: 0.8498
# Image 73:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 74:
# TP_veg: 108, FP_veg: 10, FN_veg: 682, IoU_veg: 0.1350
# TP_non_veg: 15594, FP_non_veg: 10, FN_non_veg: 790, IoU_non_veg: 0.9512
# Image 75:
# TP_veg: 285, FP_veg: 7, FN_veg: 502, IoU_veg: 0.3589
# TP_non_veg: 15597, FP_non_veg: 7, FN_non_veg: 787, IoU_non_veg: 0.9516
# Image 76:
# TP_veg: 2808, FP_veg: 3, FN_veg: 7498, IoU_veg: 0.2724
# TP_non_veg: 6078, FP_non_veg: 3, FN_non_veg: 10306, IoU_non_veg: 0.3709
# Image 77:
# TP_veg: 9480, FP_veg: 87, FN_veg: 4021, IoU_veg: 0.6977
# TP_non_veg: 2883, FP_non_veg: 87, FN_non_veg: 13501, IoU_non_veg: 0.1750
# Image 78:
# TP_veg: 1735, FP_veg: 244, FN_veg: 109, IoU_veg: 0.8309
# TP_non_veg: 14540, FP_non_veg: 244, FN_non_veg: 1844, IoU_non_veg: 0.8744
# Image 79:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 80:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 81:
# TP_veg: 302, FP_veg: 5, FN_veg: 920, IoU_veg: 0.2461
# TP_non_veg: 15162, FP_non_veg: 5, FN_non_veg: 1222, IoU_non_veg: 0.9251
# Image 82:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 83:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 84:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 85:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 86:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 87:
# TP_veg: 1011, FP_veg: 0, FN_veg: 1247, IoU_veg: 0.4477
# TP_non_veg: 14126, FP_non_veg: 0, FN_non_veg: 2258, IoU_non_veg: 0.8622
# Image 88:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 89:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 90:
# TP_veg: 451, FP_veg: 0, FN_veg: 544, IoU_veg: 0.4533
# TP_non_veg: 15389, FP_non_veg: 0, FN_non_veg: 995, IoU_non_veg: 0.9393
# Image 91:
# TP_veg: 4218, FP_veg: 1, FN_veg: 1660, IoU_veg: 0.7175
# TP_non_veg: 10506, FP_non_veg: 1, FN_non_veg: 5878, IoU_non_veg: 0.6412
# Image 92:
# TP_veg: 8686, FP_veg: 8, FN_veg: 3614, IoU_veg: 0.7057
# TP_non_veg: 4084, FP_non_veg: 8, FN_non_veg: 12300, IoU_non_veg: 0.2491
# Image 93:
# TP_veg: 9809, FP_veg: 142, FN_veg: 2765, IoU_veg: 0.7714
# TP_non_veg: 3810, FP_non_veg: 142, FN_non_veg: 12574, IoU_non_veg: 0.2305
# Image 94:
# TP_veg: 1364, FP_veg: 5, FN_veg: 267, IoU_veg: 0.8337
# TP_non_veg: 14753, FP_non_veg: 5, FN_non_veg: 1631, IoU_non_veg: 0.9002
# Image 95:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 96:
# TP_veg: 163, FP_veg: 0, FN_veg: 513, IoU_veg: 0.2411
# TP_non_veg: 15708, FP_non_veg: 0, FN_non_veg: 676, IoU_non_veg: 0.9587
# Image 97:
# TP_veg: 1028, FP_veg: 0, FN_veg: 836, IoU_veg: 0.5515
# TP_non_veg: 14520, FP_non_veg: 0, FN_non_veg: 1864, IoU_non_veg: 0.8862
# Image 98:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 99:
# TP_veg: 1102, FP_veg: 0, FN_veg: 779, IoU_veg: 0.5859
# TP_non_veg: 14503, FP_non_veg: 0, FN_non_veg: 1881, IoU_non_veg: 0.8852
# Image 100:
# TP_veg: 5, FP_veg: 0, FN_veg: 32, IoU_veg: 0.1351
# TP_non_veg: 16347, FP_non_veg: 0, FN_non_veg: 37, IoU_non_veg: 0.9977
# Image 101:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 102:
# TP_veg: 6, FP_veg: 6, FN_veg: 241, IoU_veg: 0.0237
# TP_non_veg: 16137, FP_non_veg: 6, FN_non_veg: 247, IoU_non_veg: 0.9846
# Image 103:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 104:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 105:
# TP_veg: 544, FP_veg: 0, FN_veg: 924, IoU_veg: 0.3706
# TP_non_veg: 14916, FP_non_veg: 0, FN_non_veg: 1468, IoU_non_veg: 0.9104
# Image 106:
# TP_veg: 119, FP_veg: 11, FN_veg: 99, IoU_veg: 0.5197
# TP_non_veg: 16166, FP_non_veg: 11, FN_non_veg: 218, IoU_non_veg: 0.9860
# Image 107:
# TP_veg: 3826, FP_veg: 79, FN_veg: 6991, IoU_veg: 0.3511
# TP_non_veg: 5567, FP_non_veg: 79, FN_non_veg: 10817, IoU_non_veg: 0.3382
# Image 108:
# TP_veg: 141, FP_veg: 1, FN_veg: 2493, IoU_veg: 0.0535
# TP_non_veg: 13750, FP_non_veg: 1, FN_non_veg: 2634, IoU_non_veg: 0.8392
# Image 109:
# TP_veg: 4132, FP_veg: 72, FN_veg: 2806, IoU_veg: 0.5894
# TP_non_veg: 9446, FP_non_veg: 72, FN_non_veg: 6938, IoU_non_veg: 0.5740
# Image 110:
# TP_veg: 4167, FP_veg: 108, FN_veg: 487, IoU_veg: 0.8751
# TP_non_veg: 11730, FP_non_veg: 108, FN_non_veg: 4654, IoU_non_veg: 0.7113
# Image 111:
# TP_veg: 23, FP_veg: 0, FN_veg: 480, IoU_veg: 0.0457
# TP_non_veg: 15881, FP_non_veg: 0, FN_non_veg: 503, IoU_non_veg: 0.9693
# Image 112:
# TP_veg: 360, FP_veg: 0, FN_veg: 753, IoU_veg: 0.3235
# TP_non_veg: 15271, FP_non_veg: 0, FN_non_veg: 1113, IoU_non_veg: 0.9321
# Image 113:
# TP_veg: 826, FP_veg: 1, FN_veg: 988, IoU_veg: 0.4551
# TP_non_veg: 14570, FP_non_veg: 1, FN_non_veg: 1814, IoU_non_veg: 0.8892
# Image 114:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 115:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 116:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 117:
# TP_veg: 750, FP_veg: 0, FN_veg: 10230, IoU_veg: 0.0683
# TP_non_veg: 5404, FP_non_veg: 0, FN_non_veg: 10980, IoU_non_veg: 0.3298
# Image 118:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 119:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 120:
# TP_veg: 0, FP_veg: 0, FN_veg: 35, IoU_veg: 0.0000
# TP_non_veg: 16349, FP_non_veg: 0, FN_non_veg: 35, IoU_non_veg: 0.9979
# Image 121:
# TP_veg: 738, FP_veg: 16, FN_veg: 349, IoU_veg: 0.6691
# TP_non_veg: 15297, FP_non_veg: 16, FN_non_veg: 1087, IoU_non_veg: 0.9327
# Image 122:
# TP_veg: 10569, FP_veg: 3, FN_veg: 3167, IoU_veg: 0.7693
# TP_non_veg: 2648, FP_non_veg: 3, FN_non_veg: 13736, IoU_non_veg: 0.1616
# Image 123:
# TP_veg: 9146, FP_veg: 4, FN_veg: 3248, IoU_veg: 0.7377
# TP_non_veg: 3990, FP_non_veg: 4, FN_non_veg: 12394, IoU_non_veg: 0.2435
# Image 124:
# TP_veg: 10845, FP_veg: 0, FN_veg: 4549, IoU_veg: 0.7045
# TP_non_veg: 990, FP_non_veg: 0, FN_non_veg: 15394, IoU_non_veg: 0.0604
# Image 125:
# TP_veg: 6013, FP_veg: 0, FN_veg: 3626, IoU_veg: 0.6238
# TP_non_veg: 6745, FP_non_veg: 0, FN_non_veg: 9639, IoU_non_veg: 0.4117
# Image 126:
# TP_veg: 355, FP_veg: 1, FN_veg: 1038, IoU_veg: 0.2547
# TP_non_veg: 14991, FP_non_veg: 1, FN_non_veg: 1393, IoU_non_veg: 0.9149
# Image 127:
# TP_veg: 794, FP_veg: 0, FN_veg: 1153, IoU_veg: 0.4078
# TP_non_veg: 14437, FP_non_veg: 0, FN_non_veg: 1947, IoU_non_veg: 0.8812
# Image 128:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 129:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 130:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 131:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 132:
# TP_veg: 5621, FP_veg: 7, FN_veg: 9155, IoU_veg: 0.3802
# TP_non_veg: 1608, FP_non_veg: 7, FN_non_veg: 14776, IoU_non_veg: 0.0981
# Image 133:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 134:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 135:
# TP_veg: 3965, FP_veg: 114, FN_veg: 334, IoU_veg: 0.8985
# TP_non_veg: 12085, FP_non_veg: 114, FN_non_veg: 4299, IoU_non_veg: 0.7325
# Image 136:
# TP_veg: 1708, FP_veg: 12, FN_veg: 2944, IoU_veg: 0.3662
# TP_non_veg: 11732, FP_non_veg: 12, FN_non_veg: 4652, IoU_non_veg: 0.7155
# Image 137:
# TP_veg: 1562, FP_veg: 1, FN_veg: 1528, IoU_veg: 0.5053
# TP_non_veg: 13294, FP_non_veg: 1, FN_non_veg: 3090, IoU_non_veg: 0.8114
# Image 138:
# TP_veg: 4779, FP_veg: 214, FN_veg: 3127, IoU_veg: 0.5885
# TP_non_veg: 8478, FP_non_veg: 214, FN_non_veg: 7906, IoU_non_veg: 0.5108
# Image 139:
# TP_veg: 4155, FP_veg: 0, FN_veg: 4781, IoU_veg: 0.4650
# TP_non_veg: 7448, FP_non_veg: 0, FN_non_veg: 8936, IoU_non_veg: 0.4546
# Image 140:
# TP_veg: 898, FP_veg: 0, FN_veg: 10747, IoU_veg: 0.0771
# TP_non_veg: 4739, FP_non_veg: 0, FN_non_veg: 11645, IoU_non_veg: 0.2892
# Image 141:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 142:
# TP_veg: 0, FP_veg: 0, FN_veg: 213, IoU_veg: 0.0000
# TP_non_veg: 16171, FP_non_veg: 0, FN_non_veg: 213, IoU_non_veg: 0.9870
# Image 143:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 144:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 145:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 146:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 147:
# TP_veg: 1756, FP_veg: 0, FN_veg: 2122, IoU_veg: 0.4528
# TP_non_veg: 12506, FP_non_veg: 0, FN_non_veg: 3878, IoU_non_veg: 0.7633
# Image 148:
# TP_veg: 250, FP_veg: 0, FN_veg: 50, IoU_veg: 0.8333
# TP_non_veg: 16084, FP_non_veg: 0, FN_non_veg: 300, IoU_non_veg: 0.9817
# Image 149:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 150:
# TP_veg: 10881, FP_veg: 35, FN_veg: 3551, IoU_veg: 0.7521
# TP_non_veg: 1952, FP_non_veg: 35, FN_non_veg: 14432, IoU_non_veg: 0.1189
# Image 151:
# TP_veg: 2043, FP_veg: 29, FN_veg: 2237, IoU_veg: 0.4741
# TP_non_veg: 12104, FP_non_veg: 29, FN_non_veg: 4280, IoU_non_veg: 0.7375
# Image 152:
# TP_veg: 3593, FP_veg: 9, FN_veg: 1319, IoU_veg: 0.7301
# TP_non_veg: 11472, FP_non_veg: 9, FN_non_veg: 4912, IoU_non_veg: 0.6998
# Image 153:
# TP_veg: 5319, FP_veg: 81, FN_veg: 1751, IoU_veg: 0.7438
# TP_non_veg: 9314, FP_non_veg: 81, FN_non_veg: 7070, IoU_non_veg: 0.5657
# Image 154:
# TP_veg: 20, FP_veg: 0, FN_veg: 1753, IoU_veg: 0.0113
# TP_non_veg: 14611, FP_non_veg: 0, FN_non_veg: 1773, IoU_non_veg: 0.8918
# Image 155:
# TP_veg: 5195, FP_veg: 0, FN_veg: 6040, IoU_veg: 0.4624
# TP_non_veg: 5149, FP_non_veg: 0, FN_non_veg: 11235, IoU_non_veg: 0.3143
# Image 156:
# TP_veg: 4178, FP_veg: 254, FN_veg: 128, IoU_veg: 0.9162
# TP_non_veg: 12078, FP_non_veg: 254, FN_non_veg: 4306, IoU_non_veg: 0.7259
# Image 157:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 158:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 159:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 160:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 161:
# TP_veg: 3150, FP_veg: 35, FN_veg: 823, IoU_veg: 0.7859
# TP_non_veg: 12411, FP_non_veg: 35, FN_non_veg: 3973, IoU_non_veg: 0.7559
# Image 162:
# TP_veg: 1453, FP_veg: 3, FN_veg: 1370, IoU_veg: 0.5142
# TP_non_veg: 13561, FP_non_veg: 3, FN_non_veg: 2823, IoU_non_veg: 0.8275
# Image 163:
# TP_veg: 7393, FP_veg: 115, FN_veg: 183, IoU_veg: 0.9613
# TP_non_veg: 8808, FP_non_veg: 115, FN_non_veg: 7576, IoU_non_veg: 0.5339
# Image 164:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 165:
# TP_veg: 2572, FP_veg: 0, FN_veg: 823, IoU_veg: 0.7576
# TP_non_veg: 12989, FP_non_veg: 0, FN_non_veg: 3395, IoU_non_veg: 0.7928
# Image 166:
# TP_veg: 64, FP_veg: 0, FN_veg: 1677, IoU_veg: 0.0368
# TP_non_veg: 14643, FP_non_veg: 0, FN_non_veg: 1741, IoU_non_veg: 0.8937
# Image 167:
# TP_veg: 3126, FP_veg: 11, FN_veg: 3135, IoU_veg: 0.4984
# TP_non_veg: 10123, FP_non_veg: 11, FN_non_veg: 6261, IoU_non_veg: 0.6174
# Image 168:
# TP_veg: 3, FP_veg: 0, FN_veg: 3, IoU_veg: 0.5000
# TP_non_veg: 16378, FP_non_veg: 0, FN_non_veg: 6, IoU_non_veg: 0.9996
# Image 169:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 170:
# TP_veg: 632, FP_veg: 14, FN_veg: 103, IoU_veg: 0.8438
# TP_non_veg: 15649, FP_non_veg: 14, FN_non_veg: 735, IoU_non_veg: 0.9543
# Image 171:
# TP_veg: 11070, FP_veg: 20, FN_veg: 4038, IoU_veg: 0.7318
# TP_non_veg: 1276, FP_non_veg: 20, FN_non_veg: 15108, IoU_non_veg: 0.0778
# Image 172:
# TP_veg: 4342, FP_veg: 207, FN_veg: 81, IoU_veg: 0.9378
# TP_non_veg: 11961, FP_non_veg: 207, FN_non_veg: 4423, IoU_non_veg: 0.7209
# Image 173:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 174:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 175:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 176:
# TP_veg: 1892, FP_veg: 67, FN_veg: 273, IoU_veg: 0.8477
# TP_non_veg: 14219, FP_non_veg: 67, FN_non_veg: 2165, IoU_non_veg: 0.8643
# Image 177:
# TP_veg: 722, FP_veg: 0, FN_veg: 896, IoU_veg: 0.4462
# TP_non_veg: 14766, FP_non_veg: 0, FN_non_veg: 1618, IoU_non_veg: 0.9012
# Image 178:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 179:
# TP_veg: 354, FP_veg: 8, FN_veg: 355, IoU_veg: 0.4937
# TP_non_veg: 15675, FP_non_veg: 8, FN_non_veg: 709, IoU_non_veg: 0.9563
# Image 180:
# TP_veg: 9200, FP_veg: 67, FN_veg: 2560, IoU_veg: 0.7779
# TP_non_veg: 4624, FP_non_veg: 67, FN_non_veg: 11760, IoU_non_veg: 0.2811
# Image 181:
# TP_veg: 483, FP_veg: 0, FN_veg: 442, IoU_veg: 0.5222
# TP_non_veg: 15459, FP_non_veg: 0, FN_non_veg: 925, IoU_non_veg: 0.9435
# Image 182:
# TP_veg: 1828, FP_veg: 8, FN_veg: 1370, IoU_veg: 0.5702
# TP_non_veg: 13186, FP_non_veg: 8, FN_non_veg: 3198, IoU_non_veg: 0.8044
# Image 183:
# TP_veg: 240, FP_veg: 0, FN_veg: 1729, IoU_veg: 0.1219
# TP_non_veg: 14415, FP_non_veg: 0, FN_non_veg: 1969, IoU_non_veg: 0.8798
# Image 184:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 185:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 186:
# TP_veg: 12787, FP_veg: 2, FN_veg: 3023, IoU_veg: 0.8087
# TP_non_veg: 574, FP_non_veg: 2, FN_non_veg: 15810, IoU_non_veg: 0.0350
# Image 187:
# TP_veg: 10230, FP_veg: 0, FN_veg: 6154, IoU_veg: 0.6244
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 188:
# TP_veg: 904, FP_veg: 0, FN_veg: 821, IoU_veg: 0.5241
# TP_non_veg: 14659, FP_non_veg: 0, FN_non_veg: 1725, IoU_non_veg: 0.8947
# Image 189:
# TP_veg: 0, FP_veg: 0, FN_veg: 3278, IoU_veg: 0.0000
# TP_non_veg: 13106, FP_non_veg: 0, FN_non_veg: 3278, IoU_non_veg: 0.7999
# Image 190:
# TP_veg: 459, FP_veg: 8, FN_veg: 1113, IoU_veg: 0.2905
# TP_non_veg: 14812, FP_non_veg: 8, FN_non_veg: 1572, IoU_non_veg: 0.9036
# Image 191:
# TP_veg: 3122, FP_veg: 38, FN_veg: 1791, IoU_veg: 0.6306
# TP_non_veg: 11471, FP_non_veg: 38, FN_non_veg: 4913, IoU_non_veg: 0.6985
# Image 192:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 193:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 194:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 195:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 196:
# TP_veg: 93, FP_veg: 0, FN_veg: 277, IoU_veg: 0.2514
# TP_non_veg: 16014, FP_non_veg: 0, FN_non_veg: 370, IoU_non_veg: 0.9774
# Image 197:
# TP_veg: 900, FP_veg: 0, FN_veg: 593, IoU_veg: 0.6028
# TP_non_veg: 14891, FP_non_veg: 0, FN_non_veg: 1493, IoU_non_veg: 0.9089
# Image 198:
# TP_veg: 1681, FP_veg: 100, FN_veg: 608, IoU_veg: 0.7036
# TP_non_veg: 14095, FP_non_veg: 100, FN_non_veg: 2289, IoU_non_veg: 0.8551
# Image 199:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 200:
# TP_veg: 0, FP_veg: 0, FN_veg: 109, IoU_veg: 0.0000
# TP_non_veg: 16275, FP_non_veg: 0, FN_non_veg: 109, IoU_non_veg: 0.9933
# Image 201:
# TP_veg: 2824, FP_veg: 0, FN_veg: 2424, IoU_veg: 0.5381
# TP_non_veg: 11136, FP_non_veg: 0, FN_non_veg: 5248, IoU_non_veg: 0.6797
# Image 202:
# TP_veg: 6905, FP_veg: 0, FN_veg: 5876, IoU_veg: 0.5403
# TP_non_veg: 3603, FP_non_veg: 0, FN_non_veg: 12781, IoU_non_veg: 0.2199
# Image 203:
# TP_veg: 0, FP_veg: 0, FN_veg: 1038, IoU_veg: 0.0000
# TP_non_veg: 15346, FP_non_veg: 0, FN_non_veg: 1038, IoU_non_veg: 0.9366
# Image 204:
# TP_veg: 1692, FP_veg: 0, FN_veg: 5061, IoU_veg: 0.2506
# TP_non_veg: 9631, FP_non_veg: 0, FN_non_veg: 6753, IoU_non_veg: 0.5878
# Image 205:
# TP_veg: 0, FP_veg: 0, FN_veg: 193, IoU_veg: 0.0000
# TP_non_veg: 16191, FP_non_veg: 0, FN_non_veg: 193, IoU_non_veg: 0.9882
# Image 206:
# TP_veg: 0, FP_veg: 0, FN_veg: 1, IoU_veg: 0.0000
# TP_non_veg: 16383, FP_non_veg: 0, FN_non_veg: 1, IoU_non_veg: 0.9999
# Image 207:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 208:
# TP_veg: 0, FP_veg: 0, FN_veg: 1492, IoU_veg: 0.0000
# TP_non_veg: 14892, FP_non_veg: 0, FN_non_veg: 1492, IoU_non_veg: 0.9089
# Image 209:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 210:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 211:
# TP_veg: 2125, FP_veg: 33, FN_veg: 2842, IoU_veg: 0.4250
# TP_non_veg: 11417, FP_non_veg: 33, FN_non_veg: 4967, IoU_non_veg: 0.6954
# Image 212:
# TP_veg: 1299, FP_veg: 27, FN_veg: 401, IoU_veg: 0.7522
# TP_non_veg: 14684, FP_non_veg: 27, FN_non_veg: 1700, IoU_non_veg: 0.8948
# Image 213:
# TP_veg: 622, FP_veg: 0, FN_veg: 470, IoU_veg: 0.5696
# TP_non_veg: 15292, FP_non_veg: 0, FN_non_veg: 1092, IoU_non_veg: 0.9333
# Image 214:
# TP_veg: 1176, FP_veg: 2, FN_veg: 1757, IoU_veg: 0.4007
# TP_non_veg: 13451, FP_non_veg: 2, FN_non_veg: 2933, IoU_non_veg: 0.8209
# Image 215:
# TP_veg: 4859, FP_veg: 38, FN_veg: 2471, IoU_veg: 0.6595
# TP_non_veg: 9054, FP_non_veg: 38, FN_non_veg: 7330, IoU_non_veg: 0.5513
# Image 216:
# TP_veg: 692, FP_veg: 0, FN_veg: 1084, IoU_veg: 0.3896
# TP_non_veg: 14608, FP_non_veg: 0, FN_non_veg: 1776, IoU_non_veg: 0.8916
# Image 217:
# TP_veg: 4020, FP_veg: 8, FN_veg: 3208, IoU_veg: 0.5556
# TP_non_veg: 9156, FP_non_veg: 8, FN_non_veg: 7228, IoU_non_veg: 0.5586
# Image 218:
# TP_veg: 1344, FP_veg: 0, FN_veg: 1412, IoU_veg: 0.4877
# TP_non_veg: 13628, FP_non_veg: 0, FN_non_veg: 2756, IoU_non_veg: 0.8318
# Image 219:
# TP_veg: 6785, FP_veg: 0, FN_veg: 3123, IoU_veg: 0.6848
# TP_non_veg: 6476, FP_non_veg: 0, FN_non_veg: 9908, IoU_non_veg: 0.3953
# Image 220:
# TP_veg: 0, FP_veg: 0, FN_veg: 182, IoU_veg: 0.0000
# TP_non_veg: 16202, FP_non_veg: 0, FN_non_veg: 182, IoU_non_veg: 0.9889
# Image 221:
# TP_veg: 0, FP_veg: 0, FN_veg: 406, IoU_veg: 0.0000
# TP_non_veg: 15978, FP_non_veg: 0, FN_non_veg: 406, IoU_non_veg: 0.9752
# Image 222:
# TP_veg: 1164, FP_veg: 0, FN_veg: 1901, IoU_veg: 0.3798
# TP_non_veg: 13319, FP_non_veg: 0, FN_non_veg: 3065, IoU_non_veg: 0.8129
# Image 223:
# TP_veg: 808, FP_veg: 18, FN_veg: 10724, IoU_veg: 0.0700
# TP_non_veg: 4852, FP_non_veg: 18, FN_non_veg: 11532, IoU_non_veg: 0.2958
# Image 224:
# TP_veg: 3348, FP_veg: 57, FN_veg: 5320, IoU_veg: 0.3837
# TP_non_veg: 7716, FP_non_veg: 57, FN_non_veg: 8668, IoU_non_veg: 0.4693
# Image 225:
# TP_veg: 541, FP_veg: 0, FN_veg: 480, IoU_veg: 0.5299
# TP_non_veg: 15363, FP_non_veg: 0, FN_non_veg: 1021, IoU_non_veg: 0.9377
# Image 226:
# TP_veg: 791, FP_veg: 4, FN_veg: 2708, IoU_veg: 0.2258
# TP_non_veg: 12885, FP_non_veg: 4, FN_non_veg: 3499, IoU_non_veg: 0.7862
# Image 227:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 228:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 229:
# TP_veg: 259, FP_veg: 0, FN_veg: 786, IoU_veg: 0.2478
# TP_non_veg: 15339, FP_non_veg: 0, FN_non_veg: 1045, IoU_non_veg: 0.9362
# Image 230:
# TP_veg: 7607, FP_veg: 172, FN_veg: 838, IoU_veg: 0.8828
# TP_non_veg: 7939, FP_non_veg: 172, FN_non_veg: 8445, IoU_non_veg: 0.4795
# Image 231:
# TP_veg: 2616, FP_veg: 0, FN_veg: 4071, IoU_veg: 0.3912
# TP_non_veg: 9697, FP_non_veg: 0, FN_non_veg: 6687, IoU_non_veg: 0.5919
# Image 232:
# TP_veg: 3779, FP_veg: 0, FN_veg: 1295, IoU_veg: 0.7448
# TP_non_veg: 11310, FP_non_veg: 0, FN_non_veg: 5074, IoU_non_veg: 0.6903
# Image 233:
# TP_veg: 1786, FP_veg: 25, FN_veg: 3545, IoU_veg: 0.3335
# TP_non_veg: 11053, FP_non_veg: 25, FN_non_veg: 5331, IoU_non_veg: 0.6736
# Image 234:
# TP_veg: 1601, FP_veg: 39, FN_veg: 351, IoU_veg: 0.8041
# TP_non_veg: 14432, FP_non_veg: 39, FN_non_veg: 1952, IoU_non_veg: 0.8788
# Image 235:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 236:
# TP_veg: 193, FP_veg: 0, FN_veg: 10740, IoU_veg: 0.0177
# TP_non_veg: 5451, FP_non_veg: 0, FN_non_veg: 10933, IoU_non_veg: 0.3327
# Image 237:
# TP_veg: 326, FP_veg: 0, FN_veg: 1369, IoU_veg: 0.1923
# TP_non_veg: 14689, FP_non_veg: 0, FN_non_veg: 1695, IoU_non_veg: 0.8965
# Image 238:
# TP_veg: 4802, FP_veg: 0, FN_veg: 10908, IoU_veg: 0.3057
# TP_non_veg: 674, FP_non_veg: 0, FN_non_veg: 15710, IoU_non_veg: 0.0411
# Image 239:
# TP_veg: 8646, FP_veg: 0, FN_veg: 4741, IoU_veg: 0.6459
# TP_non_veg: 2997, FP_non_veg: 0, FN_non_veg: 13387, IoU_non_veg: 0.1829
# Image 240:
# TP_veg: 60, FP_veg: 0, FN_veg: 502, IoU_veg: 0.1068
# TP_non_veg: 15822, FP_non_veg: 0, FN_non_veg: 562, IoU_non_veg: 0.9657
# Image 241:
# TP_veg: 59, FP_veg: 0, FN_veg: 873, IoU_veg: 0.0633
# TP_non_veg: 15452, FP_non_veg: 0, FN_non_veg: 932, IoU_non_veg: 0.9431
# Image 242:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 243:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 244:
# TP_veg: 630, FP_veg: 26, FN_veg: 49, IoU_veg: 0.8936
# TP_non_veg: 15705, FP_non_veg: 26, FN_non_veg: 679, IoU_non_veg: 0.9570
# Image 245:
# TP_veg: 5, FP_veg: 0, FN_veg: 71, IoU_veg: 0.0658
# TP_non_veg: 16308, FP_non_veg: 0, FN_non_veg: 76, IoU_non_veg: 0.9954
# Image 246:
# TP_veg: 1096, FP_veg: 6, FN_veg: 3220, IoU_veg: 0.2536
# TP_non_veg: 12068, FP_non_veg: 6, FN_non_veg: 4316, IoU_non_veg: 0.7363
# Image 247:
# TP_veg: 718, FP_veg: 0, FN_veg: 819, IoU_veg: 0.4671
# TP_non_veg: 14847, FP_non_veg: 0, FN_non_veg: 1537, IoU_non_veg: 0.9062
# Image 248:
# TP_veg: 473, FP_veg: 0, FN_veg: 1335, IoU_veg: 0.2616
# TP_non_veg: 14576, FP_non_veg: 0, FN_non_veg: 1808, IoU_non_veg: 0.8896
# Image 249:
# TP_veg: 0, FP_veg: 0, FN_veg: 4, IoU_veg: 0.0000
# TP_non_veg: 16380, FP_non_veg: 0, FN_non_veg: 4, IoU_non_veg: 0.9998
# Image 250:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 251:
# TP_veg: 0, FP_veg: 0, FN_veg: 1240, IoU_veg: 0.0000
# TP_non_veg: 15144, FP_non_veg: 0, FN_non_veg: 1240, IoU_non_veg: 0.9243
# Image 252:
# TP_veg: 1998, FP_veg: 20, FN_veg: 1772, IoU_veg: 0.5272
# TP_non_veg: 12614, FP_non_veg: 20, FN_non_veg: 3770, IoU_non_veg: 0.7690
# Image 253:
# TP_veg: 2624, FP_veg: 0, FN_veg: 1835, IoU_veg: 0.5885
# TP_non_veg: 11925, FP_non_veg: 0, FN_non_veg: 4459, IoU_non_veg: 0.7278
# Image 254:
# TP_veg: 12446, FP_veg: 9, FN_veg: 1494, IoU_veg: 0.8923
# TP_non_veg: 2444, FP_non_veg: 9, FN_non_veg: 13940, IoU_non_veg: 0.1491
# Image 255:
# TP_veg: 3224, FP_veg: 0, FN_veg: 2671, IoU_veg: 0.5469
# TP_non_veg: 10489, FP_non_veg: 0, FN_non_veg: 5895, IoU_non_veg: 0.6402
# Image 256:
# TP_veg: 3074, FP_veg: 0, FN_veg: 4218, IoU_veg: 0.4216
# TP_non_veg: 9092, FP_non_veg: 0, FN_non_veg: 7292, IoU_non_veg: 0.5549
# Image 257:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 258:
# TP_veg: 625, FP_veg: 0, FN_veg: 184, IoU_veg: 0.7726
# TP_non_veg: 15575, FP_non_veg: 0, FN_non_veg: 809, IoU_non_veg: 0.9506
# Image 259:
# TP_veg: 1562, FP_veg: 11, FN_veg: 491, IoU_veg: 0.7568
# TP_non_veg: 14331, FP_non_veg: 11, FN_non_veg: 2053, IoU_non_veg: 0.8741
# Image 260:
# TP_veg: 110, FP_veg: 0, FN_veg: 70, IoU_veg: 0.6111
# TP_non_veg: 16204, FP_non_veg: 0, FN_non_veg: 180, IoU_non_veg: 0.9890
# Image 261:
# TP_veg: 6398, FP_veg: 0, FN_veg: 2495, IoU_veg: 0.7194
# TP_non_veg: 7491, FP_non_veg: 0, FN_non_veg: 8893, IoU_non_veg: 0.4572
# Image 262:
# TP_veg: 2658, FP_veg: 0, FN_veg: 4612, IoU_veg: 0.3656
# TP_non_veg: 9114, FP_non_veg: 0, FN_non_veg: 7270, IoU_non_veg: 0.5563
# Image 263:
# TP_veg: 2892, FP_veg: 0, FN_veg: 1072, IoU_veg: 0.7296
# TP_non_veg: 12420, FP_non_veg: 0, FN_non_veg: 3964, IoU_non_veg: 0.7581
# Image 264:
# TP_veg: 1025, FP_veg: 0, FN_veg: 2586, IoU_veg: 0.2839
# TP_non_veg: 12773, FP_non_veg: 0, FN_non_veg: 3611, IoU_non_veg: 0.7796
# Image 265:
# TP_veg: 0, FP_veg: 0, FN_veg: 1, IoU_veg: 0.0000
# TP_non_veg: 16383, FP_non_veg: 0, FN_non_veg: 1, IoU_non_veg: 0.9999
# Image 266:
# TP_veg: 0, FP_veg: 0, FN_veg: 3989, IoU_veg: 0.0000
# TP_non_veg: 12395, FP_non_veg: 0, FN_non_veg: 3989, IoU_non_veg: 0.7565
# Image 267:
# TP_veg: 5125, FP_veg: 0, FN_veg: 2319, IoU_veg: 0.6885
# TP_non_veg: 8940, FP_non_veg: 0, FN_non_veg: 7444, IoU_non_veg: 0.5457
# Image 268:
# TP_veg: 6954, FP_veg: 5, FN_veg: 3493, IoU_veg: 0.6653
# TP_non_veg: 5937, FP_non_veg: 5, FN_non_veg: 10447, IoU_non_veg: 0.3623
# Image 269:
# TP_veg: 7110, FP_veg: 271, FN_veg: 1467, IoU_veg: 0.8036
# TP_non_veg: 7807, FP_non_veg: 271, FN_non_veg: 8577, IoU_non_veg: 0.4687
# Image 270:
# TP_veg: 8590, FP_veg: 16, FN_veg: 3175, IoU_veg: 0.7291
# TP_non_veg: 4619, FP_non_veg: 16, FN_non_veg: 11765, IoU_non_veg: 0.2816
# Image 271:
# TP_veg: 0, FP_veg: 503, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 503, FN_non_veg: 0, IoU_non_veg: 0.9702
# Image 272:
# TP_veg: 34, FP_veg: 25, FN_veg: 1, IoU_veg: 0.5667
# TP_non_veg: 16349, FP_non_veg: 25, FN_non_veg: 35, IoU_non_veg: 0.9963
# Image 273:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 274:
# TP_veg: 6282, FP_veg: 0, FN_veg: 7954, IoU_veg: 0.4413
# TP_non_veg: 2148, FP_non_veg: 0, FN_non_veg: 14236, IoU_non_veg: 0.1311
# Image 275:
# TP_veg: 6074, FP_veg: 3, FN_veg: 4712, IoU_veg: 0.5630
# TP_non_veg: 5598, FP_non_veg: 3, FN_non_veg: 10786, IoU_non_veg: 0.3416
# Image 276:
# TP_veg: 1091, FP_veg: 16, FN_veg: 1170, IoU_veg: 0.4791
# TP_non_veg: 14123, FP_non_veg: 16, FN_non_veg: 2261, IoU_non_veg: 0.8612
# Image 277:
# TP_veg: 1503, FP_veg: 29, FN_veg: 6973, IoU_veg: 0.1767
# TP_non_veg: 7908, FP_non_veg: 29, FN_non_veg: 8476, IoU_non_veg: 0.4818
# Image 278:
# TP_veg: 1334, FP_veg: 24, FN_veg: 1040, IoU_veg: 0.5563
# TP_non_veg: 14010, FP_non_veg: 24, FN_non_veg: 2374, IoU_non_veg: 0.8539
# Image 279:
# TP_veg: 6276, FP_veg: 14, FN_veg: 3638, IoU_veg: 0.6322
# TP_non_veg: 6470, FP_non_veg: 14, FN_non_veg: 9914, IoU_non_veg: 0.3946
# Image 280:
# TP_veg: 196, FP_veg: 0, FN_veg: 13591, IoU_veg: 0.0142
# TP_non_veg: 2597, FP_non_veg: 0, FN_non_veg: 13787, IoU_non_veg: 0.1585
# Image 281:
# TP_veg: 1915, FP_veg: 3, FN_veg: 6110, IoU_veg: 0.2385
# TP_non_veg: 8359, FP_non_veg: 3, FN_non_veg: 8025, IoU_non_veg: 0.5101
# Image 282:
# TP_veg: 3183, FP_veg: 0, FN_veg: 5792, IoU_veg: 0.3547
# TP_non_veg: 7409, FP_non_veg: 0, FN_non_veg: 8975, IoU_non_veg: 0.4522
# Image 283:
# TP_veg: 6139, FP_veg: 0, FN_veg: 6543, IoU_veg: 0.4841
# TP_non_veg: 3702, FP_non_veg: 0, FN_non_veg: 12682, IoU_non_veg: 0.2260
# Image 284:
# TP_veg: 4885, FP_veg: 0, FN_veg: 2115, IoU_veg: 0.6979
# TP_non_veg: 9384, FP_non_veg: 0, FN_non_veg: 7000, IoU_non_veg: 0.5728
# Image 285:
# TP_veg: 4049, FP_veg: 108, FN_veg: 6720, IoU_veg: 0.3723
# TP_non_veg: 5615, FP_non_veg: 108, FN_non_veg: 10769, IoU_non_veg: 0.3405
# Image 286:
# TP_veg: 8947, FP_veg: 6, FN_veg: 4112, IoU_veg: 0.6848
# TP_non_veg: 3325, FP_non_veg: 6, FN_non_veg: 13059, IoU_non_veg: 0.2029
# Image 287:
# TP_veg: 7171, FP_veg: 83, FN_veg: 5111, IoU_veg: 0.5799
# TP_non_veg: 4102, FP_non_veg: 83, FN_non_veg: 12282, IoU_non_veg: 0.2491
# Image 288:
# TP_veg: 4316, FP_veg: 39, FN_veg: 6885, IoU_veg: 0.3840
# TP_non_veg: 5183, FP_non_veg: 39, FN_non_veg: 11201, IoU_non_veg: 0.3156
# Image 289:
# TP_veg: 3458, FP_veg: 2, FN_veg: 1441, IoU_veg: 0.7056
# TP_non_veg: 11485, FP_non_veg: 2, FN_non_veg: 4899, IoU_non_veg: 0.7009
# Image 290:
# TP_veg: 8184, FP_veg: 24, FN_veg: 1630, IoU_veg: 0.8319
# TP_non_veg: 6570, FP_non_veg: 24, FN_non_veg: 9814, IoU_non_veg: 0.4004
# Image 291:
# TP_veg: 4795, FP_veg: 23, FN_veg: 2656, IoU_veg: 0.6416
# TP_non_veg: 8933, FP_non_veg: 23, FN_non_veg: 7451, IoU_non_veg: 0.5445
# Image 292:
# TP_veg: 1909, FP_veg: 0, FN_veg: 5276, IoU_veg: 0.2657
# TP_non_veg: 9199, FP_non_veg: 0, FN_non_veg: 7185, IoU_non_veg: 0.5615
# Image 293:
# TP_veg: 1459, FP_veg: 1, FN_veg: 4083, IoU_veg: 0.2632
# TP_non_veg: 10842, FP_non_veg: 1, FN_non_veg: 5542, IoU_non_veg: 0.6617
# Image 294:
# TP_veg: 74, FP_veg: 1, FN_veg: 2550, IoU_veg: 0.0282
# TP_non_veg: 13760, FP_non_veg: 1, FN_non_veg: 2624, IoU_non_veg: 0.8398
# Image 295:
# TP_veg: 32, FP_veg: 0, FN_veg: 1175, IoU_veg: 0.0265
# TP_non_veg: 15177, FP_non_veg: 0, FN_non_veg: 1207, IoU_non_veg: 0.9263
# Image 296:
# TP_veg: 440, FP_veg: 0, FN_veg: 3406, IoU_veg: 0.1144
# TP_non_veg: 12538, FP_non_veg: 0, FN_non_veg: 3846, IoU_non_veg: 0.7653
# Image 297:
# TP_veg: 757, FP_veg: 5, FN_veg: 4703, IoU_veg: 0.1385
# TP_non_veg: 10924, FP_non_veg: 5, FN_non_veg: 5460, IoU_non_veg: 0.6665
# Image 298:
# TP_veg: 378, FP_veg: 2, FN_veg: 2030, IoU_veg: 0.1568
# TP_non_veg: 13976, FP_non_veg: 2, FN_non_veg: 2408, IoU_non_veg: 0.8529
# Image 299:
# TP_veg: 4, FP_veg: 0, FN_veg: 609, IoU_veg: 0.0065
# TP_non_veg: 15771, FP_non_veg: 0, FN_non_veg: 613, IoU_non_veg: 0.9626
# Image 300:
# TP_veg: 1533, FP_veg: 25, FN_veg: 4592, IoU_veg: 0.2493
# TP_non_veg: 10259, FP_non_veg: 25, FN_non_veg: 6125, IoU_non_veg: 0.6252
# Image 301:
# TP_veg: 5258, FP_veg: 24, FN_veg: 1867, IoU_veg: 0.7355
# TP_non_veg: 9259, FP_non_veg: 24, FN_non_veg: 7125, IoU_non_veg: 0.5643
# Image 302:
# TP_veg: 3392, FP_veg: 4, FN_veg: 3378, IoU_veg: 0.5007
# TP_non_veg: 9614, FP_non_veg: 4, FN_non_veg: 6770, IoU_non_veg: 0.5866
# Image 303:
# TP_veg: 4544, FP_veg: 20, FN_veg: 4705, IoU_veg: 0.4902
# TP_non_veg: 7135, FP_non_veg: 20, FN_non_veg: 9249, IoU_non_veg: 0.4350
# Image 304:
# TP_veg: 1385, FP_veg: 0, FN_veg: 1326, IoU_veg: 0.5109
# TP_non_veg: 13673, FP_non_veg: 0, FN_non_veg: 2711, IoU_non_veg: 0.8345
# Image 305:
# TP_veg: 5277, FP_veg: 3, FN_veg: 2061, IoU_veg: 0.7188
# TP_non_veg: 9046, FP_non_veg: 3, FN_non_veg: 7338, IoU_non_veg: 0.5520
# Image 306:
# TP_veg: 4940, FP_veg: 1, FN_veg: 1413, IoU_veg: 0.7775
# TP_non_veg: 10031, FP_non_veg: 1, FN_non_veg: 6353, IoU_non_veg: 0.6122
# Image 307:
# TP_veg: 346, FP_veg: 0, FN_veg: 2298, IoU_veg: 0.1309
# TP_non_veg: 13740, FP_non_veg: 0, FN_non_veg: 2644, IoU_non_veg: 0.8386
# Image 308:
# TP_veg: 1230, FP_veg: 0, FN_veg: 1754, IoU_veg: 0.4122
# TP_non_veg: 13400, FP_non_veg: 0, FN_non_veg: 2984, IoU_non_veg: 0.8179
# Image 309:
# TP_veg: 2570, FP_veg: 2, FN_veg: 9205, IoU_veg: 0.2182
# TP_non_veg: 4609, FP_non_veg: 2, FN_non_veg: 11775, IoU_non_veg: 0.2813
# Image 310:
# TP_veg: 0, FP_veg: 0, FN_veg: 6106, IoU_veg: 0.0000
# TP_non_veg: 10278, FP_non_veg: 0, FN_non_veg: 6106, IoU_non_veg: 0.6273
# Image 311:
# TP_veg: 181, FP_veg: 10, FN_veg: 2942, IoU_veg: 0.0578
# TP_non_veg: 13261, FP_non_veg: 10, FN_non_veg: 3123, IoU_non_veg: 0.8089
# Image 312:
# TP_veg: 8831, FP_veg: 1, FN_veg: 7441, IoU_veg: 0.5427
# TP_non_veg: 112, FP_non_veg: 1, FN_non_veg: 16272, IoU_non_veg: 0.0068
# Image 313:
# TP_veg: 231, FP_veg: 15, FN_veg: 3131, IoU_veg: 0.0684
# TP_non_veg: 13022, FP_non_veg: 15, FN_non_veg: 3362, IoU_non_veg: 0.7941
# Image 314:
# TP_veg: 617, FP_veg: 0, FN_veg: 1807, IoU_veg: 0.2545
# TP_non_veg: 13960, FP_non_veg: 0, FN_non_veg: 2424, IoU_non_veg: 0.8521
# Image 315:
# TP_veg: 1830, FP_veg: 4, FN_veg: 8326, IoU_veg: 0.1801
# TP_non_veg: 6228, FP_non_veg: 4, FN_non_veg: 10156, IoU_non_veg: 0.3800
# Image 316:
# TP_veg: 976, FP_veg: 0, FN_veg: 1308, IoU_veg: 0.4273
# TP_non_veg: 14100, FP_non_veg: 0, FN_non_veg: 2284, IoU_non_veg: 0.8606
# Image 317:
# TP_veg: 135, FP_veg: 0, FN_veg: 4065, IoU_veg: 0.0321
# TP_non_veg: 12184, FP_non_veg: 0, FN_non_veg: 4200, IoU_non_veg: 0.7437
# Image 318:
# TP_veg: 0, FP_veg: 0, FN_veg: 1315, IoU_veg: 0.0000
# TP_non_veg: 15069, FP_non_veg: 0, FN_non_veg: 1315, IoU_non_veg: 0.9197
# Image 319:
# TP_veg: 26, FP_veg: 0, FN_veg: 1396, IoU_veg: 0.0183
# TP_non_veg: 14962, FP_non_veg: 0, FN_non_veg: 1422, IoU_non_veg: 0.9132
# Image 320:
# TP_veg: 810, FP_veg: 3, FN_veg: 5278, IoU_veg: 0.1330
# TP_non_veg: 10296, FP_non_veg: 3, FN_non_veg: 6088, IoU_non_veg: 0.6283
# Image 321:
# TP_veg: 198, FP_veg: 0, FN_veg: 141, IoU_veg: 0.5841
# TP_non_veg: 16045, FP_non_veg: 0, FN_non_veg: 339, IoU_non_veg: 0.9793
# Image 322:
# TP_veg: 187, FP_veg: 1, FN_veg: 7360, IoU_veg: 0.0248
# TP_non_veg: 8837, FP_non_veg: 1, FN_non_veg: 7547, IoU_non_veg: 0.5393
# Image 323:
# TP_veg: 312, FP_veg: 0, FN_veg: 697, IoU_veg: 0.3092
# TP_non_veg: 15375, FP_non_veg: 0, FN_non_veg: 1009, IoU_non_veg: 0.9384
# Image 324:
# TP_veg: 7804, FP_veg: 0, FN_veg: 8500, IoU_veg: 0.4787
# TP_non_veg: 80, FP_non_veg: 0, FN_non_veg: 16304, IoU_non_veg: 0.0049
# Image 325:
# TP_veg: 5252, FP_veg: 91, FN_veg: 3634, IoU_veg: 0.5851
# TP_non_veg: 7498, FP_non_veg: 91, FN_non_veg: 8886, IoU_non_veg: 0.4551
# Image 326:
# TP_veg: 2828, FP_veg: 40, FN_veg: 6061, IoU_veg: 0.3167
# TP_non_veg: 7495, FP_non_veg: 40, FN_non_veg: 8889, IoU_non_veg: 0.4563
# Image 327:
# TP_veg: 523, FP_veg: 5, FN_veg: 252, IoU_veg: 0.6705
# TP_non_veg: 15609, FP_non_veg: 5, FN_non_veg: 775, IoU_non_veg: 0.9524
# Image 328:
# TP_veg: 1888, FP_veg: 0, FN_veg: 6079, IoU_veg: 0.2370
# TP_non_veg: 8417, FP_non_veg: 0, FN_non_veg: 7967, IoU_non_veg: 0.5137
# Image 329:
# TP_veg: 8218, FP_veg: 29, FN_veg: 3376, IoU_veg: 0.7070
# TP_non_veg: 4790, FP_non_veg: 29, FN_non_veg: 11594, IoU_non_veg: 0.2918
# Image 330:
# TP_veg: 1695, FP_veg: 0, FN_veg: 690, IoU_veg: 0.7107
# TP_non_veg: 13999, FP_non_veg: 0, FN_non_veg: 2385, IoU_non_veg: 0.8544
# Image 331:
# TP_veg: 2633, FP_veg: 233, FN_veg: 7886, IoU_veg: 0.2449
# TP_non_veg: 5865, FP_non_veg: 233, FN_non_veg: 10519, IoU_non_veg: 0.3530
# Image 332:
# TP_veg: 11466, FP_veg: 74, FN_veg: 3247, IoU_veg: 0.7754
# TP_non_veg: 1671, FP_non_veg: 74, FN_non_veg: 14713, IoU_non_veg: 0.1015
# Image 333:
# TP_veg: 7227, FP_veg: 54, FN_veg: 1778, IoU_veg: 0.7978
# TP_non_veg: 7379, FP_non_veg: 54, FN_non_veg: 9005, IoU_non_veg: 0.4489
# Image 334:
# TP_veg: 11842, FP_veg: 5, FN_veg: 2565, IoU_veg: 0.8217
# TP_non_veg: 1977, FP_non_veg: 5, FN_non_veg: 14407, IoU_non_veg: 0.1206
# Image 335:
# TP_veg: 8206, FP_veg: 13, FN_veg: 3164, IoU_veg: 0.7209
# TP_non_veg: 5014, FP_non_veg: 13, FN_non_veg: 11370, IoU_non_veg: 0.3058
# Image 336:
# TP_veg: 2307, FP_veg: 0, FN_veg: 1592, IoU_veg: 0.5917
# TP_non_veg: 12485, FP_non_veg: 0, FN_non_veg: 3899, IoU_non_veg: 0.7620
# Image 337:
# TP_veg: 910, FP_veg: 0, FN_veg: 5440, IoU_veg: 0.1433
# TP_non_veg: 10034, FP_non_veg: 0, FN_non_veg: 6350, IoU_non_veg: 0.6124
# Image 338:
# TP_veg: 124, FP_veg: 0, FN_veg: 9169, IoU_veg: 0.0133
# TP_non_veg: 7091, FP_non_veg: 0, FN_non_veg: 9293, IoU_non_veg: 0.4328
# Image 339:
# TP_veg: 0, FP_veg: 0, FN_veg: 3912, IoU_veg: 0.0000
# TP_non_veg: 12472, FP_non_veg: 0, FN_non_veg: 3912, IoU_non_veg: 0.7612
# Image 340:
# TP_veg: 12, FP_veg: 0, FN_veg: 10493, IoU_veg: 0.0011
# TP_non_veg: 5879, FP_non_veg: 0, FN_non_veg: 10505, IoU_non_veg: 0.3588
# Image 341:
# TP_veg: 0, FP_veg: 0, FN_veg: 3051, IoU_veg: 0.0000
# TP_non_veg: 13333, FP_non_veg: 0, FN_non_veg: 3051, IoU_non_veg: 0.8138
# Image 342:
# TP_veg: 7181, FP_veg: 45, FN_veg: 4283, IoU_veg: 0.6239
# TP_non_veg: 4920, FP_non_veg: 45, FN_non_veg: 11464, IoU_non_veg: 0.2995
# Image 343:
# TP_veg: 2748, FP_veg: 41, FN_veg: 3188, IoU_veg: 0.4598
# TP_non_veg: 10448, FP_non_veg: 41, FN_non_veg: 5936, IoU_non_veg: 0.6361
# Image 344:
# TP_veg: 4184, FP_veg: 28, FN_veg: 2195, IoU_veg: 0.6530
# TP_non_veg: 10005, FP_non_veg: 28, FN_non_veg: 6379, IoU_non_veg: 0.6096
# Image 345:
# TP_veg: 3962, FP_veg: 39, FN_veg: 8832, IoU_veg: 0.3087
# TP_non_veg: 3590, FP_non_veg: 39, FN_non_veg: 12794, IoU_non_veg: 0.2186
# Image 346:
# TP_veg: 1525, FP_veg: 74, FN_veg: 554, IoU_veg: 0.7083
# TP_non_veg: 14305, FP_non_veg: 74, FN_non_veg: 2079, IoU_non_veg: 0.8692
# Image 347:
# TP_veg: 3626, FP_veg: 102, FN_veg: 6548, IoU_veg: 0.3529
# TP_non_veg: 6210, FP_non_veg: 102, FN_non_veg: 10174, IoU_non_veg: 0.3767
# Image 348:
# TP_veg: 389, FP_veg: 0, FN_veg: 5552, IoU_veg: 0.0655
# TP_non_veg: 10443, FP_non_veg: 0, FN_non_veg: 5941, IoU_non_veg: 0.6374
# Image 349:
# TP_veg: 80, FP_veg: 3, FN_veg: 1818, IoU_veg: 0.0421
# TP_non_veg: 14486, FP_non_veg: 3, FN_non_veg: 1898, IoU_non_veg: 0.8840
# Image 350:
# TP_veg: 5792, FP_veg: 11, FN_veg: 3542, IoU_veg: 0.6198
# TP_non_veg: 7050, FP_non_veg: 11, FN_non_veg: 9334, IoU_non_veg: 0.4300
# Image 351:
# TP_veg: 161, FP_veg: 2, FN_veg: 2041, IoU_veg: 0.0730
# TP_non_veg: 14182, FP_non_veg: 2, FN_non_veg: 2202, IoU_non_veg: 0.8655
# Image 352:
# TP_veg: 798, FP_veg: 1, FN_veg: 10054, IoU_veg: 0.0735
# TP_non_veg: 5532, FP_non_veg: 1, FN_non_veg: 10852, IoU_non_veg: 0.3376
# Image 353:
# TP_veg: 740, FP_veg: 0, FN_veg: 14381, IoU_veg: 0.0489
# TP_non_veg: 1263, FP_non_veg: 0, FN_non_veg: 15121, IoU_non_veg: 0.0771
# Image 354:
# TP_veg: 3834, FP_veg: 0, FN_veg: 12550, IoU_veg: 0.2340
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 355:
# TP_veg: 8673, FP_veg: 0, FN_veg: 7711, IoU_veg: 0.5294
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 356:
# TP_veg: 7439, FP_veg: 0, FN_veg: 5358, IoU_veg: 0.5813
# ...
# Image 640:
# TP_veg: 1244, FP_veg: 38, FN_veg: 657, IoU_veg: 0.6416
# TP_non_veg: 14483, FP_non_veg: 38, FN_non_veg: 1901, IoU_non_veg: 0.8819
# Image 641:
# TP_veg: 0, FP_veg: 0, FN_veg: 994, IoU_veg: 0.0000
# TP_non_veg: 15390, FP_non_veg: 0, FN_non_veg: 994, IoU_non_veg: 0.9393
# Image 642:
# TP_veg: 4692, FP_veg: 146, FN_veg: 1560, IoU_veg: 0.7334
# TP_non_veg: 10132, FP_non_veg: 146, FN_non_veg: 6252, IoU_non_veg: 0.6129
# Image 643:
# TP_veg: 4455, FP_veg: 63, FN_veg: 2148, IoU_veg: 0.6683
# TP_non_veg: 9781, FP_non_veg: 63, FN_non_veg: 6603, IoU_non_veg: 0.5947
# Image 644:
# TP_veg: 15844, FP_veg: 0, FN_veg: 540, IoU_veg: 0.9670
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 645:
# TP_veg: 13271, FP_veg: 0, FN_veg: 3113, IoU_veg: 0.8100
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 646:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 647:
# TP_veg: 8763, FP_veg: 0, FN_veg: 7621, IoU_veg: 0.5349
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 648:
# TP_veg: 13046, FP_veg: 0, FN_veg: 3337, IoU_veg: 0.7963
# TP_non_veg: 1, FP_non_veg: 0, FN_non_veg: 16383, IoU_non_veg: 0.0001
# Image 649:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 650:
# TP_veg: 9672, FP_veg: 0, FN_veg: 1503, IoU_veg: 0.8655
# TP_non_veg: 5209, FP_non_veg: 0, FN_non_veg: 11175, IoU_non_veg: 0.3179
# Image 651:
# TP_veg: 1211, FP_veg: 0, FN_veg: 518, IoU_veg: 0.7004
# TP_non_veg: 14655, FP_non_veg: 0, FN_non_veg: 1729, IoU_non_veg: 0.8945
# Image 652:
# TP_veg: 133, FP_veg: 1, FN_veg: 1651, IoU_veg: 0.0745
# TP_non_veg: 14600, FP_non_veg: 1, FN_non_veg: 1784, IoU_non_veg: 0.8911
# Image 653:
# TP_veg: 1486, FP_veg: 39, FN_veg: 1094, IoU_veg: 0.5674
# TP_non_veg: 13804, FP_non_veg: 39, FN_non_veg: 2580, IoU_non_veg: 0.8405
# Image 654:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 655:
# TP_veg: 0, FP_veg: 0, FN_veg: 739, IoU_veg: 0.0000
# TP_non_veg: 15645, FP_non_veg: 0, FN_non_veg: 739, IoU_non_veg: 0.9549
# Image 656:
# TP_veg: 2009, FP_veg: 0, FN_veg: 1247, IoU_veg: 0.6170
# TP_non_veg: 13128, FP_non_veg: 0, FN_non_veg: 3256, IoU_non_veg: 0.8013
# Image 657:
# TP_veg: 8908, FP_veg: 98, FN_veg: 1322, IoU_veg: 0.8625
# TP_non_veg: 6154, FP_non_veg: 98, FN_non_veg: 10230, IoU_non_veg: 0.3734
# Image 658:
# TP_veg: 12342, FP_veg: 0, FN_veg: 4042, IoU_veg: 0.7533
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 659:
# TP_veg: 13236, FP_veg: 0, FN_veg: 3148, IoU_veg: 0.8079
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 660:
# TP_veg: 3170, FP_veg: 0, FN_veg: 534, IoU_veg: 0.8558
# TP_non_veg: 12680, FP_non_veg: 0, FN_non_veg: 3704, IoU_non_veg: 0.7739
# Image 661:
# TP_veg: 3650, FP_veg: 87, FN_veg: 4118, IoU_veg: 0.4647
# TP_non_veg: 8616, FP_non_veg: 87, FN_non_veg: 7768, IoU_non_veg: 0.5231
# Image 662:
# TP_veg: 11998, FP_veg: 0, FN_veg: 2303, IoU_veg: 0.8390
# TP_non_veg: 2083, FP_non_veg: 0, FN_non_veg: 14301, IoU_non_veg: 0.1271
# Image 663:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 664:
# TP_veg: 15823, FP_veg: 0, FN_veg: 561, IoU_veg: 0.9658
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 665:
# TP_veg: 1706, FP_veg: 0, FN_veg: 1023, IoU_veg: 0.6251
# TP_non_veg: 13655, FP_non_veg: 0, FN_non_veg: 2729, IoU_non_veg: 0.8334
# Image 666:
# TP_veg: 616, FP_veg: 0, FN_veg: 1856, IoU_veg: 0.2492
# TP_non_veg: 13912, FP_non_veg: 0, FN_non_veg: 2472, IoU_non_veg: 0.8491
# Image 667:
# TP_veg: 8982, FP_veg: 20, FN_veg: 6636, IoU_veg: 0.5744
# TP_non_veg: 766, FP_non_veg: 20, FN_non_veg: 15618, IoU_non_veg: 0.0467
# Image 668:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 669:
# TP_veg: 0, FP_veg: 0, FN_veg: 87, IoU_veg: 0.0000
# TP_non_veg: 16297, FP_non_veg: 0, FN_non_veg: 87, IoU_non_veg: 0.9947
# Image 670:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 671:
# TP_veg: 2168, FP_veg: 0, FN_veg: 1319, IoU_veg: 0.6217
# TP_non_veg: 12897, FP_non_veg: 0, FN_non_veg: 3487, IoU_non_veg: 0.7872
# Image 672:
# TP_veg: 8257, FP_veg: 37, FN_veg: 3805, IoU_veg: 0.6825
# TP_non_veg: 4322, FP_non_veg: 37, FN_non_veg: 12062, IoU_non_veg: 0.2632
# Image 673:
# TP_veg: 5051, FP_veg: 166, FN_veg: 789, IoU_veg: 0.8410
# TP_non_veg: 10544, FP_non_veg: 166, FN_non_veg: 5840, IoU_non_veg: 0.6371
# Image 674:
# TP_veg: 0, FP_veg: 0, FN_veg: 2442, IoU_veg: 0.0000
# TP_non_veg: 13942, FP_non_veg: 0, FN_non_veg: 2442, IoU_non_veg: 0.8510
# Image 675:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 676:
# TP_veg: 2373, FP_veg: 11, FN_veg: 3285, IoU_veg: 0.4186
# TP_non_veg: 10726, FP_non_veg: 11, FN_non_veg: 5658, IoU_non_veg: 0.6542
# Image 677:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 678:
# TP_veg: 9157, FP_veg: 0, FN_veg: 7179, IoU_veg: 0.5605
# TP_non_veg: 48, FP_non_veg: 0, FN_non_veg: 16336, IoU_non_veg: 0.0029
# Image 679:
# TP_veg: 8194, FP_veg: 0, FN_veg: 8179, IoU_veg: 0.5005
# TP_non_veg: 11, FP_non_veg: 0, FN_non_veg: 16373, IoU_non_veg: 0.0007
# Image 680:
# TP_veg: 2677, FP_veg: 8, FN_veg: 3687, IoU_veg: 0.4201
# TP_non_veg: 10020, FP_non_veg: 8, FN_non_veg: 6364, IoU_non_veg: 0.6113
# Image 681:
# TP_veg: 8094, FP_veg: 0, FN_veg: 7493, IoU_veg: 0.5193
# TP_non_veg: 797, FP_non_veg: 0, FN_non_veg: 15587, IoU_non_veg: 0.0486
# Image 682:
# TP_veg: 4329, FP_veg: 55, FN_veg: 2760, IoU_veg: 0.6060
# TP_non_veg: 9295, FP_non_veg: 55, FN_non_veg: 7089, IoU_non_veg: 0.5654
# Image 683:
# TP_veg: 6668, FP_veg: 128, FN_veg: 4085, IoU_veg: 0.6128
# TP_non_veg: 5631, FP_non_veg: 128, FN_non_veg: 10753, IoU_non_veg: 0.3410
# Image 684:
# TP_veg: 13001, FP_veg: 2, FN_veg: 3064, IoU_veg: 0.8092
# TP_non_veg: 319, FP_non_veg: 2, FN_non_veg: 16065, IoU_non_veg: 0.0195
# Image 685:
# TP_veg: 7657, FP_veg: 0, FN_veg: 8727, IoU_veg: 0.4673
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 686:
# TP_veg: 12085, FP_veg: 0, FN_veg: 4299, IoU_veg: 0.7376
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 687:
# TP_veg: 5677, FP_veg: 9, FN_veg: 1054, IoU_veg: 0.8423
# TP_non_veg: 9653, FP_non_veg: 9, FN_non_veg: 6731, IoU_non_veg: 0.5888
# Image 688:
# TP_veg: 9, FP_veg: 0, FN_veg: 269, IoU_veg: 0.0324
# TP_non_veg: 16106, FP_non_veg: 0, FN_non_veg: 278, IoU_non_veg: 0.9830
# Image 689:
# TP_veg: 0, FP_veg: 0, FN_veg: 336, IoU_veg: 0.0000
# TP_non_veg: 16048, FP_non_veg: 0, FN_non_veg: 336, IoU_non_veg: 0.9795
# Image 690:
# TP_veg: 3405, FP_veg: 2, FN_veg: 5797, IoU_veg: 0.3699
# TP_non_veg: 7182, FP_non_veg: 2, FN_non_veg: 9202, IoU_non_veg: 0.4383
# Image 691:
# TP_veg: 0, FP_veg: 0, FN_veg: 3, IoU_veg: 0.0000
# TP_non_veg: 16381, FP_non_veg: 0, FN_non_veg: 3, IoU_non_veg: 0.9998
# Image 692:
# TP_veg: 6836, FP_veg: 0, FN_veg: 9548, IoU_veg: 0.4172
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 693:
# TP_veg: 7318, FP_veg: 0, FN_veg: 9066, IoU_veg: 0.4467
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 694:
# TP_veg: 12861, FP_veg: 0, FN_veg: 3523, IoU_veg: 0.7850
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 695:
# TP_veg: 16019, FP_veg: 0, FN_veg: 365, IoU_veg: 0.9777
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 696:
# TP_veg: 5841, FP_veg: 65, FN_veg: 3204, IoU_veg: 0.6412
# TP_non_veg: 7339, FP_non_veg: 65, FN_non_veg: 9045, IoU_non_veg: 0.4462
# Image 697:
# TP_veg: 246, FP_veg: 34, FN_veg: 199, IoU_veg: 0.5136
# TP_non_veg: 15939, FP_non_veg: 34, FN_non_veg: 445, IoU_non_veg: 0.9708
# Image 698:
# TP_veg: 0, FP_veg: 0, FN_veg: 2751, IoU_veg: 0.0000
# TP_non_veg: 13633, FP_non_veg: 0, FN_non_veg: 2751, IoU_non_veg: 0.8321
# Image 699:
# TP_veg: 1160, FP_veg: 0, FN_veg: 11245, IoU_veg: 0.0935
# TP_non_veg: 3979, FP_non_veg: 0, FN_non_veg: 12405, IoU_non_veg: 0.2429
# Image 700:
# TP_veg: 13703, FP_veg: 28, FN_veg: 727, IoU_veg: 0.9478
# TP_non_veg: 1954, FP_non_veg: 28, FN_non_veg: 14430, IoU_non_veg: 0.1191
# Image 701:
# TP_veg: 316, FP_veg: 40, FN_veg: 1500, IoU_veg: 0.1703
# TP_non_veg: 14568, FP_non_veg: 40, FN_non_veg: 1816, IoU_non_veg: 0.8870
# Image 702:
# TP_veg: 0, FP_veg: 0, FN_veg: 186, IoU_veg: 0.0000
# TP_non_veg: 16198, FP_non_veg: 0, FN_non_veg: 186, IoU_non_veg: 0.9886
# Image 703:
# TP_veg: 0, FP_veg: 0, FN_veg: 462, IoU_veg: 0.0000
# TP_non_veg: 15922, FP_non_veg: 0, FN_non_veg: 462, IoU_non_veg: 0.9718
# Image 704:
# TP_veg: 4514, FP_veg: 4, FN_veg: 5783, IoU_veg: 0.4382
# TP_non_veg: 6087, FP_non_veg: 4, FN_non_veg: 10297, IoU_non_veg: 0.3714
# Image 705:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 706:
# TP_veg: 150, FP_veg: 0, FN_veg: 7585, IoU_veg: 0.0194
# TP_non_veg: 8649, FP_non_veg: 0, FN_non_veg: 7735, IoU_non_veg: 0.5279
# Image 707:
# TP_veg: 10976, FP_veg: 0, FN_veg: 5408, IoU_veg: 0.6699
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 708:
# TP_veg: 16380, FP_veg: 0, FN_veg: 4, IoU_veg: 0.9998
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 709:
# TP_veg: 12394, FP_veg: 0, FN_veg: 3990, IoU_veg: 0.7565
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 710:
# TP_veg: 485, FP_veg: 0, FN_veg: 3383, IoU_veg: 0.1254
# TP_non_veg: 12516, FP_non_veg: 0, FN_non_veg: 3868, IoU_non_veg: 0.7639
# Image 711:
# TP_veg: 5107, FP_veg: 139, FN_veg: 3764, IoU_veg: 0.5668
# TP_non_veg: 7513, FP_non_veg: 139, FN_non_veg: 8871, IoU_non_veg: 0.4547
# Image 712:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 713:
# TP_veg: 199, FP_veg: 0, FN_veg: 239, IoU_veg: 0.4543
# TP_non_veg: 15946, FP_non_veg: 0, FN_non_veg: 438, IoU_non_veg: 0.9733
# Image 714:
# TP_veg: 2503, FP_veg: 98, FN_veg: 198, IoU_veg: 0.8942
# TP_non_veg: 13683, FP_non_veg: 98, FN_non_veg: 2701, IoU_non_veg: 0.8302
# Image 715:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 716:
# TP_veg: 126, FP_veg: 0, FN_veg: 732, IoU_veg: 0.1469
# TP_non_veg: 15526, FP_non_veg: 0, FN_non_veg: 858, IoU_non_veg: 0.9476
# Image 717:
# TP_veg: 10258, FP_veg: 7, FN_veg: 3360, IoU_veg: 0.7529
# TP_non_veg: 2766, FP_non_veg: 7, FN_non_veg: 13618, IoU_non_veg: 0.1688
# Image 718:
# TP_veg: 6733, FP_veg: 40, FN_veg: 5011, IoU_veg: 0.5714
# TP_non_veg: 4640, FP_non_veg: 40, FN_non_veg: 11744, IoU_non_veg: 0.2825
# Image 719:
# TP_veg: 898, FP_veg: 2, FN_veg: 724, IoU_veg: 0.5530
# TP_non_veg: 14762, FP_non_veg: 2, FN_non_veg: 1622, IoU_non_veg: 0.9009
# Image 720:
# TP_veg: 11553, FP_veg: 0, FN_veg: 4052, IoU_veg: 0.7403
# TP_non_veg: 779, FP_non_veg: 0, FN_non_veg: 15605, IoU_non_veg: 0.0475
# Image 721:
# TP_veg: 14860, FP_veg: 0, FN_veg: 1524, IoU_veg: 0.9070
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 722:
# TP_veg: 16384, FP_veg: 0, FN_veg: 0, IoU_veg: 1.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 723:
# TP_veg: 14613, FP_veg: 0, FN_veg: 1771, IoU_veg: 0.8919
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 724:
# TP_veg: 1914, FP_veg: 0, FN_veg: 3418, IoU_veg: 0.3590
# TP_non_veg: 11052, FP_non_veg: 0, FN_non_veg: 5332, IoU_non_veg: 0.6746
# Image 725:
# TP_veg: 1302, FP_veg: 10, FN_veg: 1909, IoU_veg: 0.4042
# TP_non_veg: 13173, FP_non_veg: 10, FN_non_veg: 3211, IoU_non_veg: 0.8035
# Image 726:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 727:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 728:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 729:
# TP_veg: 365, FP_veg: 0, FN_veg: 1441, IoU_veg: 0.2021
# TP_non_veg: 14578, FP_non_veg: 0, FN_non_veg: 1806, IoU_non_veg: 0.8898
# Image 730:
# TP_veg: 550, FP_veg: 1, FN_veg: 621, IoU_veg: 0.4693
# TP_non_veg: 15213, FP_non_veg: 1, FN_non_veg: 1171, IoU_non_veg: 0.9285
# Image 731:
# TP_veg: 11355, FP_veg: 0, FN_veg: 2102, IoU_veg: 0.8438
# TP_non_veg: 2927, FP_non_veg: 0, FN_non_veg: 13457, IoU_non_veg: 0.1786
# Image 732:
# TP_veg: 8123, FP_veg: 0, FN_veg: 8261, IoU_veg: 0.4958
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 733:
# TP_veg: 7, FP_veg: 0, FN_veg: 2835, IoU_veg: 0.0025
# TP_non_veg: 13542, FP_non_veg: 0, FN_non_veg: 2842, IoU_non_veg: 0.8265
# Image 734:
# TP_veg: 15111, FP_veg: 0, FN_veg: 1273, IoU_veg: 0.9223
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 735:
# TP_veg: 14812, FP_veg: 0, FN_veg: 1572, IoU_veg: 0.9041
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 736:
# TP_veg: 14281, FP_veg: 0, FN_veg: 2103, IoU_veg: 0.8716
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 737:
# TP_veg: 7426, FP_veg: 0, FN_veg: 8958, IoU_veg: 0.4532
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 738:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 739:
# TP_veg: 675, FP_veg: 5, FN_veg: 158, IoU_veg: 0.8055
# TP_non_veg: 15551, FP_non_veg: 5, FN_non_veg: 833, IoU_non_veg: 0.9489
# Image 740:
# TP_veg: 1744, FP_veg: 79, FN_veg: 2209, IoU_veg: 0.4325
# TP_non_veg: 12431, FP_non_veg: 79, FN_non_veg: 3953, IoU_non_veg: 0.7551
# Image 741:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 742:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 743:
# TP_veg: 2893, FP_veg: 18, FN_veg: 1850, IoU_veg: 0.6076
# TP_non_veg: 11641, FP_non_veg: 18, FN_non_veg: 4743, IoU_non_veg: 0.7097
# Image 744:
# TP_veg: 246, FP_veg: 2, FN_veg: 335, IoU_veg: 0.4220
# TP_non_veg: 15803, FP_non_veg: 2, FN_non_veg: 581, IoU_non_veg: 0.9644
# Image 745:
# TP_veg: 12, FP_veg: 0, FN_veg: 935, IoU_veg: 0.0127
# TP_non_veg: 15437, FP_non_veg: 0, FN_non_veg: 947, IoU_non_veg: 0.9422
# Image 746:
# TP_veg: 12629, FP_veg: 0, FN_veg: 1531, IoU_veg: 0.8919
# TP_non_veg: 2224, FP_non_veg: 0, FN_non_veg: 14160, IoU_non_veg: 0.1357
# Image 747:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 748:
# TP_veg: 14435, FP_veg: 0, FN_veg: 1949, IoU_veg: 0.8810
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 749:
# TP_veg: 16353, FP_veg: 0, FN_veg: 31, IoU_veg: 0.9981
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 750:
# TP_veg: 7942, FP_veg: 0, FN_veg: 8442, IoU_veg: 0.4847
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 751:
# TP_veg: 6948, FP_veg: 0, FN_veg: 9436, IoU_veg: 0.4241
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 752:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 753:
# TP_veg: 3, FP_veg: 1, FN_veg: 33, IoU_veg: 0.0811
# TP_non_veg: 16348, FP_non_veg: 1, FN_non_veg: 36, IoU_non_veg: 0.9977
# Image 754:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 755:
# TP_veg: 1737, FP_veg: 22, FN_veg: 2451, IoU_veg: 0.4126
# TP_non_veg: 12196, FP_non_veg: 22, FN_non_veg: 4188, IoU_non_veg: 0.7434
# Image 756:
# TP_veg: 533, FP_veg: 0, FN_veg: 1929, IoU_veg: 0.2165
# TP_non_veg: 13922, FP_non_veg: 0, FN_non_veg: 2462, IoU_non_veg: 0.8497
# Image 757:
# TP_veg: 266, FP_veg: 2, FN_veg: 419, IoU_veg: 0.3872
# TP_non_veg: 15699, FP_non_veg: 2, FN_non_veg: 685, IoU_non_veg: 0.9581

# %%
# mean_iou_vegetation = np.mean(IoU_vegetation)
# mean_iou_non_vegetation = np.mean(IoU_non_vegetation)
# mean_all_iou = (mean_iou_vegetation + mean_iou_non_vegetation) / 2
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_iou_vegetation * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_iou_non_vegetation * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_all_iou * 100), "%")

# %%
tp_veg_overall = np.sum(TP_vegetation)
fp_veg_overall = np.sum(FP_vegetation)
fn_veg_overall = np.sum(FN_vegetation)

print("TP Vegetation: ", tp_veg_overall)
print("FP Vegetation: ", fp_veg_overall)
print("FN Vegetation: ", fn_veg_overall)

IoU_veg_overall = tp_veg_overall / (tp_veg_overall + fp_veg_overall + fn_veg_overall)
print("IoU Vegetation: ", IoU_veg_overall)

tp_non_veg_overall = np.sum(TP_non_vegetation)
fp_non_veg_overall = np.sum(FP_non_vegetation)
fn_non_veg_overall = np.sum(FN_non_vegetation)

print("\nTP Non-Vegetation: ", tp_non_veg_overall)
print("FP Non-Vegetation: ", fp_non_veg_overall)
print("FN Non-Vegetation: ", fn_non_veg_overall)

IoU_non_veg_overall = tp_non_veg_overall / (tp_non_veg_overall + fp_non_veg_overall + fn_non_veg_overall)
print("IoU Non-Vegetation: ", IoU_non_veg_overall)

IoU_overall = (IoU_veg_overall + IoU_non_veg_overall)/2
print("\nIoU Overall: ", IoU_overall)
# Out:
# TP Vegetation:  2445840
# FP Vegetation:  12599
# FN Vegetation:  2057132
# IoU Vegetation:  0.5416457852174177
#
# TP Non-Vegetation:  7899716
# FP Non-Vegetation:  12599
# FN Non-Vegetation:  4502972
# IoU Non-Vegetation:  0.6362894389795419
#
# IoU Overall:  0.5889676120984798

# %% [markdown]
# ========================================================================================================

# %%
vegetation_color = [0, 255, 0]  # Green
non_vegetation_color = [0, 0, 255] # Blue

indexing = 1600
input_image = images_load[indexing]
ground_truth = ground_truths[indexing]
features_get = fe.extract(input_image)

# Preprocess the input image
input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_reshaped.reshape(-1, 3)  # Remove the transpose operation here

# Predict segmentation mask
predicted_mask = model_loaded.forward(features)
predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)

# Create segmented image
segmented_image[predicted_mask == 0] = non_vegetation_color
segmented_image[predicted_mask == 1] = vegetation_color

# Visualize input image, ground truth, and segmented image
plt.figure(figsize=(12, 5))
plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Input Image')

plt.subplot(1, 3, 2)
plt.imshow(features_get)
plt.title('Feature Maps')

plt.subplot(1, 3, 3)
plt.imshow(ground_truth)
plt.title('Ground Truth')

# plt.subplot(1, 3, 3)
# plt.imshow(segmented_image)
# plt.title('Segmented Image')

plt.show()

# Function to compare pixel values at specific coordinates
def compare_pixels(x, y):
    input_pixel = input_image[y, x]
    ground_truth_pixel = ground_truth[y, x]
    segmented_pixel = segmented_image[y, x]
    
    print(f"Coordinates (x, y): ({x}, {y})")
    print(f"Input Image Pixel Value:\t{input_pixel}")
    print(f"Ground Truth Pixel Value:\t{ground_truth_pixel}")
    print(f"Segmented Image Pixel Value:\t{segmented_pixel}")

# Example coordinates to compare
x, y = 0, 1  # Change this to any coordinate you want to check
compare_pixels(x, y)
# Out:
# Coordinates (x, y): (0, 1)
# Input Image Pixel Value:	[184  76  86]
# Ground Truth Pixel Value:	[  0 255   0]
# Segmented Image Pixel Value:	[  0 255   0]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Define colors for segmentation
vegetation_color = [0, 255, 0]  # Green
non_vegetation_color = [0, 0, 255]  # Blue

# Index for the current image
indexing = 5
input_image = images_load[indexing]
ground_truth = ground_truths[indexing]
features_get = fe.extract(input_image)

# Preprocess the input image
input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_reshaped.reshape(-1, 3)

# Predict segmentation mask and capture the last layer's output
output_logits = model_loaded.forward(features)
predicted_mask = output_logits.argmax(axis=1).reshape(128, 128)
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)

# Create segmented image
segmented_image[predicted_mask == 0] = non_vegetation_color
segmented_image[predicted_mask == 1] = vegetation_color

# Visualize input image, ground truth, and segmented image
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Input Image')

# plt.subplot(1, 4, 2)
# plt.imshow(features_get)
# plt.title('Feature Maps')

plt.subplot(1, 3, 2)
plt.imshow(ground_truth)
plt.title('Ground Truth')

plt.subplot(1, 3, 3)
plt.imshow(segmented_image)
plt.title('Predicted Pixel Class Image')

plt.show()

# Function to compare pixel values at specific coordinates and the raw prediction values
def compare_pixels(x, y):
    input_pixel = input_image[y, x]
    ground_truth_pixel = ground_truth[y, x]
    segmented_pixel = segmented_image[y, x]
    raw_prediction = output_logits[y * 128 + x]  # Get the raw prediction values

    print("Pixel Class -> [0 255 0] = vegetation, [0 0 255] = non-vegetation")
    print(f"Coordinates (x, y):\t\t\t\t({x}, {y})")
    print(f"Input Image Pixel Value:\t\t\t{input_pixel}")
    print(f"Prediction Values (non-vegetation, vegetation):\t{raw_prediction}")
    print(f"Class Prediction Image Pixel:\t\t\t{segmented_pixel}")
    print(f"Ground Truth Pixel Value:\t\t\t{ground_truth_pixel}")
    

# Example coordinates to compare
x, y = 0,0   # Change this to any coordinate you want to check
compare_pixels(x, y)
# Out:
# Pixel Class -> [0 255 0] = vegetation, [0 0 255] = non-vegetation
# Coordinates (x, y):				(0, 0)
# Input Image Pixel Value:			[185  81  85]
# Prediction Values (non-vegetation, vegetation):	[0.05899952 0.94100048]
# Class Prediction Image Pixel:			[  0 255   0]
# Ground Truth Pixel Value:			[  0 255 255]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define color classes in BGR (OpenCV uses BGR by default)
vegetation_colors = [np.array([0, 255, 0]), np.array([0, 255, 255])]
non_vegetation_colors = [np.array([255, 255, 255]), np.array([255, 0, 0]), np.array([0, 0, 255]), np.array([255, 255, 0])]

# 5, 1506, 1602, 1813
# Load the ground truth image
index = 5
input_image = images_load[index]
ground_truth = ground_truths[index]
features_get = fe.extract(input_image)
ground_truth_image = ground_truth

# Initialize counters
vegetation_count = 0
non_vegetation_count = 0

# Check each pixel in the ground truth image
for y in range(ground_truth_image.shape[0]):
    for x in range(ground_truth_image.shape[1]):
        pixel = ground_truth_image[y, x]
        if any(np.array_equal(pixel, color) for color in vegetation_colors):
            vegetation_count += 1
        elif any(np.array_equal(pixel, color) for color in non_vegetation_colors):
            non_vegetation_count += 1

# Print the results
print("Total Pixels:", vegetation_count + non_vegetation_count)
print(f"Total vegetation pixels: {vegetation_count}")
print(f"Total non-vegetation pixels: {non_vegetation_count}")

# Preprocess the input image
input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_reshaped.reshape(-1, 3)  # Remove the transpose operation here

# Predict segmentation mask
predicted_mask = model_loaded.forward(features)
predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)

# Create segmented image
segmented_image[predicted_mask == 0] = non_vegetation_color
segmented_image[predicted_mask == 1] = vegetation_color

# Load the predicted image (assuming you have it as 'predicted_image')
predicted_image = segmented_image  # Replace with actual predicted image

# Initialize counters for predicted image
vegetation_count_pred = 0
non_vegetation_count_pred = 0

# Check each pixel in the predicted image
for y in range(predicted_image.shape[0]):
    for x in range(predicted_image.shape[1]):
        pixel = predicted_image[y, x]
        if any(np.array_equal(pixel, color) for color in vegetation_colors):
            vegetation_count_pred += 1
        elif any(np.array_equal(pixel, color) for color in non_vegetation_colors):
            non_vegetation_count_pred += 1

# Print the predicted results
print("Predicted Image:")
print("Total Pixels:", vegetation_count_pred + non_vegetation_count_pred)
print(f"Total vegetation pixels: {vegetation_count_pred}")
print(f"Total non-vegetation pixels: {non_vegetation_count_pred}")

# Optionally, visualize the ground truth and predicted images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(ground_truth_image)
plt.title('Ground Truth Image')

plt.subplot(1, 2, 2)
plt.imshow(predicted_image)
plt.title('Predicted Image')

plt.show()
# Out:
# Total Pixels: 16384
# Total vegetation pixels: 14588
# Total non-vegetation pixels: 1796
# Predicted Image:
# Total Pixels: 16384
# Total vegetation pixels: 8517
# Total non-vegetation pixels: 7867

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Define color classes in BGR (OpenCV uses BGR by default)
vegetation_colors = [np.array([0, 255, 0]), np.array([0, 255, 255])]
non_vegetation_colors = [np.array([255, 255, 255]), np.array([255, 0, 0]), np.array([0, 0, 255]), np.array([255, 255, 0])]

# Example indices
indices = [5, 1506, 1602, 1813]

# Select the index
index = 1813

# Load the input image and ground truth
input_image = images_load[index]
ground_truth = ground_truths[index]

# Extract features
features_get = fe.extract(input_image)

# Initialize counters for the ground truth image
vegetation_count_gt = 0
non_vegetation_count_gt = 0

# Check each pixel in the ground truth image
for y in range(ground_truth.shape[0]):
    for x in range(ground_truth.shape[1]):
        pixel = ground_truth[y, x]
        if any(np.array_equal(pixel, color) for color in vegetation_colors):
            vegetation_count_gt += 1
        elif any(np.array_equal(pixel, color) for color in non_vegetation_colors):
            non_vegetation_count_gt += 1

# Print the ground truth results
print("Ground Truth:")
print("Total Pixels:", vegetation_count_gt + non_vegetation_count_gt)
print(f"Total vegetation pixels: {vegetation_count_gt}")
print(f"Total non-vegetation pixels: {non_vegetation_count_gt}")

# Preprocess the input image for the model
input_image_resized = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_resized.reshape(-1, 3)

# Predict segmentation mask
predicted_mask = model_loaded.forward(features)
predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

# Create segmented image
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)
segmented_image[predicted_mask == 0] = non_vegetation_colors[0]  # Assuming non-vegetation class 0
segmented_image[predicted_mask == 1] = vegetation_colors[0]  # Assuming vegetation class 1

# Initialize counters for the predicted image
vegetation_count_pred = 0
non_vegetation_count_pred = 0

# Check each pixel in the predicted image
for y in range(segmented_image.shape[0]):
    for x in range(segmented_image.shape[1]):
        pixel = segmented_image[y, x]
        if any(np.array_equal(pixel, color) for color in vegetation_colors):
            vegetation_count_pred += 1
        elif any(np.array_equal(pixel, color) for color in non_vegetation_colors):
            non_vegetation_count_pred += 1

# Print the predicted results
print("Predicted Image:")
print("Total Pixels:", vegetation_count_pred + non_vegetation_count_pred)
print(f"Total vegetation pixels: {vegetation_count_pred}")
print(f"Total non-vegetation pixels: {non_vegetation_count_pred}")

# Compare the results
print("\nComparison:")
print(f"Difference in vegetation pixels: {vegetation_count_pred - vegetation_count_gt}")
print(f"Difference in non-vegetation pixels: {non_vegetation_count_pred - non_vegetation_count_gt}")

# Visualization
categories = ['Vegetation', 'Non-Vegetation']
ground_truth_counts = [vegetation_count_gt, non_vegetation_count_gt]
predicted_counts = [vegetation_count_pred, non_vegetation_count_pred]

x = np.arange(len(categories))
width = 0.35

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, ground_truth_counts, width, label='Ground Truth')
bars2 = ax.bar(x + width/2, predicted_counts, width, label='Predicted')

ax.set_xlabel('Category')
ax.set_ylabel('Pixel Count')
ax.set_title('Pixel Count Comparison between Ground Truth and Predicted Image')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate('{}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.show()
# Out:
# Ground Truth:
# Total Pixels: 16384
# Total vegetation pixels: 9250
# Total non-vegetation pixels: 7134
# Predicted Image:
# Total Pixels: 16384
# Total vegetation pixels: 8323
# Total non-vegetation pixels: 8061
#
# Comparison:
# Difference in vegetation pixels: -927
# Difference in non-vegetation pixels: 927

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import math

# Load images and ground truth labels
images_path = 'patching_fix/patch_image'
feature_images_path = 'patching_fix/feature_extract'
ground_truths_path = 'patching_fix/patch_ground'

images_load = dp.load_images_from_folder(images_path)
feature_images_load = dp.load_images_from_folder(feature_images_path)
ground_truths = dp.load_ground_truth_from_folder(ground_truths_path)

feature_images_train = feature_images_load[:math.ceil(len(feature_images_load)*0.7)] 
image_label_train = ground_truths[:math.ceil(len(ground_truths)*0.7)]

image_test = images_load[math.ceil(len(images_load)*0.7):]
image_label_test = ground_truths[math.ceil(len(ground_truths)*0.7):]

# Define color classes in BGR (OpenCV uses BGR by default)
vegetation_colors = [np.array([0, 255, 0]), np.array([0, 255, 255])]
non_vegetation_colors = [np.array([255, 255, 255]), np.array([255, 0, 0]), np.array([0, 0, 255]), np.array([255, 255, 0])]

# Initialize total counters for ground truth and predicted images
total_vegetation_count_gt = 0
total_non_vegetation_count_gt = 0
total_vegetation_count_pred = 0
total_non_vegetation_count_pred = 0

# Iterate through all images
for index in range(len(images_load)):
    # Load the input image and ground truth
    input_image = images_load[index]
    ground_truth = ground_truths[index]

    # Extract features
    features_get = fe.extract(input_image)

    # Initialize counters for the ground truth image
    vegetation_count_gt = 0
    non_vegetation_count_gt = 0

    # Check each pixel in the ground truth image
    for y in range(ground_truth.shape[0]):
        for x in range(ground_truth.shape[1]):
            pixel = ground_truth[y, x]
            if any(np.array_equal(pixel, color) for color in vegetation_colors):
                vegetation_count_gt += 1
            elif any(np.array_equal(pixel, color) for color in non_vegetation_colors):
                non_vegetation_count_gt += 1

    # Add to total counts
    total_vegetation_count_gt += vegetation_count_gt
    total_non_vegetation_count_gt += non_vegetation_count_gt

    # Preprocess the input image for the model
    input_image_resized = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_resized.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Create segmented image
    segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)
    segmented_image[predicted_mask == 0] = non_vegetation_colors[0]  # Assuming non-vegetation class 0
    segmented_image[predicted_mask == 1] = vegetation_colors[0]  # Assuming vegetation class 1

    # Initialize counters for the predicted image
    vegetation_count_pred = 0
    non_vegetation_count_pred = 0

    # Check each pixel in the predicted image
    for y in range(segmented_image.shape[0]):
        for x in range(segmented_image.shape[1]):
            pixel = segmented_image[y, x]
            if any(np.array_equal(pixel, color) for color in vegetation_colors):
                vegetation_count_pred += 1
            elif any(np.array_equal(pixel, color) for color in non_vegetation_colors):
                non_vegetation_count_pred += 1

    # Add to total counts
    total_vegetation_count_pred += vegetation_count_pred
    total_non_vegetation_count_pred += non_vegetation_count_pred

# Calculate total pixels in ground truth and predicted images
total_pixels_gt = total_vegetation_count_gt + total_non_vegetation_count_gt
total_pixels_pred = total_vegetation_count_pred + total_non_vegetation_count_pred

# Calculate distribution percentages
vegetation_percentage_gt = (total_vegetation_count_gt / total_pixels_gt) * 100
non_vegetation_percentage_gt = (total_non_vegetation_count_gt / total_pixels_gt) * 100
vegetation_percentage_pred = (total_vegetation_count_pred / total_pixels_pred) * 100
non_vegetation_percentage_pred = (total_non_vegetation_count_pred / total_pixels_pred) * 100

# Print the total results
print("Ground Truth:")
print("Total Pixels:", total_pixels_gt)
print(f"Total vegetation pixels: {total_vegetation_count_gt} ({vegetation_percentage_gt:.2f}%)")
print(f"Total non-vegetation pixels: {total_non_vegetation_count_gt} ({non_vegetation_percentage_gt:.2f}%)")

print("Predicted Image:")
print("Total Pixels:", total_pixels_pred)
print(f"Total vegetation pixels: {total_vegetation_count_pred} ({vegetation_percentage_pred:.2f}%)")
print(f"Total non-vegetation pixels: {total_non_vegetation_count_pred} ({non_vegetation_percentage_pred:.2f}%)")
# Out:
# Ground Truth:
# Total Pixels: 41385984
# Total vegetation pixels: 17036636 (41.17%)
# Total non-vegetation pixels: 24349348 (58.83%)
# Predicted Image:
# Total Pixels: 41385984
# Total vegetation pixels: 9793303 (23.66%)
# Total non-vegetation pixels: 31592681 (76.34%)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data from the previous calculations
total_pixels_gt = 41385984
total_vegetation_count_gt = 17036636 
total_non_vegetation_count_gt = 24349348 
vegetation_percentage_gt = (total_vegetation_count_gt / total_pixels_gt) * 100
non_vegetation_percentage_gt = (total_non_vegetation_count_gt / total_pixels_gt) * 100

total_pixels_pred = 41385984
total_vegetation_count_pred = 9793303 
total_non_vegetation_count_pred = 31592681 
vegetation_percentage_pred = (total_vegetation_count_pred / total_pixels_pred) * 100
non_vegetation_percentage_pred = (total_non_vegetation_count_pred / total_pixels_pred) * 100

# Print the total results
print("Ground Truth:")
print("Total Pixels:", total_pixels_gt)
print(f"Total vegetation pixels: {total_vegetation_count_gt} ({vegetation_percentage_gt:.2f}%)")
print(f"Total non-vegetation pixels: {total_non_vegetation_count_gt} ({non_vegetation_percentage_gt:.2f}%)")

print("Predicted Image:")
print("Total Pixels:", total_pixels_pred)
print(f"Total vegetation pixels: {total_vegetation_count_pred} ({vegetation_percentage_pred:.2f}%)")
print(f"Total non-vegetation pixels: {total_non_vegetation_count_pred} ({non_vegetation_percentage_pred:.2f}%)")

# Visualization
categories = ['Vegetation', 'Non-Vegetation']
ground_truth_counts = [vegetation_percentage_gt, non_vegetation_percentage_gt]
predicted_counts = [vegetation_percentage_pred, non_vegetation_percentage_pred]

x = np.arange(len(categories))
width = 0.35

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, ground_truth_counts, width, label='Ground Truth')
bars2 = ax.bar(x + width/2, predicted_counts, width, label='Predicted')

ax.set_xlabel('Category')
ax.set_ylabel('Percentage of Pixels')
ax.set_title('Pixel Distribution Comparison between Ground Truth and Predicted Image')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.show()
# Out:
# Ground Truth:
# Total Pixels: 41385984
# Total vegetation pixels: 17036636 (41.17%)
# Total non-vegetation pixels: 24349348 (58.83%)
# Predicted Image:
# Total Pixels: 41385984
# Total vegetation pixels: 9793303 (23.66%)
# Total non-vegetation pixels: 31592681 (76.34%)

# %%
# vegetation_color = [0, 255, 0]  # Green
# non_vegetation_color = [0, 0, 255] # Blue

# # Initialize lists for TP, FP, FN, and IoU
# vegetation_TP = []
# vegetation_FP = []
# vegetation_FN = []
# non_vegetation_TP = []
# non_vegetation_FP = []
# non_vegetation_FN = []
# IoU_vegetation = []
# IoU_non_vegetation = []

# # Loop over testing images
# for i in range(len(image_test)):
#     # Reset counts for each image
#     TP_vegetation = 0
#     FP_vegetation = 0
#     FN_vegetation = 0
#     TP_non_vegetation = 0
#     FP_non_vegetation = 0
#     FN_non_vegetation = 0
    
#     input_image = image_test[i]
#     ground_truth = image_label_test[i]

#     # Preprocess the input image
#     input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
#     features = input_image_reshaped.reshape(-1, 3)

#     # Predict segmentation mask
#     predicted_mask = model_loaded.forward(features)
#     predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

#     # Convert ground truth to single-channel binary masks for vegetation and non-vegetation
#     vegetation_ground_truth = (ground_truth == [0, 255, 0]).all(axis=2)
#     non_vegetation_ground_truth = ~vegetation_ground_truth

#     # Iterate over each pixel in the patch
#     for y in range(128):
#         for x in range(128):
#             # Check if the pixel is vegetation in both prediction and ground truth
#             if vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 TP_vegetation += 1
#             # Check if the pixel is non-vegetation in both prediction and ground truth
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 TP_non_vegetation += 1
#             # Check if the pixel is vegetation in ground truth but non-vegetation in prediction
#             elif vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 FN_vegetation += 1
#             # Check if the pixel is non-vegetation in ground truth but vegetation in prediction
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 FP_non_vegetation += 1
                
#     # Append TP, FP, FN counts for both classes
#     vegetation_TP.append(TP_vegetation)
#     vegetation_FP.append(FP_vegetation)
#     vegetation_FN.append(FN_vegetation)
#     non_vegetation_TP.append(TP_non_vegetation)
#     non_vegetation_FP.append(FP_non_vegetation)
#     non_vegetation_FN.append(FN_non_vegetation)

#     # Calculate IoU for both classes if the denominator is not zero
#     if (TP_vegetation + FP_vegetation + FN_vegetation) != 0:
#         IoU_vegetation.append(TP_vegetation / (TP_vegetation + FP_vegetation + FN_vegetation))
#     else:
#         IoU_vegetation.append(0.0)

#     if (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation) != 0:
#         IoU_non_vegetation.append(TP_non_vegetation / (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation))
#     else:
#         IoU_non_vegetation.append(0.0)

#     print("===============================Image {}==================================".format(i+1))
#     print("vegetation_TP: {}, vegetation_FP: {}, vegetation_FN: {}\nnon_vegetation_TP: {}, non_vegetation_FP: {}, non_vegetation_FN: {}".format(TP_vegetation, FP_vegetation, FN_vegetation, TP_non_vegetation, FP_non_vegetation, FN_non_vegetation))
#     print("Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}, Mean IoU: {:.4f}".format(IoU_vegetation[-1], IoU_non_vegetation[-1], (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2))
#     # Visualize input image, ground truth, and segmented image
#     # plt.figure(figsize=(12, 5))
#     # plt.subplot(1, 3, 1)
#     # plt.imshow(input_image)
#     # plt.title('Input Image')
    
#     # plt.subplot(1, 3, 2)
#     # plt.imshow(ground_truth)
#     # plt.title('Ground Truth')
    
#     # # Create segmented image
#     # segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)
#     # segmented_image[predicted_mask == 0] = non_vegetation_color
#     # segmented_image[predicted_mask == 1] = vegetation_color
    
#     # # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
#     # plt.subplot(1, 3, 3)
#     # plt.imshow(segmented_image)
#     # IoU = (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2
#     # plt.title('Segmented Image (Mean IoU: {:.4f})'.format(IoU))
    
#     # plt.show()

# %%
# # Compute mean IoU across all images for vegetation and non-vegetation classes
# mean_IoU_vegetation_class = sum(IoU_vegetation) / len(IoU_vegetation)
# mean_IoU_non_vegetation_class = sum(IoU_non_vegetation) / len(IoU_non_vegetation)
# mean_IoU_overall = (mean_IoU_vegetation_class + mean_IoU_non_vegetation_class) / 2

# # Print mean IoU for both classes
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_IoU_vegetation_class * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_IoU_non_vegetation_class * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_IoU_overall * 100), "%")
