# %%
from utils import conv
from utils import NN as nn
from utils import dataprepare as dp
from utils import Feature_extract as fe

import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
# Load the saved weights
def load_weights(filename):
    with open(filename, 'rb') as f:
        data = np.load(f)
        weights_hidden_output = data['weights_hidden_output']
        bias_hidden_output = data['bias_hidden_output']
        weights_input_hidden = data['weights_input_hidden']
        bias_input_hidden = data['bias_input_hidden']
    return weights_hidden_output, bias_hidden_output, weights_input_hidden, bias_input_hidden

# %%
# Load images and ground truth labels
images_path = 'patching_fix/patch_image'
feature_images_path = 'patching_fix/feature_extract'
ground_truths_path = 'patching_fix/patch_ground'

images_load = dp.load_images_from_folder(images_path)
feature_images_load = dp.load_images_from_folder(feature_images_path)
ground_truths = dp.load_ground_truth_from_folder(ground_truths_path)

# %%
feature_images_train = feature_images_load[:math.ceil(len(feature_images_load)*0.8)] 
image_label_train = ground_truths[:math.ceil(len(ground_truths)*0.8)]

image_test = images_load[math.ceil(len(images_load)*0.8):]
image_label_test = ground_truths[math.ceil(len(ground_truths)*0.8):]

# %%
# Prepare data
X_test, y_test = dp.prepare_data(image_test, image_label_test)
# Normalize the features
X__test_normalized = X_test / 255.0

# %%
# input_size = X__test_normalized.shape[0]
input_size = 3
hidden_size = 2  # hidden neuron
output_size = 2  # 2 classes: vegetation and non-vegetation

# %%
# Load weights for testing
weights_hidden_output, bias_hidden_output, weights_input_hidden, bias_input_hidden = load_weights('3. Bobot_skenario_3.npz')

# Initialize the neural network with the loaded weights
model_loaded = nn.NeuralNetwork(input_size, hidden_size, output_size)
model_loaded.weights_hidden_output = weights_hidden_output
model_loaded.bias_hidden_output = bias_hidden_output
model_loaded.weights_input_hidden = weights_input_hidden
model_loaded.bias_input_hidden = bias_input_hidden

# %%
print('Load Bobot dan bias optimal')
print('Bobot hidden-output:')
print(model_loaded.weights_hidden_output)
print('Bias hidden-output:')
print(model_loaded.bias_hidden_output[0][0])
print('Bobot input-hidden:')
print(model_loaded.weights_input_hidden)
print('Bias input-hidden:')
print(model_loaded.bias_input_hidden[0][0])
# Out:
# Load Bobot dan bias optimal
# Bobot hidden-output:
# [[-0.78224552  0.78224552]
#  [ 3.94819671 -3.94819671]]
# Bias hidden-output:
# 1.0202716058236792
# Bobot input-hidden:
# [[ 45.92721522 -13.20697089]
#  [-60.70172361  -6.89439074]
#  [-37.97780135  -2.57614358]]
# Bias input-hidden:
# 1.0770760576988978

# %%
TP = 0  # True Positives
FP = 0  # False Positives
FN = 0  # False Negatives
TN = 0  # True Negatives

# Loop over testing images
for i in range(len(image_test)):
    TPi = 0  # True Positives index
    FPi = 0  # False Positives index
    FNi = 0  # False Negatives index
    TNi = 0  # True Negatives index

    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN, TN for the current image
    for row in range(predicted_mask.shape[0]):
        for col in range(predicted_mask.shape[1]):
            if predicted_mask[row, col] == 1 and vegetation_ground_truth[row, col]:
                TPi += 1
                TP += 1
            elif predicted_mask[row, col] == 1 and not vegetation_ground_truth[row, col]:
                FPi += 1
                FP += 1
            elif predicted_mask[row, col] == 0 and vegetation_ground_truth[row, col]:
                FNi += 1
                FN += 1
            elif predicted_mask[row, col] == 0 and not vegetation_ground_truth[row, col]:
                TNi += 1
                TN += 1
    
    # Print the values for TP, FP, FN, TN for the current image
    print("Image {}: TP = {}, FP = {}, FN = {}, TN = {}".format(i+1, TPi, FPi, FNi, TNi))
# Out:
# Image 1: TP = 1089, FP = 0, FN = 3370, TN = 11925
# Image 2: TP = 9527, FP = 0, FN = 4413, TN = 2444
# Image 3: TP = 2605, FP = 0, FN = 3290, TN = 10489
# Image 4: TP = 1639, FP = 0, FN = 5653, TN = 9092
# Image 5: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 6: TP = 556, FP = 0, FN = 253, TN = 15575
# Image 7: TP = 1402, FP = 3, FN = 651, TN = 14328
# Image 8: TP = 85, FP = 0, FN = 95, TN = 16204
# Image 9: TP = 5094, FP = 0, FN = 3799, TN = 7491
# Image 10: TP = 1260, FP = 0, FN = 6010, TN = 9114
# Image 11: TP = 2567, FP = 0, FN = 1397, TN = 12420
# Image 12: TP = 531, FP = 0, FN = 3080, TN = 12773
# Image 13: TP = 0, FP = 0, FN = 1, TN = 16383
# Image 14: TP = 0, FP = 0, FN = 3989, TN = 12395
# Image 15: TP = 4785, FP = 0, FN = 2659, TN = 8940
# Image 16: TP = 6564, FP = 0, FN = 3883, TN = 5937
# Image 17: TP = 6697, FP = 198, FN = 1880, TN = 7609
# Image 18: TP = 7379, FP = 13, FN = 4386, TN = 4606
# Image 19: TP = 0, FP = 16, FN = 0, TN = 16368
# Image 20: TP = 31, FP = 7, FN = 4, TN = 16342
# Image 21: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 22: TP = 4984, FP = 0, FN = 9252, TN = 2148
# Image 23: TP = 5367, FP = 1, FN = 5419, TN = 5597
# Image 24: TP = 897, FP = 5, FN = 1364, TN = 14118
# Image 25: TP = 1259, FP = 26, FN = 7217, TN = 7882
# Image 26: TP = 1110, FP = 13, FN = 1264, TN = 13997
# Image 27: TP = 5532, FP = 5, FN = 4382, TN = 6465
# Image 28: TP = 0, FP = 0, FN = 13787, TN = 2597
# Image 29: TP = 1725, FP = 3, FN = 6300, TN = 8356
# Image 30: TP = 2711, FP = 0, FN = 6264, TN = 7409
# Image 31: TP = 3670, FP = 0, FN = 9012, TN = 3702
# Image 32: TP = 2391, FP = 0, FN = 4609, TN = 9384
# Image 33: TP = 3524, FP = 4, FN = 7245, TN = 5611
# Image 34: TP = 5964, FP = 0, FN = 7095, TN = 3325
# Image 35: TP = 5456, FP = 37, FN = 6826, TN = 4065
# Image 36: TP = 2312, FP = 24, FN = 8889, TN = 5159
# Image 37: TP = 2909, FP = 0, FN = 1990, TN = 11485
# Image 38: TP = 6626, FP = 7, FN = 3188, TN = 6563
# Image 39: TP = 3630, FP = 9, FN = 3821, TN = 8924
# Image 40: TP = 1454, FP = 0, FN = 5731, TN = 9199
# Image 41: TP = 1144, FP = 0, FN = 4398, TN = 10842
# Image 42: TP = 17, FP = 1, FN = 2607, TN = 13759
# Image 43: TP = 3, FP = 0, FN = 1204, TN = 15177
# Image 44: TP = 241, FP = 0, FN = 3605, TN = 12538
# Image 45: TP = 335, FP = 2, FN = 5125, TN = 10922
# Image 46: TP = 178, FP = 0, FN = 2230, TN = 13976
# Image 47: TP = 0, FP = 0, FN = 613, TN = 15771
# Image 48: TP = 1190, FP = 8, FN = 4935, TN = 10251
# Image 49: TP = 4632, FP = 8, FN = 2493, TN = 9251
# Image 50: TP = 2492, FP = 3, FN = 4278, TN = 9611
# Image 51: TP = 3487, FP = 12, FN = 5762, TN = 7123
# Image 52: TP = 1013, FP = 0, FN = 1698, TN = 13673
# Image 53: TP = 4270, FP = 0, FN = 3068, TN = 9046
# Image 54: TP = 4192, FP = 0, FN = 2161, TN = 10031
# Image 55: TP = 202, FP = 0, FN = 2442, TN = 13740
# Image 56: TP = 382, FP = 0, FN = 2602, TN = 13400
# Image 57: TP = 1653, FP = 0, FN = 10122, TN = 4609
# Image 58: TP = 0, FP = 0, FN = 6106, TN = 10278
# Image 59: TP = 116, FP = 2, FN = 3007, TN = 13259
# Image 60: TP = 4617, FP = 0, FN = 11655, TN = 112
# Image 61: TP = 165, FP = 8, FN = 3197, TN = 13014
# Image 62: TP = 448, FP = 0, FN = 1976, TN = 13960
# Image 63: TP = 1408, FP = 0, FN = 8748, TN = 6228
# Image 64: TP = 750, FP = 0, FN = 1534, TN = 14100
# Image 65: TP = 94, FP = 0, FN = 4106, TN = 12184
# Image 66: TP = 0, FP = 0, FN = 1315, TN = 15069
# Image 67: TP = 0, FP = 0, FN = 1422, TN = 14962
# Image 68: TP = 604, FP = 0, FN = 5484, TN = 10296
# Image 69: TP = 184, FP = 0, FN = 155, TN = 16045
# Image 70: TP = 64, FP = 0, FN = 7483, TN = 8837
# Image 71: TP = 230, FP = 0, FN = 779, TN = 15375
# Image 72: TP = 4930, FP = 0, FN = 11374, TN = 80
# Image 73: TP = 4085, FP = 0, FN = 4801, TN = 7498
# Image 74: TP = 2408, FP = 31, FN = 6481, TN = 7464
# Image 75: TP = 463, FP = 2, FN = 312, TN = 15607
# Image 76: TP = 1196, FP = 0, FN = 6771, TN = 8417
# Image 77: TP = 7202, FP = 13, FN = 4392, TN = 4777
# Image 78: TP = 1363, FP = 0, FN = 1022, TN = 13999
# Image 79: TP = 1826, FP = 42, FN = 8693, TN = 5823
# Image 80: TP = 10526, FP = 29, FN = 4187, TN = 1642
# Image 81: TP = 6645, FP = 32, FN = 2360, TN = 7347
# Image 82: TP = 11210, FP = 4, FN = 3197, TN = 1973
# Image 83: TP = 7616, FP = 5, FN = 3754, TN = 5009
# Image 84: TP = 1991, FP = 0, FN = 1908, TN = 12485
# Image 85: TP = 684, FP = 0, FN = 5666, TN = 10034
# Image 86: TP = 87, FP = 0, FN = 9206, TN = 7091
# Image 87: TP = 0, FP = 0, FN = 3912, TN = 12472
# Image 88: TP = 3, FP = 0, FN = 10502, TN = 5879
# Image 89: TP = 0, FP = 0, FN = 3051, TN = 13333
# Image 90: TP = 4244, FP = 25, FN = 7220, TN = 4895
# Image 91: TP = 1851, FP = 26, FN = 4085, TN = 10422
# Image 92: TP = 3451, FP = 7, FN = 2928, TN = 9998
# Image 93: TP = 3165, FP = 28, FN = 9629, TN = 3562
# Image 94: TP = 1065, FP = 41, FN = 1014, TN = 14264
# Image 95: TP = 3035, FP = 80, FN = 7139, TN = 6130
# Image 96: TP = 144, FP = 0, FN = 5797, TN = 10443
# Image 97: TP = 38, FP = 0, FN = 1860, TN = 14486
# Image 98: TP = 4833, FP = 1, FN = 4501, TN = 7049
# Image 99: TP = 44, FP = 0, FN = 2158, TN = 14182
# Image 100: TP = 494, FP = 0, FN = 10358, TN = 5532
# Image 101: TP = 193, FP = 0, FN = 14928, TN = 1263
# Image 102: TP = 1596, FP = 0, FN = 14788, TN = 0
# Image 103: TP = 6711, FP = 0, FN = 9673, TN = 0
# Image 104: TP = 6322, FP = 0, FN = 6475, TN = 3587
# Image 105: TP = 3683, FP = 0, FN = 9522, TN = 3179
# Image 106: TP = 1, FP = 0, FN = 1287, TN = 15096
# Image 107: TP = 186, FP = 0, FN = 1699, TN = 14499
# Image 108: TP = 4944, FP = 0, FN = 11440, TN = 0
# Image 109: TP = 2239, FP = 0, FN = 1424, TN = 12721
# Image 110: TP = 7202, FP = 11, FN = 6857, TN = 2314
# Image 111: TP = 535, FP = 0, FN = 6500, TN = 9349
# Image 112: TP = 157, FP = 11, FN = 1555, TN = 14661
# Image 113: TP = 855, FP = 0, FN = 4669, TN = 10860
# Image 114: TP = 2169, FP = 0, FN = 13489, TN = 726
# Image 115: TP = 2865, FP = 0, FN = 13519, TN = 0
# Image 116: TP = 2754, FP = 0, FN = 13630, TN = 0
# Image 117: TP = 3001, FP = 0, FN = 13383, TN = 0
# Image 118: TP = 1767, FP = 0, FN = 13218, TN = 1399
# Image 119: TP = 399, FP = 1, FN = 5904, TN = 10080
# Image 120: TP = 3964, FP = 0, FN = 10463, TN = 1957
# Image 121: TP = 3305, FP = 0, FN = 3241, TN = 9838
# Image 122: TP = 5252, FP = 16, FN = 2235, TN = 8881
# Image 123: TP = 4528, FP = 0, FN = 10540, TN = 1316
# Image 124: TP = 2311, FP = 50, FN = 1595, TN = 12428
# Image 125: TP = 7157, FP = 0, FN = 5090, TN = 4137
# Image 126: TP = 34, FP = 0, FN = 4230, TN = 12120
# Image 127: TP = 0, FP = 0, FN = 34, TN = 16350
# Image 128: TP = 6, FP = 0, FN = 2468, TN = 13910
# Image 129: TP = 4396, FP = 0, FN = 11822, TN = 166
# Image 130: TP = 862, FP = 0, FN = 7646, TN = 7876
# Image 131: TP = 29, FP = 0, FN = 14556, TN = 1799
# Image 132: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 133: TP = 82, FP = 0, FN = 11537, TN = 4765
# Image 134: TP = 1852, FP = 0, FN = 8124, TN = 6408
# Image 135: TP = 6068, FP = 0, FN = 10316, TN = 0
# Image 136: TP = 991, FP = 0, FN = 1291, TN = 14102
# Image 137: TP = 1813, FP = 5, FN = 4467, TN = 10099
# Image 138: TP = 3145, FP = 0, FN = 9993, TN = 3246
# Image 139: TP = 3352, FP = 0, FN = 2035, TN = 10997
# Image 140: TP = 2997, FP = 0, FN = 6713, TN = 6674
# Image 141: TP = 163, FP = 0, FN = 4357, TN = 11864
# Image 142: TP = 271, FP = 8, FN = 1804, TN = 14301
# Image 143: TP = 1045, FP = 0, FN = 13519, TN = 1820
# Image 144: TP = 27, FP = 0, FN = 13917, TN = 2440
# Image 145: TP = 0, FP = 0, FN = 8077, TN = 8307
# Image 146: TP = 0, FP = 0, FN = 16322, TN = 62
# Image 147: TP = 11, FP = 0, FN = 16373, TN = 0
# Image 148: TP = 1264, FP = 0, FN = 15120, TN = 0
# Image 149: TP = 1487, FP = 0, FN = 14580, TN = 317
# Image 150: TP = 7467, FP = 63, FN = 3296, TN = 5558
# Image 151: TP = 267, FP = 0, FN = 6053, TN = 10064
# Image 152: TP = 7125, FP = 210, FN = 2808, TN = 6241
# Image 153: TP = 1744, FP = 20, FN = 539, TN = 14081
# Image 154: TP = 621, FP = 1, FN = 217, TN = 15545
# Image 155: TP = 1687, FP = 106, FN = 1705, TN = 12886
# Image 156: TP = 1194, FP = 1, FN = 6587, TN = 8602
# Image 157: TP = 24, FP = 0, FN = 1412, TN = 14948
# Image 158: TP = 0, FP = 0, FN = 1126, TN = 15258
# Image 159: TP = 3900, FP = 100, FN = 2235, TN = 10149
# Image 160: TP = 394, FP = 6, FN = 2166, TN = 13818
# Image 161: TP = 1037, FP = 0, FN = 7850, TN = 7497
# Image 162: TP = 2852, FP = 10, FN = 732, TN = 12790
# Image 163: TP = 4452, FP = 0, FN = 7984, TN = 3948
# Image 164: TP = 1239, FP = 2, FN = 3549, TN = 11594
# Image 165: TP = 5991, FP = 17, FN = 2873, TN = 7503
# Image 166: TP = 5423, FP = 10, FN = 7007, TN = 3944
# Image 167: TP = 6759, FP = 12, FN = 7850, TN = 1763
# Image 168: TP = 6531, FP = 18, FN = 2003, TN = 7832
# Image 169: TP = 4490, FP = 7, FN = 7243, TN = 4644
# Image 170: TP = 3993, FP = 20, FN = 2646, TN = 9725
# Image 171: TP = 4116, FP = 3, FN = 3817, TN = 8448
# Image 172: TP = 4395, FP = 89, FN = 6699, TN = 5201
# Image 173: TP = 4367, FP = 28, FN = 5084, TN = 6905
# Image 174: TP = 10383, FP = 167, FN = 2950, TN = 2884
# Image 175: TP = 254, FP = 63, FN = 339, TN = 15728
# Image 176: TP = 1647, FP = 0, FN = 6398, TN = 8339
# Image 177: TP = 790, FP = 0, FN = 7735, TN = 7859
# Image 178: TP = 421, FP = 1, FN = 3268, TN = 12694
# Image 179: TP = 3605, FP = 0, FN = 7769, TN = 5010
# Image 180: TP = 14287, FP = 117, FN = 1377, TN = 603
# Image 181: TP = 1558, FP = 15, FN = 3214, TN = 11597
# Image 182: TP = 3010, FP = 0, FN = 9318, TN = 4056
# Image 183: TP = 7846, FP = 0, FN = 6948, TN = 1590
# Image 184: TP = 6195, FP = 0, FN = 8015, TN = 2174
# Image 185: TP = 4343, FP = 63, FN = 9093, TN = 2885
# Image 186: TP = 5159, FP = 12, FN = 8391, TN = 2822
# Image 187: TP = 3260, FP = 4, FN = 9697, TN = 3423
# Image 188: TP = 2478, FP = 5, FN = 11208, TN = 2693
# Image 189: TP = 2216, FP = 2, FN = 2887, TN = 11279
# Image 190: TP = 1664, FP = 21, FN = 2286, TN = 12413
# Image 191: TP = 11, FP = 0, FN = 1772, TN = 14601
# Image 192: TP = 318, FP = 0, FN = 9097, TN = 6969
# Image 193: TP = 465, FP = 25, FN = 3595, TN = 12299
# Image 194: TP = 2147, FP = 0, FN = 10877, TN = 3360
# Image 195: TP = 2679, FP = 114, FN = 5900, TN = 7691
# Image 196: TP = 1963, FP = 0, FN = 11506, TN = 2915
# Image 197: TP = 519, FP = 0, FN = 5736, TN = 10129
# Image 198: TP = 4394, FP = 0, FN = 6140, TN = 5850
# Image 199: TP = 263, FP = 0, FN = 16121, TN = 0
# Image 200: TP = 2199, FP = 0, FN = 14185, TN = 0
# Image 201: TP = 79, FP = 0, FN = 16305, TN = 0
# Image 202: TP = 0, FP = 0, FN = 16384, TN = 0
# Image 203: TP = 370, FP = 0, FN = 16014, TN = 0
# Image 204: TP = 2002, FP = 10, FN = 4119, TN = 10253
# Image 205: TP = 519, FP = 0, FN = 8078, TN = 7787
# Image 206: TP = 268, FP = 38, FN = 934, TN = 15144
# Image 207: TP = 844, FP = 0, FN = 9221, TN = 6319
# Image 208: TP = 4000, FP = 0, FN = 12384, TN = 0
# Image 209: TP = 9090, FP = 0, FN = 7294, TN = 0
# Image 210: TP = 2243, FP = 7, FN = 5330, TN = 8804
# Image 211: TP = 12793, FP = 0, FN = 3560, TN = 31
# Image 212: TP = 1550, FP = 0, FN = 5350, TN = 9484
# Image 213: TP = 5129, FP = 31, FN = 2799, TN = 8425
# Image 214: TP = 2225, FP = 0, FN = 12741, TN = 1418
# Image 215: TP = 229, FP = 0, FN = 14920, TN = 1235
# Image 216: TP = 361, FP = 0, FN = 15827, TN = 196
# Image 217: TP = 644, FP = 0, FN = 14595, TN = 1145
# Image 218: TP = 5, FP = 0, FN = 11457, TN = 4922
# Image 219: TP = 6933, FP = 0, FN = 9112, TN = 339
# Image 220: TP = 0, FP = 0, FN = 2348, TN = 14036
# Image 221: TP = 361, FP = 3, FN = 1563, TN = 14457
# Image 222: TP = 858, FP = 0, FN = 3543, TN = 11983
# Image 223: TP = 12093, FP = 0, FN = 4222, TN = 69
# Image 224: TP = 13228, FP = 0, FN = 3156, TN = 0
# Image 225: TP = 6381, FP = 0, FN = 2068, TN = 7935
# Image 226: TP = 11933, FP = 0, FN = 4451, TN = 0
# Image 227: TP = 3475, FP = 0, FN = 2665, TN = 10244
# Image 228: TP = 3944, FP = 0, FN = 8625, TN = 3815
# Image 229: TP = 0, FP = 0, FN = 2739, TN = 13645
# Image 230: TP = 80, FP = 0, FN = 5103, TN = 11201
# Image 231: TP = 0, FP = 0, FN = 224, TN = 16160
# Image 232: TP = 462, FP = 0, FN = 5513, TN = 10409
# Image 233: TP = 282, FP = 0, FN = 1169, TN = 14933
# Image 234: TP = 5790, FP = 0, FN = 3625, TN = 6969
# Image 235: TP = 2199, FP = 1, FN = 5442, TN = 8742
# Image 236: TP = 931, FP = 20, FN = 3078, TN = 12355
# Image 237: TP = 59, FP = 0, FN = 410, TN = 15915
# Image 238: TP = 1825, FP = 0, FN = 4590, TN = 9969
# Image 239: TP = 7140, FP = 0, FN = 8831, TN = 413
# Image 240: TP = 3608, FP = 34, FN = 2382, TN = 10360
# Image 241: TP = 660, FP = 17, FN = 590, TN = 15117
# Image 242: TP = 379, FP = 1, FN = 223, TN = 15781
# Image 243: TP = 13362, FP = 36, FN = 1296, TN = 1690
# Image 244: TP = 980, FP = 27, FN = 1042, TN = 14335
# Image 245: TP = 5921, FP = 129, FN = 1526, TN = 8808
# Image 246: TP = 936, FP = 14, FN = 1484, TN = 13950
# Image 247: TP = 4887, FP = 0, FN = 5123, TN = 6374
# Image 248: TP = 7973, FP = 27, FN = 5135, TN = 3249
# Image 249: TP = 13339, FP = 9, FN = 2136, TN = 900
# Image 250: TP = 10594, FP = 7, FN = 2717, TN = 3066
# Image 251: TP = 7716, FP = 120, FN = 337, TN = 8211
# Image 252: TP = 71, FP = 56, FN = 465, TN = 15792
# Image 253: TP = 1502, FP = 35, FN = 637, TN = 14210
# Image 254: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 255: TP = 2370, FP = 92, FN = 696, TN = 13226
# Image 256: TP = 12251, FP = 74, FN = 2123, TN = 1936
# Image 257: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 258: TP = 10910, FP = 0, FN = 5474, TN = 0
# Image 259: TP = 13372, FP = 0, FN = 3012, TN = 0
# Image 260: TP = 3943, FP = 0, FN = 12441, TN = 0
# Image 261: TP = 12326, FP = 0, FN = 4058, TN = 0
# Image 262: TP = 27, FP = 0, FN = 277, TN = 16080
# Image 263: TP = 610, FP = 38, FN = 1211, TN = 14525
# Image 264: TP = 73, FP = 0, FN = 223, TN = 16088
# Image 265: TP = 35, FP = 0, FN = 512, TN = 15837
# Image 266: TP = 3635, FP = 0, FN = 3063, TN = 9686
# Image 267: TP = 206, FP = 0, FN = 895, TN = 15283
# Image 268: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 269: TP = 780, FP = 19, FN = 3881, TN = 11704
# Image 270: TP = 3518, FP = 94, FN = 2887, TN = 9885
# Image 271: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 272: TP = 11838, FP = 36, FN = 1699, TN = 2811
# Image 273: TP = 9699, FP = 1, FN = 6498, TN = 186
# Image 274: TP = 12819, FP = 0, FN = 3565, TN = 0
# Image 275: TP = 8821, FP = 0, FN = 7563, TN = 0
# Image 276: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 277: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 278: TP = 769, FP = 0, FN = 780, TN = 14835
# Image 279: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 280: TP = 176, FP = 0, FN = 194, TN = 16014
# Image 281: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 282: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 283: TP = 5731, FP = 43, FN = 4380, TN = 6230
# Image 284: TP = 3151, FP = 113, FN = 2629, TN = 10491
# Image 285: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 286: TP = 0, FP = 0, FN = 253, TN = 16131
# Image 287: TP = 2229, FP = 0, FN = 5557, TN = 8598
# Image 288: TP = 9243, FP = 0, FN = 7141, TN = 0
# Image 289: TP = 14187, FP = 10, FN = 1460, TN = 727
# Image 290: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 291: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 292: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 293: TP = 219, FP = 0, FN = 417, TN = 15748
# Image 294: TP = 163, FP = 0, FN = 140, TN = 16081
# Image 295: TP = 431, FP = 1, FN = 156, TN = 15796
# Image 296: TP = 4477, FP = 3, FN = 1871, TN = 10033
# Image 297: TP = 124, FP = 1, FN = 100, TN = 16159
# Image 298: TP = 2631, FP = 24, FN = 5337, TN = 8392
# Image 299: TP = 1683, FP = 8, FN = 211, TN = 14482
# Image 300: TP = 1547, FP = 0, FN = 3518, TN = 11319
# Image 301: TP = 2363, FP = 0, FN = 2936, TN = 11085
# Image 302: TP = 1865, FP = 40, FN = 5440, TN = 9039
# Image 303: TP = 4304, FP = 39, FN = 1600, TN = 10441
# Image 304: TP = 4028, FP = 4, FN = 6931, TN = 5421
# Image 305: TP = 8612, FP = 0, FN = 7772, TN = 0
# Image 306: TP = 13909, FP = 0, FN = 2475, TN = 0
# Image 307: TP = 8044, FP = 1, FN = 7656, TN = 683
# Image 308: TP = 603, FP = 0, FN = 4673, TN = 11108
# Image 309: TP = 5247, FP = 56, FN = 1532, TN = 9549
# Image 310: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 311: TP = 1653, FP = 5, FN = 1752, TN = 12974
# Image 312: TP = 5952, FP = 101, FN = 3064, TN = 7267
# Image 313: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 314: TP = 5370, FP = 47, FN = 2599, TN = 8368
# Image 315: TP = 5500, FP = 6, FN = 6014, TN = 4864
# Image 316: TP = 16125, FP = 0, FN = 259, TN = 0
# Image 317: TP = 11486, FP = 62, FN = 954, TN = 3882
# Image 318: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 319: TP = 0, FP = 0, FN = 24, TN = 16360
# Image 320: TP = 1739, FP = 0, FN = 4082, TN = 10563
# Image 321: TP = 138, FP = 0, FN = 464, TN = 15782
# Image 322: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 323: TP = 588, FP = 0, FN = 910, TN = 14886
# Image 324: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 325: TP = 8820, FP = 0, FN = 1079, TN = 6485
# Image 326: TP = 597, FP = 1, FN = 511, TN = 15275
# Image 327: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 328: TP = 151, FP = 12, FN = 197, TN = 16024
# Image 329: TP = 8021, FP = 0, FN = 5166, TN = 3197
# Image 330: TP = 12252, FP = 0, FN = 4132, TN = 0
# Image 331: TP = 3190, FP = 0, FN = 2383, TN = 10811
# Image 332: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 333: TP = 39, FP = 2, FN = 341, TN = 16002
# Image 334: TP = 1446, FP = 0, FN = 1643, TN = 13295
# Image 335: TP = 2097, FP = 3, FN = 1676, TN = 12608
# Image 336: TP = 615, FP = 37, FN = 1079, TN = 14653
# Image 337: TP = 14272, FP = 1, FN = 1493, TN = 618
# Image 338: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 339: TP = 9147, FP = 0, FN = 7237, TN = 0
# Image 340: TP = 7779, FP = 89, FN = 2235, TN = 6281
# Image 341: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 342: TP = 3990, FP = 0, FN = 687, TN = 11707
# Image 343: TP = 653, FP = 14, FN = 1095, TN = 14622
# Image 344: TP = 2642, FP = 0, FN = 5808, TN = 7934
# Image 345: TP = 0, FP = 0, FN = 1453, TN = 14931
# Image 346: TP = 0, FP = 0, FN = 57, TN = 16327
# Image 347: TP = 0, FP = 0, FN = 264, TN = 16120
# Image 348: TP = 0, FP = 0, FN = 156, TN = 16228
# Image 349: TP = 104, FP = 6, FN = 612, TN = 15662
# Image 350: TP = 7354, FP = 6, FN = 904, TN = 8120
# Image 351: TP = 15040, FP = 0, FN = 1344, TN = 0
# Image 352: TP = 0, FP = 0, FN = 111, TN = 16273
# Image 353: TP = 11623, FP = 0, FN = 4761, TN = 0
# Image 354: TP = 7427, FP = 109, FN = 4381, TN = 4467
# Image 355: TP = 0, FP = 0, FN = 178, TN = 16206
# Image 356: TP = 7864, FP = 0, FN = 8067, TN = 453
# Image 357: TP = 5678, FP = 27, FN = 1778, TN = 8901
# Image 358: TP = 234, FP = 0, FN = 382, TN = 15768
# Image 359: TP = 279, FP = 0, FN = 542, TN = 15563
# Image 360: TP = 1141, FP = 2, FN = 1876, TN = 13365
# Image 361: TP = 5825, FP = 0, FN = 8415, TN = 2144
# Image 362: TP = 881, FP = 0, FN = 3285, TN = 12218
# Image 363: TP = 0, FP = 0, FN = 571, TN = 15813
# Image 364: TP = 13191, FP = 0, FN = 1942, TN = 1251
# Image 365: TP = 12847, FP = 0, FN = 3537, TN = 0
# Image 366: TP = 196, FP = 0, FN = 1129, TN = 15059
# Image 367: TP = 15977, FP = 0, FN = 407, TN = 0
# Image 368: TP = 4464, FP = 3, FN = 6413, TN = 5504
# Image 369: TP = 1616, FP = 0, FN = 2177, TN = 12591
# Image 370: TP = 3347, FP = 0, FN = 4959, TN = 8078
# Image 371: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 372: TP = 0, FP = 0, FN = 3146, TN = 13238
# Image 373: TP = 33, FP = 10, FN = 491, TN = 15850
# Image 374: TP = 8353, FP = 0, FN = 2916, TN = 5115
# Image 375: TP = 4993, FP = 64, FN = 4389, TN = 6938
# Image 376: TP = 5580, FP = 50, FN = 1729, TN = 9025
# Image 377: TP = 5427, FP = 0, FN = 3811, TN = 7146
# Image 378: TP = 15581, FP = 0, FN = 803, TN = 0
# Image 379: TP = 12054, FP = 0, FN = 4330, TN = 0
# Image 380: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 381: TP = 11652, FP = 0, FN = 4732, TN = 0
# Image 382: TP = 6296, FP = 0, FN = 4914, TN = 5174
# Image 383: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 384: TP = 0, FP = 0, FN = 524, TN = 15860
# Image 385: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 386: TP = 0, FP = 0, FN = 3278, TN = 13106
# Image 387: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 388: TP = 1122, FP = 29, FN = 779, TN = 14454
# Image 389: TP = 0, FP = 0, FN = 994, TN = 15390
# Image 390: TP = 4485, FP = 89, FN = 1767, TN = 10043
# Image 391: TP = 4067, FP = 34, FN = 2536, TN = 9747
# Image 392: TP = 15540, FP = 0, FN = 844, TN = 0
# Image 393: TP = 12073, FP = 0, FN = 4311, TN = 0
# Image 394: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 395: TP = 6407, FP = 0, FN = 9977, TN = 0
# Image 396: TP = 12498, FP = 0, FN = 3885, TN = 1
# Image 397: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 398: TP = 9239, FP = 0, FN = 1936, TN = 5209
# Image 399: TP = 1068, FP = 0, FN = 661, TN = 14655
# Image 400: TP = 47, FP = 0, FN = 1737, TN = 14600
# Image 401: TP = 1357, FP = 17, FN = 1223, TN = 13787
# Image 402: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 403: TP = 0, FP = 0, FN = 739, TN = 15645
# Image 404: TP = 1870, FP = 0, FN = 1386, TN = 13128
# Image 405: TP = 8560, FP = 67, FN = 1670, TN = 6087
# Image 406: TP = 11265, FP = 0, FN = 5119, TN = 0
# Image 407: TP = 11954, FP = 0, FN = 4430, TN = 0
# Image 408: TP = 2953, FP = 0, FN = 751, TN = 12680
# Image 409: TP = 3393, FP = 73, FN = 4375, TN = 8543
# Image 410: TP = 11687, FP = 0, FN = 2614, TN = 2083
# Image 411: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 412: TP = 15299, FP = 0, FN = 1085, TN = 0
# Image 413: TP = 1538, FP = 0, FN = 1191, TN = 13655
# Image 414: TP = 448, FP = 0, FN = 2024, TN = 13912
# Image 415: TP = 7016, FP = 12, FN = 8602, TN = 754
# Image 416: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 417: TP = 0, FP = 0, FN = 87, TN = 16297
# Image 418: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 419: TP = 2059, FP = 0, FN = 1428, TN = 12897
# Image 420: TP = 7699, FP = 23, FN = 4363, TN = 4299
# Image 421: TP = 4711, FP = 91, FN = 1129, TN = 10453
# Image 422: TP = 0, FP = 0, FN = 2442, TN = 13942
# Image 423: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 424: TP = 1981, FP = 0, FN = 3677, TN = 10726
# Image 425: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 426: TP = 8020, FP = 0, FN = 8316, TN = 48
# Image 427: TP = 6777, FP = 0, FN = 9596, TN = 11
# Image 428: TP = 2319, FP = 2, FN = 4045, TN = 10018
# Image 429: TP = 6888, FP = 0, FN = 8699, TN = 797
# Image 430: TP = 3600, FP = 49, FN = 3489, TN = 9246
# Image 431: TP = 5992, FP = 98, FN = 4761, TN = 5533
# Image 432: TP = 11780, FP = 0, FN = 4285, TN = 319
# Image 433: TP = 6627, FP = 0, FN = 9757, TN = 0
# Image 434: TP = 11040, FP = 0, FN = 5344, TN = 0
# Image 435: TP = 5316, FP = 2, FN = 1415, TN = 9651
# Image 436: TP = 0, FP = 0, FN = 278, TN = 16106
# Image 437: TP = 0, FP = 0, FN = 336, TN = 16048
# Image 438: TP = 2445, FP = 0, FN = 6757, TN = 7182
# Image 439: TP = 0, FP = 0, FN = 3, TN = 16381
# Image 440: TP = 5684, FP = 0, FN = 10700, TN = 0
# Image 441: TP = 5977, FP = 0, FN = 10407, TN = 0
# Image 442: TP = 10901, FP = 0, FN = 5483, TN = 0
# Image 443: TP = 14665, FP = 0, FN = 1719, TN = 0
# Image 444: TP = 5236, FP = 33, FN = 3809, TN = 7306
# Image 445: TP = 218, FP = 25, FN = 227, TN = 15914
# Image 446: TP = 0, FP = 0, FN = 2751, TN = 13633
# Image 447: TP = 596, FP = 0, FN = 11809, TN = 3979
# Image 448: TP = 13084, FP = 20, FN = 1346, TN = 1934
# Image 449: TP = 272, FP = 5, FN = 1544, TN = 14563
# Image 450: TP = 0, FP = 0, FN = 186, TN = 16198
# Image 451: TP = 0, FP = 0, FN = 462, TN = 15922
# Image 452: TP = 4178, FP = 0, FN = 6119, TN = 6087
# Image 453: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 454: TP = 41, FP = 0, FN = 7694, TN = 8649
# Image 455: TP = 8442, FP = 0, FN = 7942, TN = 0
# Image 456: TP = 16376, FP = 0, FN = 8, TN = 0
# Image 457: TP = 11445, FP = 0, FN = 4939, TN = 0
# Image 458: TP = 222, FP = 0, FN = 3646, TN = 12516
# Image 459: TP = 4907, FP = 94, FN = 3964, TN = 7419
# Image 460: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 461: TP = 129, FP = 0, FN = 309, TN = 15946
# Image 462: TP = 2444, FP = 60, FN = 257, TN = 13623
# Image 463: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 464: TP = 30, FP = 0, FN = 828, TN = 15526
# Image 465: TP = 9631, FP = 5, FN = 3987, TN = 2761
# Image 466: TP = 6023, FP = 9, FN = 5721, TN = 4631
# Image 467: TP = 787, FP = 0, FN = 835, TN = 14762
# Image 468: TP = 10261, FP = 0, FN = 5344, TN = 779
# Image 469: TP = 14245, FP = 0, FN = 2139, TN = 0
# Image 470: TP = 16384, FP = 0, FN = 0, TN = 0
# Image 471: TP = 13055, FP = 0, FN = 3329, TN = 0
# Image 472: TP = 1534, FP = 0, FN = 3798, TN = 11052
# Image 473: TP = 1065, FP = 1, FN = 2146, TN = 13172
# Image 474: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 475: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 476: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 477: TP = 280, FP = 0, FN = 1526, TN = 14578
# Image 478: TP = 446, FP = 0, FN = 725, TN = 15213
# Image 479: TP = 10764, FP = 0, FN = 2693, TN = 2927
# Image 480: TP = 7010, FP = 0, FN = 9374, TN = 0
# Image 481: TP = 0, FP = 0, FN = 2842, TN = 13542
# Image 482: TP = 14003, FP = 0, FN = 2381, TN = 0
# Image 483: TP = 13763, FP = 0, FN = 2621, TN = 0
# Image 484: TP = 13984, FP = 0, FN = 2400, TN = 0
# Image 485: TP = 4948, FP = 0, FN = 11436, TN = 0
# Image 486: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 487: TP = 608, FP = 0, FN = 225, TN = 15551
# Image 488: TP = 1283, FP = 61, FN = 2670, TN = 12370
# Image 489: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 490: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 491: TP = 2694, FP = 11, FN = 2049, TN = 11630
# Image 492: TP = 199, FP = 0, FN = 382, TN = 15803
# Image 493: TP = 11, FP = 0, FN = 936, TN = 15437
# Image 494: TP = 12358, FP = 0, FN = 1802, TN = 2224
# Image 495: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 496: TP = 13663, FP = 0, FN = 2721, TN = 0
# Image 497: TP = 16161, FP = 0, FN = 223, TN = 0
# Image 498: TP = 7251, FP = 0, FN = 9133, TN = 0
# Image 499: TP = 6185, FP = 0, FN = 10199, TN = 0
# Image 500: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 501: TP = 1, FP = 0, FN = 35, TN = 16348
# Image 502: TP = 0, FP = 0, FN = 0, TN = 16384
# Image 503: TP = 1242, FP = 5, FN = 2946, TN = 12191
# Image 504: TP = 395, FP = 0, FN = 2067, TN = 13922
# Image 505: TP = 201, FP = 0, FN = 484, TN = 15699

# %%
recall = TP / (TP + FN)
precision = TP / (TP + FP)
accuracy = (TP + TN) / (TP + FP + FN + TN)
f1_score = 2 * (precision * recall) / (precision + recall)
IoU = TP / (TP + FP + FN)

print('TP:', TP)
print('FP:', FP)
print('FN:', FN)
print('TN:', TN)

print()
print('Recall: {:.3f}'.format(recall))
print('Precision: {:.3f}'.format(precision))
print('Accuracy: {:.3f}'.format(accuracy))
print('F1 Score: {:.3f}'.format(f1_score))

print()
print("IoU Overall: {:.3f} ".format(IoU))
# Out:
# TP: 1741138
# FP: 5106
# FN: 2021096
# TN: 4506580
#
# Recall: 0.463
# Precision: 0.997
# Accuracy: 0.755
# F1 Score: 0.632
#
# IoU Overall: 0.462

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
conf_matrix = np.array([[TP, FP],
                        [FN, TN]])

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted Vegetation', 'Predicted Non-Vegetation'], 
            yticklabels=['Actual Vegetation', 'Actual Non-Vegetation'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Initialize lists for TP, FP, FN, and IoU
TP_vegetation = []
FP_vegetation = []
FN_vegetation = []
IoU_vegetation = []

TP_non_vegetation = []
FP_non_vegetation = []
FN_non_vegetation = []
IoU_non_vegetation = []

# Loop over testing images
for i in range(len(image_test)):
    input_image = image_test[i]
    ground_truth = image_label_test[i]

    # Preprocess the input image
    input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
    features = input_image_reshaped.reshape(-1, 3)

    # Predict segmentation mask
    predicted_mask = model_loaded.forward(features)
    predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

    # Convert ground truth to binary mask for both vegetation and non-vegetation
    vegetation_ground_truth = np.logical_or(
        np.all(ground_truth == [0, 255, 255], axis=2),
        np.all(ground_truth == [0, 255, 0], axis=2)
    )
    
    # Calculate TP, FP, FN counts for both vegetation and non-vegetation classes
    TP_veg = np.sum(np.logical_and(vegetation_ground_truth, predicted_mask))
    FP_veg = np.sum(predicted_mask & ~vegetation_ground_truth)
    FN_veg = np.sum(vegetation_ground_truth & ~predicted_mask)
    
    TP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, ~predicted_mask))
    FP_non_veg = np.sum(np.logical_and(~vegetation_ground_truth, predicted_mask))
    FN_non_veg = np.sum(np.logical_and(vegetation_ground_truth, ~predicted_mask))

    # Append TP, FP, FN counts for vegetation and non-vegetation classes
    TP_vegetation.append(TP_veg)
    FP_vegetation.append(FP_veg)
    FN_vegetation.append(FN_veg)
    
    TP_non_vegetation.append(TP_non_veg)
    FP_non_vegetation.append(FP_non_veg)
    FN_non_vegetation.append(FN_non_veg)

    # Calculate IoU for vegetation and non-vegetation
    # IoU_vegetation.append(TP_veg / (TP_veg + FP_veg + FN_veg))
    # IoU_non_vegetation.append(TP_non_veg / (TP_non_veg + FP_non_veg + FN_non_veg))
    
    # Calculate IoU for vegetation and non-vegetation classes if the denominator is not zero
    denominator_veg = TP_veg + FP_veg + FN_veg
    denominator_non_veg = TP_non_veg + FP_non_veg + FN_non_veg

    IoU_vegetation.append(TP_veg / denominator_veg if denominator_veg != 0 else 0.0)
    IoU_non_vegetation.append(TP_non_veg / denominator_non_veg if denominator_non_veg != 0 else 0.0)

    # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
    print("Image {}:".format(i+1))
    print("TP_veg: {}, FP_veg: {}, FN_veg: {}, IoU_veg: {:.4f}".format(TP_veg, FP_veg, FN_veg, IoU_vegetation[-1]))
    print("TP_non_veg: {}, FP_non_veg: {}, FN_non_veg: {}, IoU_non_veg: {:.4f}".format(TP_non_veg, FP_non_veg, FN_non_veg, IoU_non_vegetation[-1]))
# Out:
# Image 1:
# TP_veg: 1089, FP_veg: 0, FN_veg: 3370, IoU_veg: 0.2442
# TP_non_veg: 11925, FP_non_veg: 0, FN_non_veg: 4459, IoU_non_veg: 0.7278
# Image 2:
# TP_veg: 9527, FP_veg: 0, FN_veg: 4413, IoU_veg: 0.6834
# TP_non_veg: 2444, FP_non_veg: 0, FN_non_veg: 13940, IoU_non_veg: 0.1492
# Image 3:
# TP_veg: 2605, FP_veg: 0, FN_veg: 3290, IoU_veg: 0.4419
# TP_non_veg: 10489, FP_non_veg: 0, FN_non_veg: 5895, IoU_non_veg: 0.6402
# Image 4:
# TP_veg: 1639, FP_veg: 0, FN_veg: 5653, IoU_veg: 0.2248
# TP_non_veg: 9092, FP_non_veg: 0, FN_non_veg: 7292, IoU_non_veg: 0.5549
# Image 5:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 6:
# TP_veg: 556, FP_veg: 0, FN_veg: 253, IoU_veg: 0.6873
# TP_non_veg: 15575, FP_non_veg: 0, FN_non_veg: 809, IoU_non_veg: 0.9506
# Image 7:
# TP_veg: 1402, FP_veg: 3, FN_veg: 651, IoU_veg: 0.6819
# TP_non_veg: 14331, FP_non_veg: 3, FN_non_veg: 2053, IoU_non_veg: 0.8745
# Image 8:
# TP_veg: 85, FP_veg: 0, FN_veg: 95, IoU_veg: 0.4722
# TP_non_veg: 16204, FP_non_veg: 0, FN_non_veg: 180, IoU_non_veg: 0.9890
# Image 9:
# TP_veg: 5094, FP_veg: 0, FN_veg: 3799, IoU_veg: 0.5728
# TP_non_veg: 7491, FP_non_veg: 0, FN_non_veg: 8893, IoU_non_veg: 0.4572
# Image 10:
# TP_veg: 1260, FP_veg: 0, FN_veg: 6010, IoU_veg: 0.1733
# TP_non_veg: 9114, FP_non_veg: 0, FN_non_veg: 7270, IoU_non_veg: 0.5563
# Image 11:
# TP_veg: 2567, FP_veg: 0, FN_veg: 1397, IoU_veg: 0.6476
# TP_non_veg: 12420, FP_non_veg: 0, FN_non_veg: 3964, IoU_non_veg: 0.7581
# Image 12:
# TP_veg: 531, FP_veg: 0, FN_veg: 3080, IoU_veg: 0.1471
# TP_non_veg: 12773, FP_non_veg: 0, FN_non_veg: 3611, IoU_non_veg: 0.7796
# Image 13:
# TP_veg: 0, FP_veg: 0, FN_veg: 1, IoU_veg: 0.0000
# TP_non_veg: 16383, FP_non_veg: 0, FN_non_veg: 1, IoU_non_veg: 0.9999
# Image 14:
# TP_veg: 0, FP_veg: 0, FN_veg: 3989, IoU_veg: 0.0000
# TP_non_veg: 12395, FP_non_veg: 0, FN_non_veg: 3989, IoU_non_veg: 0.7565
# Image 15:
# TP_veg: 4785, FP_veg: 0, FN_veg: 2659, IoU_veg: 0.6428
# TP_non_veg: 8940, FP_non_veg: 0, FN_non_veg: 7444, IoU_non_veg: 0.5457
# Image 16:
# TP_veg: 6564, FP_veg: 0, FN_veg: 3883, IoU_veg: 0.6283
# TP_non_veg: 5937, FP_non_veg: 0, FN_non_veg: 10447, IoU_non_veg: 0.3624
# Image 17:
# TP_veg: 6697, FP_veg: 198, FN_veg: 1880, IoU_veg: 0.7632
# TP_non_veg: 7807, FP_non_veg: 198, FN_non_veg: 8577, IoU_non_veg: 0.4708
# Image 18:
# TP_veg: 7379, FP_veg: 13, FN_veg: 4386, IoU_veg: 0.6265
# TP_non_veg: 4619, FP_non_veg: 13, FN_non_veg: 11765, IoU_non_veg: 0.2817
# Image 19:
# TP_veg: 0, FP_veg: 16, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 16, FN_non_veg: 0, IoU_non_veg: 0.9990
# Image 20:
# TP_veg: 31, FP_veg: 7, FN_veg: 4, IoU_veg: 0.7381
# TP_non_veg: 16349, FP_non_veg: 7, FN_non_veg: 35, IoU_non_veg: 0.9974
# Image 21:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 22:
# TP_veg: 4984, FP_veg: 0, FN_veg: 9252, IoU_veg: 0.3501
# TP_non_veg: 2148, FP_non_veg: 0, FN_non_veg: 14236, IoU_non_veg: 0.1311
# Image 23:
# TP_veg: 5367, FP_veg: 1, FN_veg: 5419, IoU_veg: 0.4975
# TP_non_veg: 5598, FP_non_veg: 1, FN_non_veg: 10786, IoU_non_veg: 0.3417
# Image 24:
# TP_veg: 897, FP_veg: 5, FN_veg: 1364, IoU_veg: 0.3959
# TP_non_veg: 14123, FP_non_veg: 5, FN_non_veg: 2261, IoU_non_veg: 0.8617
# Image 25:
# TP_veg: 1259, FP_veg: 26, FN_veg: 7217, IoU_veg: 0.1481
# TP_non_veg: 7908, FP_non_veg: 26, FN_non_veg: 8476, IoU_non_veg: 0.4819
# Image 26:
# TP_veg: 1110, FP_veg: 13, FN_veg: 1264, IoU_veg: 0.4650
# TP_non_veg: 14010, FP_non_veg: 13, FN_non_veg: 2374, IoU_non_veg: 0.8544
# Image 27:
# TP_veg: 5532, FP_veg: 5, FN_veg: 4382, IoU_veg: 0.5577
# TP_non_veg: 6470, FP_non_veg: 5, FN_non_veg: 9914, IoU_non_veg: 0.3948
# Image 28:
# TP_veg: 0, FP_veg: 0, FN_veg: 13787, IoU_veg: 0.0000
# TP_non_veg: 2597, FP_non_veg: 0, FN_non_veg: 13787, IoU_non_veg: 0.1585
# Image 29:
# TP_veg: 1725, FP_veg: 3, FN_veg: 6300, IoU_veg: 0.2149
# TP_non_veg: 8359, FP_non_veg: 3, FN_non_veg: 8025, IoU_non_veg: 0.5101
# Image 30:
# TP_veg: 2711, FP_veg: 0, FN_veg: 6264, IoU_veg: 0.3021
# TP_non_veg: 7409, FP_non_veg: 0, FN_non_veg: 8975, IoU_non_veg: 0.4522
# Image 31:
# TP_veg: 3670, FP_veg: 0, FN_veg: 9012, IoU_veg: 0.2894
# TP_non_veg: 3702, FP_non_veg: 0, FN_non_veg: 12682, IoU_non_veg: 0.2260
# Image 32:
# TP_veg: 2391, FP_veg: 0, FN_veg: 4609, IoU_veg: 0.3416
# TP_non_veg: 9384, FP_non_veg: 0, FN_non_veg: 7000, IoU_non_veg: 0.5728
# Image 33:
# TP_veg: 3524, FP_veg: 4, FN_veg: 7245, IoU_veg: 0.3271
# TP_non_veg: 5615, FP_non_veg: 4, FN_non_veg: 10769, IoU_non_veg: 0.3426
# Image 34:
# TP_veg: 5964, FP_veg: 0, FN_veg: 7095, IoU_veg: 0.4567
# TP_non_veg: 3325, FP_non_veg: 0, FN_non_veg: 13059, IoU_non_veg: 0.2029
# Image 35:
# TP_veg: 5456, FP_veg: 37, FN_veg: 6826, IoU_veg: 0.4429
# TP_non_veg: 4102, FP_non_veg: 37, FN_non_veg: 12282, IoU_non_veg: 0.2498
# Image 36:
# TP_veg: 2312, FP_veg: 24, FN_veg: 8889, IoU_veg: 0.2060
# TP_non_veg: 5183, FP_non_veg: 24, FN_non_veg: 11201, IoU_non_veg: 0.3159
# Image 37:
# TP_veg: 2909, FP_veg: 0, FN_veg: 1990, IoU_veg: 0.5938
# TP_non_veg: 11485, FP_non_veg: 0, FN_non_veg: 4899, IoU_non_veg: 0.7010
# Image 38:
# TP_veg: 6626, FP_veg: 7, FN_veg: 3188, IoU_veg: 0.6747
# TP_non_veg: 6570, FP_non_veg: 7, FN_non_veg: 9814, IoU_non_veg: 0.4008
# Image 39:
# TP_veg: 3630, FP_veg: 9, FN_veg: 3821, IoU_veg: 0.4866
# TP_non_veg: 8933, FP_non_veg: 9, FN_non_veg: 7451, IoU_non_veg: 0.5449
# Image 40:
# TP_veg: 1454, FP_veg: 0, FN_veg: 5731, IoU_veg: 0.2024
# TP_non_veg: 9199, FP_non_veg: 0, FN_non_veg: 7185, IoU_non_veg: 0.5615
# Image 41:
# TP_veg: 1144, FP_veg: 0, FN_veg: 4398, IoU_veg: 0.2064
# TP_non_veg: 10842, FP_non_veg: 0, FN_non_veg: 5542, IoU_non_veg: 0.6617
# Image 42:
# TP_veg: 17, FP_veg: 1, FN_veg: 2607, IoU_veg: 0.0065
# TP_non_veg: 13760, FP_non_veg: 1, FN_non_veg: 2624, IoU_non_veg: 0.8398
# Image 43:
# TP_veg: 3, FP_veg: 0, FN_veg: 1204, IoU_veg: 0.0025
# TP_non_veg: 15177, FP_non_veg: 0, FN_non_veg: 1207, IoU_non_veg: 0.9263
# Image 44:
# TP_veg: 241, FP_veg: 0, FN_veg: 3605, IoU_veg: 0.0627
# TP_non_veg: 12538, FP_non_veg: 0, FN_non_veg: 3846, IoU_non_veg: 0.7653
# Image 45:
# TP_veg: 335, FP_veg: 2, FN_veg: 5125, IoU_veg: 0.0613
# TP_non_veg: 10924, FP_non_veg: 2, FN_non_veg: 5460, IoU_non_veg: 0.6667
# Image 46:
# TP_veg: 178, FP_veg: 0, FN_veg: 2230, IoU_veg: 0.0739
# TP_non_veg: 13976, FP_non_veg: 0, FN_non_veg: 2408, IoU_non_veg: 0.8530
# Image 47:
# TP_veg: 0, FP_veg: 0, FN_veg: 613, IoU_veg: 0.0000
# TP_non_veg: 15771, FP_non_veg: 0, FN_non_veg: 613, IoU_non_veg: 0.9626
# Image 48:
# TP_veg: 1190, FP_veg: 8, FN_veg: 4935, IoU_veg: 0.1940
# TP_non_veg: 10259, FP_non_veg: 8, FN_non_veg: 6125, IoU_non_veg: 0.6259
# Image 49:
# TP_veg: 4632, FP_veg: 8, FN_veg: 2493, IoU_veg: 0.6494
# TP_non_veg: 9259, FP_non_veg: 8, FN_non_veg: 7125, IoU_non_veg: 0.5648
# Image 50:
# TP_veg: 2492, FP_veg: 3, FN_veg: 4278, IoU_veg: 0.3679
# TP_non_veg: 9614, FP_non_veg: 3, FN_non_veg: 6770, IoU_non_veg: 0.5867
# Image 51:
# TP_veg: 3487, FP_veg: 12, FN_veg: 5762, IoU_veg: 0.3765
# TP_non_veg: 7135, FP_non_veg: 12, FN_non_veg: 9249, IoU_non_veg: 0.4352
# Image 52:
# TP_veg: 1013, FP_veg: 0, FN_veg: 1698, IoU_veg: 0.3737
# TP_non_veg: 13673, FP_non_veg: 0, FN_non_veg: 2711, IoU_non_veg: 0.8345
# Image 53:
# TP_veg: 4270, FP_veg: 0, FN_veg: 3068, IoU_veg: 0.5819
# TP_non_veg: 9046, FP_non_veg: 0, FN_non_veg: 7338, IoU_non_veg: 0.5521
# Image 54:
# TP_veg: 4192, FP_veg: 0, FN_veg: 2161, IoU_veg: 0.6598
# TP_non_veg: 10031, FP_non_veg: 0, FN_non_veg: 6353, IoU_non_veg: 0.6122
# Image 55:
# TP_veg: 202, FP_veg: 0, FN_veg: 2442, IoU_veg: 0.0764
# TP_non_veg: 13740, FP_non_veg: 0, FN_non_veg: 2644, IoU_non_veg: 0.8386
# Image 56:
# TP_veg: 382, FP_veg: 0, FN_veg: 2602, IoU_veg: 0.1280
# TP_non_veg: 13400, FP_non_veg: 0, FN_non_veg: 2984, IoU_non_veg: 0.8179
# Image 57:
# TP_veg: 1653, FP_veg: 0, FN_veg: 10122, IoU_veg: 0.1404
# TP_non_veg: 4609, FP_non_veg: 0, FN_non_veg: 11775, IoU_non_veg: 0.2813
# Image 58:
# TP_veg: 0, FP_veg: 0, FN_veg: 6106, IoU_veg: 0.0000
# TP_non_veg: 10278, FP_non_veg: 0, FN_non_veg: 6106, IoU_non_veg: 0.6273
# Image 59:
# TP_veg: 116, FP_veg: 2, FN_veg: 3007, IoU_veg: 0.0371
# TP_non_veg: 13261, FP_non_veg: 2, FN_non_veg: 3123, IoU_non_veg: 0.8093
# Image 60:
# TP_veg: 4617, FP_veg: 0, FN_veg: 11655, IoU_veg: 0.2837
# TP_non_veg: 112, FP_non_veg: 0, FN_non_veg: 16272, IoU_non_veg: 0.0068
# Image 61:
# TP_veg: 165, FP_veg: 8, FN_veg: 3197, IoU_veg: 0.0490
# TP_non_veg: 13022, FP_non_veg: 8, FN_non_veg: 3362, IoU_non_veg: 0.7944
# Image 62:
# TP_veg: 448, FP_veg: 0, FN_veg: 1976, IoU_veg: 0.1848
# TP_non_veg: 13960, FP_non_veg: 0, FN_non_veg: 2424, IoU_non_veg: 0.8521
# Image 63:
# TP_veg: 1408, FP_veg: 0, FN_veg: 8748, IoU_veg: 0.1386
# TP_non_veg: 6228, FP_non_veg: 0, FN_non_veg: 10156, IoU_non_veg: 0.3801
# Image 64:
# TP_veg: 750, FP_veg: 0, FN_veg: 1534, IoU_veg: 0.3284
# TP_non_veg: 14100, FP_non_veg: 0, FN_non_veg: 2284, IoU_non_veg: 0.8606
# Image 65:
# TP_veg: 94, FP_veg: 0, FN_veg: 4106, IoU_veg: 0.0224
# TP_non_veg: 12184, FP_non_veg: 0, FN_non_veg: 4200, IoU_non_veg: 0.7437
# Image 66:
# TP_veg: 0, FP_veg: 0, FN_veg: 1315, IoU_veg: 0.0000
# TP_non_veg: 15069, FP_non_veg: 0, FN_non_veg: 1315, IoU_non_veg: 0.9197
# Image 67:
# TP_veg: 0, FP_veg: 0, FN_veg: 1422, IoU_veg: 0.0000
# TP_non_veg: 14962, FP_non_veg: 0, FN_non_veg: 1422, IoU_non_veg: 0.9132
# Image 68:
# TP_veg: 604, FP_veg: 0, FN_veg: 5484, IoU_veg: 0.0992
# TP_non_veg: 10296, FP_non_veg: 0, FN_non_veg: 6088, IoU_non_veg: 0.6284
# Image 69:
# TP_veg: 184, FP_veg: 0, FN_veg: 155, IoU_veg: 0.5428
# TP_non_veg: 16045, FP_non_veg: 0, FN_non_veg: 339, IoU_non_veg: 0.9793
# Image 70:
# TP_veg: 64, FP_veg: 0, FN_veg: 7483, IoU_veg: 0.0085
# TP_non_veg: 8837, FP_non_veg: 0, FN_non_veg: 7547, IoU_non_veg: 0.5394
# Image 71:
# TP_veg: 230, FP_veg: 0, FN_veg: 779, IoU_veg: 0.2279
# TP_non_veg: 15375, FP_non_veg: 0, FN_non_veg: 1009, IoU_non_veg: 0.9384
# Image 72:
# TP_veg: 4930, FP_veg: 0, FN_veg: 11374, IoU_veg: 0.3024
# TP_non_veg: 80, FP_non_veg: 0, FN_non_veg: 16304, IoU_non_veg: 0.0049
# Image 73:
# TP_veg: 4085, FP_veg: 0, FN_veg: 4801, IoU_veg: 0.4597
# TP_non_veg: 7498, FP_non_veg: 0, FN_non_veg: 8886, IoU_non_veg: 0.4576
# Image 74:
# TP_veg: 2408, FP_veg: 31, FN_veg: 6481, IoU_veg: 0.2700
# TP_non_veg: 7495, FP_non_veg: 31, FN_non_veg: 8889, IoU_non_veg: 0.4566
# Image 75:
# TP_veg: 463, FP_veg: 2, FN_veg: 312, IoU_veg: 0.5959
# TP_non_veg: 15609, FP_non_veg: 2, FN_non_veg: 775, IoU_non_veg: 0.9526
# Image 76:
# TP_veg: 1196, FP_veg: 0, FN_veg: 6771, IoU_veg: 0.1501
# TP_non_veg: 8417, FP_non_veg: 0, FN_non_veg: 7967, IoU_non_veg: 0.5137
# Image 77:
# TP_veg: 7202, FP_veg: 13, FN_veg: 4392, IoU_veg: 0.6205
# TP_non_veg: 4790, FP_non_veg: 13, FN_non_veg: 11594, IoU_non_veg: 0.2921
# Image 78:
# TP_veg: 1363, FP_veg: 0, FN_veg: 1022, IoU_veg: 0.5715
# TP_non_veg: 13999, FP_non_veg: 0, FN_non_veg: 2385, IoU_non_veg: 0.8544
# Image 79:
# TP_veg: 1826, FP_veg: 42, FN_veg: 8693, IoU_veg: 0.1729
# TP_non_veg: 5865, FP_non_veg: 42, FN_non_veg: 10519, IoU_non_veg: 0.3571
# Image 80:
# TP_veg: 10526, FP_veg: 29, FN_veg: 4187, IoU_veg: 0.7140
# TP_non_veg: 1671, FP_non_veg: 29, FN_non_veg: 14713, IoU_non_veg: 0.1018
# Image 81:
# TP_veg: 6645, FP_veg: 32, FN_veg: 2360, IoU_veg: 0.7353
# TP_non_veg: 7379, FP_non_veg: 32, FN_non_veg: 9005, IoU_non_veg: 0.4495
# Image 82:
# TP_veg: 11210, FP_veg: 4, FN_veg: 3197, IoU_veg: 0.7779
# TP_non_veg: 1977, FP_non_veg: 4, FN_non_veg: 14407, IoU_non_veg: 0.1206
# Image 83:
# TP_veg: 7616, FP_veg: 5, FN_veg: 3754, IoU_veg: 0.6695
# TP_non_veg: 5014, FP_non_veg: 5, FN_non_veg: 11370, IoU_non_veg: 0.3059
# Image 84:
# TP_veg: 1991, FP_veg: 0, FN_veg: 1908, IoU_veg: 0.5106
# TP_non_veg: 12485, FP_non_veg: 0, FN_non_veg: 3899, IoU_non_veg: 0.7620
# Image 85:
# TP_veg: 684, FP_veg: 0, FN_veg: 5666, IoU_veg: 0.1077
# TP_non_veg: 10034, FP_non_veg: 0, FN_non_veg: 6350, IoU_non_veg: 0.6124
# Image 86:
# TP_veg: 87, FP_veg: 0, FN_veg: 9206, IoU_veg: 0.0094
# TP_non_veg: 7091, FP_non_veg: 0, FN_non_veg: 9293, IoU_non_veg: 0.4328
# Image 87:
# TP_veg: 0, FP_veg: 0, FN_veg: 3912, IoU_veg: 0.0000
# TP_non_veg: 12472, FP_non_veg: 0, FN_non_veg: 3912, IoU_non_veg: 0.7612
# Image 88:
# TP_veg: 3, FP_veg: 0, FN_veg: 10502, IoU_veg: 0.0003
# TP_non_veg: 5879, FP_non_veg: 0, FN_non_veg: 10505, IoU_non_veg: 0.3588
# Image 89:
# TP_veg: 0, FP_veg: 0, FN_veg: 3051, IoU_veg: 0.0000
# TP_non_veg: 13333, FP_non_veg: 0, FN_non_veg: 3051, IoU_non_veg: 0.8138
# Image 90:
# TP_veg: 4244, FP_veg: 25, FN_veg: 7220, IoU_veg: 0.3694
# TP_non_veg: 4920, FP_non_veg: 25, FN_non_veg: 11464, IoU_non_veg: 0.2998
# Image 91:
# TP_veg: 1851, FP_veg: 26, FN_veg: 4085, IoU_veg: 0.3105
# TP_non_veg: 10448, FP_non_veg: 26, FN_non_veg: 5936, IoU_non_veg: 0.6367
# Image 92:
# TP_veg: 3451, FP_veg: 7, FN_veg: 2928, IoU_veg: 0.5404
# TP_non_veg: 10005, FP_non_veg: 7, FN_non_veg: 6379, IoU_non_veg: 0.6104
# Image 93:
# TP_veg: 3165, FP_veg: 28, FN_veg: 9629, IoU_veg: 0.2468
# TP_non_veg: 3590, FP_non_veg: 28, FN_non_veg: 12794, IoU_non_veg: 0.2187
# Image 94:
# TP_veg: 1065, FP_veg: 41, FN_veg: 1014, IoU_veg: 0.5024
# TP_non_veg: 14305, FP_non_veg: 41, FN_non_veg: 2079, IoU_non_veg: 0.8709
# Image 95:
# TP_veg: 3035, FP_veg: 80, FN_veg: 7139, IoU_veg: 0.2960
# TP_non_veg: 6210, FP_non_veg: 80, FN_non_veg: 10174, IoU_non_veg: 0.3772
# Image 96:
# TP_veg: 144, FP_veg: 0, FN_veg: 5797, IoU_veg: 0.0242
# TP_non_veg: 10443, FP_non_veg: 0, FN_non_veg: 5941, IoU_non_veg: 0.6374
# Image 97:
# TP_veg: 38, FP_veg: 0, FN_veg: 1860, IoU_veg: 0.0200
# TP_non_veg: 14486, FP_non_veg: 0, FN_non_veg: 1898, IoU_non_veg: 0.8842
# Image 98:
# TP_veg: 4833, FP_veg: 1, FN_veg: 4501, IoU_veg: 0.5177
# TP_non_veg: 7050, FP_non_veg: 1, FN_non_veg: 9334, IoU_non_veg: 0.4303
# Image 99:
# TP_veg: 44, FP_veg: 0, FN_veg: 2158, IoU_veg: 0.0200
# TP_non_veg: 14182, FP_non_veg: 0, FN_non_veg: 2202, IoU_non_veg: 0.8656
# Image 100:
# TP_veg: 494, FP_veg: 0, FN_veg: 10358, IoU_veg: 0.0455
# TP_non_veg: 5532, FP_non_veg: 0, FN_non_veg: 10852, IoU_non_veg: 0.3376
# Image 101:
# TP_veg: 193, FP_veg: 0, FN_veg: 14928, IoU_veg: 0.0128
# TP_non_veg: 1263, FP_non_veg: 0, FN_non_veg: 15121, IoU_non_veg: 0.0771
# Image 102:
# TP_veg: 1596, FP_veg: 0, FN_veg: 14788, IoU_veg: 0.0974
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 103:
# TP_veg: 6711, FP_veg: 0, FN_veg: 9673, IoU_veg: 0.4096
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 104:
# TP_veg: 6322, FP_veg: 0, FN_veg: 6475, IoU_veg: 0.4940
# TP_non_veg: 3587, FP_non_veg: 0, FN_non_veg: 12797, IoU_non_veg: 0.2189
# Image 105:
# TP_veg: 3683, FP_veg: 0, FN_veg: 9522, IoU_veg: 0.2789
# TP_non_veg: 3179, FP_non_veg: 0, FN_non_veg: 13205, IoU_non_veg: 0.1940
# Image 106:
# TP_veg: 1, FP_veg: 0, FN_veg: 1287, IoU_veg: 0.0008
# TP_non_veg: 15096, FP_non_veg: 0, FN_non_veg: 1288, IoU_non_veg: 0.9214
# Image 107:
# TP_veg: 186, FP_veg: 0, FN_veg: 1699, IoU_veg: 0.0987
# TP_non_veg: 14499, FP_non_veg: 0, FN_non_veg: 1885, IoU_non_veg: 0.8849
# Image 108:
# TP_veg: 4944, FP_veg: 0, FN_veg: 11440, IoU_veg: 0.3018
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 109:
# TP_veg: 2239, FP_veg: 0, FN_veg: 1424, IoU_veg: 0.6112
# TP_non_veg: 12721, FP_non_veg: 0, FN_non_veg: 3663, IoU_non_veg: 0.7764
# Image 110:
# TP_veg: 7202, FP_veg: 11, FN_veg: 6857, IoU_veg: 0.5119
# TP_non_veg: 2325, FP_non_veg: 11, FN_non_veg: 14059, IoU_non_veg: 0.1418
# Image 111:
# TP_veg: 535, FP_veg: 0, FN_veg: 6500, IoU_veg: 0.0760
# TP_non_veg: 9349, FP_non_veg: 0, FN_non_veg: 7035, IoU_non_veg: 0.5706
# Image 112:
# TP_veg: 157, FP_veg: 11, FN_veg: 1555, IoU_veg: 0.0911
# TP_non_veg: 14672, FP_non_veg: 11, FN_non_veg: 1712, IoU_non_veg: 0.8949
# Image 113:
# TP_veg: 855, FP_veg: 0, FN_veg: 4669, IoU_veg: 0.1548
# TP_non_veg: 10860, FP_non_veg: 0, FN_non_veg: 5524, IoU_non_veg: 0.6628
# Image 114:
# TP_veg: 2169, FP_veg: 0, FN_veg: 13489, IoU_veg: 0.1385
# TP_non_veg: 726, FP_non_veg: 0, FN_non_veg: 15658, IoU_non_veg: 0.0443
# Image 115:
# TP_veg: 2865, FP_veg: 0, FN_veg: 13519, IoU_veg: 0.1749
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 116:
# TP_veg: 2754, FP_veg: 0, FN_veg: 13630, IoU_veg: 0.1681
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 117:
# TP_veg: 3001, FP_veg: 0, FN_veg: 13383, IoU_veg: 0.1832
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 118:
# TP_veg: 1767, FP_veg: 0, FN_veg: 13218, IoU_veg: 0.1179
# TP_non_veg: 1399, FP_non_veg: 0, FN_non_veg: 14985, IoU_non_veg: 0.0854
# Image 119:
# TP_veg: 399, FP_veg: 1, FN_veg: 5904, IoU_veg: 0.0633
# TP_non_veg: 10081, FP_non_veg: 1, FN_non_veg: 6303, IoU_non_veg: 0.6153
# Image 120:
# TP_veg: 3964, FP_veg: 0, FN_veg: 10463, IoU_veg: 0.2748
# TP_non_veg: 1957, FP_non_veg: 0, FN_non_veg: 14427, IoU_non_veg: 0.1194
# Image 121:
# TP_veg: 3305, FP_veg: 0, FN_veg: 3241, IoU_veg: 0.5049
# TP_non_veg: 9838, FP_non_veg: 0, FN_non_veg: 6546, IoU_non_veg: 0.6005
# Image 122:
# TP_veg: 5252, FP_veg: 16, FN_veg: 2235, IoU_veg: 0.7000
# TP_non_veg: 8897, FP_non_veg: 16, FN_non_veg: 7487, IoU_non_veg: 0.5425
# Image 123:
# TP_veg: 4528, FP_veg: 0, FN_veg: 10540, IoU_veg: 0.3005
# TP_non_veg: 1316, FP_non_veg: 0, FN_non_veg: 15068, IoU_non_veg: 0.0803
# Image 124:
# TP_veg: 2311, FP_veg: 50, FN_veg: 1595, IoU_veg: 0.5842
# TP_non_veg: 12478, FP_non_veg: 50, FN_non_veg: 3906, IoU_non_veg: 0.7593
# Image 125:
# TP_veg: 7157, FP_veg: 0, FN_veg: 5090, IoU_veg: 0.5844
# TP_non_veg: 4137, FP_non_veg: 0, FN_non_veg: 12247, IoU_non_veg: 0.2525
# Image 126:
# TP_veg: 34, FP_veg: 0, FN_veg: 4230, IoU_veg: 0.0080
# TP_non_veg: 12120, FP_non_veg: 0, FN_non_veg: 4264, IoU_non_veg: 0.7397
# Image 127:
# TP_veg: 0, FP_veg: 0, FN_veg: 34, IoU_veg: 0.0000
# TP_non_veg: 16350, FP_non_veg: 0, FN_non_veg: 34, IoU_non_veg: 0.9979
# Image 128:
# TP_veg: 6, FP_veg: 0, FN_veg: 2468, IoU_veg: 0.0024
# TP_non_veg: 13910, FP_non_veg: 0, FN_non_veg: 2474, IoU_non_veg: 0.8490
# Image 129:
# TP_veg: 4396, FP_veg: 0, FN_veg: 11822, IoU_veg: 0.2711
# TP_non_veg: 166, FP_non_veg: 0, FN_non_veg: 16218, IoU_non_veg: 0.0101
# Image 130:
# TP_veg: 862, FP_veg: 0, FN_veg: 7646, IoU_veg: 0.1013
# TP_non_veg: 7876, FP_non_veg: 0, FN_non_veg: 8508, IoU_non_veg: 0.4807
# Image 131:
# TP_veg: 29, FP_veg: 0, FN_veg: 14556, IoU_veg: 0.0020
# TP_non_veg: 1799, FP_non_veg: 0, FN_non_veg: 14585, IoU_non_veg: 0.1098
# Image 132:
# TP_veg: 0, FP_veg: 0, FN_veg: 16384, IoU_veg: 0.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 133:
# TP_veg: 82, FP_veg: 0, FN_veg: 11537, IoU_veg: 0.0071
# TP_non_veg: 4765, FP_non_veg: 0, FN_non_veg: 11619, IoU_non_veg: 0.2908
# Image 134:
# TP_veg: 1852, FP_veg: 0, FN_veg: 8124, IoU_veg: 0.1856
# TP_non_veg: 6408, FP_non_veg: 0, FN_non_veg: 9976, IoU_non_veg: 0.3911
# Image 135:
# TP_veg: 6068, FP_veg: 0, FN_veg: 10316, IoU_veg: 0.3704
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 136:
# TP_veg: 991, FP_veg: 0, FN_veg: 1291, IoU_veg: 0.4343
# TP_non_veg: 14102, FP_non_veg: 0, FN_non_veg: 2282, IoU_non_veg: 0.8607
# Image 137:
# TP_veg: 1813, FP_veg: 5, FN_veg: 4467, IoU_veg: 0.2885
# TP_non_veg: 10104, FP_non_veg: 5, FN_non_veg: 6280, IoU_non_veg: 0.6165
# Image 138:
# TP_veg: 3145, FP_veg: 0, FN_veg: 9993, IoU_veg: 0.2394
# TP_non_veg: 3246, FP_non_veg: 0, FN_non_veg: 13138, IoU_non_veg: 0.1981
# Image 139:
# TP_veg: 3352, FP_veg: 0, FN_veg: 2035, IoU_veg: 0.6222
# TP_non_veg: 10997, FP_non_veg: 0, FN_non_veg: 5387, IoU_non_veg: 0.6712
# Image 140:
# TP_veg: 2997, FP_veg: 0, FN_veg: 6713, IoU_veg: 0.3087
# TP_non_veg: 6674, FP_non_veg: 0, FN_non_veg: 9710, IoU_non_veg: 0.4073
# Image 141:
# TP_veg: 163, FP_veg: 0, FN_veg: 4357, IoU_veg: 0.0361
# TP_non_veg: 11864, FP_non_veg: 0, FN_non_veg: 4520, IoU_non_veg: 0.7241
# Image 142:
# TP_veg: 271, FP_veg: 8, FN_veg: 1804, IoU_veg: 0.1301
# TP_non_veg: 14309, FP_non_veg: 8, FN_non_veg: 2075, IoU_non_veg: 0.8729
# Image 143:
# TP_veg: 1045, FP_veg: 0, FN_veg: 13519, IoU_veg: 0.0718
# TP_non_veg: 1820, FP_non_veg: 0, FN_non_veg: 14564, IoU_non_veg: 0.1111
# Image 144:
# TP_veg: 27, FP_veg: 0, FN_veg: 13917, IoU_veg: 0.0019
# TP_non_veg: 2440, FP_non_veg: 0, FN_non_veg: 13944, IoU_non_veg: 0.1489
# Image 145:
# TP_veg: 0, FP_veg: 0, FN_veg: 8077, IoU_veg: 0.0000
# TP_non_veg: 8307, FP_non_veg: 0, FN_non_veg: 8077, IoU_non_veg: 0.5070
# Image 146:
# TP_veg: 0, FP_veg: 0, FN_veg: 16322, IoU_veg: 0.0000
# TP_non_veg: 62, FP_non_veg: 0, FN_non_veg: 16322, IoU_non_veg: 0.0038
# Image 147:
# TP_veg: 11, FP_veg: 0, FN_veg: 16373, IoU_veg: 0.0007
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 148:
# TP_veg: 1264, FP_veg: 0, FN_veg: 15120, IoU_veg: 0.0771
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 149:
# TP_veg: 1487, FP_veg: 0, FN_veg: 14580, IoU_veg: 0.0925
# TP_non_veg: 317, FP_non_veg: 0, FN_non_veg: 16067, IoU_non_veg: 0.0193
# Image 150:
# TP_veg: 7467, FP_veg: 63, FN_veg: 3296, IoU_veg: 0.6897
# TP_non_veg: 5621, FP_non_veg: 63, FN_non_veg: 10763, IoU_non_veg: 0.3418
# Image 151:
# TP_veg: 267, FP_veg: 0, FN_veg: 6053, IoU_veg: 0.0422
# TP_non_veg: 10064, FP_non_veg: 0, FN_non_veg: 6320, IoU_non_veg: 0.6143
# Image 152:
# TP_veg: 7125, FP_veg: 210, FN_veg: 2808, IoU_veg: 0.7025
# TP_non_veg: 6451, FP_non_veg: 210, FN_non_veg: 9933, IoU_non_veg: 0.3888
# Image 153:
# TP_veg: 1744, FP_veg: 20, FN_veg: 539, IoU_veg: 0.7573
# TP_non_veg: 14101, FP_non_veg: 20, FN_non_veg: 2283, IoU_non_veg: 0.8596
# Image 154:
# TP_veg: 621, FP_veg: 1, FN_veg: 217, IoU_veg: 0.7402
# TP_non_veg: 15546, FP_non_veg: 1, FN_non_veg: 838, IoU_non_veg: 0.9488
# Image 155:
# TP_veg: 1687, FP_veg: 106, FN_veg: 1705, IoU_veg: 0.4823
# TP_non_veg: 12992, FP_non_veg: 106, FN_non_veg: 3392, IoU_non_veg: 0.7879
# Image 156:
# TP_veg: 1194, FP_veg: 1, FN_veg: 6587, IoU_veg: 0.1534
# TP_non_veg: 8603, FP_non_veg: 1, FN_non_veg: 7781, IoU_non_veg: 0.5251
# Image 157:
# TP_veg: 24, FP_veg: 0, FN_veg: 1412, IoU_veg: 0.0167
# TP_non_veg: 14948, FP_non_veg: 0, FN_non_veg: 1436, IoU_non_veg: 0.9124
# Image 158:
# TP_veg: 0, FP_veg: 0, FN_veg: 1126, IoU_veg: 0.0000
# TP_non_veg: 15258, FP_non_veg: 0, FN_non_veg: 1126, IoU_non_veg: 0.9313
# Image 159:
# TP_veg: 3900, FP_veg: 100, FN_veg: 2235, IoU_veg: 0.6255
# TP_non_veg: 10249, FP_non_veg: 100, FN_non_veg: 6135, IoU_non_veg: 0.6218
# Image 160:
# TP_veg: 394, FP_veg: 6, FN_veg: 2166, IoU_veg: 0.1535
# TP_non_veg: 13824, FP_non_veg: 6, FN_non_veg: 2560, IoU_non_veg: 0.8434
# Image 161:
# TP_veg: 1037, FP_veg: 0, FN_veg: 7850, IoU_veg: 0.1167
# TP_non_veg: 7497, FP_non_veg: 0, FN_non_veg: 8887, IoU_non_veg: 0.4576
# Image 162:
# TP_veg: 2852, FP_veg: 10, FN_veg: 732, IoU_veg: 0.7935
# TP_non_veg: 12800, FP_non_veg: 10, FN_non_veg: 3584, IoU_non_veg: 0.7808
# Image 163:
# TP_veg: 4452, FP_veg: 0, FN_veg: 7984, IoU_veg: 0.3580
# TP_non_veg: 3948, FP_non_veg: 0, FN_non_veg: 12436, IoU_non_veg: 0.2410
# Image 164:
# TP_veg: 1239, FP_veg: 2, FN_veg: 3549, IoU_veg: 0.2587
# TP_non_veg: 11596, FP_non_veg: 2, FN_non_veg: 4788, IoU_non_veg: 0.7077
# Image 165:
# TP_veg: 5991, FP_veg: 17, FN_veg: 2873, IoU_veg: 0.6746
# TP_non_veg: 7520, FP_non_veg: 17, FN_non_veg: 8864, IoU_non_veg: 0.4585
# Image 166:
# TP_veg: 5423, FP_veg: 10, FN_veg: 7007, IoU_veg: 0.4359
# TP_non_veg: 3954, FP_non_veg: 10, FN_non_veg: 12430, IoU_non_veg: 0.2412
# Image 167:
# TP_veg: 6759, FP_veg: 12, FN_veg: 7850, IoU_veg: 0.4623
# TP_non_veg: 1775, FP_non_veg: 12, FN_non_veg: 14609, IoU_non_veg: 0.1083
# Image 168:
# TP_veg: 6531, FP_veg: 18, FN_veg: 2003, IoU_veg: 0.7637
# TP_non_veg: 7850, FP_non_veg: 18, FN_non_veg: 8534, IoU_non_veg: 0.4786
# Image 169:
# TP_veg: 4490, FP_veg: 7, FN_veg: 7243, IoU_veg: 0.3825
# TP_non_veg: 4651, FP_non_veg: 7, FN_non_veg: 11733, IoU_non_veg: 0.2838
# Image 170:
# TP_veg: 3993, FP_veg: 20, FN_veg: 2646, IoU_veg: 0.5996
# TP_non_veg: 9745, FP_non_veg: 20, FN_non_veg: 6639, IoU_non_veg: 0.5941
# Image 171:
# TP_veg: 4116, FP_veg: 3, FN_veg: 3817, IoU_veg: 0.5186
# TP_non_veg: 8451, FP_non_veg: 3, FN_non_veg: 7933, IoU_non_veg: 0.5157
# Image 172:
# TP_veg: 4395, FP_veg: 89, FN_veg: 6699, IoU_veg: 0.3930
# TP_non_veg: 5290, FP_non_veg: 89, FN_non_veg: 11094, IoU_non_veg: 0.3211
# Image 173:
# TP_veg: 4367, FP_veg: 28, FN_veg: 5084, IoU_veg: 0.4607
# TP_non_veg: 6933, FP_non_veg: 28, FN_non_veg: 9451, IoU_non_veg: 0.4224
# Image 174:
# TP_veg: 10383, FP_veg: 167, FN_veg: 2950, IoU_veg: 0.7691
# TP_non_veg: 3051, FP_non_veg: 167, FN_non_veg: 13333, IoU_non_veg: 0.1843
# Image 175:
# TP_veg: 254, FP_veg: 63, FN_veg: 339, IoU_veg: 0.3872
# TP_non_veg: 15791, FP_non_veg: 63, FN_non_veg: 593, IoU_non_veg: 0.9601
# Image 176:
# TP_veg: 1647, FP_veg: 0, FN_veg: 6398, IoU_veg: 0.2047
# TP_non_veg: 8339, FP_non_veg: 0, FN_non_veg: 8045, IoU_non_veg: 0.5090
# Image 177:
# TP_veg: 790, FP_veg: 0, FN_veg: 7735, IoU_veg: 0.0927
# TP_non_veg: 7859, FP_non_veg: 0, FN_non_veg: 8525, IoU_non_veg: 0.4797
# Image 178:
# TP_veg: 421, FP_veg: 1, FN_veg: 3268, IoU_veg: 0.1141
# TP_non_veg: 12695, FP_non_veg: 1, FN_non_veg: 3689, IoU_non_veg: 0.7748
# Image 179:
# TP_veg: 3605, FP_veg: 0, FN_veg: 7769, IoU_veg: 0.3170
# TP_non_veg: 5010, FP_non_veg: 0, FN_non_veg: 11374, IoU_non_veg: 0.3058
# Image 180:
# TP_veg: 14287, FP_veg: 117, FN_veg: 1377, IoU_veg: 0.9053
# TP_non_veg: 720, FP_non_veg: 117, FN_non_veg: 15664, IoU_non_veg: 0.0436
# Image 181:
# TP_veg: 1558, FP_veg: 15, FN_veg: 3214, IoU_veg: 0.3255
# TP_non_veg: 11612, FP_non_veg: 15, FN_non_veg: 4772, IoU_non_veg: 0.7081
# Image 182:
# TP_veg: 3010, FP_veg: 0, FN_veg: 9318, IoU_veg: 0.2442
# TP_non_veg: 4056, FP_non_veg: 0, FN_non_veg: 12328, IoU_non_veg: 0.2476
# Image 183:
# TP_veg: 7846, FP_veg: 0, FN_veg: 6948, IoU_veg: 0.5304
# TP_non_veg: 1590, FP_non_veg: 0, FN_non_veg: 14794, IoU_non_veg: 0.0970
# Image 184:
# TP_veg: 6195, FP_veg: 0, FN_veg: 8015, IoU_veg: 0.4360
# TP_non_veg: 2174, FP_non_veg: 0, FN_non_veg: 14210, IoU_non_veg: 0.1327
# Image 185:
# TP_veg: 4343, FP_veg: 63, FN_veg: 9093, IoU_veg: 0.3217
# TP_non_veg: 2948, FP_non_veg: 63, FN_non_veg: 13436, IoU_non_veg: 0.1792
# Image 186:
# TP_veg: 5159, FP_veg: 12, FN_veg: 8391, IoU_veg: 0.3804
# TP_non_veg: 2834, FP_non_veg: 12, FN_non_veg: 13550, IoU_non_veg: 0.1728
# Image 187:
# TP_veg: 3260, FP_veg: 4, FN_veg: 9697, IoU_veg: 0.2515
# TP_non_veg: 3427, FP_non_veg: 4, FN_non_veg: 12957, IoU_non_veg: 0.2091
# Image 188:
# TP_veg: 2478, FP_veg: 5, FN_veg: 11208, IoU_veg: 0.1810
# TP_non_veg: 2698, FP_non_veg: 5, FN_non_veg: 13686, IoU_non_veg: 0.1646
# Image 189:
# TP_veg: 2216, FP_veg: 2, FN_veg: 2887, IoU_veg: 0.4341
# TP_non_veg: 11281, FP_non_veg: 2, FN_non_veg: 5103, IoU_non_veg: 0.6885
# Image 190:
# TP_veg: 1664, FP_veg: 21, FN_veg: 2286, IoU_veg: 0.4190
# TP_non_veg: 12434, FP_non_veg: 21, FN_non_veg: 3950, IoU_non_veg: 0.7579
# Image 191:
# TP_veg: 11, FP_veg: 0, FN_veg: 1772, IoU_veg: 0.0062
# TP_non_veg: 14601, FP_non_veg: 0, FN_non_veg: 1783, IoU_non_veg: 0.8912
# Image 192:
# TP_veg: 318, FP_veg: 0, FN_veg: 9097, IoU_veg: 0.0338
# TP_non_veg: 6969, FP_non_veg: 0, FN_non_veg: 9415, IoU_non_veg: 0.4254
# Image 193:
# TP_veg: 465, FP_veg: 25, FN_veg: 3595, IoU_veg: 0.1138
# TP_non_veg: 12324, FP_non_veg: 25, FN_non_veg: 4060, IoU_non_veg: 0.7511
# Image 194:
# TP_veg: 2147, FP_veg: 0, FN_veg: 10877, IoU_veg: 0.1648
# TP_non_veg: 3360, FP_non_veg: 0, FN_non_veg: 13024, IoU_non_veg: 0.2051
# Image 195:
# TP_veg: 2679, FP_veg: 114, FN_veg: 5900, IoU_veg: 0.3082
# TP_non_veg: 7805, FP_non_veg: 114, FN_non_veg: 8579, IoU_non_veg: 0.4731
# Image 196:
# TP_veg: 1963, FP_veg: 0, FN_veg: 11506, IoU_veg: 0.1457
# TP_non_veg: 2915, FP_non_veg: 0, FN_non_veg: 13469, IoU_non_veg: 0.1779
# Image 197:
# TP_veg: 519, FP_veg: 0, FN_veg: 5736, IoU_veg: 0.0830
# TP_non_veg: 10129, FP_non_veg: 0, FN_non_veg: 6255, IoU_non_veg: 0.6182
# Image 198:
# TP_veg: 4394, FP_veg: 0, FN_veg: 6140, IoU_veg: 0.4171
# TP_non_veg: 5850, FP_non_veg: 0, FN_non_veg: 10534, IoU_non_veg: 0.3571
# Image 199:
# TP_veg: 263, FP_veg: 0, FN_veg: 16121, IoU_veg: 0.0161
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 200:
# TP_veg: 2199, FP_veg: 0, FN_veg: 14185, IoU_veg: 0.1342
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 201:
# TP_veg: 79, FP_veg: 0, FN_veg: 16305, IoU_veg: 0.0048
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 202:
# TP_veg: 0, FP_veg: 0, FN_veg: 16384, IoU_veg: 0.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 203:
# TP_veg: 370, FP_veg: 0, FN_veg: 16014, IoU_veg: 0.0226
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 204:
# TP_veg: 2002, FP_veg: 10, FN_veg: 4119, IoU_veg: 0.3265
# TP_non_veg: 10263, FP_non_veg: 10, FN_non_veg: 6121, IoU_non_veg: 0.6260
# Image 205:
# TP_veg: 519, FP_veg: 0, FN_veg: 8078, IoU_veg: 0.0604
# TP_non_veg: 7787, FP_non_veg: 0, FN_non_veg: 8597, IoU_non_veg: 0.4753
# Image 206:
# TP_veg: 268, FP_veg: 38, FN_veg: 934, IoU_veg: 0.2161
# TP_non_veg: 15182, FP_non_veg: 38, FN_non_veg: 1202, IoU_non_veg: 0.9245
# Image 207:
# TP_veg: 844, FP_veg: 0, FN_veg: 9221, IoU_veg: 0.0839
# TP_non_veg: 6319, FP_non_veg: 0, FN_non_veg: 10065, IoU_non_veg: 0.3857
# Image 208:
# TP_veg: 4000, FP_veg: 0, FN_veg: 12384, IoU_veg: 0.2441
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 209:
# TP_veg: 9090, FP_veg: 0, FN_veg: 7294, IoU_veg: 0.5548
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 210:
# TP_veg: 2243, FP_veg: 7, FN_veg: 5330, IoU_veg: 0.2959
# TP_non_veg: 8811, FP_non_veg: 7, FN_non_veg: 7573, IoU_non_veg: 0.5376
# Image 211:
# TP_veg: 12793, FP_veg: 0, FN_veg: 3560, IoU_veg: 0.7823
# TP_non_veg: 31, FP_non_veg: 0, FN_non_veg: 16353, IoU_non_veg: 0.0019
# Image 212:
# TP_veg: 1550, FP_veg: 0, FN_veg: 5350, IoU_veg: 0.2246
# TP_non_veg: 9484, FP_non_veg: 0, FN_non_veg: 6900, IoU_non_veg: 0.5789
# Image 213:
# TP_veg: 5129, FP_veg: 31, FN_veg: 2799, IoU_veg: 0.6444
# TP_non_veg: 8456, FP_non_veg: 31, FN_non_veg: 7928, IoU_non_veg: 0.5151
# Image 214:
# TP_veg: 2225, FP_veg: 0, FN_veg: 12741, IoU_veg: 0.1487
# TP_non_veg: 1418, FP_non_veg: 0, FN_non_veg: 14966, IoU_non_veg: 0.0865
# Image 215:
# TP_veg: 229, FP_veg: 0, FN_veg: 14920, IoU_veg: 0.0151
# TP_non_veg: 1235, FP_non_veg: 0, FN_non_veg: 15149, IoU_non_veg: 0.0754
# Image 216:
# TP_veg: 361, FP_veg: 0, FN_veg: 15827, IoU_veg: 0.0223
# TP_non_veg: 196, FP_non_veg: 0, FN_non_veg: 16188, IoU_non_veg: 0.0120
# Image 217:
# TP_veg: 644, FP_veg: 0, FN_veg: 14595, IoU_veg: 0.0423
# TP_non_veg: 1145, FP_non_veg: 0, FN_non_veg: 15239, IoU_non_veg: 0.0699
# Image 218:
# TP_veg: 5, FP_veg: 0, FN_veg: 11457, IoU_veg: 0.0004
# TP_non_veg: 4922, FP_non_veg: 0, FN_non_veg: 11462, IoU_non_veg: 0.3004
# Image 219:
# TP_veg: 6933, FP_veg: 0, FN_veg: 9112, IoU_veg: 0.4321
# TP_non_veg: 339, FP_non_veg: 0, FN_non_veg: 16045, IoU_non_veg: 0.0207
# Image 220:
# TP_veg: 0, FP_veg: 0, FN_veg: 2348, IoU_veg: 0.0000
# TP_non_veg: 14036, FP_non_veg: 0, FN_non_veg: 2348, IoU_non_veg: 0.8567
# Image 221:
# TP_veg: 361, FP_veg: 3, FN_veg: 1563, IoU_veg: 0.1873
# TP_non_veg: 14460, FP_non_veg: 3, FN_non_veg: 1924, IoU_non_veg: 0.8824
# Image 222:
# TP_veg: 858, FP_veg: 0, FN_veg: 3543, IoU_veg: 0.1950
# TP_non_veg: 11983, FP_non_veg: 0, FN_non_veg: 4401, IoU_non_veg: 0.7314
# Image 223:
# TP_veg: 12093, FP_veg: 0, FN_veg: 4222, IoU_veg: 0.7412
# TP_non_veg: 69, FP_non_veg: 0, FN_non_veg: 16315, IoU_non_veg: 0.0042
# Image 224:
# TP_veg: 13228, FP_veg: 0, FN_veg: 3156, IoU_veg: 0.8074
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 225:
# TP_veg: 6381, FP_veg: 0, FN_veg: 2068, IoU_veg: 0.7552
# TP_non_veg: 7935, FP_non_veg: 0, FN_non_veg: 8449, IoU_non_veg: 0.4843
# Image 226:
# TP_veg: 11933, FP_veg: 0, FN_veg: 4451, IoU_veg: 0.7283
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 227:
# TP_veg: 3475, FP_veg: 0, FN_veg: 2665, IoU_veg: 0.5660
# TP_non_veg: 10244, FP_non_veg: 0, FN_non_veg: 6140, IoU_non_veg: 0.6252
# Image 228:
# TP_veg: 3944, FP_veg: 0, FN_veg: 8625, IoU_veg: 0.3138
# TP_non_veg: 3815, FP_non_veg: 0, FN_non_veg: 12569, IoU_non_veg: 0.2328
# Image 229:
# TP_veg: 0, FP_veg: 0, FN_veg: 2739, IoU_veg: 0.0000
# TP_non_veg: 13645, FP_non_veg: 0, FN_non_veg: 2739, IoU_non_veg: 0.8328
# Image 230:
# TP_veg: 80, FP_veg: 0, FN_veg: 5103, IoU_veg: 0.0154
# TP_non_veg: 11201, FP_non_veg: 0, FN_non_veg: 5183, IoU_non_veg: 0.6837
# Image 231:
# TP_veg: 0, FP_veg: 0, FN_veg: 224, IoU_veg: 0.0000
# TP_non_veg: 16160, FP_non_veg: 0, FN_non_veg: 224, IoU_non_veg: 0.9863
# Image 232:
# TP_veg: 462, FP_veg: 0, FN_veg: 5513, IoU_veg: 0.0773
# TP_non_veg: 10409, FP_non_veg: 0, FN_non_veg: 5975, IoU_non_veg: 0.6353
# Image 233:
# TP_veg: 282, FP_veg: 0, FN_veg: 1169, IoU_veg: 0.1943
# TP_non_veg: 14933, FP_non_veg: 0, FN_non_veg: 1451, IoU_non_veg: 0.9114
# Image 234:
# TP_veg: 5790, FP_veg: 0, FN_veg: 3625, IoU_veg: 0.6150
# TP_non_veg: 6969, FP_non_veg: 0, FN_non_veg: 9415, IoU_non_veg: 0.4254
# Image 235:
# TP_veg: 2199, FP_veg: 1, FN_veg: 5442, IoU_veg: 0.2878
# TP_non_veg: 8743, FP_non_veg: 1, FN_non_veg: 7641, IoU_non_veg: 0.5336
# Image 236:
# TP_veg: 931, FP_veg: 20, FN_veg: 3078, IoU_veg: 0.2311
# TP_non_veg: 12375, FP_non_veg: 20, FN_non_veg: 4009, IoU_non_veg: 0.7544
# Image 237:
# TP_veg: 59, FP_veg: 0, FN_veg: 410, IoU_veg: 0.1258
# TP_non_veg: 15915, FP_non_veg: 0, FN_non_veg: 469, IoU_non_veg: 0.9714
# Image 238:
# TP_veg: 1825, FP_veg: 0, FN_veg: 4590, IoU_veg: 0.2845
# TP_non_veg: 9969, FP_non_veg: 0, FN_non_veg: 6415, IoU_non_veg: 0.6085
# Image 239:
# TP_veg: 7140, FP_veg: 0, FN_veg: 8831, IoU_veg: 0.4471
# TP_non_veg: 413, FP_non_veg: 0, FN_non_veg: 15971, IoU_non_veg: 0.0252
# Image 240:
# TP_veg: 3608, FP_veg: 34, FN_veg: 2382, IoU_veg: 0.5989
# TP_non_veg: 10394, FP_non_veg: 34, FN_non_veg: 5990, IoU_non_veg: 0.6331
# Image 241:
# TP_veg: 660, FP_veg: 17, FN_veg: 590, IoU_veg: 0.5209
# TP_non_veg: 15134, FP_non_veg: 17, FN_non_veg: 1250, IoU_non_veg: 0.9227
# Image 242:
# TP_veg: 379, FP_veg: 1, FN_veg: 223, IoU_veg: 0.6285
# TP_non_veg: 15782, FP_non_veg: 1, FN_non_veg: 602, IoU_non_veg: 0.9632
# Image 243:
# TP_veg: 13362, FP_veg: 36, FN_veg: 1296, IoU_veg: 0.9094
# TP_non_veg: 1726, FP_non_veg: 36, FN_non_veg: 14658, IoU_non_veg: 0.1051
# Image 244:
# TP_veg: 980, FP_veg: 27, FN_veg: 1042, IoU_veg: 0.4783
# TP_non_veg: 14362, FP_non_veg: 27, FN_non_veg: 2022, IoU_non_veg: 0.8751
# Image 245:
# TP_veg: 5921, FP_veg: 129, FN_veg: 1526, IoU_veg: 0.7815
# TP_non_veg: 8937, FP_non_veg: 129, FN_non_veg: 7447, IoU_non_veg: 0.5412
# Image 246:
# TP_veg: 936, FP_veg: 14, FN_veg: 1484, IoU_veg: 0.3846
# TP_non_veg: 13964, FP_non_veg: 14, FN_non_veg: 2420, IoU_non_veg: 0.8516
# Image 247:
# TP_veg: 4887, FP_veg: 0, FN_veg: 5123, IoU_veg: 0.4882
# TP_non_veg: 6374, FP_non_veg: 0, FN_non_veg: 10010, IoU_non_veg: 0.3890
# Image 248:
# TP_veg: 7973, FP_veg: 27, FN_veg: 5135, IoU_veg: 0.6070
# TP_non_veg: 3276, FP_non_veg: 27, FN_non_veg: 13108, IoU_non_veg: 0.1996
# Image 249:
# TP_veg: 13339, FP_veg: 9, FN_veg: 2136, IoU_veg: 0.8615
# TP_non_veg: 909, FP_non_veg: 9, FN_non_veg: 15475, IoU_non_veg: 0.0555
# Image 250:
# TP_veg: 10594, FP_veg: 7, FN_veg: 2717, IoU_veg: 0.7955
# TP_non_veg: 3073, FP_non_veg: 7, FN_non_veg: 13311, IoU_non_veg: 0.1875
# Image 251:
# TP_veg: 7716, FP_veg: 120, FN_veg: 337, IoU_veg: 0.9441
# TP_non_veg: 8331, FP_non_veg: 120, FN_non_veg: 8053, IoU_non_veg: 0.5048
# Image 252:
# TP_veg: 71, FP_veg: 56, FN_veg: 465, IoU_veg: 0.1199
# TP_non_veg: 15848, FP_non_veg: 56, FN_non_veg: 536, IoU_non_veg: 0.9640
# Image 253:
# TP_veg: 1502, FP_veg: 35, FN_veg: 637, IoU_veg: 0.6909
# TP_non_veg: 14245, FP_non_veg: 35, FN_non_veg: 2139, IoU_non_veg: 0.8676
# Image 254:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 255:
# TP_veg: 2370, FP_veg: 92, FN_veg: 696, IoU_veg: 0.7505
# TP_non_veg: 13318, FP_non_veg: 92, FN_non_veg: 3066, IoU_non_veg: 0.8083
# Image 256:
# TP_veg: 12251, FP_veg: 74, FN_veg: 2123, IoU_veg: 0.8479
# TP_non_veg: 2010, FP_non_veg: 74, FN_non_veg: 14374, IoU_non_veg: 0.1221
# Image 257:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 258:
# TP_veg: 10910, FP_veg: 0, FN_veg: 5474, IoU_veg: 0.6659
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 259:
# TP_veg: 13372, FP_veg: 0, FN_veg: 3012, IoU_veg: 0.8162
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 260:
# TP_veg: 3943, FP_veg: 0, FN_veg: 12441, IoU_veg: 0.2407
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 261:
# TP_veg: 12326, FP_veg: 0, FN_veg: 4058, IoU_veg: 0.7523
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 262:
# TP_veg: 27, FP_veg: 0, FN_veg: 277, IoU_veg: 0.0888
# TP_non_veg: 16080, FP_non_veg: 0, FN_non_veg: 304, IoU_non_veg: 0.9814
# Image 263:
# TP_veg: 610, FP_veg: 38, FN_veg: 1211, IoU_veg: 0.3281
# TP_non_veg: 14563, FP_non_veg: 38, FN_non_veg: 1821, IoU_non_veg: 0.8868
# Image 264:
# TP_veg: 73, FP_veg: 0, FN_veg: 223, IoU_veg: 0.2466
# TP_non_veg: 16088, FP_non_veg: 0, FN_non_veg: 296, IoU_non_veg: 0.9819
# Image 265:
# TP_veg: 35, FP_veg: 0, FN_veg: 512, IoU_veg: 0.0640
# TP_non_veg: 15837, FP_non_veg: 0, FN_non_veg: 547, IoU_non_veg: 0.9666
# Image 266:
# TP_veg: 3635, FP_veg: 0, FN_veg: 3063, IoU_veg: 0.5427
# TP_non_veg: 9686, FP_non_veg: 0, FN_non_veg: 6698, IoU_non_veg: 0.5912
# Image 267:
# TP_veg: 206, FP_veg: 0, FN_veg: 895, IoU_veg: 0.1871
# TP_non_veg: 15283, FP_non_veg: 0, FN_non_veg: 1101, IoU_non_veg: 0.9328
# Image 268:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 269:
# TP_veg: 780, FP_veg: 19, FN_veg: 3881, IoU_veg: 0.1667
# TP_non_veg: 11723, FP_non_veg: 19, FN_non_veg: 4661, IoU_non_veg: 0.7147
# Image 270:
# TP_veg: 3518, FP_veg: 94, FN_veg: 2887, IoU_veg: 0.5413
# TP_non_veg: 9979, FP_non_veg: 94, FN_non_veg: 6405, IoU_non_veg: 0.6056
# Image 271:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 272:
# TP_veg: 11838, FP_veg: 36, FN_veg: 1699, IoU_veg: 0.8722
# TP_non_veg: 2847, FP_non_veg: 36, FN_non_veg: 13537, IoU_non_veg: 0.1734
# Image 273:
# TP_veg: 9699, FP_veg: 1, FN_veg: 6498, IoU_veg: 0.5988
# TP_non_veg: 187, FP_non_veg: 1, FN_non_veg: 16197, IoU_non_veg: 0.0114
# Image 274:
# TP_veg: 12819, FP_veg: 0, FN_veg: 3565, IoU_veg: 0.7824
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 275:
# TP_veg: 8821, FP_veg: 0, FN_veg: 7563, IoU_veg: 0.5384
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 276:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 277:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 278:
# TP_veg: 769, FP_veg: 0, FN_veg: 780, IoU_veg: 0.4964
# TP_non_veg: 14835, FP_non_veg: 0, FN_non_veg: 1549, IoU_non_veg: 0.9055
# Image 279:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 280:
# TP_veg: 176, FP_veg: 0, FN_veg: 194, IoU_veg: 0.4757
# TP_non_veg: 16014, FP_non_veg: 0, FN_non_veg: 370, IoU_non_veg: 0.9774
# Image 281:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 282:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 283:
# TP_veg: 5731, FP_veg: 43, FN_veg: 4380, IoU_veg: 0.5644
# TP_non_veg: 6273, FP_non_veg: 43, FN_non_veg: 10111, IoU_non_veg: 0.3819
# Image 284:
# TP_veg: 3151, FP_veg: 113, FN_veg: 2629, IoU_veg: 0.5347
# TP_non_veg: 10604, FP_non_veg: 113, FN_non_veg: 5780, IoU_non_veg: 0.6428
# Image 285:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 286:
# TP_veg: 0, FP_veg: 0, FN_veg: 253, IoU_veg: 0.0000
# TP_non_veg: 16131, FP_non_veg: 0, FN_non_veg: 253, IoU_non_veg: 0.9846
# Image 287:
# TP_veg: 2229, FP_veg: 0, FN_veg: 5557, IoU_veg: 0.2863
# TP_non_veg: 8598, FP_non_veg: 0, FN_non_veg: 7786, IoU_non_veg: 0.5248
# Image 288:
# TP_veg: 9243, FP_veg: 0, FN_veg: 7141, IoU_veg: 0.5641
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 289:
# TP_veg: 14187, FP_veg: 10, FN_veg: 1460, IoU_veg: 0.9061
# TP_non_veg: 737, FP_non_veg: 10, FN_non_veg: 15647, IoU_non_veg: 0.0450
# Image 290:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 291:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 292:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 293:
# TP_veg: 219, FP_veg: 0, FN_veg: 417, IoU_veg: 0.3443
# TP_non_veg: 15748, FP_non_veg: 0, FN_non_veg: 636, IoU_non_veg: 0.9612
# Image 294:
# TP_veg: 163, FP_veg: 0, FN_veg: 140, IoU_veg: 0.5380
# TP_non_veg: 16081, FP_non_veg: 0, FN_non_veg: 303, IoU_non_veg: 0.9815
# Image 295:
# TP_veg: 431, FP_veg: 1, FN_veg: 156, IoU_veg: 0.7330
# TP_non_veg: 15797, FP_non_veg: 1, FN_non_veg: 587, IoU_non_veg: 0.9641
# Image 296:
# TP_veg: 4477, FP_veg: 3, FN_veg: 1871, IoU_veg: 0.7049
# TP_non_veg: 10036, FP_non_veg: 3, FN_non_veg: 6348, IoU_non_veg: 0.6124
# Image 297:
# TP_veg: 124, FP_veg: 1, FN_veg: 100, IoU_veg: 0.5511
# TP_non_veg: 16160, FP_non_veg: 1, FN_non_veg: 224, IoU_non_veg: 0.9863
# Image 298:
# TP_veg: 2631, FP_veg: 24, FN_veg: 5337, IoU_veg: 0.3292
# TP_non_veg: 8416, FP_non_veg: 24, FN_non_veg: 7968, IoU_non_veg: 0.5129
# Image 299:
# TP_veg: 1683, FP_veg: 8, FN_veg: 211, IoU_veg: 0.8849
# TP_non_veg: 14490, FP_non_veg: 8, FN_non_veg: 1894, IoU_non_veg: 0.8840
# Image 300:
# TP_veg: 1547, FP_veg: 0, FN_veg: 3518, IoU_veg: 0.3054
# TP_non_veg: 11319, FP_non_veg: 0, FN_non_veg: 5065, IoU_non_veg: 0.6909
# Image 301:
# TP_veg: 2363, FP_veg: 0, FN_veg: 2936, IoU_veg: 0.4459
# TP_non_veg: 11085, FP_non_veg: 0, FN_non_veg: 5299, IoU_non_veg: 0.6766
# Image 302:
# TP_veg: 1865, FP_veg: 40, FN_veg: 5440, IoU_veg: 0.2539
# TP_non_veg: 9079, FP_non_veg: 40, FN_non_veg: 7305, IoU_non_veg: 0.5528
# Image 303:
# TP_veg: 4304, FP_veg: 39, FN_veg: 1600, IoU_veg: 0.7242
# TP_non_veg: 10480, FP_non_veg: 39, FN_non_veg: 5904, IoU_non_veg: 0.6381
# Image 304:
# TP_veg: 4028, FP_veg: 4, FN_veg: 6931, IoU_veg: 0.3674
# TP_non_veg: 5425, FP_non_veg: 4, FN_non_veg: 10959, IoU_non_veg: 0.3310
# Image 305:
# TP_veg: 8612, FP_veg: 0, FN_veg: 7772, IoU_veg: 0.5256
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 306:
# TP_veg: 13909, FP_veg: 0, FN_veg: 2475, IoU_veg: 0.8489
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 307:
# TP_veg: 8044, FP_veg: 1, FN_veg: 7656, IoU_veg: 0.5123
# TP_non_veg: 684, FP_non_veg: 1, FN_non_veg: 15700, IoU_non_veg: 0.0417
# Image 308:
# TP_veg: 603, FP_veg: 0, FN_veg: 4673, IoU_veg: 0.1143
# TP_non_veg: 11108, FP_non_veg: 0, FN_non_veg: 5276, IoU_non_veg: 0.6780
# Image 309:
# TP_veg: 5247, FP_veg: 56, FN_veg: 1532, IoU_veg: 0.7677
# TP_non_veg: 9605, FP_non_veg: 56, FN_non_veg: 6779, IoU_non_veg: 0.5842
# Image 310:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 311:
# TP_veg: 1653, FP_veg: 5, FN_veg: 1752, IoU_veg: 0.4848
# TP_non_veg: 12979, FP_non_veg: 5, FN_non_veg: 3405, IoU_non_veg: 0.7919
# Image 312:
# TP_veg: 5952, FP_veg: 101, FN_veg: 3064, IoU_veg: 0.6528
# TP_non_veg: 7368, FP_non_veg: 101, FN_non_veg: 9016, IoU_non_veg: 0.4470
# Image 313:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 314:
# TP_veg: 5370, FP_veg: 47, FN_veg: 2599, IoU_veg: 0.6699
# TP_non_veg: 8415, FP_non_veg: 47, FN_non_veg: 7969, IoU_non_veg: 0.5121
# Image 315:
# TP_veg: 5500, FP_veg: 6, FN_veg: 6014, IoU_veg: 0.4774
# TP_non_veg: 4870, FP_non_veg: 6, FN_non_veg: 11514, IoU_non_veg: 0.2971
# Image 316:
# TP_veg: 16125, FP_veg: 0, FN_veg: 259, IoU_veg: 0.9842
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 317:
# TP_veg: 11486, FP_veg: 62, FN_veg: 954, IoU_veg: 0.9187
# TP_non_veg: 3944, FP_non_veg: 62, FN_non_veg: 12440, IoU_non_veg: 0.2398
# Image 318:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 319:
# TP_veg: 0, FP_veg: 0, FN_veg: 24, IoU_veg: 0.0000
# TP_non_veg: 16360, FP_non_veg: 0, FN_non_veg: 24, IoU_non_veg: 0.9985
# Image 320:
# TP_veg: 1739, FP_veg: 0, FN_veg: 4082, IoU_veg: 0.2987
# TP_non_veg: 10563, FP_non_veg: 0, FN_non_veg: 5821, IoU_non_veg: 0.6447
# Image 321:
# TP_veg: 138, FP_veg: 0, FN_veg: 464, IoU_veg: 0.2292
# TP_non_veg: 15782, FP_non_veg: 0, FN_non_veg: 602, IoU_non_veg: 0.9633
# Image 322:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 323:
# TP_veg: 588, FP_veg: 0, FN_veg: 910, IoU_veg: 0.3925
# TP_non_veg: 14886, FP_non_veg: 0, FN_non_veg: 1498, IoU_non_veg: 0.9086
# Image 324:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 325:
# TP_veg: 8820, FP_veg: 0, FN_veg: 1079, IoU_veg: 0.8910
# TP_non_veg: 6485, FP_non_veg: 0, FN_non_veg: 9899, IoU_non_veg: 0.3958
# Image 326:
# TP_veg: 597, FP_veg: 1, FN_veg: 511, IoU_veg: 0.5383
# TP_non_veg: 15276, FP_non_veg: 1, FN_non_veg: 1108, IoU_non_veg: 0.9323
# Image 327:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 328:
# TP_veg: 151, FP_veg: 12, FN_veg: 197, IoU_veg: 0.4194
# TP_non_veg: 16036, FP_non_veg: 12, FN_non_veg: 348, IoU_non_veg: 0.9780
# Image 329:
# TP_veg: 8021, FP_veg: 0, FN_veg: 5166, IoU_veg: 0.6083
# TP_non_veg: 3197, FP_non_veg: 0, FN_non_veg: 13187, IoU_non_veg: 0.1951
# Image 330:
# TP_veg: 12252, FP_veg: 0, FN_veg: 4132, IoU_veg: 0.7478
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 331:
# TP_veg: 3190, FP_veg: 0, FN_veg: 2383, IoU_veg: 0.5724
# TP_non_veg: 10811, FP_non_veg: 0, FN_non_veg: 5573, IoU_non_veg: 0.6599
# Image 332:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 333:
# TP_veg: 39, FP_veg: 2, FN_veg: 341, IoU_veg: 0.1021
# TP_non_veg: 16004, FP_non_veg: 2, FN_non_veg: 380, IoU_non_veg: 0.9767
# Image 334:
# TP_veg: 1446, FP_veg: 0, FN_veg: 1643, IoU_veg: 0.4681
# TP_non_veg: 13295, FP_non_veg: 0, FN_non_veg: 3089, IoU_non_veg: 0.8115
# Image 335:
# TP_veg: 2097, FP_veg: 3, FN_veg: 1676, IoU_veg: 0.5553
# TP_non_veg: 12611, FP_non_veg: 3, FN_non_veg: 3773, IoU_non_veg: 0.7696
# Image 336:
# TP_veg: 615, FP_veg: 37, FN_veg: 1079, IoU_veg: 0.3553
# TP_non_veg: 14690, FP_non_veg: 37, FN_non_veg: 1694, IoU_non_veg: 0.8946
# Image 337:
# TP_veg: 14272, FP_veg: 1, FN_veg: 1493, IoU_veg: 0.9052
# TP_non_veg: 619, FP_non_veg: 1, FN_non_veg: 15765, IoU_non_veg: 0.0378
# Image 338:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 339:
# TP_veg: 9147, FP_veg: 0, FN_veg: 7237, IoU_veg: 0.5583
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 340:
# TP_veg: 7779, FP_veg: 89, FN_veg: 2235, IoU_veg: 0.7700
# TP_non_veg: 6370, FP_non_veg: 89, FN_non_veg: 10014, IoU_non_veg: 0.3867
# Image 341:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 342:
# TP_veg: 3990, FP_veg: 0, FN_veg: 687, IoU_veg: 0.8531
# TP_non_veg: 11707, FP_non_veg: 0, FN_non_veg: 4677, IoU_non_veg: 0.7145
# Image 343:
# TP_veg: 653, FP_veg: 14, FN_veg: 1095, IoU_veg: 0.3706
# TP_non_veg: 14636, FP_non_veg: 14, FN_non_veg: 1748, IoU_non_veg: 0.8925
# Image 344:
# TP_veg: 2642, FP_veg: 0, FN_veg: 5808, IoU_veg: 0.3127
# TP_non_veg: 7934, FP_non_veg: 0, FN_non_veg: 8450, IoU_non_veg: 0.4843
# Image 345:
# TP_veg: 0, FP_veg: 0, FN_veg: 1453, IoU_veg: 0.0000
# TP_non_veg: 14931, FP_non_veg: 0, FN_non_veg: 1453, IoU_non_veg: 0.9113
# Image 346:
# TP_veg: 0, FP_veg: 0, FN_veg: 57, IoU_veg: 0.0000
# TP_non_veg: 16327, FP_non_veg: 0, FN_non_veg: 57, IoU_non_veg: 0.9965
# Image 347:
# TP_veg: 0, FP_veg: 0, FN_veg: 264, IoU_veg: 0.0000
# TP_non_veg: 16120, FP_non_veg: 0, FN_non_veg: 264, IoU_non_veg: 0.9839
# Image 348:
# TP_veg: 0, FP_veg: 0, FN_veg: 156, IoU_veg: 0.0000
# TP_non_veg: 16228, FP_non_veg: 0, FN_non_veg: 156, IoU_non_veg: 0.9905
# Image 349:
# TP_veg: 104, FP_veg: 6, FN_veg: 612, IoU_veg: 0.1440
# TP_non_veg: 15668, FP_non_veg: 6, FN_non_veg: 716, IoU_non_veg: 0.9559
# Image 350:
# TP_veg: 7354, FP_veg: 6, FN_veg: 904, IoU_veg: 0.8899
# TP_non_veg: 8126, FP_non_veg: 6, FN_non_veg: 8258, IoU_non_veg: 0.4958
# Image 351:
# TP_veg: 15040, FP_veg: 0, FN_veg: 1344, IoU_veg: 0.9180
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 352:
# TP_veg: 0, FP_veg: 0, FN_veg: 111, IoU_veg: 0.0000
# ...
# Image 388:
# TP_veg: 1122, FP_veg: 29, FN_veg: 779, IoU_veg: 0.5813
# TP_non_veg: 14483, FP_non_veg: 29, FN_non_veg: 1901, IoU_non_veg: 0.8824
# Image 389:
# TP_veg: 0, FP_veg: 0, FN_veg: 994, IoU_veg: 0.0000
# TP_non_veg: 15390, FP_non_veg: 0, FN_non_veg: 994, IoU_non_veg: 0.9393
# Image 390:
# TP_veg: 4485, FP_veg: 89, FN_veg: 1767, IoU_veg: 0.7073
# TP_non_veg: 10132, FP_non_veg: 89, FN_non_veg: 6252, IoU_non_veg: 0.6151
# Image 391:
# TP_veg: 4067, FP_veg: 34, FN_veg: 2536, IoU_veg: 0.6128
# TP_non_veg: 9781, FP_non_veg: 34, FN_non_veg: 6603, IoU_non_veg: 0.5957
# Image 392:
# TP_veg: 15540, FP_veg: 0, FN_veg: 844, IoU_veg: 0.9485
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 393:
# TP_veg: 12073, FP_veg: 0, FN_veg: 4311, IoU_veg: 0.7369
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 394:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 395:
# TP_veg: 6407, FP_veg: 0, FN_veg: 9977, IoU_veg: 0.3911
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 396:
# TP_veg: 12498, FP_veg: 0, FN_veg: 3885, IoU_veg: 0.7629
# TP_non_veg: 1, FP_non_veg: 0, FN_non_veg: 16383, IoU_non_veg: 0.0001
# Image 397:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 398:
# TP_veg: 9239, FP_veg: 0, FN_veg: 1936, IoU_veg: 0.8268
# TP_non_veg: 5209, FP_non_veg: 0, FN_non_veg: 11175, IoU_non_veg: 0.3179
# Image 399:
# TP_veg: 1068, FP_veg: 0, FN_veg: 661, IoU_veg: 0.6177
# TP_non_veg: 14655, FP_non_veg: 0, FN_non_veg: 1729, IoU_non_veg: 0.8945
# Image 400:
# TP_veg: 47, FP_veg: 0, FN_veg: 1737, IoU_veg: 0.0263
# TP_non_veg: 14600, FP_non_veg: 0, FN_non_veg: 1784, IoU_non_veg: 0.8911
# Image 401:
# TP_veg: 1357, FP_veg: 17, FN_veg: 1223, IoU_veg: 0.5225
# TP_non_veg: 13804, FP_non_veg: 17, FN_non_veg: 2580, IoU_non_veg: 0.8417
# Image 402:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 403:
# TP_veg: 0, FP_veg: 0, FN_veg: 739, IoU_veg: 0.0000
# TP_non_veg: 15645, FP_non_veg: 0, FN_non_veg: 739, IoU_non_veg: 0.9549
# Image 404:
# TP_veg: 1870, FP_veg: 0, FN_veg: 1386, IoU_veg: 0.5743
# TP_non_veg: 13128, FP_non_veg: 0, FN_non_veg: 3256, IoU_non_veg: 0.8013
# Image 405:
# TP_veg: 8560, FP_veg: 67, FN_veg: 1670, IoU_veg: 0.8313
# TP_non_veg: 6154, FP_non_veg: 67, FN_non_veg: 10230, IoU_non_veg: 0.3741
# Image 406:
# TP_veg: 11265, FP_veg: 0, FN_veg: 5119, IoU_veg: 0.6876
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 407:
# TP_veg: 11954, FP_veg: 0, FN_veg: 4430, IoU_veg: 0.7296
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 408:
# TP_veg: 2953, FP_veg: 0, FN_veg: 751, IoU_veg: 0.7972
# TP_non_veg: 12680, FP_non_veg: 0, FN_non_veg: 3704, IoU_non_veg: 0.7739
# Image 409:
# TP_veg: 3393, FP_veg: 73, FN_veg: 4375, IoU_veg: 0.4327
# TP_non_veg: 8616, FP_non_veg: 73, FN_non_veg: 7768, IoU_non_veg: 0.5235
# Image 410:
# TP_veg: 11687, FP_veg: 0, FN_veg: 2614, IoU_veg: 0.8172
# TP_non_veg: 2083, FP_non_veg: 0, FN_non_veg: 14301, IoU_non_veg: 0.1271
# Image 411:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 412:
# TP_veg: 15299, FP_veg: 0, FN_veg: 1085, IoU_veg: 0.9338
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 413:
# TP_veg: 1538, FP_veg: 0, FN_veg: 1191, IoU_veg: 0.5636
# TP_non_veg: 13655, FP_non_veg: 0, FN_non_veg: 2729, IoU_non_veg: 0.8334
# Image 414:
# TP_veg: 448, FP_veg: 0, FN_veg: 2024, IoU_veg: 0.1812
# TP_non_veg: 13912, FP_non_veg: 0, FN_non_veg: 2472, IoU_non_veg: 0.8491
# Image 415:
# TP_veg: 7016, FP_veg: 12, FN_veg: 8602, IoU_veg: 0.4489
# TP_non_veg: 766, FP_non_veg: 12, FN_non_veg: 15618, IoU_non_veg: 0.0467
# Image 416:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 417:
# TP_veg: 0, FP_veg: 0, FN_veg: 87, IoU_veg: 0.0000
# TP_non_veg: 16297, FP_non_veg: 0, FN_non_veg: 87, IoU_non_veg: 0.9947
# Image 418:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 419:
# TP_veg: 2059, FP_veg: 0, FN_veg: 1428, IoU_veg: 0.5905
# TP_non_veg: 12897, FP_non_veg: 0, FN_non_veg: 3487, IoU_non_veg: 0.7872
# Image 420:
# TP_veg: 7699, FP_veg: 23, FN_veg: 4363, IoU_veg: 0.6371
# TP_non_veg: 4322, FP_non_veg: 23, FN_non_veg: 12062, IoU_non_veg: 0.2634
# Image 421:
# TP_veg: 4711, FP_veg: 91, FN_veg: 1129, IoU_veg: 0.7943
# TP_non_veg: 10544, FP_non_veg: 91, FN_non_veg: 5840, IoU_non_veg: 0.6400
# Image 422:
# TP_veg: 0, FP_veg: 0, FN_veg: 2442, IoU_veg: 0.0000
# TP_non_veg: 13942, FP_non_veg: 0, FN_non_veg: 2442, IoU_non_veg: 0.8510
# Image 423:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 424:
# TP_veg: 1981, FP_veg: 0, FN_veg: 3677, IoU_veg: 0.3501
# TP_non_veg: 10726, FP_non_veg: 0, FN_non_veg: 5658, IoU_non_veg: 0.6547
# Image 425:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 426:
# TP_veg: 8020, FP_veg: 0, FN_veg: 8316, IoU_veg: 0.4909
# TP_non_veg: 48, FP_non_veg: 0, FN_non_veg: 16336, IoU_non_veg: 0.0029
# Image 427:
# TP_veg: 6777, FP_veg: 0, FN_veg: 9596, IoU_veg: 0.4139
# TP_non_veg: 11, FP_non_veg: 0, FN_non_veg: 16373, IoU_non_veg: 0.0007
# Image 428:
# TP_veg: 2319, FP_veg: 2, FN_veg: 4045, IoU_veg: 0.3643
# TP_non_veg: 10020, FP_non_veg: 2, FN_non_veg: 6364, IoU_non_veg: 0.6115
# Image 429:
# TP_veg: 6888, FP_veg: 0, FN_veg: 8699, IoU_veg: 0.4419
# TP_non_veg: 797, FP_non_veg: 0, FN_non_veg: 15587, IoU_non_veg: 0.0486
# Image 430:
# TP_veg: 3600, FP_veg: 49, FN_veg: 3489, IoU_veg: 0.5043
# TP_non_veg: 9295, FP_non_veg: 49, FN_non_veg: 7089, IoU_non_veg: 0.5656
# Image 431:
# TP_veg: 5992, FP_veg: 98, FN_veg: 4761, IoU_veg: 0.5522
# TP_non_veg: 5631, FP_non_veg: 98, FN_non_veg: 10753, IoU_non_veg: 0.3416
# Image 432:
# TP_veg: 11780, FP_veg: 0, FN_veg: 4285, IoU_veg: 0.7333
# TP_non_veg: 319, FP_non_veg: 0, FN_non_veg: 16065, IoU_non_veg: 0.0195
# Image 433:
# TP_veg: 6627, FP_veg: 0, FN_veg: 9757, IoU_veg: 0.4045
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 434:
# TP_veg: 11040, FP_veg: 0, FN_veg: 5344, IoU_veg: 0.6738
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 435:
# TP_veg: 5316, FP_veg: 2, FN_veg: 1415, IoU_veg: 0.7895
# TP_non_veg: 9653, FP_non_veg: 2, FN_non_veg: 6731, IoU_non_veg: 0.5891
# Image 436:
# TP_veg: 0, FP_veg: 0, FN_veg: 278, IoU_veg: 0.0000
# TP_non_veg: 16106, FP_non_veg: 0, FN_non_veg: 278, IoU_non_veg: 0.9830
# Image 437:
# TP_veg: 0, FP_veg: 0, FN_veg: 336, IoU_veg: 0.0000
# TP_non_veg: 16048, FP_non_veg: 0, FN_non_veg: 336, IoU_non_veg: 0.9795
# Image 438:
# TP_veg: 2445, FP_veg: 0, FN_veg: 6757, IoU_veg: 0.2657
# TP_non_veg: 7182, FP_non_veg: 0, FN_non_veg: 9202, IoU_non_veg: 0.4384
# Image 439:
# TP_veg: 0, FP_veg: 0, FN_veg: 3, IoU_veg: 0.0000
# TP_non_veg: 16381, FP_non_veg: 0, FN_non_veg: 3, IoU_non_veg: 0.9998
# Image 440:
# TP_veg: 5684, FP_veg: 0, FN_veg: 10700, IoU_veg: 0.3469
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 441:
# TP_veg: 5977, FP_veg: 0, FN_veg: 10407, IoU_veg: 0.3648
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 442:
# TP_veg: 10901, FP_veg: 0, FN_veg: 5483, IoU_veg: 0.6653
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 443:
# TP_veg: 14665, FP_veg: 0, FN_veg: 1719, IoU_veg: 0.8951
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 444:
# TP_veg: 5236, FP_veg: 33, FN_veg: 3809, IoU_veg: 0.5768
# TP_non_veg: 7339, FP_non_veg: 33, FN_non_veg: 9045, IoU_non_veg: 0.4470
# Image 445:
# TP_veg: 218, FP_veg: 25, FN_veg: 227, IoU_veg: 0.4638
# TP_non_veg: 15939, FP_non_veg: 25, FN_non_veg: 445, IoU_non_veg: 0.9714
# Image 446:
# TP_veg: 0, FP_veg: 0, FN_veg: 2751, IoU_veg: 0.0000
# TP_non_veg: 13633, FP_non_veg: 0, FN_non_veg: 2751, IoU_non_veg: 0.8321
# Image 447:
# TP_veg: 596, FP_veg: 0, FN_veg: 11809, IoU_veg: 0.0480
# TP_non_veg: 3979, FP_non_veg: 0, FN_non_veg: 12405, IoU_non_veg: 0.2429
# Image 448:
# TP_veg: 13084, FP_veg: 20, FN_veg: 1346, IoU_veg: 0.9055
# TP_non_veg: 1954, FP_non_veg: 20, FN_non_veg: 14430, IoU_non_veg: 0.1191
# Image 449:
# TP_veg: 272, FP_veg: 5, FN_veg: 1544, IoU_veg: 0.1494
# TP_non_veg: 14568, FP_non_veg: 5, FN_non_veg: 1816, IoU_non_veg: 0.8889
# Image 450:
# TP_veg: 0, FP_veg: 0, FN_veg: 186, IoU_veg: 0.0000
# TP_non_veg: 16198, FP_non_veg: 0, FN_non_veg: 186, IoU_non_veg: 0.9886
# Image 451:
# TP_veg: 0, FP_veg: 0, FN_veg: 462, IoU_veg: 0.0000
# TP_non_veg: 15922, FP_non_veg: 0, FN_non_veg: 462, IoU_non_veg: 0.9718
# Image 452:
# TP_veg: 4178, FP_veg: 0, FN_veg: 6119, IoU_veg: 0.4057
# TP_non_veg: 6087, FP_non_veg: 0, FN_non_veg: 10297, IoU_non_veg: 0.3715
# Image 453:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 454:
# TP_veg: 41, FP_veg: 0, FN_veg: 7694, IoU_veg: 0.0053
# TP_non_veg: 8649, FP_non_veg: 0, FN_non_veg: 7735, IoU_non_veg: 0.5279
# Image 455:
# TP_veg: 8442, FP_veg: 0, FN_veg: 7942, IoU_veg: 0.5153
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 456:
# TP_veg: 16376, FP_veg: 0, FN_veg: 8, IoU_veg: 0.9995
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 457:
# TP_veg: 11445, FP_veg: 0, FN_veg: 4939, IoU_veg: 0.6985
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 458:
# TP_veg: 222, FP_veg: 0, FN_veg: 3646, IoU_veg: 0.0574
# TP_non_veg: 12516, FP_non_veg: 0, FN_non_veg: 3868, IoU_non_veg: 0.7639
# Image 459:
# TP_veg: 4907, FP_veg: 94, FN_veg: 3964, IoU_veg: 0.5474
# TP_non_veg: 7513, FP_non_veg: 94, FN_non_veg: 8871, IoU_non_veg: 0.4559
# Image 460:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 461:
# TP_veg: 129, FP_veg: 0, FN_veg: 309, IoU_veg: 0.2945
# TP_non_veg: 15946, FP_non_veg: 0, FN_non_veg: 438, IoU_non_veg: 0.9733
# Image 462:
# TP_veg: 2444, FP_veg: 60, FN_veg: 257, IoU_veg: 0.8852
# TP_non_veg: 13683, FP_non_veg: 60, FN_non_veg: 2701, IoU_non_veg: 0.8321
# Image 463:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 464:
# TP_veg: 30, FP_veg: 0, FN_veg: 828, IoU_veg: 0.0350
# TP_non_veg: 15526, FP_non_veg: 0, FN_non_veg: 858, IoU_non_veg: 0.9476
# Image 465:
# TP_veg: 9631, FP_veg: 5, FN_veg: 3987, IoU_veg: 0.7070
# TP_non_veg: 2766, FP_non_veg: 5, FN_non_veg: 13618, IoU_non_veg: 0.1688
# Image 466:
# TP_veg: 6023, FP_veg: 9, FN_veg: 5721, IoU_veg: 0.5125
# TP_non_veg: 4640, FP_non_veg: 9, FN_non_veg: 11744, IoU_non_veg: 0.2830
# Image 467:
# TP_veg: 787, FP_veg: 0, FN_veg: 835, IoU_veg: 0.4852
# TP_non_veg: 14762, FP_non_veg: 0, FN_non_veg: 1622, IoU_non_veg: 0.9010
# Image 468:
# TP_veg: 10261, FP_veg: 0, FN_veg: 5344, IoU_veg: 0.6575
# TP_non_veg: 779, FP_non_veg: 0, FN_non_veg: 15605, IoU_non_veg: 0.0475
# Image 469:
# TP_veg: 14245, FP_veg: 0, FN_veg: 2139, IoU_veg: 0.8694
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 470:
# TP_veg: 16384, FP_veg: 0, FN_veg: 0, IoU_veg: 1.0000
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 471:
# TP_veg: 13055, FP_veg: 0, FN_veg: 3329, IoU_veg: 0.7968
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 472:
# TP_veg: 1534, FP_veg: 0, FN_veg: 3798, IoU_veg: 0.2877
# TP_non_veg: 11052, FP_non_veg: 0, FN_non_veg: 5332, IoU_non_veg: 0.6746
# Image 473:
# TP_veg: 1065, FP_veg: 1, FN_veg: 2146, IoU_veg: 0.3316
# TP_non_veg: 13173, FP_non_veg: 1, FN_non_veg: 3211, IoU_non_veg: 0.8040
# Image 474:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 475:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 476:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 477:
# TP_veg: 280, FP_veg: 0, FN_veg: 1526, IoU_veg: 0.1550
# TP_non_veg: 14578, FP_non_veg: 0, FN_non_veg: 1806, IoU_non_veg: 0.8898
# Image 478:
# TP_veg: 446, FP_veg: 0, FN_veg: 725, IoU_veg: 0.3809
# TP_non_veg: 15213, FP_non_veg: 0, FN_non_veg: 1171, IoU_non_veg: 0.9285
# Image 479:
# TP_veg: 10764, FP_veg: 0, FN_veg: 2693, IoU_veg: 0.7999
# TP_non_veg: 2927, FP_non_veg: 0, FN_non_veg: 13457, IoU_non_veg: 0.1786
# Image 480:
# TP_veg: 7010, FP_veg: 0, FN_veg: 9374, IoU_veg: 0.4279
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 481:
# TP_veg: 0, FP_veg: 0, FN_veg: 2842, IoU_veg: 0.0000
# TP_non_veg: 13542, FP_non_veg: 0, FN_non_veg: 2842, IoU_non_veg: 0.8265
# Image 482:
# TP_veg: 14003, FP_veg: 0, FN_veg: 2381, IoU_veg: 0.8547
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 483:
# TP_veg: 13763, FP_veg: 0, FN_veg: 2621, IoU_veg: 0.8400
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 484:
# TP_veg: 13984, FP_veg: 0, FN_veg: 2400, IoU_veg: 0.8535
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 485:
# TP_veg: 4948, FP_veg: 0, FN_veg: 11436, IoU_veg: 0.3020
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 486:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 487:
# TP_veg: 608, FP_veg: 0, FN_veg: 225, IoU_veg: 0.7299
# TP_non_veg: 15551, FP_non_veg: 0, FN_non_veg: 833, IoU_non_veg: 0.9492
# Image 488:
# TP_veg: 1283, FP_veg: 61, FN_veg: 2670, IoU_veg: 0.3196
# TP_non_veg: 12431, FP_non_veg: 61, FN_non_veg: 3953, IoU_non_veg: 0.7559
# Image 489:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 490:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 491:
# TP_veg: 2694, FP_veg: 11, FN_veg: 2049, IoU_veg: 0.5667
# TP_non_veg: 11641, FP_non_veg: 11, FN_non_veg: 4743, IoU_non_veg: 0.7100
# Image 492:
# TP_veg: 199, FP_veg: 0, FN_veg: 382, IoU_veg: 0.3425
# TP_non_veg: 15803, FP_non_veg: 0, FN_non_veg: 581, IoU_non_veg: 0.9645
# Image 493:
# TP_veg: 11, FP_veg: 0, FN_veg: 936, IoU_veg: 0.0116
# TP_non_veg: 15437, FP_non_veg: 0, FN_non_veg: 947, IoU_non_veg: 0.9422
# Image 494:
# TP_veg: 12358, FP_veg: 0, FN_veg: 1802, IoU_veg: 0.8727
# TP_non_veg: 2224, FP_non_veg: 0, FN_non_veg: 14160, IoU_non_veg: 0.1357
# Image 495:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 496:
# TP_veg: 13663, FP_veg: 0, FN_veg: 2721, IoU_veg: 0.8339
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 497:
# TP_veg: 16161, FP_veg: 0, FN_veg: 223, IoU_veg: 0.9864
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 498:
# TP_veg: 7251, FP_veg: 0, FN_veg: 9133, IoU_veg: 0.4426
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 499:
# TP_veg: 6185, FP_veg: 0, FN_veg: 10199, IoU_veg: 0.3775
# TP_non_veg: 0, FP_non_veg: 0, FN_non_veg: 16384, IoU_non_veg: 0.0000
# Image 500:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 501:
# TP_veg: 1, FP_veg: 0, FN_veg: 35, IoU_veg: 0.0278
# TP_non_veg: 16348, FP_non_veg: 0, FN_non_veg: 36, IoU_non_veg: 0.9978
# Image 502:
# TP_veg: 0, FP_veg: 0, FN_veg: 0, IoU_veg: 0.0000
# TP_non_veg: 16384, FP_non_veg: 0, FN_non_veg: 0, IoU_non_veg: 1.0000
# Image 503:
# TP_veg: 1242, FP_veg: 5, FN_veg: 2946, IoU_veg: 0.2962
# TP_non_veg: 12196, FP_non_veg: 5, FN_non_veg: 4188, IoU_non_veg: 0.7442
# Image 504:
# TP_veg: 395, FP_veg: 0, FN_veg: 2067, IoU_veg: 0.1604
# TP_non_veg: 13922, FP_non_veg: 0, FN_non_veg: 2462, IoU_non_veg: 0.8497
# Image 505:
# TP_veg: 201, FP_veg: 0, FN_veg: 484, IoU_veg: 0.2934
# TP_non_veg: 15699, FP_non_veg: 0, FN_non_veg: 685, IoU_non_veg: 0.9582

# %%
# mean_iou_vegetation = np.mean(IoU_vegetation)
# mean_iou_non_vegetation = np.mean(IoU_non_vegetation)
# mean_all_iou = (mean_iou_vegetation + mean_iou_non_vegetation) / 2
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_iou_vegetation * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_iou_non_vegetation * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_all_iou * 100), "%")

# %%
tp_veg_overall = np.sum(TP_vegetation)
fp_veg_overall = np.sum(FP_vegetation)
fn_veg_overall = np.sum(FN_vegetation)

print("TP Vegetation: ", tp_veg_overall)
print("FP Vegetation: ", fp_veg_overall)
print("FN Vegetation: ", fn_veg_overall)

IoU_veg_overall = tp_veg_overall / (tp_veg_overall + fp_veg_overall + fn_veg_overall)
print("IoU Vegetation: ", IoU_veg_overall)

tp_non_veg_overall = np.sum(TP_non_vegetation)
fp_non_veg_overall = np.sum(FP_non_vegetation)
fn_non_veg_overall = np.sum(FN_non_vegetation)

print("\nTP Non-Vegetation: ", tp_non_veg_overall)
print("FP Non-Vegetation: ", fp_non_veg_overall)
print("FN Non-Vegetation: ", fn_non_veg_overall)

IoU_non_veg_overall = tp_non_veg_overall / (tp_non_veg_overall + fp_non_veg_overall + fn_non_veg_overall)
print("IoU Non-Vegetation: ", IoU_non_veg_overall)

IoU_overall = (IoU_veg_overall + IoU_non_veg_overall)/2
print("\nIoU Overall: ", IoU_overall)
# Out:
# TP Vegetation:  1741138
# FP Vegetation:  5106
# FN Vegetation:  2021096
# IoU Vegetation:  0.46216640919056945
#
# TP Non-Vegetation:  4511686
# FP Non-Vegetation:  5106
# FN Non-Vegetation:  3762234
# IoU Non-Vegetation:  0.5449537179856664
#
# IoU Overall:  0.5035600635881179

# %% [markdown]
# ========================================================================================================

# %%
vegetation_color = [0, 255, 0]  # Green
non_vegetation_color = [0, 0, 255] # Blue

indexing = 250
input_image = images_load[indexing]
ground_truth = ground_truths[indexing]
features_get = fe.extract(input_image)

# Preprocess the input image
input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
features = input_image_reshaped.reshape(-1, 3)  # Remove the transpose operation here

# Predict segmentation mask
predicted_mask = model_loaded.forward(features)
predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)
segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)

# Create segmented image
segmented_image[predicted_mask == 0] = non_vegetation_color
segmented_image[predicted_mask == 1] = vegetation_color

# Visualize input image, ground truth, and segmented image
plt.figure(figsize=(12, 5))
plt.subplot(1, 3, 1)
plt.imshow(input_image)
plt.title('Input Image')

plt.subplot(1, 3, 2)
plt.imshow(ground_truth)
plt.title('Ground Truth')

# print("IoU Vegetation: {:.4f}".format(IoU_vegetation[indexing]))
# print("IoU Non-Vegetation: {:.4f}".format(IoU_non_vegetation[indexing]))
# print("Mean IoU: {:.4f}".format((IoU_vegetation[indexing] + IoU_non_vegetation[indexing])/2))
plt.subplot(1, 3, 3)
plt.imshow(segmented_image)
# IoU = (IoU_vegetation[indexing] + IoU_non_vegetation[indexing]) / 2
plt.title('Segmented Image')

plt.show()

# %%
# vegetation_color = [0, 255, 0]  # Green
# non_vegetation_color = [0, 0, 255] # Blue

# # Initialize lists for TP, FP, FN, and IoU
# vegetation_TP = []
# vegetation_FP = []
# vegetation_FN = []
# non_vegetation_TP = []
# non_vegetation_FP = []
# non_vegetation_FN = []
# IoU_vegetation = []
# IoU_non_vegetation = []

# # Loop over testing images
# for i in range(len(image_test)):
#     # Reset counts for each image
#     TP_vegetation = 0
#     FP_vegetation = 0
#     FN_vegetation = 0
#     TP_non_vegetation = 0
#     FP_non_vegetation = 0
#     FN_non_vegetation = 0
    
#     input_image = image_test[i]
#     ground_truth = image_label_test[i]

#     # Preprocess the input image
#     input_image_reshaped = cv2.resize(input_image, (128, 128)) / 255.0
#     features = input_image_reshaped.reshape(-1, 3)

#     # Predict segmentation mask
#     predicted_mask = model_loaded.forward(features)
#     predicted_mask = predicted_mask.argmax(axis=1).reshape(128, 128)

#     # Convert ground truth to single-channel binary masks for vegetation and non-vegetation
#     vegetation_ground_truth = (ground_truth == [0, 255, 0]).all(axis=2)
#     non_vegetation_ground_truth = ~vegetation_ground_truth

#     # Iterate over each pixel in the patch
#     for y in range(128):
#         for x in range(128):
#             # Check if the pixel is vegetation in both prediction and ground truth
#             if vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 TP_vegetation += 1
#             # Check if the pixel is non-vegetation in both prediction and ground truth
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 TP_non_vegetation += 1
#             # Check if the pixel is vegetation in ground truth but non-vegetation in prediction
#             elif vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 0:
#                 FN_vegetation += 1
#             # Check if the pixel is non-vegetation in ground truth but vegetation in prediction
#             elif non_vegetation_ground_truth[y, x] == 1 and predicted_mask[y, x] == 1:
#                 FP_non_vegetation += 1
                
#     # Append TP, FP, FN counts for both classes
#     vegetation_TP.append(TP_vegetation)
#     vegetation_FP.append(FP_vegetation)
#     vegetation_FN.append(FN_vegetation)
#     non_vegetation_TP.append(TP_non_vegetation)
#     non_vegetation_FP.append(FP_non_vegetation)
#     non_vegetation_FN.append(FN_non_vegetation)

#     # Calculate IoU for both classes if the denominator is not zero
#     if (TP_vegetation + FP_vegetation + FN_vegetation) != 0:
#         IoU_vegetation.append(TP_vegetation / (TP_vegetation + FP_vegetation + FN_vegetation))
#     else:
#         IoU_vegetation.append(0.0)

#     if (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation) != 0:
#         IoU_non_vegetation.append(TP_non_vegetation / (TP_non_vegetation + FP_non_vegetation + FN_non_vegetation))
#     else:
#         IoU_non_vegetation.append(0.0)

#     print("===============================Image {}==================================".format(i+1))
#     print("vegetation_TP: {}, vegetation_FP: {}, vegetation_FN: {}\nnon_vegetation_TP: {}, non_vegetation_FP: {}, non_vegetation_FN: {}".format(TP_vegetation, FP_vegetation, FN_vegetation, TP_non_vegetation, FP_non_vegetation, FN_non_vegetation))
#     print("Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}, Mean IoU: {:.4f}".format(IoU_vegetation[-1], IoU_non_vegetation[-1], (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2))
#     # Visualize input image, ground truth, and segmented image
#     # plt.figure(figsize=(12, 5))
#     # plt.subplot(1, 3, 1)
#     # plt.imshow(input_image)
#     # plt.title('Input Image')
    
#     # plt.subplot(1, 3, 2)
#     # plt.imshow(ground_truth)
#     # plt.title('Ground Truth')
    
#     # # Create segmented image
#     # segmented_image = np.zeros((128, 128, 3), dtype=np.uint8)
#     # segmented_image[predicted_mask == 0] = non_vegetation_color
#     # segmented_image[predicted_mask == 1] = vegetation_color
    
#     # # print("Image {}: Vegetation IoU: {:.4f}, Non-Vegetation IoU: {:.4f}".format(i+1, IoU_vegetation[-1], IoU_non_vegetation[-1]))
#     # plt.subplot(1, 3, 3)
#     # plt.imshow(segmented_image)
#     # IoU = (IoU_vegetation[-1] + IoU_non_vegetation[-1]) / 2
#     # plt.title('Segmented Image (Mean IoU: {:.4f})'.format(IoU))
    
#     # plt.show()

# %%
# # Compute mean IoU across all images for vegetation and non-vegetation classes
# mean_IoU_vegetation_class = sum(IoU_vegetation) / len(IoU_vegetation)
# mean_IoU_non_vegetation_class = sum(IoU_non_vegetation) / len(IoU_non_vegetation)
# mean_IoU_overall = (mean_IoU_vegetation_class + mean_IoU_non_vegetation_class) / 2

# # Print mean IoU for both classes
# print("Mean IoU for Vegetation Class: {:.2f}".format(mean_IoU_vegetation_class * 100), "%")
# print("Mean IoU for Non-Vegetation Class: {:.2f}".format(mean_IoU_non_vegetation_class * 100), "%")
# print("Mean IoU Overall: {:.2f}".format(mean_IoU_overall * 100), "%")
